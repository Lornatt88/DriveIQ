# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
motor_df = pd.read_csv("motor_window_features.csv")
secondary_df = pd.read_csv("secondary_window_features.csv")

print("Motor windows:", motor_df.shape)
print("Secondary windows:", secondary_df.shape)

secondary_df.head(5)
# Out:
# Motor windows: (174, 38)
# Secondary windows: (106, 38)
#    speed_kmh_mean   lat_mean  lon_mean    alt_mean  vert_acc_mean  \
# 0       91.240625  40.526646 -3.423336  627.781250       5.421875
# 1       92.764062  40.538838 -3.454947  659.992188       5.656250
# 2       95.117188  40.551629 -3.491250  698.904688       5.968750
# 3       99.273438  40.568392 -3.523362  667.884375       6.187500
# 4      113.846875  40.528696 -3.428616  628.712500       5.187500
#
#    horiz_acc_mean  course_mean  difcourse_mean  hdop_mean  vdop_mean  ...  \
# 0        5.000000   306.257812        2.576344   0.296875   2.531250  ...
# 1        5.000000   298.306250        2.296172   0.203125   2.484375  ...
# 2        5.000000   294.450000        3.010266   0.265625   1.843750  ...
# 3        5.000000   294.421875        2.834469   0.390625   2.109375  ...
# 4        5.078125   298.756250        2.675219   0.593750   2.875000  ...
#
#    gps_speed_mean  max_speed_mean  speed_rel_mean  num_lanes_mean  \
# 0       91.104327       88.109375         0.96875        1.968750
# 1       92.667156       85.140625         1.12500        1.812500
# 2       95.123289       87.031250         1.31250        2.031250
# 3       99.289772       90.468750         1.15625        2.171875
# 4      113.908890       92.343750         1.09375        1.953125
#
#    lat_osm_mean  lon_osm_mean  osm_delay_mean  gps_speed_osm_mean  \
# 0     40.526330     -3.422519        2.959000           90.890625
# 1     40.538434     -3.453860        4.221875           92.462500
# 2     40.551079     -3.490306        4.102469           95.145313
# 3     40.567937     -3.522519        3.000172           99.471875
# 4     40.528568     -3.428031        1.988625          113.910938
#
#    speed_ratio_mean  label
# 0         -0.546738      2
# 1         -0.412580      2
# 2          1.180434      2
# 3          1.097944      2
# 4          1.237124      0
#
# [5 rows x 38 columns]

# %% [markdown]
# We isolate normal driving windows to use them as the reference baseline for distance calculations.

# %%
motor_normal_df = motor_df[motor_df["label"] == 2]
secondary_normal_df = secondary_df[secondary_df["label"] == 2]

print("Motor NORMAL:", motor_normal_df.shape)
print("Secondary NORMAL:", secondary_normal_df.shape)
# Out:
# Motor NORMAL: (58, 38)
# Secondary NORMAL: (39, 38)

# %% [markdown]
# We define which numeric driving features are used to measure similarity and distance.

# %%
feature_cols = (motor_normal_df.select_dtypes(include=["int64", "float64"]).drop(columns=["label"]).columns.tolist())
print("Number of features:", len(feature_cols))
feature_cols[:5]
# Out:
# Number of features: 37
# ['speed_kmh_mean', 'lat_mean', 'lon_mean', 'alt_mean', 'vert_acc_mean']

# %% [markdown]
# Scaling = teaching the system what “normal” looks like, feature by feature.

# %%
motor_scaler = StandardScaler()
secondary_scaler = StandardScaler()

motor_normal_scaled = motor_scaler.fit_transform(motor_normal_df[feature_cols])
secondary_normal_scaled = secondary_scaler.fit_transform(secondary_normal_df[feature_cols])

print("Scalers fitted for both road types")
# Out:
# Scalers fitted for both road types

# %%
motor_knn = NearestNeighbors(n_neighbors=5, metric="euclidean")
secondary_knn = NearestNeighbors(n_neighbors=5, metric="euclidean")

motor_knn.fit(motor_normal_scaled)
secondary_knn.fit(secondary_normal_scaled)

print("KNN models trained for motor & secondary")
# Out:
# KNN models trained for motor & secondary

# %%
def knn_distance(row, scaler, knn, feature_cols):
    row_df = row[feature_cols].to_frame().T
    row_scaled = scaler.transform(row_df)
    distances, _ = knn.kneighbors(row_scaled)
    return distances.mean()

# %% [markdown]
# Apply distance to all windows (per road)

# %%
motor_df["knn_distance"] = motor_df.apply(
    lambda row: knn_distance(row, motor_scaler, motor_knn, feature_cols),
    axis=1
)

# %%
secondary_df["knn_distance"] = secondary_df.apply(
    lambda row: knn_distance(row, secondary_scaler, secondary_knn, feature_cols),
    axis=1
)

# %%
print("Motor mean distance by label")
print(motor_df.groupby("label")["knn_distance"].mean())

print("\nSecondary mean distance by label")
print(secondary_df.groupby("label")["knn_distance"].mean())
# Out:
# Motor mean distance by label
# label
# 0    19.754331
# 1    63.254465
# 2     3.577592
# Name: knn_distance, dtype: float64
#
# Secondary mean distance by label
# label
# 0     8.163683
# 1    15.051760
# 2     4.180375
# Name: knn_distance, dtype: float64

# %%
# Motor threshold (based on NORMAL only)
motor_normal_dist = motor_df[motor_df["label"] == 2]["knn_distance"]
motor_threshold = motor_normal_dist.mean() + 2 * motor_normal_dist.std()

# Secondary threshold
secondary_normal_dist = secondary_df[secondary_df["label"] == 2]["knn_distance"]
secondary_threshold = secondary_normal_dist.mean() + 2 * secondary_normal_dist.std()

motor_threshold, secondary_threshold
# Out:
# (np.float64(6.2254730357718975), np.float64(5.6229375986193215))

# %%
motor_abnormal = motor_df[motor_df["knn_distance"] > motor_threshold].copy()
secondary_abnormal = secondary_df[secondary_df["knn_distance"] > secondary_threshold].copy()

motor_abnormal.shape, secondary_abnormal.shape
# Out:
# ((82, 39), (67, 39))

# %% [markdown]
# These are just quick checks to see if everything is okay

# %%
motor_abnormal["label"].value_counts()
# Out:
# label
# 1    58
# 0    21
# 2     3
# Name: count, dtype: int64

# %%
motor_df.groupby("label")["knn_distance"].describe()
# Out:
#        count       mean        std       min       25%        50%         75%  \
# label
# 0       52.0  19.754331  40.718379  3.311306  4.267894   5.654961    7.802823
# 1       64.0  63.254465  58.126759  4.885960  8.830011  50.990718  100.326638
# 2       58.0   3.577592   1.323941  2.259098  2.797049   3.113860    3.954000
#
#               max
# label
# 0      202.324247
# 1      244.651420
# 2        9.081914

# %%
motor_df.shape, motor_abnormal.shape
len(motor_abnormal) / len(motor_df)
# Out:
# 0.47126436781609193

# %% [markdown]
# Preparing data for clustering

# %%
motor_X = motor_scaler.transform(motor_abnormal[feature_cols])
secondary_X = secondary_scaler.transform(secondary_abnormal[feature_cols])

# %%
from sklearn.cluster import KMeans

motor_kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

motor_clusters = motor_kmeans.fit_predict(motor_X)

motor_abnormal["cluster"] = motor_clusters
motor_abnormal["cluster"].value_counts()
# Out:
# cluster
# 0    54
# 1    19
# 2     9
# Name: count, dtype: int64

# %%
secondary_kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

secondary_clusters = secondary_kmeans.fit_predict(secondary_X)

secondary_abnormal["cluster"] = secondary_clusters
secondary_abnormal["cluster"].value_counts()
# Out:
# cluster
# 1    39
# 2    17
# 0    11
# Name: count, dtype: int64

# %% [markdown]
# Naming the clusters, we decide this through seeing which features are the highest in each cluster (for each type of aggressive or drowsy behaving there is features that explain the type of this action, example: max_speed --> overspeeding and so on...

# %%
# Look at average feature values per cluster (motor)
motor_cluster_summary = (
    motor_abnormal
    .groupby("cluster")[feature_cols]
    .mean()
)

motor_cluster_summary
# Out:
#          speed_kmh_mean   lat_mean  lon_mean    alt_mean  vert_acc_mean  \
# cluster
# 0             92.698785  40.474965 -3.437817  591.587008       3.622106
# 1             96.786760  40.480537 -3.412900  591.917352       4.010691
# 2            103.791146  40.480308 -3.413121  591.742014       4.281250
#
#          horiz_acc_mean  course_mean  difcourse_mean  hdop_mean  vdop_mean  \
# cluster
# 0              5.001447   184.784172        2.293389   0.425347   2.456597
# 1              5.008224   138.631743        1.077618   0.760691   4.690789
# 2              5.052083   245.287326        1.308042   0.328125   1.774306
#
#          ...  num_vehicles_mean  gps_speed_mean  max_speed_mean  \
# cluster  ...
# 0        ...           1.454548       92.688568      104.553241
# 1        ...           1.647077       96.752966      117.258224
# 2        ...           1.649730      103.792952      113.194444
#
#          speed_rel_mean  num_lanes_mean  lat_osm_mean  lon_osm_mean  \
# cluster
# 0              0.979456        2.424479     39.338164     -3.343247
# 1              1.013158        2.930099     40.480528     -3.413003
# 2              1.065972        2.836806     40.480474     -3.412714
#
#          osm_delay_mean  gps_speed_osm_mean  speed_ratio_mean
# cluster
# 0              1.374106           92.693229         -3.736482
# 1              2.062301           96.763487          0.537677
# 2              1.742707          103.806771         -2.110217
#
# [3 rows x 37 columns]

# %%
# Look at average feature values per cluster (secondary)
secondary_cluster_summary = (
    secondary_abnormal
    .groupby("cluster")[feature_cols]
    .mean()
)

secondary_cluster_summary
# Out:
#          speed_kmh_mean   lat_mean  lon_mean    alt_mean  vert_acc_mean  \
# cluster
# 0            105.423864  40.541942 -3.466214  651.248295       4.224432
# 1             89.856891  40.549476 -3.482158  666.862620       3.643429
# 2             87.460938  40.555042 -3.493988  674.646324       3.719669
#
#          horiz_acc_mean  course_mean  difcourse_mean  hdop_mean  vdop_mean  \
# cluster
# 0              5.042614   305.367756        2.613810   0.301136   1.735795
# 1              5.000000   118.288061        2.165746   0.772436   4.719551
# 2              5.000000   303.846599        1.842494   0.278493   2.008272
#
#          ...  num_vehicles_mean  gps_speed_mean  max_speed_mean  \
# cluster  ...
# 0        ...           0.584197      105.445847       88.573864
# 1        ...           0.273021       89.849015       89.457532
# 2        ...           0.918786       87.495392       87.578125
#
#          speed_rel_mean  num_lanes_mean  lat_osm_mean  lon_osm_mean  \
# cluster
# 0              1.144886        1.936080     40.541690     -3.465677
# 1              1.128606        2.046474     40.549666     -3.482578
# 2              1.084559        1.994485     40.554791     -3.493446
#
#          osm_delay_mean  gps_speed_osm_mean  speed_ratio_mean
# cluster
# 0              1.905416          105.460938          0.570380
# 1              1.697770           89.832572          0.891769
# 2              2.217870           87.504779          0.617021
#
# [3 rows x 37 columns]

# %%
motor_cluster_summary["harsh_score"] = (
    motor_cluster_summary["vert_acc_mean"].rank() +
    motor_cluster_summary["horiz_acc_mean"].rank()
)

motor_cluster_summary["overspeed_score"] = (
    motor_cluster_summary["speed_kmh_mean"].rank() +
    motor_cluster_summary["speed_ratio_mean"].rank()
)

motor_cluster_summary["unstable_score"] = (
    motor_cluster_summary["difcourse_mean"].rank()
)

motor_cluster_summary[
    ["harsh_score", "overspeed_score", "unstable_score"]
]
# Out:
#          harsh_score  overspeed_score  unstable_score
# cluster
# 0                2.0              2.0             3.0
# 1                4.0              5.0             1.0
# 2                6.0              5.0             2.0

# %%
motor_cluster_labels = {}

for cluster_id, row in motor_cluster_summary.iterrows():

    scores = {
        "Overspeeding": row["overspeed_score"],
        "Harsh acceleration / braking": row["harsh_score"],
        "Unstable driving": row["unstable_score"]
    }

    dominant_behavior = max(scores, key=scores.get)
    motor_cluster_labels[cluster_id] = dominant_behavior

motor_cluster_labels
# Out:
# {0: 'Unstable driving', 1: 'Overspeeding', 2: 'Harsh acceleration / braking'}

# %%
motor_cluster_summary[
    ["speed_kmh_mean", "vert_acc_mean", "horiz_acc_mean", "difcourse_mean",
     "overspeed_score", "harsh_score", "unstable_score"]
]
# Out:
#          speed_kmh_mean  vert_acc_mean  horiz_acc_mean  difcourse_mean  \
# cluster
# 0             92.698785       3.622106        5.001447        2.293389
# 1             96.786760       4.010691        5.008224        1.077618
# 2            103.791146       4.281250        5.052083        1.308042
#
#          overspeed_score  harsh_score  unstable_score
# cluster
# 0                    2.0          2.0             3.0
# 1                    5.0          4.0             1.0
# 2                    5.0          6.0             2.0

# %% [markdown]
# Now for secondary

# %%
secondary_cluster_summary["overspeed_score"] = (
    secondary_cluster_summary["speed_kmh_mean"].rank() +
    secondary_cluster_summary["speed_ratio_mean"].rank()
)

secondary_cluster_summary["harsh_score"] = (
    secondary_cluster_summary["vert_acc_mean"].rank() +
    secondary_cluster_summary["horiz_acc_mean"].rank()
)

secondary_cluster_summary["unstable_score"] = (
    secondary_cluster_summary["difcourse_mean"].rank()
)

# %%
secondary_cluster_labels = {}

for cluster_id, row in motor_cluster_summary.iterrows():

    scores = {
        "Overspeeding": row["overspeed_score"],
        "Harsh acceleration / braking": row["harsh_score"],
        "Unstable driving": row["unstable_score"]
    }

    dominant_behavior = max(scores, key=scores.get)
    secondary_cluster_labels[cluster_id] = dominant_behavior

secondary_cluster_labels
# Out:
# {0: 'Unstable driving', 1: 'Overspeeding', 2: 'Harsh acceleration / braking'}

# %%
secondary_cluster_summary[
    ["speed_kmh_mean", "vert_acc_mean", "horiz_acc_mean", "difcourse_mean",
     "overspeed_score", "harsh_score", "unstable_score"]
]
# Out:
#          speed_kmh_mean  vert_acc_mean  horiz_acc_mean  difcourse_mean  \
# cluster
# 0            105.423864       4.224432        5.042614        2.613810
# 1             89.856891       3.643429        5.000000        2.165746
# 2             87.460938       3.719669        5.000000        1.842494
#
#          overspeed_score  harsh_score  unstable_score
# cluster
# 0                    4.0          6.0             3.0
# 1                    5.0          2.5             2.0
# 2                    3.0          3.5             1.0

# %% [markdown]
# ### KNN NORMAL DIFFERENCES (Tells us how far a window is from normal driving) & CLUSTERING (Tell us what type of abnormal behaviour it looks like) PHASE IS DONE

# %% [markdown]
# ### Now we move to the next step: ALERTS APPEARING ON THE APP:
# This is the logic:
#
# If knn_distance > threshold → abnormal
# Else → no alert

# %%
def motor_alert(row, threshold):
    if row["knn_distance"] <= threshold:
        return "No alert"

    return row["cluster_label"]

# %% [markdown]
# Here we only assign clusters and behavior labels to windows that are far from normal, while normal windows remain unclustered and produce no alerts.

# %%
motor_df["cluster"] = np.nan
motor_df.loc[motor_abnormal.index, "cluster"] = motor_abnormal["cluster"]
motor_df["cluster_label"] = motor_df["cluster"].map(motor_cluster_labels)

# %%
secondary_df["cluster"] = np.nan
secondary_df.loc[secondary_abnormal.index, "cluster"] = secondary_abnormal["cluster"]
secondary_df["cluster_label"] = secondary_df["cluster"].map(secondary_cluster_labels)

# %%
motor_df["alert"] = motor_df.apply(
    lambda row: motor_alert(row, motor_threshold),
    axis=1
)

motor_df[["knn_distance", "cluster_label", "alert"]].head(10)
# Out:
#    knn_distance     cluster_label             alert
# 0      6.962918  Unstable driving  Unstable driving
# 1      3.204688               NaN          No alert
# 2      2.700637               NaN          No alert
# 3      3.151015               NaN          No alert
# 4      2.976016               NaN          No alert
# 5      6.030598               NaN          No alert
# 6      5.889323               NaN          No alert
# 7      3.828616               NaN          No alert
# 8      3.093380               NaN          No alert
# 9      2.916400               NaN          No alert

# %%
secondary_df["alert"] = secondary_df.apply(
    lambda row: motor_alert(row, secondary_threshold),
    axis=1
)

secondary_df[["knn_distance", "cluster_label", "alert"]].head(10)
# Out:
#    knn_distance     cluster_label             alert
# 0      5.089209               NaN          No alert
# 1      4.992051               NaN          No alert
# 2      5.067595               NaN          No alert
# 3      5.175336               NaN          No alert
# 4      9.727734  Unstable driving  Unstable driving
# 5      9.138435  Unstable driving  Unstable driving
# 6     13.264669  Unstable driving  Unstable driving
# 7     10.773913  Unstable driving  Unstable driving
# 8     15.316556      Overspeeding      Overspeeding
# 9     15.362665      Overspeeding      Overspeeding

# %%
motor_df["alert"].value_counts()
# Out:
# alert
# No alert                        92
# Unstable driving                54
# Overspeeding                    19
# Harsh acceleration / braking     9
# Name: count, dtype: int64

# %%
secondary_df["alert"].value_counts()
# Out:
# alert
# No alert                        39
# Overspeeding                    39
# Harsh acceleration / braking    17
# Unstable driving                11
# Name: count, dtype: int64

# %% [markdown]
# Now we create the mapping messages

# %%
alert_messages = {
    "Overspeeding": "⚠️ Speed limit exceeded",
    "Harsh acceleration / braking": "⚠️ Harsh driving detected",
    "Unstable driving": "⚠️ Vehicle instability detected",
    "No alert": "Normal driving"
}

# %%
motor_df["alert_message"] = motor_df["alert"].map(alert_messages)
secondary_df["alert_message"] = secondary_df["alert"].map(alert_messages)

# %%
motor_df[["alert", "alert_message"]].head()
# Out:
#               alert                    alert_message
# 0  Unstable driving  ⚠️ Vehicle instability detected
# 1          No alert                   Normal driving
# 2          No alert                   Normal driving
# 3          No alert                   Normal driving
# 4          No alert                   Normal driving

# %%
secondary_df[["alert", "alert_message"]].head()
# Out:
#               alert                    alert_message
# 0          No alert                   Normal driving
# 1          No alert                   Normal driving
# 2          No alert                   Normal driving
# 3          No alert                   Normal driving
# 4  Unstable driving  ⚠️ Vehicle instability detected

# %% [markdown]
# ### Normalizing

# %%
motor_alert_pct = (
    motor_df["alert"]
    .value_counts(normalize=True) * 100
).round(2)

motor_alert_pct
# Out:
# alert
# No alert                        52.87
# Unstable driving                31.03
# Overspeeding                    10.92
# Harsh acceleration / braking     5.17
# Name: proportion, dtype: float64

# %%
secondary_alert_pct = (
    secondary_df["alert"]
    .value_counts(normalize=True) * 100
).round(2)

secondary_alert_pct
# Out:
# alert
# No alert                        36.79
# Overspeeding                    36.79
# Harsh acceleration / braking    16.04
# Unstable driving                10.38
# Name: proportion, dtype: float64

# %% [markdown]
# ### Side-by-side comparison table

# %%
alert_comparison = (
    pd.concat(
        [
            motor_alert_pct.rename("Motorway (%)"),
            secondary_alert_pct.rename("Secondary (%)")
        ],
        axis=1
    )
    .fillna(0)
)

alert_comparison
# Out:
#                               Motorway (%)  Secondary (%)
# alert
# No alert                             52.87          36.79
# Unstable driving                     31.03          10.38
# Overspeeding                         10.92          36.79
# Harsh acceleration / braking          5.17          16.04

# %%
alert_comparison.plot(
    kind="bar",
    figsize=(7,4),
    title="Alert Distribution by Road Type"
)
# Out:
# <Axes: title={'center': 'Alert Distribution by Road Type'}, xlabel='alert'>

# %% [markdown]
# The alert distribution aligns with real-world driving expectations, confirming that the KNN-based detection and clustering pipeline produces meaningful and context-aware driving risk alerts.

# %% [markdown]
# # NOW WE REACHED THE PERFORMANCE SCORING

# %% [markdown]
# ### `“Given all detected behaviours, how risky is this driving profile?”`

# %% [markdown]
# We need a score that: increases when alerts increase, increases when alerts are severe and easy to explain
#
# The clean formula we’ll use
# Average severity × scaling factor

# %%
severity_map = {
    "No alert": 0,
    "Unstable driving": 1,
    "Harsh acceleration / braking": 2,
    "Overspeeding": 3
}

# %%
motor_df["severity"] = motor_df["alert"].map(severity_map)
secondary_df["severity"] = secondary_df["alert"].map(severity_map)

# %%
motor_avg_severity = motor_df["severity"].mean()
motor_avg_severity
# Out:
# np.float64(0.7413793103448276)

# %%
secondary_avg_severity = secondary_df["severity"].mean()
secondary_avg_severity
# Out:
# np.float64(1.528301886792453)

# %% [markdown]
# Here we define the formula

# %%
def compute_session_performance(df, max_severity=3):
    avg_severity = df["severity"].mean()
    score = 100 - (avg_severity / max_severity) * 100
    return round(score, 2)

# %%
motor_score = compute_session_performance(motor_df)
secondary_score = compute_session_performance(secondary_df)

motor_score, secondary_score
# Out:
# (np.float64(75.29), np.float64(49.06))

# %% [markdown]
# # phase 3

# %% [markdown]
# Compute normal_score and severity input s (0–1) from k-NN distance

# %%
import numpy as np
import pandas as pd

NORMAL_LABEL = 2

# Convert distance -> normal_score (bounded)
motor_df["normal_score"] = 1.0 / (1.0 + motor_df["knn_distance"])
secondary_df["normal_score"] = 1.0 / (1.0 + secondary_df["knn_distance"])

# Road-specific quantiles from NORMAL windows (used to normalize severity for fuzzy)
motor_q95 = motor_df.loc[motor_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.95)
motor_q99 = motor_df.loc[motor_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.99)

sec_q95   = secondary_df.loc[secondary_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.95)
sec_q99   = secondary_df.loc[secondary_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.99)

def normalize_distance(d, q95, q99):
    # maps knn_distance -> severity s in [0,1]
    if d <= q95: return 0.0
    if d >= q99: return 1.0
    return float((d - q95) / (q99 - q95))

# %% [markdown]
# We explain abnormality in the same space as k-NN: standardized features.

# %%
def window_zscores(df, scaler, cols):
    Z = scaler.transform(df[cols])
    return pd.DataFrame(Z, columns=cols, index=df.index)

motor_Z = window_zscores(motor_df, motor_scaler, feature_cols)
sec_Z   = window_zscores(secondary_df, secondary_scaler, feature_cols)

# squared deviation per feature (in z-space)
motor_contrib = motor_Z**2
sec_contrib   = sec_Z**2

# normalize per window -> percentages (sum = 1)
motor_contrib_norm = motor_contrib.div(motor_contrib.sum(axis=1).replace(0,np.nan), axis=0).fillna(0)
sec_contrib_norm   = sec_contrib.div(sec_contrib.sum(axis=1).replace(0,np.nan), axis=0).fillna(0)

# %%
def pick_cols_by_keywords(cols, keywords):
    cols = list(cols)
    out = []
    for c in cols:
        lc = c.lower()
        if any(k in lc for k in keywords):
            out.append(c)
    return out

CAUSE_GROUPS = {
    "Overspeed": pick_cols_by_keywords(feature_cols, ["speed", "max_speed", "speed_ratio", "gps_speed"]),
    "Tailgating": pick_cols_by_keywords(feature_cols, ["dist_front", "ttc_front", "headway", "num_vehicles"]),
    "Harsh maneuvers": pick_cols_by_keywords(feature_cols, ["acc_", "vert_acc", "horiz_acc", "jerk"]),
    "Unstable steering": pick_cols_by_keywords(feature_cols, ["difcourse", "yaw", "steer"]),
}

# remove empty groups (if any keywords don't exist in your file)
CAUSE_GROUPS = {k:v for k,v in CAUSE_GROUPS.items() if len(v)>0}
print("CAUSE_GROUPS:", {k: len(v) for k,v in CAUSE_GROUPS.items()})
# Out:
# CAUSE_GROUPS: {'Overspeed': 6, 'Tailgating': 3, 'Harsh maneuvers': 8, 'Unstable steering': 2}

# %%
def cause_percentages(contrib_norm_row, cause_groups):
    out = {}
    for cause, cols in cause_groups.items():
        cols = [c for c in cols if c in contrib_norm_row.index]
        if cols:
            out[cause] = float(contrib_norm_row[cols].sum())
    s = sum(out.values())
    if s > 0:
        out = {k: v/s for k,v in out.items()}  # re-normalize causes to sum=1
    return dict(sorted(out.items(), key=lambda x: x[1], reverse=True))

motor_df["top_causes_norm"] = motor_contrib_norm.apply(lambda r: cause_percentages(r, CAUSE_GROUPS), axis=1)
secondary_df["top_causes_norm"] = sec_contrib_norm.apply(lambda r: cause_percentages(r, CAUSE_GROUPS), axis=1)

# %% [markdown]
# tsk fuzzy

# %%
def tri(x, a, b, c):
    if x < a or x > c: return 0.0
    if x == b: return 1.0
    if a <= x < b:
        return 0.0 if b == a else (x - a) / (b - a)
    return 0.0 if c == b else (c - x) / (c - b)

def trap(x, a, b, c, d):
    if x < a or x > d: return 0.0
    if b <= x <= c: return 1.0
    if a <= x < b:
        return 0.0 if b == a else (x - a) / (b - a)
    return 0.0 if d == c else (d - x) / (d - c)

def fuzzify_inputs(s, p):
    # severity sets
    s_low  = trap(s, 0.0, 0.0, 0.2, 0.4)
    s_med  = tri (s, 0.3, 0.6, 0.85)
    s_high = trap(s, 0.7, 0.85, 1.0, 1.0)

    # dominance sets (tuned for percentages)
    p_small = trap(p, 0.0, 0.0, 0.15, 0.30)
    p_med   = tri (p, 0.25, 0.45, 0.65)
    p_dom   = trap(p, 0.45, 0.60, 1.0, 1.0)

    return {"s_low": s_low, "s_med": s_med, "s_high": s_high,
            "p_small": p_small, "p_med": p_med, "p_dom": p_dom}

def tsk_output(weights, outputs):
    w = np.array(weights, dtype=float)
    y = np.array(outputs, dtype=float)
    if w.sum() == 0:
        return 0.0
    return float((w*y).sum() / w.sum())

def intensity_for_cause(s, p):
    m = fuzzify_inputs(s, p)
    w1 = m["s_high"] * m["p_dom"]
    w2 = m["s_med"]  * m["p_dom"]
    w3 = m["s_high"] * m["p_med"]
    w4 = m["p_small"]
    return tsk_output([w1,w2,w3,w4], [0.95, 0.80, 0.60, 0.10])

# %%
MSG = {
    "Overspeed": "Reduce speed and keep within the road limit.",
    "Tailgating": "Increase following distance and keep a safe time gap.",
    "Harsh maneuvers": "Avoid harsh braking/acceleration; drive more smoothly.",
    "Unstable steering": "Avoid sudden steering/lane changes; keep smoother control."
}

def phase3_for_row(knn_d, q95, q99, causes_norm_dict):
    s = normalize_distance(knn_d, q95, q99)
    ranked = []
    for cause, p in causes_norm_dict.items():
        inten = intensity_for_cause(s, p)
        ranked.append((cause, p, inten, MSG.get(cause, cause)))
    ranked.sort(key=lambda x: x[2], reverse=True)  # sort by intensity
    return s, ranked

def build_phase3_table(df, q95, q99, top_col="top_causes_norm"):
    rows = []
    for idx, r in df.iterrows():
        s, ranked = phase3_for_row(float(r["knn_distance"]), q95, q99, r[top_col])
        rows.append({
            "index": idx,
            "label": int(r["label"]),
            "knn_distance": float(r["knn_distance"]),
            "severity_0_1": float(s),
            "top_2": ranked[:2],   # (cause, percent, intensity, msg)
        })
    return pd.DataFrame(rows)

motor_phase3 = build_phase3_table(motor_df, motor_q95, motor_q99)
sec_phase3   = build_phase3_table(secondary_df, sec_q95, sec_q99)

motor_phase3.head(10)
# Out:
#    index  label  knn_distance  severity_0_1  \
# 0      0      2      6.962918      0.471458
# 1      1      2      3.204688      0.000000
# 2      2      2      2.700637      0.000000
# 3      3      2      3.151015      0.000000
# 4      4      2      2.976016      0.000000
# 5      5      2      6.030598      0.000000
# 6      6      2      5.889323      0.000000
# 7      7      2      3.828616      0.000000
# 8      8      2      3.093380      0.000000
# 9      9      2      2.916400      0.000000
#
#                                                top_2
# 0  [(Harsh maneuvers, 0.729855951401501, 0.8, Avo...
# 1  [(Tailgating, 0.1350859738156038, 0.1, Increas...
# 2  [(Tailgating, 0.06602227708444351, 0.1, Increa...
# 3  [(Overspeed, 0.241963655766128, 0.100000000000...
# 4  [(Tailgating, 0.234563988642232, 0.10000000000...
# 5  [(Unstable steering, 0.0854338111115253, 0.1, ...
# 6  [(Unstable steering, 0.11751118406618745, 0.1,...
# 7  [(Harsh maneuvers, 0.20949305048871822, 0.1, A...
# 8  [(Unstable steering, 0.23409085826627604, 0.10...
# 9  [(Tailgating, 0.20908195222941928, 0.1, Increa...

# %%
motor_abn = motor_phase3[motor_phase3["label"] != NORMAL_LABEL].sort_values("knn_distance", ascending=False).head(10)
sec_abn   = sec_phase3[sec_phase3["label"] != NORMAL_LABEL].sort_values("knn_distance", ascending=False).head(10)

display(motor_abn)
display(sec_abn)
# Out:
#      index  label  knn_distance  severity_0_1  \
# 173    173      1    244.651420           1.0
# 170    170      1    221.675408           1.0
# 40      40      0    202.324247           1.0
# 60      60      1    186.926797           1.0
# 41      41      0    179.209855           1.0
# 172    172      1    171.814225           1.0
# 171    171      1    171.737202           1.0
# 26      26      1    144.838464           1.0
# 163    163      1    132.145715           1.0
# 59      59      1    129.431594           1.0
#
#                                                  top_2
# 173  [(Tailgating, 0.5003743556778343, 0.7084361603...
# 170  [(Harsh maneuvers, 0.4589483009155416, 0.62057...
# 40   [(Tailgating, 0.5073446447931094, 0.7221315231...
# 60   [(Harsh maneuvers, 0.5967286570658384, 0.87509...
# 41   [(Harsh maneuvers, 0.6270993443177122, 0.91404...
# 172  [(Tailgating, 0.5882907831328148, 0.8622369137...
# 171  [(Harsh maneuvers, 0.3981000855036028, 0.6, Av...
# 26   [(Harsh maneuvers, 0.5811478612732718, 0.85112...
# 163  [(Harsh maneuvers, 0.9996429556988111, 0.95, A...
# 59   [(Harsh maneuvers, 0.32012630151599536, 0.6, A...
#      index  label  knn_distance  severity_0_1  \
# 59      59      1     17.843988           1.0
# 64      64      1     17.319013           1.0
# 104    104      1     17.275297           1.0
# 65      65      1     17.077730           1.0
# 103    103      1     16.914402           1.0
# 105    105      1     16.397091           1.0
# 95      95      0     16.387700           1.0
# 58      58      1     16.078563           1.0
# 60      60      1     15.987257           1.0
# 29      29      1     15.719194           1.0
#
#                                                  top_2
# 59   [(Overspeed, 0.39868023390952223, 0.6, Reduce ...
# 64   [(Unstable steering, 0.5079492037076178, 0.723...
# 104  [(Unstable steering, 0.5477184686322166, 0.796...
# 65   [(Harsh maneuvers, 0.4696441763526577, 0.64438...
# 103  [(Harsh maneuvers, 0.5793868715644183, 0.84834...
# 105  [(Unstable steering, 0.5147657583276533, 0.736...
# 95   [(Harsh maneuvers, 0.8397617554810711, 0.95, A...
# 58   [(Unstable steering, 0.5328709391479816, 0.769...
# 60   [(Overspeed, 0.5398602080568575, 0.78236200582...
# 29   [(Unstable steering, 0.4545482013009305, 0.610...

# %%
def pct_dict(d, top_n=None):
    # d can be dict or list of tuples
    if isinstance(d, list):
        d = dict(d)
    items = list(d.items())
    if top_n is not None:
        items = items[:top_n]
    return {k: f"{v*100:.1f}%" for k, v in items}

def dict_topn(d, n=5):
    return dict(list(d.items())[:n])  # keeps ordering if already sorted

# %%
for idx, r in motor_phase3.iterrows():
    # Get top causes from motor_df using the index from motor_phase3
    top_causes_list = [(cause_tuple[0], cause_tuple[1]) for cause_tuple in r["top_2"]]
    # Get top features from motor_contrib_norm using the index from motor_phase3
    top_features_dict = motor_contrib_norm.loc[r["index"]].nlargest(6).to_dict()

    print("window:", r["index"], "knn:", round(float(r["knn_distance"]), 3))
    print("Top causes:", pct_dict(top_causes_list))
    print("Top features:", pct_dict(top_features_dict))
    print("----")
# Out:
# window: 0 knn: 6.963
# Top causes: {'Harsh maneuvers': '73.0%', 'Tailgating': '4.9%'}
# Top features: {'pdop_mean': '73.6%', 'vert_acc_mean': '3.5%', 'lat_mean': '3.4%', 'vdop_mean': '3.2%', 'lon_mean': '2.2%', 'pitch_mean': '2.0%'}
# ----
# window: 1 knn: 3.205
# Top causes: {'Tailgating': '13.5%', 'Unstable steering': '2.0%'}
# Top features: {'vert_acc_mean': '22.0%', 'dist_front_mean': '8.0%', 'speed_kmh_mean': '7.9%', 'gps_speed_osm_mean': '7.9%', 'gps_speed_mean': '7.9%', 'pitch_mean': '7.0%'}
# ----
# window: 2 knn: 2.701
# Top causes: {'Tailgating': '6.6%', 'Unstable steering': '1.6%'}
# Top features: {'vert_acc_mean': '28.7%', 'alt_mean': '15.7%', 'gps_speed_mean': '8.3%', 'gps_speed_osm_mean': '8.3%', 'roll_mean': '8.2%', 'speed_kmh_mean': '8.2%'}
# ----
# window: 3 knn: 3.151
# Top causes: {'Overspeed': '24.2%', 'Tailgating': '5.2%'}
# Top features: {'vert_acc_mean': '38.2%', 'alt_mean': '19.1%', 'gps_speed_mean': '4.6%', 'gps_speed_osm_mean': '4.6%', 'speed_kmh_mean': '4.5%', 'roll_mean': '4.3%'}
# ----
# window: 4 knn: 2.976
# Top causes: {'Tailgating': '23.5%', 'Overspeed': '11.9%'}
# Top features: {'vert_acc_mean': '22.4%', 'alt_mean': '14.2%', 'dist_front_mean': '7.2%', 'course_mean': '5.8%', 'acc_x_kf_mean': '5.4%', 'ttc_front_mean': '5.3%'}
# ----
# window: 5 knn: 6.031
# Top causes: {'Unstable steering': '8.5%', 'Overspeed': '3.6%'}
# Top features: {'acc_y_kf_mean': '19.8%', 'acc_y_mean': '19.8%', 'acc_z_kf_mean': '18.1%', 'acc_z_mean': '17.6%', 'difcourse_mean': '7.7%', 'lon_mean': '2.2%'}
# ----
# window: 6 knn: 5.889
# Top causes: {'Unstable steering': '11.8%', 'Overspeed': '3.7%'}
# Top features: {'acc_y_kf_mean': '19.4%', 'acc_y_mean': '19.3%', 'acc_z_kf_mean': '15.1%', 'acc_z_mean': '14.5%', 'difcourse_mean': '9.3%', 'roll_mean': '4.2%'}
# ----
# window: 7 knn: 3.829
# Top causes: {'Harsh maneuvers': '20.9%', 'Unstable steering': '18.1%'}
# Top features: {'osm_delay_mean': '12.9%', 'vert_acc_mean': '11.8%', 'yaw_mean': '11.6%', 'ttc_front_mean': '11.3%', 'num_vehicles_mean': '8.9%', 'dist_front_mean': '8.4%'}
# ----
# window: 8 knn: 3.093
# Top causes: {'Unstable steering': '23.4%', 'Tailgating': '7.6%'}
# Top features: {'yaw_mean': '14.9%', 'acc_x_mean': '11.4%', 'acc_x_kf_mean': '10.1%', 'osm_delay_mean': '8.6%', 'course_mean': '7.6%', 'vert_acc_mean': '6.9%'}
# ----
# window: 9 knn: 2.916
# Top causes: {'Tailgating': '20.9%', 'Overspeed': '7.7%'}
# Top features: {'yaw_mean': '17.2%', 'lat_mean': '10.8%', 'course_mean': '9.9%', 'roll_mean': '9.9%', 'lon_mean': '7.5%', 'acc_x_kf_mean': '5.5%'}
# ----
# window: 10 knn: 5.907
# Top causes: {'Tailgating': '17.8%', 'Harsh maneuvers': '13.9%'}
# Top features: {'road_width_mean': '34.1%', 'speed_kmh_mean': '10.6%', 'gps_speed_mean': '10.5%', 'gps_speed_osm_mean': '10.3%', 'lat_mean': '5.1%', 'num_vehicles_mean': '4.5%'}
# ----
# window: 11 knn: 6.174
# Top causes: {'Tailgating': '27.1%', 'Harsh maneuvers': '1.7%'}
# Top features: {'road_width_mean': '35.8%', 'gps_speed_mean': '11.9%', 'gps_speed_osm_mean': '11.9%', 'speed_kmh_mean': '11.9%', 'num_vehicles_mean': '6.0%', 'roll_mean': '5.7%'}
# ----
# window: 12 knn: 6.298
# Top causes: {'Harsh maneuvers': '26.0%', 'Tailgating': '18.4%'}
# Top features: {'road_width_mean': '27.4%', 'gps_speed_mean': '9.1%', 'gps_speed_osm_mean': '9.0%', 'speed_kmh_mean': '9.0%', 'pitch_mean': '7.5%', 'alt_mean': '7.4%'}
# ----
# window: 13 knn: 5.982
# Top causes: {'Harsh maneuvers': '25.7%', 'Tailgating': '20.8%'}
# Top features: {'road_width_mean': '22.3%', 'gps_speed_osm_mean': '9.7%', 'speed_kmh_mean': '9.7%', 'gps_speed_mean': '9.7%', 'alt_mean': '6.8%', 'vert_acc_mean': '6.8%'}
# ----
# window: 14 knn: 4.93
# Top causes: {'Tailgating': '8.2%', 'Unstable steering': '5.9%'}
# Top features: {'road_width_mean': '39.0%', 'vert_acc_mean': '8.7%', 'alt_mean': '8.2%', 'roll_mean': '5.6%', 'gps_speed_osm_mean': '4.8%', 'gps_speed_mean': '4.8%'}
# ----
# window: 15 knn: 7.251
# Top causes: {'Harsh maneuvers': '62.9%', 'Unstable steering': '25.9%'}
# Top features: {'road_width_mean': '30.1%', 'difcourse_mean': '13.3%', 'acc_z_kf_mean': '9.7%', 'acc_z_mean': '7.9%', 'acc_x_kf_mean': '6.7%', 'acc_x_mean': '6.4%'}
# ----
# window: 16 knn: 7.408
# Top causes: {'Harsh maneuvers': '65.6%', 'Unstable steering': '22.1%'}
# Top features: {'acc_z_kf_mean': '17.5%', 'acc_z_mean': '17.3%', 'difcourse_mean': '15.3%', 'roll_mean': '7.2%', 'road_width_mean': '7.1%', 'acc_x_kf_mean': '6.2%'}
# ----
# window: 17 knn: 5.172
# Top causes: {'Overspeed': '26.3%', 'Tailgating': '17.5%'}
# Top features: {'vert_acc_mean': '21.6%', 'roll_mean': '10.8%', 'yaw_mean': '7.5%', 'lane_state_mean': '6.9%', 'speed_kmh_mean': '5.5%', 'gps_speed_mean': '5.4%'}
# ----
# window: 18 knn: 5.869
# Top causes: {'Tailgating': '17.9%', 'Unstable steering': '4.0%'}
# Top features: {'vert_acc_mean': '14.0%', 'gps_speed_osm_mean': '12.6%', 'speed_kmh_mean': '12.6%', 'gps_speed_mean': '12.6%', 'ttc_front_mean': '5.9%', 'dist_front_mean': '5.8%'}
# ----
# window: 19 knn: 5.723
# Top causes: {'Tailgating': '13.0%', 'Unstable steering': '3.8%'}
# Top features: {'vert_acc_mean': '21.9%', 'gps_speed_osm_mean': '13.1%', 'gps_speed_mean': '13.1%', 'speed_kmh_mean': '13.0%', 'lane_state_mean': '4.4%', 'num_vehicles_mean': '4.0%'}
# ----
# window: 20 knn: 49.05
# Top causes: {'Harsh maneuvers': '69.3%', 'Tailgating': '29.8%'}
# Top features: {'pdop_mean': '96.9%', 'vdop_mean': '0.9%', 'hdop_mean': '0.6%', 'vert_acc_mean': '0.5%', 'road_width_mean': '0.2%', 'osm_delay_mean': '0.1%'}
# ----
# window: 21 knn: 117.954
# Top causes: {'Harsh maneuvers': '92.1%', 'Tailgating': '5.3%'}
# Top features: {'pdop_mean': '99.2%', 'vdop_mean': '0.3%', 'hdop_mean': '0.2%', 'vert_acc_mean': '0.2%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.0%'}
# ----
# window: 22 knn: 87.276
# Top causes: {'Harsh maneuvers': '89.2%', 'Tailgating': '6.6%'}
# Top features: {'pdop_mean': '98.8%', 'vdop_mean': '0.5%', 'vert_acc_mean': '0.2%', 'hdop_mean': '0.2%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.1%'}
# ----
# window: 23 knn: 7.955
# Top causes: {'Harsh maneuvers': '72.1%', 'Tailgating': '12.6%'}
# Top features: {'vdop_mean': '15.7%', 'vert_acc_mean': '13.5%', 'acc_z_mean': '10.7%', 'acc_z_kf_mean': '10.1%', 'roll_mean': '6.8%', 'difcourse_mean': '5.6%'}
# ----
# window: 24 knn: 7.355
# Top causes: {'Harsh maneuvers': '77.9%', 'Unstable steering': '11.1%'}
# Top features: {'acc_z_mean': '12.1%', 'roll_mean': '11.6%', 'acc_z_kf_mean': '11.4%', 'vdop_mean': '11.2%', 'vert_acc_mean': '10.4%', 'difcourse_mean': '6.5%'}
# ----
# window: 25 knn: 60.438
# Top causes: {'Harsh maneuvers': '66.6%', 'Unstable steering': '21.9%'}
# Top features: {'pdop_mean': '98.1%', 'vdop_mean': '0.7%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.2%', 'road_width_mean': '0.1%', 'vert_acc_mean': '0.1%'}
# ----
# window: 26 knn: 144.838
# Top causes: {'Harsh maneuvers': '58.1%', 'Unstable steering': '21.4%'}
# Top features: {'pdop_mean': '99.4%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.0%', 'vert_acc_mean': '0.0%'}
# ----
# window: 27 knn: 83.477
# Top causes: {'Harsh maneuvers': '82.1%', 'Tailgating': '9.1%'}
# Top features: {'pdop_mean': '98.6%', 'vdop_mean': '0.6%', 'vert_acc_mean': '0.2%', 'hdop_mean': '0.2%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.1%'}
# ----
# window: 28 knn: 56.718
# Top causes: {'Harsh maneuvers': '66.7%', 'Tailgating': '27.4%'}
# Top features: {'pdop_mean': '97.2%', 'vdop_mean': '0.9%', 'hdop_mean': '0.6%', 'vert_acc_mean': '0.3%', 'x_lane_mean': '0.3%', 'road_width_mean': '0.2%'}
# ----
# window: 29 knn: 3.928
# Top causes: {'Tailgating': '26.8%', 'Unstable steering': '2.5%'}
# Top features: {'alt_mean': '19.6%', 'vdop_mean': '16.3%', 'lat_mean': '12.0%', 'hdop_mean': '7.7%', 'lon_mean': '7.1%', 'roll_mean': '6.5%'}
# ----
# window: 30 knn: 2.759
# Top causes: {'Harsh maneuvers': '28.3%', 'Unstable steering': '24.0%'}
# Top features: {'alt_mean': '28.0%', 'lat_mean': '13.6%', 'road_width_mean': '11.2%', 'lon_mean': '8.7%', 'difcourse_mean': '4.2%', 'vert_acc_mean': '3.9%'}
# ----
# window: 31 knn: 2.268
# Top causes: {'Tailgating': '22.6%', 'Harsh maneuvers': '17.9%'}
# Top features: {'road_width_mean': '22.1%', 'vdop_mean': '10.2%', 'alt_mean': '10.2%', 'x_lane_mean': '7.3%', 'lon_mean': '5.4%', 'course_mean': '4.8%'}
# ----
# window: 32 knn: 2.274
# Top causes: {'Unstable steering': '19.6%', 'Harsh maneuvers': '16.1%'}
# Top features: {'road_width_mean': '35.0%', 'vdop_mean': '12.9%', 'course_mean': '7.9%', 'x_lane_mean': '6.0%', 'num_vehicles_mean': '3.4%', 'difcourse_mean': '3.0%'}
# ----
# window: 33 knn: 2.419
# Top causes: {'Unstable steering': '23.1%', 'Harsh maneuvers': '21.0%'}
# Top features: {'road_width_mean': '35.8%', 'course_mean': '12.1%', 'ttc_front_mean': '5.7%', 'x_lane_mean': '5.5%', 'difcourse_mean': '4.9%', 'num_vehicles_mean': '4.6%'}
# ----
# window: 34 knn: 3.104
# Top causes: {'Tailgating': '15.5%', 'Unstable steering': '7.7%'}
# Top features: {'road_width_mean': '16.9%', 'course_mean': '11.8%', 'pitch_mean': '7.2%', 'osm_delay_mean': '7.1%', 'lon_mean': '7.0%', 'lat_mean': '6.8%'}
# ----
# window: 35 knn: 4.363
# Top causes: {'Harsh maneuvers': '25.1%', 'Unstable steering': '14.2%'}
# Top features: {'gps_speed_osm_mean': '9.1%', 'gps_speed_mean': '9.0%', 'speed_kmh_mean': '9.0%', 'difcourse_mean': '8.6%', 'pitch_mean': '6.2%', 'lon_mean': '5.7%'}
# ----
# window: 36 knn: 4.153
# Top causes: {'Overspeed': '25.6%', 'Unstable steering': '16.6%'}
# Top features: {'road_width_mean': '8.9%', 'pitch_mean': '8.8%', 'roll_mean': '7.6%', 'hdop_mean': '5.5%', 'acc_z_kf_mean': '5.5%', 'lon_mean': '5.4%'}
# ----
# window: 37 knn: 2.818
# Top causes: {'Overspeed': '17.4%', 'Tailgating': '9.4%'}
# Top features: {'road_width_mean': '32.9%', 'yaw_mean': '16.3%', 'vert_acc_mean': '7.6%', 'course_mean': '6.7%', 'lat_mean': '4.5%', 'num_vehicles_mean': '3.7%'}
# ----
# window: 38 knn: 2.797
# Top causes: {'Harsh maneuvers': '14.6%', 'Tailgating': '6.4%'}
# Top features: {'road_width_mean': '24.2%', 'yaw_mean': '18.2%', 'course_mean': '10.4%', 'speed_kmh_mean': '6.6%', 'gps_speed_osm_mean': '6.5%', 'gps_speed_mean': '6.4%'}
# ----
# window: 39 knn: 3.274
# Top causes: {'Harsh maneuvers': '30.0%', 'Overspeed': '28.9%'}
# Top features: {'road_width_mean': '10.4%', 'yaw_mean': '10.3%', 'hdop_mean': '9.9%', 'course_mean': '7.0%', 'acc_x_kf_mean': '5.0%', 'acc_x_mean': '4.8%'}
# ----
# window: 40 knn: 202.324
# Top causes: {'Tailgating': '50.7%', 'Harsh maneuvers': '26.0%'}
# Top features: {'pdop_mean': '99.6%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'alt_mean': '0.0%', 'lat_mean': '0.0%', 'road_width_mean': '0.0%'}
# ----
# window: 41 knn: 179.21
# Top causes: {'Harsh maneuvers': '62.7%', 'Overspeed': '29.9%'}
# Top features: {'pdop_mean': '99.7%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'alt_mean': '0.0%', 'acc_z_kf_mean': '0.0%', 'acc_z_mean': '0.0%'}
# ----
# window: 42 knn: 56.324
# Top causes: {'Harsh maneuvers': '48.2%', 'Overspeed': '41.6%'}
# Top features: {'pdop_mean': '99.1%', 'vdop_mean': '0.3%', 'road_width_mean': '0.2%', 'acc_z_kf_mean': '0.1%', 'acc_z_mean': '0.1%', 'gps_speed_osm_mean': '0.0%'}
# ----
# window: 43 knn: 4.039
# Top causes: {'Tailgating': '10.8%', 'Unstable steering': '3.8%'}
# Top features: {'road_width_mean': '23.7%', 'gps_speed_mean': '6.8%', 'speed_kmh_mean': '6.7%', 'gps_speed_osm_mean': '6.7%', 'vert_acc_mean': '6.4%', 'course_mean': '5.4%'}
# ----
# window: 44 knn: 4.05
# Top causes: {'Tailgating': '13.4%', 'Overspeed': '2.5%'}
# Top features: {'road_width_mean': '19.9%', 'acc_x_kf_mean': '13.4%', 'acc_x_mean': '13.1%', 'vert_acc_mean': '8.2%', 'course_mean': '8.0%', 'lon_mean': '6.4%'}
# ----
# window: 45 knn: 8.221
# Top causes: {'Harsh maneuvers': '63.0%', 'Unstable steering': '24.3%'}
# Top features: {'acc_x_kf_mean': '21.2%', 'acc_x_mean': '20.3%', 'difcourse_mean': '18.9%', 'pitch_mean': '8.9%', 'acc_z_mean': '3.2%', 'acc_z_kf_mean': '3.2%'}
# ----
# window: 46 knn: 8.058
# Top causes: {'Harsh maneuvers': '55.2%', 'Unstable steering': '37.7%'}
# Top features: {'difcourse_mean': '22.9%', 'acc_x_kf_mean': '14.5%', 'acc_x_mean': '13.9%', 'roll_mean': '12.6%', 'pitch_mean': '8.5%', 'vdop_mean': '3.5%'}
# ----
# window: 47 knn: 4.264
# Top causes: {'Unstable steering': '18.8%', 'Tailgating': '3.6%'}
# Top features: {'road_width_mean': '12.2%', 'yaw_mean': '11.5%', 'speed_kmh_mean': '9.7%', 'gps_speed_osm_mean': '9.6%', 'gps_speed_mean': '9.4%', 'acc_z_kf_mean': '8.4%'}
# ----
# window: 48 knn: 4.749
# Top causes: {'Harsh maneuvers': '26.8%', 'Unstable steering': '19.4%'}
# Top features: {'osm_delay_mean': '20.2%', 'road_width_mean': '15.0%', 'yaw_mean': '8.3%', 'gps_speed_mean': '7.8%', 'gps_speed_osm_mean': '7.7%', 'speed_kmh_mean': '7.6%'}
# ----
# window: 49 knn: 25.972
# Top causes: {'Harsh maneuvers': '62.5%', 'Overspeed': '20.1%'}
# Top features: {'pdop_mean': '94.0%', 'hdop_mean': '2.2%', 'vdop_mean': '0.8%', 'alt_mean': '0.6%', 'lat_mean': '0.5%', 'roll_mean': '0.5%'}
# ----
# window: 50 knn: 110.176
# Top causes: {'Harsh maneuvers': '58.8%', 'Unstable steering': '16.7%'}
# Top features: {'pdop_mean': '99.2%', 'vdop_mean': '0.4%', 'hdop_mean': '0.3%', 'alt_mean': '0.0%', 'lat_mean': '0.0%', 'roll_mean': '0.0%'}
# ----
# window: 51 knn: 83.324
# Top causes: {'Harsh maneuvers': '43.1%', 'Tailgating': '35.5%'}
# Top features: {'pdop_mean': '99.0%', 'vdop_mean': '0.5%', 'hdop_mean': '0.3%', 'road_width_mean': '0.0%', 'vert_acc_mean': '0.0%', 'num_vehicles_mean': '0.0%'}
# ----
# window: 52 knn: 6.66
# Top causes: {'Unstable steering': '11.4%', 'Overspeed': '11.3%'}
# Top features: {'hdop_mean': '42.4%', 'vdop_mean': '36.7%', 'road_width_mean': '4.0%', 'vert_acc_mean': '2.8%', 'pitch_mean': '2.7%', 'num_vehicles_mean': '2.0%'}
# ----
# window: 53 knn: 37.713
# Top causes: {'Harsh maneuvers': '57.6%', 'Tailgating': '25.0%'}
# Top features: {'pdop_mean': '95.1%', 'vdop_mean': '2.4%', 'hdop_mean': '1.8%', 'road_width_mean': '0.1%', 'vert_acc_mean': '0.1%', 'x_lane_mean': '0.1%'}
# ----
# window: 54 knn: 56.863
# Top causes: {'Harsh maneuvers': '62.3%', 'Tailgating': '14.2%'}
# Top features: {'pdop_mean': '96.8%', 'vdop_mean': '1.4%', 'hdop_mean': '1.2%', 'x_lane_mean': '0.2%', 'road_width_mean': '0.1%', 'vert_acc_mean': '0.0%'}
# ----
# window: 55 knn: 71.913
# Top causes: {'Harsh maneuvers': '39.5%', 'Tailgating': '29.2%'}
# Top features: {'pdop_mean': '98.6%', 'vdop_mean': '0.8%', 'hdop_mean': '0.3%', 'dist_front_mean': '0.0%', 'vert_acc_mean': '0.0%', 'course_mean': '0.0%'}
# ----
# window: 56 knn: 52.68
# Top causes: {'Harsh maneuvers': '40.5%', 'Overspeed': '28.5%'}
# Top features: {'pdop_mean': '97.8%', 'vdop_mean': '0.4%', 'difcourse_mean': '0.3%', 'acc_x_mean': '0.2%', 'pitch_mean': '0.2%', 'acc_x_kf_mean': '0.2%'}
# ----
# window: 57 knn: 5.076
# Top causes: {'Unstable steering': '25.4%', 'Overspeed': '15.8%'}
# Top features: {'roll_mean': '12.8%', 'difcourse_mean': '10.1%', 'hdop_mean': '8.3%', 'acc_x_mean': '7.1%', 'pitch_mean': '7.0%', 'acc_x_kf_mean': '6.3%'}
# ----
# window: 58 knn: 26.398
# Top causes: {'Harsh maneuvers': '36.5%', 'Unstable steering': '30.0%'}
# Top features: {'pdop_mean': '92.1%', 'hdop_mean': '4.3%', 'vdop_mean': '1.7%', 'road_width_mean': '0.3%', 'x_lane_mean': '0.3%', 'yaw_mean': '0.2%'}
# ----
# window: 59 knn: 129.432
# Top causes: {'Harsh maneuvers': '32.0%', 'Overspeed': '28.5%'}
# Top features: {'pdop_mean': '99.3%', 'vdop_mean': '0.3%', 'hdop_mean': '0.3%', 'road_width_mean': '0.0%', 'yaw_mean': '0.0%', 'course_mean': '0.0%'}
# ----
# window: 60 knn: 186.927
# Top causes: {'Harsh maneuvers': '59.7%', 'Tailgating': '14.7%'}
# Top features: {'pdop_mean': '99.7%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'acc_z_mean': '0.0%', 'road_width_mean': '0.0%', 'acc_z_kf_mean': '0.0%'}
# ----
# window: 61 knn: 9.082
# Top causes: {'Overspeed': '89.6%', 'Tailgating': '8.1%'}
# Top features: {'lat_osm_mean': '20.9%', 'lon_osm_mean': '20.7%', 'speed_rel_mean': '9.0%', 'max_speed_mean': '8.2%', 'speed_ratio_mean': '8.1%', 'num_lanes_mean': '7.2%'}
# ----
# window: 62 knn: 6.828
# Top causes: {'Overspeed': '79.0%', 'Tailgating': '16.3%'}
# Top features: {'speed_ratio_mean': '15.0%', 'speed_rel_mean': '13.4%', 'max_speed_mean': '12.3%', 'num_lanes_mean': '10.7%', 'vdop_mean': '8.1%', 'lon_osm_mean': '8.0%'}
# ----
# window: 63 knn: 5.865
# Top causes: {'Tailgating': '25.3%', 'Harsh maneuvers': '4.3%'}
# Top features: {'speed_ratio_mean': '17.7%', 'speed_rel_mean': '15.5%', 'max_speed_mean': '13.6%', 'num_lanes_mean': '11.7%', 'ttc_front_mean': '6.8%', 'num_vehicles_mean': '5.9%'}
# ----
# window: 64 knn: 3.619
# Top causes: {'Harsh maneuvers': '8.6%', 'Unstable steering': '2.7%'}
# Top features: {'ttc_front_mean': '13.8%', 'dist_front_mean': '11.3%', 'num_vehicles_mean': '9.1%', 'speed_ratio_mean': '7.1%', 'speed_rel_mean': '6.5%', 'gps_speed_osm_mean': '5.5%'}
# ----
# window: 65 knn: 2.911
# Top causes: {'Harsh maneuvers': '14.8%', 'Unstable steering': '5.1%'}
# Top features: {'alt_mean': '12.8%', 'ttc_front_mean': '9.3%', 'num_vehicles_mean': '9.2%', 'lane_state_mean': '9.1%', 'dist_front_mean': '8.1%', 'x_lane_mean': '6.0%'}
# ----
# window: 66 knn: 2.713
# Top causes: {'Unstable steering': '11.8%', 'Tailgating': '11.2%'}
# Top features: {'alt_mean': '15.2%', 'course_mean': '8.2%', 'gps_speed_mean': '7.6%', 'gps_speed_osm_mean': '7.6%', 'speed_kmh_mean': '7.6%', 'acc_y_kf_mean': '5.0%'}
# ----
# window: 67 knn: 2.898
# Top causes: {'Harsh maneuvers': '27.3%', 'Unstable steering': '19.6%'}
# Top features: {'road_width_mean': '15.2%', 'course_mean': '11.0%', 'roll_mean': '7.3%', 'num_vehicles_mean': '7.3%', 'lat_mean': '6.2%', 'alt_mean': '5.6%'}
# ----
# window: 68 knn: 3.48
# Top causes: {'Unstable steering': '8.5%', 'Tailgating': '2.3%'}
# Top features: {'road_width_mean': '19.2%', 'roll_mean': '15.7%', 'lon_mean': '8.8%', 'course_mean': '8.1%', 'speed_kmh_mean': '6.6%', 'gps_speed_osm_mean': '6.5%'}
# ----
# window: 69 knn: 4.746
# Top causes: {'Unstable steering': '10.5%', 'Tailgating': '7.5%'}
# Top features: {'acc_x_kf_mean': '13.3%', 'acc_x_mean': '13.0%', 'active_mean': '11.5%', 'phi_mean': '8.6%', 'pitch_mean': '6.7%', 'difcourse_mean': '6.4%'}
# ----
# window: 70 knn: 4.277
# Top causes: {'Unstable steering': '15.0%', 'Tailgating': '2.9%'}
# Top features: {'active_mean': '15.0%', 'phi_mean': '14.9%', 'acc_x_mean': '8.8%', 'hdop_mean': '7.8%', 'acc_x_kf_mean': '7.3%', 'pitch_mean': '5.8%'}
# ----
# window: 71 knn: 2.69
# Top causes: {'Harsh maneuvers': '28.7%', 'Tailgating': '20.8%'}
# Top features: {'road_width_mean': '19.3%', 'yaw_mean': '12.6%', 'lon_mean': '8.5%', 'x_lane_mean': '6.6%', 'lat_mean': '6.6%', 'num_vehicles_mean': '6.6%'}
# ----
# window: 72 knn: 2.39
# Top causes: {'Harsh maneuvers': '17.1%', 'Tailgating': '3.4%'}
# Top features: {'road_width_mean': '15.6%', 'yaw_mean': '11.0%', 'x_lane_mean': '10.5%', 'gps_speed_osm_mean': '8.0%', 'speed_kmh_mean': '7.9%', 'gps_speed_mean': '7.9%'}
# ----
# window: 73 knn: 2.259
# Top causes: {'Unstable steering': '29.8%', 'Tailgating': '16.6%'}
# Top features: {'road_width_mean': '14.2%', 'yaw_mean': '13.2%', 'course_mean': '9.5%', 'roll_mean': '8.0%', 'gps_speed_osm_mean': '5.2%', 'speed_kmh_mean': '5.2%'}
# ----
# window: 74 knn: 2.36
# Top causes: {'Overspeed': '25.2%', 'Harsh maneuvers': '23.0%'}
# Top features: {'yaw_mean': '15.3%', 'course_mean': '14.8%', 'road_width_mean': '14.4%', 'vdop_mean': '10.6%', 'dist_front_mean': '6.6%', 'acc_z_mean': '4.0%'}
# ----
# window: 75 knn: 2.503
# Top causes: {'Harsh maneuvers': '18.1%', 'Tailgating': '6.0%'}
# Top features: {'course_mean': '13.8%', 'road_width_mean': '12.4%', 'alt_mean': '11.9%', 'yaw_mean': '11.8%', 'lane_state_mean': '6.7%', 'lon_mean': '4.5%'}
# ----
# window: 76 knn: 3.482
# Top causes: {'Harsh maneuvers': '7.0%', 'Unstable steering': '20.1%'}
# Top features: {'hdop_mean': '17.8%', 'alt_mean': '13.6%', 'x_lane_mean': '12.7%', 'lat_mean': '6.4%', 'num_vehicles_mean': '5.9%', 'road_width_mean': '5.2%'}
# ----
# window: 77 knn: 91.677
# Top causes: {'Harsh maneuvers': '99.8%', 'Overspeed': '0.1%'}
# Top features: {'acc_y_kf_mean': '39.5%', 'acc_y_mean': '37.2%', 'acc_x_kf_mean': '7.7%', 'acc_x_mean': '7.2%', 'pitch_mean': '4.8%', 'acc_z_kf_mean': '1.5%'}
# ----
# window: 78 knn: 90.649
# Top causes: {'Harsh maneuvers': '99.8%', 'Overspeed': '0.2%'}
# Top features: {'acc_y_kf_mean': '35.5%', 'acc_y_mean': '33.3%', 'acc_x_kf_mean': '8.6%', 'acc_x_mean': '8.0%', 'pitch_mean': '4.9%', 'acc_z_kf_mean': '4.6%'}
# ----
# window: 79 knn: 84.415
# Top causes: {'Harsh maneuvers': '99.9%', 'Overspeed': '0.1%'}
# Top features: {'acc_y_kf_mean': '31.4%', 'acc_y_mean': '29.5%', 'acc_z_kf_mean': '8.9%', 'acc_z_mean': '8.8%', 'acc_x_kf_mean': '8.0%', 'acc_x_mean': '7.6%'}
# ----
# window: 80 knn: 54.441
# Top causes: {'Harsh maneuvers': '99.7%', 'Overspeed': '0.2%'}
# Top features: {'acc_y_kf_mean': '31.5%', 'acc_y_mean': '29.7%', 'acc_z_kf_mean': '10.8%', 'acc_z_mean': '10.8%', 'acc_x_kf_mean': '5.5%', 'acc_x_mean': '5.3%'}
# ----
# window: 81 knn: 13.458
# Top causes: {'Harsh maneuvers': '98.5%', 'Tailgating': '1.0%'}
# Top features: {'acc_y_kf_mean': '32.6%', 'acc_y_mean': '31.0%', 'acc_z_mean': '9.6%', 'acc_z_kf_mean': '9.4%', 'acc_x_mean': '4.3%', 'pitch_mean': '4.3%'}
# ----
# window: 82 knn: 6.506
# Top causes: {'Overspeed': '14.6%', 'Unstable steering': '7.8%'}
# Top features: {'acc_x_mean': '24.2%', 'acc_x_kf_mean': '23.4%', 'road_width_mean': '5.9%', 'difcourse_mean': '5.5%', 'pitch_mean': '4.2%', 'lon_mean': '4.1%'}
# ----
# window: 83 knn: 7.034
# Top causes: {'Harsh maneuvers': '71.3%', 'Overspeed': '16.0%'}
# Top features: {'acc_x_kf_mean': '16.0%', 'acc_x_mean': '14.5%', 'acc_z_mean': '10.3%', 'acc_z_kf_mean': '9.4%', 'road_width_mean': '7.8%', 'difcourse_mean': '7.2%'}
# ----
# window: 84 knn: 4.238
# Top causes: {'Harsh maneuvers': '17.7%', 'Overspeed': '9.1%'}
# Top features: {'road_width_mean': '25.7%', 'yaw_mean': '19.5%', 'lon_mean': '9.5%', 'ttc_front_mean': '8.7%', 'lat_mean': '5.2%', 'course_mean': '5.1%'}
# ----
# window: 85 knn: 3.563
# Top causes: {'Overspeed': '19.9%', 'Harsh maneuvers': '15.2%'}
# Top features: {'yaw_mean': '23.8%', 'road_width_mean': '20.9%', 'roll_mean': '5.8%', 'lat_mean': '5.4%', 'course_mean': '5.4%', 'lon_mean': '4.9%'}
# ----
# window: 86 knn: 3.816
# Top causes: {'Unstable steering': '24.6%', 'Harsh maneuvers': '16.2%'}
# Top features: {'yaw_mean': '17.1%', 'gps_speed_osm_mean': '12.7%', 'gps_speed_mean': '12.6%', 'speed_kmh_mean': '12.6%', 'road_width_mean': '11.6%', 'course_mean': '4.8%'}
# ----
# window: 87 knn: 4.951
# Top causes: {'Unstable steering': '12.2%', 'Harsh maneuvers': '7.9%'}
# Top features: {'gps_speed_mean': '19.2%', 'speed_kmh_mean': '19.2%', 'gps_speed_osm_mean': '19.1%', 'yaw_mean': '9.6%', 'road_width_mean': '6.3%', 'course_mean': '4.1%'}
# ----
# window: 88 knn: 4.706
# Top causes: {'Unstable steering': '13.7%', 'Harsh maneuvers': '10.7%'}
# Top features: {'speed_kmh_mean': '14.6%', 'gps_speed_osm_mean': '14.6%', 'gps_speed_mean': '14.5%', 'roll_mean': '10.2%', 'yaw_mean': '9.0%', 'road_width_mean': '6.6%'}
# ----
# window: 89 knn: 4.137
# Top causes: {'Tailgating': '1.5%', 'Harsh maneuvers': '24.9%'}
# Top features: {'lane_state_mean': '19.7%', 'yaw_mean': '14.5%', 'lat_mean': '7.7%', 'course_mean': '7.4%', 'vdop_mean': '5.8%', 'vert_acc_mean': '5.4%'}
# ----
# window: 90 knn: 10.029
# Top causes: {'Harsh maneuvers': '62.6%', 'Overspeed': '16.3%'}
# Top features: {'pdop_mean': '41.1%', 'hdop_mean': '23.0%', 'vdop_mean': '14.0%', 'x_lane_mean': '8.7%', 'alt_mean': '3.7%', 'lat_mean': '2.8%'}
# ----
# window: 91 knn: 87.295
# Top causes: {'Harsh maneuvers': '63.0%', 'Unstable steering': '14.1%'}
# Top features: {'pdop_mean': '98.5%', 'vdop_mean': '0.6%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.2%', 'lane_state_mean': '0.1%', 'alt_mean': '0.0%'}
# ----
# window: 92 knn: 117.884
# Top causes: {'Harsh maneuvers': '64.9%', 'Unstable steering': '15.9%'}
# Top features: {'pdop_mean': '99.3%', 'vdop_mean': '0.4%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'lane_state_mean': '0.1%', 'vert_acc_mean': '0.0%'}
# ----
# window: 93 knn: 37.899
# Top causes: {'Harsh maneuvers': '48.9%', 'Tailgating': '28.5%'}
# Top features: {'pdop_mean': '94.6%', 'vdop_mean': '2.5%', 'hdop_mean': '1.1%', 'lane_state_mean': '0.7%', 'x_lane_mean': '0.5%', 'pitch_mean': '0.1%'}
# ----
# window: 94 knn: 9.29
# Top causes: {'Tailgating': '56.1%', 'Harsh maneuvers': '24.9%'}
# Top features: {'vdop_mean': '35.4%', 'lane_state_mean': '22.5%', 'hdop_mean': '20.6%', 'x_lane_mean': '9.4%', 'num_vehicles_mean': '1.9%', 'ttc_front_mean': '1.3%'}
# ----
# window: 95 knn: 8.308
# Top causes: {'Harsh maneuvers': '32.6%', 'Overspeed': '31.6%'}
# Top features: {'vdop_mean': '38.3%', 'hdop_mean': '22.3%', 'lane_state_mean': '15.7%', 'x_lane_mean': '11.3%', 'pitch_mean': '3.4%', 'course_mean': '1.7%'}
# ----
# window: 96 knn: 6.838
# Top causes: {'Overspeed': '58.0%', 'Harsh maneuvers': '16.2%'}
# Top features: {'vdop_mean': '46.0%', 'x_lane_mean': '13.8%', 'hdop_mean': '11.1%', 'gps_speed_osm_mean': '3.3%', 'speed_kmh_mean': '3.3%', 'gps_speed_mean': '3.3%'}
# ----
# window: 97 knn: 6.528
# Top causes: {'Harsh maneuvers': '17.4%', 'Tailgating': '7.3%'}
# Top features: {'vdop_mean': '24.8%', 'gps_speed_osm_mean': '11.0%', 'speed_kmh_mean': '11.0%', 'gps_speed_mean': '11.0%', 'x_lane_mean': '6.3%', 'lane_state_mean': '4.3%'}
# ----
# window: 98 knn: 7.539
# Top causes: {'Harsh maneuvers': '41.4%', 'Overspeed': '31.4%'}
# Top features: {'difcourse_mean': '13.0%', 'acc_x_mean': '11.2%', 'acc_x_kf_mean': '10.9%', 'gps_speed_osm_mean': '7.8%', 'speed_kmh_mean': '7.8%', 'gps_speed_mean': '7.7%'}
# ----
# window: 99 knn: 6.819
# Top causes: {'Unstable steering': '20.2%', 'Tailgating': '0.3%'}
# Top features: {'vdop_mean': '18.4%', 'x_lane_mean': '11.5%', 'hdop_mean': '9.0%', 'acc_x_mean': '8.0%', 'acc_x_kf_mean': '7.7%', 'difcourse_mean': '7.7%'}
# ----
# window: 100 knn: 6.83
# Top causes: {'Overspeed': '13.9%', 'Harsh maneuvers': '12.1%'}
# Top features: {'vdop_mean': '36.3%', 'lane_state_mean': '14.6%', 'hdop_mean': '14.0%', 'x_lane_mean': '13.1%', 'yaw_mean': '4.1%', 'pitch_mean': '3.3%'}
# ----
# window: 101 knn: 4.886
# Top causes: {'Overspeed': '10.5%', 'Harsh maneuvers': '6.7%'}
# Top features: {'vdop_mean': '23.8%', 'lane_state_mean': '15.9%', 'x_lane_mean': '15.5%', 'hdop_mean': '10.4%', 'yaw_mean': '8.0%', 'course_mean': '4.1%'}
# ----
# window: 102 knn: 9.004
# Top causes: {'Unstable steering': '54.8%', 'Tailgating': '20.8%'}
# Top features: {'pdop_mean': '60.3%', 'vdop_mean': '14.6%', 'hdop_mean': '11.5%', 'x_lane_mean': '5.6%', 'yaw_mean': '2.2%', 'course_mean': '1.3%'}
# ----
# window: 103 knn: 9.423
# Top causes: {'Harsh maneuvers': '40.5%', 'Unstable steering': '37.6%'}
# Top features: {'pdop_mean': '50.2%', 'vdop_mean': '21.6%', 'hdop_mean': '14.0%', 'x_lane_mean': '3.7%', 'yaw_mean': '1.8%', 'course_mean': '1.6%'}
# ----
# window: 104 knn: 5.286
# Top causes: {'Tailgating': '18.9%', 'Overspeed': '13.3%'}
# Top features: {'vdop_mean': '32.0%', 'lane_state_mean': '15.4%', 'hdop_mean': '13.7%', 'x_lane_mean': '8.4%', 'course_mean': '5.3%', 'yaw_mean': '5.0%'}
# ----
# window: 105 knn: 6.189
# Top causes: {'Overspeed': '7.3%', 'Tailgating': '0.7%'}
# Top features: {'lane_state_mean': '37.9%', 'vdop_mean': '22.9%', 'x_lane_mean': '6.0%', 'hdop_mean': '5.6%', 'yaw_mean': '3.9%', 'course_mean': '3.8%'}
# ----
# window: 106 knn: 5.896
# Top causes: {'Overspeed': '18.7%', 'Tailgating': '3.0%'}
# Top features: {'vdop_mean': '24.0%', 'hdop_mean': '15.2%', 'x_lane_mean': '12.3%', 'lane_state_mean': '11.9%', 'lat_mean': '5.6%', 'alt_mean': '5.6%'}
# ----
# window: 107 knn: 3.493
# Top causes: {'Overspeed': '10.7%', 'Unstable steering': '5.1%'}
# Top features: {'lat_mean': '15.5%', 'alt_mean': '13.6%', 'roll_mean': '12.6%', 'road_width_mean': '12.2%', 'lon_mean': '9.5%', 'acc_x_mean': '4.2%'}
# ----
# window: 108 knn: 2.974
# Top causes: {'Tailgating': '25.4%', 'Unstable steering': '9.3%'}
# Top features: {'acc_x_mean': '12.9%', 'acc_x_kf_mean': '8.6%', 'vert_acc_mean': '8.0%', 'lat_mean': '7.9%', 'lon_mean': '7.4%', 'num_vehicles_mean': '7.0%'}
# ----
# window: 109 knn: 2.806
# Top causes: {'Overspeed': '5.4%', 'Unstable steering': '1.2%'}
# Top features: {'acc_z_mean': '11.7%', 'num_vehicles_mean': '11.3%', 'acc_z_kf_mean': '10.6%', 'pitch_mean': '7.9%', 'vdop_mean': '7.6%', 'ttc_front_mean': '7.2%'}
# ----
# window: 110 knn: 2.991
# Top causes: {'Overspeed': '11.3%', 'Unstable steering': '1.2%'}
# Top features: {'pitch_mean': '13.8%', 'x_lane_mean': '12.1%', 'dist_front_mean': '11.2%', 'acc_x_kf_mean': '9.2%', 'ttc_front_mean': '6.7%', 'acc_z_mean': '6.2%'}
# ----
# window: 111 knn: 3.124
# Top causes: {'Unstable steering': '7.8%', 'Overspeed': '5.0%'}
# Top features: {'roll_mean': '19.4%', 'course_mean': '9.8%', 'dist_front_mean': '7.3%', 'vdop_mean': '7.3%', 'lat_mean': '5.3%', 'osm_delay_mean': '4.6%'}
# ----
# window: 112 knn: 4.772
# Top causes: {'Unstable steering': '8.4%', 'Tailgating': '4.6%'}
# Top features: {'active_mean': '17.5%', 'lane_state_mean': '16.1%', 'phi_mean': '15.1%', 'hdop_mean': '10.8%', 'x_lane_mean': '6.8%', 'acc_x_kf_mean': '3.4%'}
# ----
# window: 113 knn: 4.756
# Top causes: {'Unstable steering': '6.5%', 'Tailgating': '2.8%'}
# Top features: {'phi_mean': '15.9%', 'active_mean': '15.8%', 'x_lane_mean': '11.8%', 'speed_kmh_mean': '6.2%', 'gps_speed_mean': '6.2%', 'gps_speed_osm_mean': '6.2%'}
# ----
# window: 114 knn: 3.963
# Top causes: {'Unstable steering': '9.2%', 'Harsh maneuvers': '7.8%'}
# Top features: {'gps_speed_mean': '11.7%', 'speed_kmh_mean': '11.7%', 'gps_speed_osm_mean': '11.5%', 'ttc_front_mean': '10.5%', 'num_vehicles_mean': '9.0%', 'lane_state_mean': '7.6%'}
# ----
# window: 115 knn: 3.276
# Top causes: {'Harsh maneuvers': '13.9%', 'Unstable steering': '11.2%'}
# Top features: {'num_vehicles_mean': '23.5%', 'gps_speed_mean': '8.2%', 'speed_kmh_mean': '8.1%', 'gps_speed_osm_mean': '8.1%', 'yaw_mean': '7.1%', 'ttc_front_mean': '6.4%'}
# ----
# window: 116 knn: 2.798
# Top causes: {'Tailgating': '15.2%', 'Overspeed': '13.6%'}
# Top features: {'yaw_mean': '12.9%', 'x_lane_mean': '10.2%', 'vdop_mean': '6.9%', 'lane_state_mean': '6.4%', 'acc_x_mean': '6.2%', 'course_mean': '5.6%'}
# ----
# window: 117 knn: 2.671
# Top causes: {'Unstable steering': '20.6%', 'Harsh maneuvers': '7.7%'}
# Top features: {'dist_front_mean': '22.5%', 'ttc_front_mean': '14.1%', 'x_lane_mean': '11.2%', 'yaw_mean': '10.7%', 'course_mean': '7.6%', 'lane_state_mean': '6.0%'}
# ----
# window: 118 knn: 2.666
# Top causes: {'Unstable steering': '13.8%', 'Harsh maneuvers': '11.2%'}
# Top features: {'dist_front_mean': '22.0%', 'ttc_front_mean': '19.3%', 'yaw_mean': '8.8%', 'course_mean': '8.3%', 'num_vehicles_mean': '5.5%', 'x_lane_mean': '5.2%'}
# ----
# window: 119 knn: 2.671
# Top causes: {'Unstable steering': '21.0%', 'Harsh maneuvers': '17.5%'}
# Top features: {'dist_front_mean': '17.0%', 'ttc_front_mean': '15.4%', 'yaw_mean': '11.4%', 'course_mean': '9.6%', 'vdop_mean': '6.1%', 'lane_state_mean': '5.5%'}
# ----
# window: 120 knn: 3.424
# Top causes: {'Unstable steering': '29.4%', 'Tailgating': '15.8%'}
# Top features: {'lat_mean': '10.9%', 'yaw_mean': '9.0%', 'alt_mean': '8.1%', 'lon_mean': '6.8%', 'course_mean': '6.6%', 'roll_mean': '6.6%'}
# ----
# window: 121 knn: 4.253
# Top causes: {'Tailgating': '10.3%', 'Unstable steering': '2.2%'}
# Top features: {'acc_x_kf_mean': '18.8%', 'acc_x_mean': '18.2%', 'lat_mean': '10.1%', 'alt_mean': '6.9%', 'lon_mean': '6.3%', 'vdop_mean': '4.7%'}
# ----
# window: 122 knn: 3.321
# Top causes: {'Tailgating': '13.2%', 'Unstable steering': '6.6%'}
# Top features: {'roll_mean': '15.1%', 'gps_speed_mean': '6.6%', 'acc_x_kf_mean': '6.6%', 'gps_speed_osm_mean': '6.6%', 'speed_kmh_mean': '6.6%', 'acc_z_kf_mean': '5.6%'}
# ----
# window: 123 knn: 3.442
# Top causes: {'Tailgating': '12.2%', 'Unstable steering': '6.2%'}
# Top features: {'roll_mean': '27.8%', 'alt_mean': '13.0%', 'acc_x_mean': '9.5%', 'acc_x_kf_mean': '8.5%', 'course_mean': '6.6%', 'hdop_mean': '3.3%'}
# ----
# window: 124 knn: 3.311
# Top causes: {'Overspeed': '11.2%', 'Unstable steering': '3.6%'}
# Top features: {'pitch_mean': '13.7%', 'alt_mean': '10.8%', 'course_mean': '9.5%', 'ttc_front_mean': '8.8%', 'acc_x_mean': '6.6%', 'acc_x_kf_mean': '6.4%'}
# ----
# window: 125 knn: 3.491
# Top causes: {'Harsh maneuvers': '26.8%', 'Overspeed': '11.1%'}
# Top features: {'ttc_front_mean': '14.3%', 'dist_front_mean': '13.8%', 'course_mean': '11.3%', 'pitch_mean': '8.0%', 'acc_z_mean': '7.1%', 'lat_mean': '6.1%'}
# ----
# window: 126 knn: 3.941
# Top causes: {'Tailgating': '20.8%', 'Overspeed': '12.6%'}
# Top features: {'vert_acc_mean': '26.4%', 'course_mean': '9.6%', 'speed_rel_mean': '6.5%', 'ttc_front_mean': '6.4%', 'lon_mean': '5.9%', 'lat_mean': '5.5%'}
# ----
# window: 127 knn: 7.718
# Top causes: {'Harsh maneuvers': '85.4%', 'Unstable steering': '7.6%'}
# Top features: {'acc_z_mean': '30.1%', 'acc_z_kf_mean': '29.4%', 'acc_x_kf_mean': '7.2%', 'difcourse_mean': '6.6%', 'acc_x_mean': '5.6%', 'lon_mean': '3.1%'}
# ----
# window: 128 knn: 7.103
# Top causes: {'Harsh maneuvers': '62.5%', 'Overspeed': '21.5%'}
# Top features: {'acc_x_mean': '17.4%', 'acc_x_kf_mean': '16.6%', 'difcourse_mean': '10.2%', 'acc_z_mean': '7.5%', 'acc_z_kf_mean': '7.4%', 'road_width_mean': '5.5%'}
# ----
# window: 129 knn: 7.618
# Top causes: {'Overspeed': '66.9%', 'Harsh maneuvers': '16.9%'}
# Top features: {'x_lane_mean': '18.2%', 'active_mean': '14.6%', 'phi_mean': '14.3%', 'gps_speed_osm_mean': '7.9%', 'speed_kmh_mean': '7.9%', 'gps_speed_mean': '7.8%'}
# ----
# window: 130 knn: 9.512
# Top causes: {'Overspeed': '49.2%', 'Tailgating': '42.2%'}
# Top features: {'active_mean': '23.0%', 'phi_mean': '20.7%', 'x_lane_mean': '12.1%', 'lane_state_mean': '12.0%', 'hdop_mean': '9.5%', 'num_vehicles_mean': '5.8%'}
# ----
# window: 131 knn: 5.587
# Top causes: {'Overspeed': '6.4%', 'Unstable steering': '5.0%'}
# Top features: {'x_lane_mean': '13.8%', 'active_mean': '13.5%', 'phi_mean': '13.4%', 'num_vehicles_mean': '11.5%', 'osm_delay_mean': '10.0%', 'hdop_mean': '7.9%'}
# ----
# window: 132 knn: 4.269
# Top causes: {'Overspeed': '18.6%', 'Unstable steering': '3.3%'}
# Top features: {'num_vehicles_mean': '19.2%', 'course_mean': '14.2%', 'vert_acc_mean': '12.5%', 'lon_mean': '5.0%', 'lat_mean': '4.9%', 'osm_delay_mean': '4.7%'}
# ----
# window: 133 knn: 4.486
# Top causes: {'Tailgating': '18.9%', 'Overspeed': '14.7%'}
# Top features: {'lat_mean': '12.8%', 'alt_mean': '9.9%', 'acc_x_mean': '8.7%', 'course_mean': '8.4%', 'lon_mean': '8.0%', 'acc_x_kf_mean': '7.6%'}
# ----
# window: 134 knn: 7.94
# Top causes: {'Tailgating': '47.7%', 'Unstable steering': '40.1%'}
# Top features: {'pdop_mean': '18.8%', 'road_width_mean': '17.1%', 'vdop_mean': '14.3%', 'hdop_mean': '13.6%', 'difcourse_mean': '6.7%', 'lane_state_mean': '5.6%'}
# ----
# window: 135 knn: 9.449
# Top causes: {'Tailgating': '79.8%', 'Harsh maneuvers': '12.6%'}
# Top features: {'vdop_mean': '37.8%', 'pdop_mean': '12.8%', 'hdop_mean': '12.8%', 'road_width_mean': '12.5%', 'ttc_front_mean': '4.9%', 'dist_front_mean': '4.1%'}
# ----
# window: 136 knn: 49.302
# Top causes: {'Tailgating': '60.3%', 'Harsh maneuvers': '27.3%'}
# Top features: {'pdop_mean': '95.9%', 'vdop_mean': '1.9%', 'hdop_mean': '0.8%', 'road_width_mean': '0.6%', 'lane_state_mean': '0.2%', 'ttc_front_mean': '0.1%'}
# ----
# window: 137 knn: 64.44
# Top causes: {'Tailgating': '32.5%', 'Overspeed': '32.0%'}
# Top features: {'pdop_mean': '97.6%', 'vdop_mean': '1.2%', 'hdop_mean': '0.6%', 'road_width_mean': '0.4%', 'lane_state_mean': '0.1%', 'x_lane_mean': '0.0%'}
# ----
# window: 138 knn: 34.169
# Top causes: {'Tailgating': '48.2%', 'Overspeed': '34.8%'}
# Top features: {'pdop_mean': '92.9%', 'vdop_mean': '3.5%', 'road_width_mean': '1.2%', 'hdop_mean': '1.1%', 'lane_state_mean': '0.4%', 'x_lane_mean': '0.2%'}
# ----
# window: 139 knn: 34.22
# Top causes: {'Overspeed': '52.0%', 'Tailgating': '21.3%'}
# Top features: {'pdop_mean': '92.9%', 'vdop_mean': '3.5%', 'road_width_mean': '1.1%', 'hdop_mean': '0.7%', 'x_lane_mean': '0.4%', 'lane_state_mean': '0.4%'}
# ----
# window: 140 knn: 16.044
# Top causes: {'Harsh maneuvers': '40.0%', 'Overspeed': '38.8%'}
# Top features: {'pdop_mean': '76.8%', 'vdop_mean': '7.4%', 'road_width_mean': '2.1%', 'acc_z_mean': '1.5%', 'acc_z_kf_mean': '1.4%', 'gps_speed_osm_mean': '1.1%'}
# ----
# window: 141 knn: 5.883
# Top causes: {'Unstable steering': '8.9%', 'Tailgating': '3.7%'}
# Top features: {'acc_x_mean': '10.3%', 'gps_speed_osm_mean': '10.2%', 'speed_kmh_mean': '10.1%', 'gps_speed_mean': '10.1%', 'acc_z_kf_mean': '7.7%', 'acc_x_kf_mean': '7.5%'}
# ----
# window: 142 knn: 67.984
# Top causes: {'Overspeed': '45.6%', 'Harsh maneuvers': '21.3%'}
# Top features: {'pdop_mean': '98.9%', 'hdop_mean': '0.4%', 'vdop_mean': '0.3%', 'lane_state_mean': '0.0%', 'num_vehicles_mean': '0.0%', 'gps_speed_osm_mean': '0.0%'}
# ----
# window: 143 knn: 114.118
# Top causes: {'Harsh maneuvers': '60.8%', 'Unstable steering': '22.0%'}
# Top features: {'pdop_mean': '99.2%', 'vdop_mean': '0.4%', 'hdop_mean': '0.3%', 'x_lane_mean': '0.0%', 'yaw_mean': '0.0%', 'acc_x_mean': '0.0%'}
# ----
# window: 144 knn: 91.089
# Top causes: {'Harsh maneuvers': '39.6%', 'Unstable steering': '35.8%'}
# Top features: {'pdop_mean': '99.0%', 'vdop_mean': '0.6%', 'hdop_mean': '0.3%', 'vert_acc_mean': '0.0%', 'yaw_mean': '0.0%', 'x_lane_mean': '0.0%'}
# ----
# window: 145 knn: 45.289
# Top causes: {'Unstable steering': '42.6%', 'Overspeed': '27.0%'}
# Top features: {'pdop_mean': '96.7%', 'vdop_mean': '1.9%', 'hdop_mean': '0.9%', 'yaw_mean': '0.1%', 'course_mean': '0.1%', 'x_lane_mean': '0.1%'}
# ----
# window: 146 knn: 71.922
# Top causes: {'Unstable steering': '48.3%', 'Overspeed': '24.7%'}
# Top features: {'pdop_mean': '98.4%', 'vdop_mean': '0.8%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.1%', 'yaw_mean': '0.0%', 'course_mean': '0.0%'}
# ----
# window: 147 knn: 75.873
# Top causes: {'Harsh maneuvers': '32.8%', 'Overspeed': '29.8%'}
# Top features: {'pdop_mean': '98.2%', 'vdop_mean': '0.8%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.2%', 'lane_state_mean': '0.1%', 'yaw_mean': '0.0%'}
# ----
# window: 148 knn: 37.983
# Top causes: {'Harsh maneuvers': '64.4%', 'Overspeed': '20.7%'}
# Top features: {'pdop_mean': '93.5%', 'vdop_mean': '2.7%', 'hdop_mean': '1.3%', 'vert_acc_mean': '1.0%', 'x_lane_mean': '0.3%', 'lat_mean': '0.2%'}
# ----
# window: 149 knn: 2.955
# Top causes: {'Tailgating': '21.8%', 'Unstable steering': '9.1%'}
# Top features: {'lat_mean': '21.7%', 'lon_mean': '14.5%', 'vdop_mean': '12.2%', 'roll_mean': '8.1%', 'course_mean': '6.5%', 'alt_mean': '5.8%'}
# ----
# window: 150 knn: 2.891
# Top causes: {'Overspeed': '29.8%', 'Tailgating': '9.6%'}
# Top features: {'pitch_mean': '21.2%', 'osm_delay_mean': '17.2%', 'acc_z_mean': '10.1%', 'acc_z_kf_mean': '10.0%', 'x_lane_mean': '5.6%', 'course_mean': '5.2%'}
# ----
# window: 151 knn: 3.232
# Top causes: {'Overspeed': '6.8%', 'Unstable steering': '3.8%'}
# Top features: {'pitch_mean': '31.1%', 'osm_delay_mean': '20.6%', 'acc_z_mean': '5.7%', 'course_mean': '5.1%', 'acc_z_kf_mean': '5.0%', 'alt_mean': '4.6%'}
# ----
# window: 152 knn: 4.4
# Top causes: {'Unstable steering': '21.5%', 'Overspeed': '16.1%'}
# Top features: {'difcourse_mean': '13.6%', 'osm_delay_mean': '10.6%', 'acc_y_kf_mean': '9.6%', 'acc_y_mean': '9.5%', 'acc_x_mean': '9.3%', 'acc_x_kf_mean': '8.8%'}
# ----
# window: 153 knn: 4.483
# Top causes: {'Unstable steering': '22.0%', 'Tailgating': '7.4%'}
# Top features: {'acc_y_mean': '16.9%', 'acc_y_kf_mean': '16.9%', 'difcourse_mean': '13.3%', 'osm_delay_mean': '11.9%', 'acc_x_kf_mean': '5.3%', 'acc_x_mean': '4.5%'}
# ----
# window: 154 knn: 2.925
# Top causes: {'Harsh maneuvers': '28.9%', 'Overspeed': '2.4%'}
# Top features: {'num_vehicles_mean': '18.1%', 'osm_delay_mean': '15.3%', 'pitch_mean': '14.6%', 'yaw_mean': '11.2%', 'course_mean': '7.5%', 'lane_state_mean': '4.4%'}
# ----
# window: 155 knn: 3.22
# Top causes: {'Unstable steering': '24.3%', 'Overspeed': '4.2%'}
# Top features: {'num_vehicles_mean': '16.8%', 'pitch_mean': '12.5%', 'yaw_mean': '9.9%', 'course_mean': '8.7%', 'osm_delay_mean': '8.6%', 'acc_x_kf_mean': '7.1%'}
# ----
# window: 156 knn: 4.818
# Top causes: {'Tailgating': '28.6%', 'Unstable steering': '1.1%'}
# Top features: {'speed_kmh_mean': '8.9%', 'gps_speed_osm_mean': '8.9%', 'gps_speed_mean': '8.8%', 'ttc_front_mean': '7.7%', 'osm_delay_mean': '7.2%', 'dist_front_mean': '6.6%'}
# ----
# window: 157 knn: 5.048
# Top causes: {'Tailgating': '9.8%', 'Unstable steering': '2.6%'}
# Top features: {'gps_speed_mean': '16.7%', 'gps_speed_osm_mean': '16.7%', 'speed_kmh_mean': '16.6%', 'pitch_mean': '13.9%', 'roll_mean': '9.6%', 'lane_state_mean': '5.6%'}
# ----
# window: 158 knn: 5.212
# Top causes: {'Unstable steering': '4.6%', 'Tailgating': '2.3%'}
# Top features: {'acc_x_mean': '16.4%', 'acc_x_kf_mean': '15.8%', 'acc_y_kf_mean': '6.6%', 'course_mean': '5.3%', 'acc_y_mean': '4.6%', 'pitch_mean': '4.4%'}
# ----
# window: 159 knn: 15.397
# Top causes: {'Harsh maneuvers': '95.9%', 'Unstable steering': '3.7%'}
# Top features: {'acc_z_kf_mean': '32.6%', 'acc_z_mean': '32.6%', 'acc_x_kf_mean': '8.3%', 'acc_x_mean': '8.0%', 'roll_mean': '6.6%', 'difcourse_mean': '3.3%'}
# ----
# window: 160 knn: 13.637
# Top causes: {'Harsh maneuvers': '97.4%', 'Unstable steering': '2.2%'}
# Top features: {'acc_z_mean': '34.0%', 'acc_z_kf_mean': '33.8%', 'roll_mean': '6.1%', 'acc_y_kf_mean': '5.7%', 'acc_y_mean': '5.4%', 'acc_x_mean': '3.3%'}
# ----
# window: 161 knn: 5.08
# Top causes: {'Harsh maneuvers': '23.7%', 'Unstable steering': '16.4%'}
# Top features: {'vdop_mean': '19.2%', 'road_width_mean': '10.5%', 'pitch_mean': '10.4%', 'gps_speed_mean': '6.9%', 'speed_kmh_mean': '6.8%', 'gps_speed_osm_mean': '6.8%'}
# ----
# window: 162 knn: 4.438
# Top causes: {'Unstable steering': '21.2%', 'Harsh maneuvers': '14.0%'}
# Top features: {'vdop_mean': '13.4%', 'road_width_mean': '11.8%', 'osm_delay_mean': '10.4%', 'yaw_mean': '7.9%', 'course_mean': '7.7%', 'speed_kmh_mean': '7.6%'}
# ----
# window: 163 knn: 132.146
# Top causes: {'Harsh maneuvers': '100.0%', 'Overspeed': '0.0%'}
# Top features: {'pdop_mean': '28.7%', 'acc_y_kf_mean': '26.0%', 'acc_y_mean': '24.4%', 'acc_x_kf_mean': '8.7%', 'acc_x_mean': '8.1%', 'pitch_mean': '3.6%'}
# ----
# window: 164 knn: 117.341
# Top causes: {'Harsh maneuvers': '99.9%', 'Tailgating': '0.1%'}
# Top features: {'acc_y_kf_mean': '33.6%', 'acc_y_mean': '31.6%', 'acc_x_kf_mean': '13.5%', 'acc_x_mean': '12.7%', 'pitch_mean': '4.8%', 'acc_z_kf_mean': '1.7%'}
# ----
# window: 165 knn: 111.892
# Top causes: {'Harsh maneuvers': '99.5%', 'Tailgating': '0.5%'}
# Top features: {'acc_y_kf_mean': '33.2%', 'acc_y_mean': '31.2%', 'acc_x_kf_mean': '13.5%', 'acc_x_mean': '12.8%', 'pitch_mean': '5.0%', 'acc_z_mean': '1.6%'}
# ----
# window: 166 knn: 103.68
# Top causes: {'Harsh maneuvers': '99.5%', 'Tailgating': '0.4%'}
# Top features: {'acc_y_kf_mean': '35.7%', 'acc_y_mean': '33.6%', 'acc_x_kf_mean': '12.5%', 'acc_x_mean': '11.8%', 'pitch_mean': '5.4%', 'dist_front_mean': '0.2%'}
# ----
# window: 167 knn: 113.585
# Top causes: {'Harsh maneuvers': '99.6%', 'Tailgating': '0.3%'}
# Top features: {'pdop_mean': '34.9%', 'acc_y_kf_mean': '22.2%', 'acc_y_mean': '20.8%', 'acc_x_kf_mean': '8.6%', 'acc_x_mean': '8.0%', 'pitch_mean': '3.2%'}
# ----
# window: 168 knn: 80.712
# Top causes: {'Harsh maneuvers': '99.2%', 'Overspeed': '0.4%'}
# Top features: {'pdop_mean': '68.0%', 'acc_y_kf_mean': '11.2%', 'acc_y_mean': '10.5%', 'acc_x_kf_mean': '4.1%', 'acc_x_mean': '3.9%', 'pitch_mean': '1.0%'}
# ----
# window: 169 knn: 99.209
# Top causes: {'Harsh maneuvers': '77.2%', 'Overspeed': '10.6%'}
# Top features: {'pdop_mean': '97.8%', 'vdop_mean': '0.7%', 'hdop_mean': '0.5%', 'acc_y_kf_mean': '0.2%', 'acc_y_mean': '0.2%', 'acc_z_kf_mean': '0.1%'}
# ----
# window: 170 knn: 221.675
# Top causes: {'Harsh maneuvers': '45.9%', 'Overspeed': '31.3%'}
# Top features: {'pdop_mean': '99.6%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'vert_acc_mean': '0.0%', 'yaw_mean': '0.0%', 'osm_delay_mean': '0.0%'}
# ----
# window: 171 knn: 171.737
# Top causes: {'Harsh maneuvers': '39.8%', 'Overspeed': '24.4%'}
# Top features: {'pdop_mean': '99.4%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'vert_acc_mean': '0.0%', 'osm_delay_mean': '0.0%'}
# ----
# window: 172 knn: 171.814
# Top causes: {'Tailgating': '58.8%', 'Harsh maneuvers': '17.9%'}
# Top features: {'pdop_mean': '99.3%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'dist_front_mean': '0.0%', 'ttc_front_mean': '0.0%'}
# ----
# window: 173 knn: 244.651
# Top causes: {'Tailgating': '50.0%', 'Overspeed': '19.8%'}
# Top features: {'pdop_mean': '99.6%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.0%', 'dist_front_mean': '0.0%', 'ttc_front_mean': '0.0%'}
# ----

# %%
print(motor_phase3.columns.tolist())
# Out:
# ['index', 'label', 'knn_distance', 'severity_0_1', 'top_2']

# %%
print("\n=== MOTOR ===")
for idx, r in motor_phase3.iterrows():
    top_causes_list = [(cause_tuple[0], cause_tuple[1]) for cause_tuple in r["top_2"]]
    top_features_dict = motor_contrib_norm.loc[r["index"]].nlargest(6).to_dict()

    print("window:", r["index"], "knn:", round(float(r["knn_distance"]), 3))
    print("Top causes:", pct_dict(top_causes_list))
    print("Top features:", pct_dict(top_features_dict))
    print("----")

print("\n=== SECONDARY ===")
for idx, r in sec_phase3.iterrows():
    top_causes_list = [(cause_tuple[0], cause_tuple[1]) for cause_tuple in r["top_2"]]
    top_features_dict = sec_contrib_norm.loc[r["index"]].nlargest(6).to_dict()

    print("window:", r["index"], "knn:", round(float(r["knn_distance"]), 3))
    print("Top causes:", pct_dict(top_causes_list))
    print("Top features:", pct_dict(top_features_dict))
    print("----")
# Out:
# === MOTOR ===
# window: 0 knn: 6.963
# Top causes: {'Harsh maneuvers': '73.0%', 'Tailgating': '4.9%'}
# Top features: {'pdop_mean': '73.6%', 'vert_acc_mean': '3.5%', 'lat_mean': '3.4%', 'vdop_mean': '3.2%', 'lon_mean': '2.2%', 'pitch_mean': '2.0%'}
# ----
# window: 1 knn: 3.205
# Top causes: {'Tailgating': '13.5%', 'Unstable steering': '2.0%'}
# Top features: {'vert_acc_mean': '22.0%', 'dist_front_mean': '8.0%', 'speed_kmh_mean': '7.9%', 'gps_speed_osm_mean': '7.9%', 'gps_speed_mean': '7.9%', 'pitch_mean': '7.0%'}
# ----
# window: 2 knn: 2.701
# Top causes: {'Tailgating': '6.6%', 'Unstable steering': '1.6%'}
# Top features: {'vert_acc_mean': '28.7%', 'alt_mean': '15.7%', 'gps_speed_mean': '8.3%', 'gps_speed_osm_mean': '8.3%', 'roll_mean': '8.2%', 'speed_kmh_mean': '8.2%'}
# ----
# window: 3 knn: 3.151
# Top causes: {'Overspeed': '24.2%', 'Tailgating': '5.2%'}
# Top features: {'vert_acc_mean': '38.2%', 'alt_mean': '19.1%', 'gps_speed_mean': '4.6%', 'gps_speed_osm_mean': '4.6%', 'speed_kmh_mean': '4.5%', 'roll_mean': '4.3%'}
# ----
# window: 4 knn: 2.976
# Top causes: {'Tailgating': '23.5%', 'Overspeed': '11.9%'}
# Top features: {'vert_acc_mean': '22.4%', 'alt_mean': '14.2%', 'dist_front_mean': '7.2%', 'course_mean': '5.8%', 'acc_x_kf_mean': '5.4%', 'ttc_front_mean': '5.3%'}
# ----
# window: 5 knn: 6.031
# Top causes: {'Unstable steering': '8.5%', 'Overspeed': '3.6%'}
# Top features: {'acc_y_kf_mean': '19.8%', 'acc_y_mean': '19.8%', 'acc_z_kf_mean': '18.1%', 'acc_z_mean': '17.6%', 'difcourse_mean': '7.7%', 'lon_mean': '2.2%'}
# ----
# window: 6 knn: 5.889
# Top causes: {'Unstable steering': '11.8%', 'Overspeed': '3.7%'}
# Top features: {'acc_y_kf_mean': '19.4%', 'acc_y_mean': '19.3%', 'acc_z_kf_mean': '15.1%', 'acc_z_mean': '14.5%', 'difcourse_mean': '9.3%', 'roll_mean': '4.2%'}
# ----
# window: 7 knn: 3.829
# Top causes: {'Harsh maneuvers': '20.9%', 'Unstable steering': '18.1%'}
# Top features: {'osm_delay_mean': '12.9%', 'vert_acc_mean': '11.8%', 'yaw_mean': '11.6%', 'ttc_front_mean': '11.3%', 'num_vehicles_mean': '8.9%', 'dist_front_mean': '8.4%'}
# ----
# window: 8 knn: 3.093
# Top causes: {'Unstable steering': '23.4%', 'Tailgating': '7.6%'}
# Top features: {'yaw_mean': '14.9%', 'acc_x_mean': '11.4%', 'acc_x_kf_mean': '10.1%', 'osm_delay_mean': '8.6%', 'course_mean': '7.6%', 'vert_acc_mean': '6.9%'}
# ----
# window: 9 knn: 2.916
# Top causes: {'Tailgating': '20.9%', 'Overspeed': '7.7%'}
# Top features: {'yaw_mean': '17.2%', 'lat_mean': '10.8%', 'course_mean': '9.9%', 'roll_mean': '9.9%', 'lon_mean': '7.5%', 'acc_x_kf_mean': '5.5%'}
# ----
# window: 10 knn: 5.907
# Top causes: {'Tailgating': '17.8%', 'Harsh maneuvers': '13.9%'}
# Top features: {'road_width_mean': '34.1%', 'speed_kmh_mean': '10.6%', 'gps_speed_mean': '10.5%', 'gps_speed_osm_mean': '10.3%', 'lat_mean': '5.1%', 'num_vehicles_mean': '4.5%'}
# ----
# window: 11 knn: 6.174
# Top causes: {'Tailgating': '27.1%', 'Harsh maneuvers': '1.7%'}
# Top features: {'road_width_mean': '35.8%', 'gps_speed_mean': '11.9%', 'gps_speed_osm_mean': '11.9%', 'speed_kmh_mean': '11.9%', 'num_vehicles_mean': '6.0%', 'roll_mean': '5.7%'}
# ----
# window: 12 knn: 6.298
# Top causes: {'Harsh maneuvers': '26.0%', 'Tailgating': '18.4%'}
# Top features: {'road_width_mean': '27.4%', 'gps_speed_mean': '9.1%', 'gps_speed_osm_mean': '9.0%', 'speed_kmh_mean': '9.0%', 'pitch_mean': '7.5%', 'alt_mean': '7.4%'}
# ----
# window: 13 knn: 5.982
# Top causes: {'Harsh maneuvers': '25.7%', 'Tailgating': '20.8%'}
# Top features: {'road_width_mean': '22.3%', 'gps_speed_osm_mean': '9.7%', 'speed_kmh_mean': '9.7%', 'gps_speed_mean': '9.7%', 'alt_mean': '6.8%', 'vert_acc_mean': '6.8%'}
# ----
# window: 14 knn: 4.93
# Top causes: {'Tailgating': '8.2%', 'Unstable steering': '5.9%'}
# Top features: {'road_width_mean': '39.0%', 'vert_acc_mean': '8.7%', 'alt_mean': '8.2%', 'roll_mean': '5.6%', 'gps_speed_osm_mean': '4.8%', 'gps_speed_mean': '4.8%'}
# ----
# window: 15 knn: 7.251
# Top causes: {'Harsh maneuvers': '62.9%', 'Unstable steering': '25.9%'}
# Top features: {'road_width_mean': '30.1%', 'difcourse_mean': '13.3%', 'acc_z_kf_mean': '9.7%', 'acc_z_mean': '7.9%', 'acc_x_kf_mean': '6.7%', 'acc_x_mean': '6.4%'}
# ----
# window: 16 knn: 7.408
# Top causes: {'Harsh maneuvers': '65.6%', 'Unstable steering': '22.1%'}
# Top features: {'acc_z_kf_mean': '17.5%', 'acc_z_mean': '17.3%', 'difcourse_mean': '15.3%', 'roll_mean': '7.2%', 'road_width_mean': '7.1%', 'acc_x_kf_mean': '6.2%'}
# ----
# window: 17 knn: 5.172
# Top causes: {'Overspeed': '26.3%', 'Tailgating': '17.5%'}
# Top features: {'vert_acc_mean': '21.6%', 'roll_mean': '10.8%', 'yaw_mean': '7.5%', 'lane_state_mean': '6.9%', 'speed_kmh_mean': '5.5%', 'gps_speed_mean': '5.4%'}
# ----
# window: 18 knn: 5.869
# Top causes: {'Tailgating': '17.9%', 'Unstable steering': '4.0%'}
# Top features: {'vert_acc_mean': '14.0%', 'gps_speed_osm_mean': '12.6%', 'speed_kmh_mean': '12.6%', 'gps_speed_mean': '12.6%', 'ttc_front_mean': '5.9%', 'dist_front_mean': '5.8%'}
# ----
# window: 19 knn: 5.723
# Top causes: {'Tailgating': '13.0%', 'Unstable steering': '3.8%'}
# Top features: {'vert_acc_mean': '21.9%', 'gps_speed_osm_mean': '13.1%', 'gps_speed_mean': '13.1%', 'speed_kmh_mean': '13.0%', 'lane_state_mean': '4.4%', 'num_vehicles_mean': '4.0%'}
# ----
# window: 20 knn: 49.05
# Top causes: {'Harsh maneuvers': '69.3%', 'Tailgating': '29.8%'}
# Top features: {'pdop_mean': '96.9%', 'vdop_mean': '0.9%', 'hdop_mean': '0.6%', 'vert_acc_mean': '0.5%', 'road_width_mean': '0.2%', 'osm_delay_mean': '0.1%'}
# ----
# window: 21 knn: 117.954
# Top causes: {'Harsh maneuvers': '92.1%', 'Tailgating': '5.3%'}
# Top features: {'pdop_mean': '99.2%', 'vdop_mean': '0.3%', 'hdop_mean': '0.2%', 'vert_acc_mean': '0.2%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.0%'}
# ----
# window: 22 knn: 87.276
# Top causes: {'Harsh maneuvers': '89.2%', 'Tailgating': '6.6%'}
# Top features: {'pdop_mean': '98.8%', 'vdop_mean': '0.5%', 'vert_acc_mean': '0.2%', 'hdop_mean': '0.2%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.1%'}
# ----
# window: 23 knn: 7.955
# Top causes: {'Harsh maneuvers': '72.1%', 'Tailgating': '12.6%'}
# Top features: {'vdop_mean': '15.7%', 'vert_acc_mean': '13.5%', 'acc_z_mean': '10.7%', 'acc_z_kf_mean': '10.1%', 'roll_mean': '6.8%', 'difcourse_mean': '5.6%'}
# ----
# window: 24 knn: 7.355
# Top causes: {'Harsh maneuvers': '77.9%', 'Unstable steering': '11.1%'}
# Top features: {'acc_z_mean': '12.1%', 'roll_mean': '11.6%', 'acc_z_kf_mean': '11.4%', 'vdop_mean': '11.2%', 'vert_acc_mean': '10.4%', 'difcourse_mean': '6.5%'}
# ----
# window: 25 knn: 60.438
# Top causes: {'Harsh maneuvers': '66.6%', 'Unstable steering': '21.9%'}
# Top features: {'pdop_mean': '98.1%', 'vdop_mean': '0.7%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.2%', 'road_width_mean': '0.1%', 'vert_acc_mean': '0.1%'}
# ----
# window: 26 knn: 144.838
# Top causes: {'Harsh maneuvers': '58.1%', 'Unstable steering': '21.4%'}
# Top features: {'pdop_mean': '99.4%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.0%', 'vert_acc_mean': '0.0%'}
# ----
# window: 27 knn: 83.477
# Top causes: {'Harsh maneuvers': '82.1%', 'Tailgating': '9.1%'}
# Top features: {'pdop_mean': '98.6%', 'vdop_mean': '0.6%', 'vert_acc_mean': '0.2%', 'hdop_mean': '0.2%', 'x_lane_mean': '0.1%', 'road_width_mean': '0.1%'}
# ----
# window: 28 knn: 56.718
# Top causes: {'Harsh maneuvers': '66.7%', 'Tailgating': '27.4%'}
# Top features: {'pdop_mean': '97.2%', 'vdop_mean': '0.9%', 'hdop_mean': '0.6%', 'vert_acc_mean': '0.3%', 'x_lane_mean': '0.3%', 'road_width_mean': '0.2%'}
# ----
# window: 29 knn: 3.928
# Top causes: {'Tailgating': '26.8%', 'Unstable steering': '2.5%'}
# Top features: {'alt_mean': '19.6%', 'vdop_mean': '16.3%', 'lat_mean': '12.0%', 'hdop_mean': '7.7%', 'lon_mean': '7.1%', 'roll_mean': '6.5%'}
# ----
# window: 30 knn: 2.759
# Top causes: {'Harsh maneuvers': '28.3%', 'Unstable steering': '24.0%'}
# Top features: {'alt_mean': '28.0%', 'lat_mean': '13.6%', 'road_width_mean': '11.2%', 'lon_mean': '8.7%', 'difcourse_mean': '4.2%', 'vert_acc_mean': '3.9%'}
# ----
# window: 31 knn: 2.268
# Top causes: {'Tailgating': '22.6%', 'Harsh maneuvers': '17.9%'}
# Top features: {'road_width_mean': '22.1%', 'vdop_mean': '10.2%', 'alt_mean': '10.2%', 'x_lane_mean': '7.3%', 'lon_mean': '5.4%', 'course_mean': '4.8%'}
# ----
# window: 32 knn: 2.274
# Top causes: {'Unstable steering': '19.6%', 'Harsh maneuvers': '16.1%'}
# Top features: {'road_width_mean': '35.0%', 'vdop_mean': '12.9%', 'course_mean': '7.9%', 'x_lane_mean': '6.0%', 'num_vehicles_mean': '3.4%', 'difcourse_mean': '3.0%'}
# ----
# window: 33 knn: 2.419
# Top causes: {'Unstable steering': '23.1%', 'Harsh maneuvers': '21.0%'}
# Top features: {'road_width_mean': '35.8%', 'course_mean': '12.1%', 'ttc_front_mean': '5.7%', 'x_lane_mean': '5.5%', 'difcourse_mean': '4.9%', 'num_vehicles_mean': '4.6%'}
# ----
# window: 34 knn: 3.104
# Top causes: {'Tailgating': '15.5%', 'Unstable steering': '7.7%'}
# Top features: {'road_width_mean': '16.9%', 'course_mean': '11.8%', 'pitch_mean': '7.2%', 'osm_delay_mean': '7.1%', 'lon_mean': '7.0%', 'lat_mean': '6.8%'}
# ----
# window: 35 knn: 4.363
# Top causes: {'Harsh maneuvers': '25.1%', 'Unstable steering': '14.2%'}
# Top features: {'gps_speed_osm_mean': '9.1%', 'gps_speed_mean': '9.0%', 'speed_kmh_mean': '9.0%', 'difcourse_mean': '8.6%', 'pitch_mean': '6.2%', 'lon_mean': '5.7%'}
# ----
# window: 36 knn: 4.153
# Top causes: {'Overspeed': '25.6%', 'Unstable steering': '16.6%'}
# Top features: {'road_width_mean': '8.9%', 'pitch_mean': '8.8%', 'roll_mean': '7.6%', 'hdop_mean': '5.5%', 'acc_z_kf_mean': '5.5%', 'lon_mean': '5.4%'}
# ----
# window: 37 knn: 2.818
# Top causes: {'Overspeed': '17.4%', 'Tailgating': '9.4%'}
# Top features: {'road_width_mean': '32.9%', 'yaw_mean': '16.3%', 'vert_acc_mean': '7.6%', 'course_mean': '6.7%', 'lat_mean': '4.5%', 'num_vehicles_mean': '3.7%'}
# ----
# window: 38 knn: 2.797
# Top causes: {'Harsh maneuvers': '14.6%', 'Tailgating': '6.4%'}
# Top features: {'road_width_mean': '24.2%', 'yaw_mean': '18.2%', 'course_mean': '10.4%', 'speed_kmh_mean': '6.6%', 'gps_speed_osm_mean': '6.5%', 'gps_speed_mean': '6.4%'}
# ----
# window: 39 knn: 3.274
# Top causes: {'Harsh maneuvers': '30.0%', 'Overspeed': '28.9%'}
# Top features: {'road_width_mean': '10.4%', 'yaw_mean': '10.3%', 'hdop_mean': '9.9%', 'course_mean': '7.0%', 'acc_x_kf_mean': '5.0%', 'acc_x_mean': '4.8%'}
# ----
# window: 40 knn: 202.324
# Top causes: {'Tailgating': '50.7%', 'Harsh maneuvers': '26.0%'}
# Top features: {'pdop_mean': '99.6%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'alt_mean': '0.0%', 'lat_mean': '0.0%', 'road_width_mean': '0.0%'}
# ----
# window: 41 knn: 179.21
# Top causes: {'Harsh maneuvers': '62.7%', 'Overspeed': '29.9%'}
# Top features: {'pdop_mean': '99.7%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'alt_mean': '0.0%', 'acc_z_kf_mean': '0.0%', 'acc_z_mean': '0.0%'}
# ----
# window: 42 knn: 56.324
# Top causes: {'Harsh maneuvers': '48.2%', 'Overspeed': '41.6%'}
# Top features: {'pdop_mean': '99.1%', 'vdop_mean': '0.3%', 'road_width_mean': '0.2%', 'acc_z_kf_mean': '0.1%', 'acc_z_mean': '0.1%', 'gps_speed_osm_mean': '0.0%'}
# ----
# window: 43 knn: 4.039
# Top causes: {'Tailgating': '10.8%', 'Unstable steering': '3.8%'}
# Top features: {'road_width_mean': '23.7%', 'gps_speed_mean': '6.8%', 'speed_kmh_mean': '6.7%', 'gps_speed_osm_mean': '6.7%', 'vert_acc_mean': '6.4%', 'course_mean': '5.4%'}
# ----
# window: 44 knn: 4.05
# Top causes: {'Tailgating': '13.4%', 'Overspeed': '2.5%'}
# Top features: {'road_width_mean': '19.9%', 'acc_x_kf_mean': '13.4%', 'acc_x_mean': '13.1%', 'vert_acc_mean': '8.2%', 'course_mean': '8.0%', 'lon_mean': '6.4%'}
# ----
# window: 45 knn: 8.221
# Top causes: {'Harsh maneuvers': '63.0%', 'Unstable steering': '24.3%'}
# Top features: {'acc_x_kf_mean': '21.2%', 'acc_x_mean': '20.3%', 'difcourse_mean': '18.9%', 'pitch_mean': '8.9%', 'acc_z_mean': '3.2%', 'acc_z_kf_mean': '3.2%'}
# ----
# window: 46 knn: 8.058
# Top causes: {'Harsh maneuvers': '55.2%', 'Unstable steering': '37.7%'}
# Top features: {'difcourse_mean': '22.9%', 'acc_x_kf_mean': '14.5%', 'acc_x_mean': '13.9%', 'roll_mean': '12.6%', 'pitch_mean': '8.5%', 'vdop_mean': '3.5%'}
# ----
# window: 47 knn: 4.264
# Top causes: {'Unstable steering': '18.8%', 'Tailgating': '3.6%'}
# Top features: {'road_width_mean': '12.2%', 'yaw_mean': '11.5%', 'speed_kmh_mean': '9.7%', 'gps_speed_osm_mean': '9.6%', 'gps_speed_mean': '9.4%', 'acc_z_kf_mean': '8.4%'}
# ----
# window: 48 knn: 4.749
# Top causes: {'Harsh maneuvers': '26.8%', 'Unstable steering': '19.4%'}
# Top features: {'osm_delay_mean': '20.2%', 'road_width_mean': '15.0%', 'yaw_mean': '8.3%', 'gps_speed_mean': '7.8%', 'gps_speed_osm_mean': '7.7%', 'speed_kmh_mean': '7.6%'}
# ----
# window: 49 knn: 25.972
# Top causes: {'Harsh maneuvers': '62.5%', 'Overspeed': '20.1%'}
# Top features: {'pdop_mean': '94.0%', 'hdop_mean': '2.2%', 'vdop_mean': '0.8%', 'alt_mean': '0.6%', 'lat_mean': '0.5%', 'roll_mean': '0.5%'}
# ----
# window: 50 knn: 110.176
# Top causes: {'Harsh maneuvers': '58.8%', 'Unstable steering': '16.7%'}
# Top features: {'pdop_mean': '99.2%', 'vdop_mean': '0.4%', 'hdop_mean': '0.3%', 'alt_mean': '0.0%', 'lat_mean': '0.0%', 'roll_mean': '0.0%'}
# ----
# window: 51 knn: 83.324
# Top causes: {'Harsh maneuvers': '43.1%', 'Tailgating': '35.5%'}
# Top features: {'pdop_mean': '99.0%', 'vdop_mean': '0.5%', 'hdop_mean': '0.3%', 'road_width_mean': '0.0%', 'vert_acc_mean': '0.0%', 'num_vehicles_mean': '0.0%'}
# ----
# window: 52 knn: 6.66
# Top causes: {'Unstable steering': '11.4%', 'Overspeed': '11.3%'}
# Top features: {'hdop_mean': '42.4%', 'vdop_mean': '36.7%', 'road_width_mean': '4.0%', 'vert_acc_mean': '2.8%', 'pitch_mean': '2.7%', 'num_vehicles_mean': '2.0%'}
# ----
# window: 53 knn: 37.713
# Top causes: {'Harsh maneuvers': '57.6%', 'Tailgating': '25.0%'}
# Top features: {'pdop_mean': '95.1%', 'vdop_mean': '2.4%', 'hdop_mean': '1.8%', 'road_width_mean': '0.1%', 'vert_acc_mean': '0.1%', 'x_lane_mean': '0.1%'}
# ----
# window: 54 knn: 56.863
# Top causes: {'Harsh maneuvers': '62.3%', 'Tailgating': '14.2%'}
# Top features: {'pdop_mean': '96.8%', 'vdop_mean': '1.4%', 'hdop_mean': '1.2%', 'x_lane_mean': '0.2%', 'road_width_mean': '0.1%', 'vert_acc_mean': '0.0%'}
# ----
# window: 55 knn: 71.913
# Top causes: {'Harsh maneuvers': '39.5%', 'Tailgating': '29.2%'}
# Top features: {'pdop_mean': '98.6%', 'vdop_mean': '0.8%', 'hdop_mean': '0.3%', 'dist_front_mean': '0.0%', 'vert_acc_mean': '0.0%', 'course_mean': '0.0%'}
# ----
# window: 56 knn: 52.68
# Top causes: {'Harsh maneuvers': '40.5%', 'Overspeed': '28.5%'}
# Top features: {'pdop_mean': '97.8%', 'vdop_mean': '0.4%', 'difcourse_mean': '0.3%', 'acc_x_mean': '0.2%', 'pitch_mean': '0.2%', 'acc_x_kf_mean': '0.2%'}
# ----
# window: 57 knn: 5.076
# Top causes: {'Unstable steering': '25.4%', 'Overspeed': '15.8%'}
# Top features: {'roll_mean': '12.8%', 'difcourse_mean': '10.1%', 'hdop_mean': '8.3%', 'acc_x_mean': '7.1%', 'pitch_mean': '7.0%', 'acc_x_kf_mean': '6.3%'}
# ----
# window: 58 knn: 26.398
# Top causes: {'Harsh maneuvers': '36.5%', 'Unstable steering': '30.0%'}
# Top features: {'pdop_mean': '92.1%', 'hdop_mean': '4.3%', 'vdop_mean': '1.7%', 'road_width_mean': '0.3%', 'x_lane_mean': '0.3%', 'yaw_mean': '0.2%'}
# ----
# window: 59 knn: 129.432
# Top causes: {'Harsh maneuvers': '32.0%', 'Overspeed': '28.5%'}
# Top features: {'pdop_mean': '99.3%', 'vdop_mean': '0.3%', 'hdop_mean': '0.3%', 'road_width_mean': '0.0%', 'yaw_mean': '0.0%', 'course_mean': '0.0%'}
# ----
# window: 60 knn: 186.927
# Top causes: {'Harsh maneuvers': '59.7%', 'Tailgating': '14.7%'}
# Top features: {'pdop_mean': '99.7%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'acc_z_mean': '0.0%', 'road_width_mean': '0.0%', 'acc_z_kf_mean': '0.0%'}
# ----
# window: 61 knn: 9.082
# Top causes: {'Overspeed': '89.6%', 'Tailgating': '8.1%'}
# Top features: {'lat_osm_mean': '20.9%', 'lon_osm_mean': '20.7%', 'speed_rel_mean': '9.0%', 'max_speed_mean': '8.2%', 'speed_ratio_mean': '8.1%', 'num_lanes_mean': '7.2%'}
# ----
# window: 62 knn: 6.828
# Top causes: {'Overspeed': '79.0%', 'Tailgating': '16.3%'}
# Top features: {'speed_ratio_mean': '15.0%', 'speed_rel_mean': '13.4%', 'max_speed_mean': '12.3%', 'num_lanes_mean': '10.7%', 'vdop_mean': '8.1%', 'lon_osm_mean': '8.0%'}
# ----
# window: 63 knn: 5.865
# Top causes: {'Tailgating': '25.3%', 'Harsh maneuvers': '4.3%'}
# Top features: {'speed_ratio_mean': '17.7%', 'speed_rel_mean': '15.5%', 'max_speed_mean': '13.6%', 'num_lanes_mean': '11.7%', 'ttc_front_mean': '6.8%', 'num_vehicles_mean': '5.9%'}
# ----
# window: 64 knn: 3.619
# Top causes: {'Harsh maneuvers': '8.6%', 'Unstable steering': '2.7%'}
# Top features: {'ttc_front_mean': '13.8%', 'dist_front_mean': '11.3%', 'num_vehicles_mean': '9.1%', 'speed_ratio_mean': '7.1%', 'speed_rel_mean': '6.5%', 'gps_speed_osm_mean': '5.5%'}
# ----
# window: 65 knn: 2.911
# Top causes: {'Harsh maneuvers': '14.8%', 'Unstable steering': '5.1%'}
# Top features: {'alt_mean': '12.8%', 'ttc_front_mean': '9.3%', 'num_vehicles_mean': '9.2%', 'lane_state_mean': '9.1%', 'dist_front_mean': '8.1%', 'x_lane_mean': '6.0%'}
# ----
# window: 66 knn: 2.713
# Top causes: {'Unstable steering': '11.8%', 'Tailgating': '11.2%'}
# Top features: {'alt_mean': '15.2%', 'course_mean': '8.2%', 'gps_speed_mean': '7.6%', 'gps_speed_osm_mean': '7.6%', 'speed_kmh_mean': '7.6%', 'acc_y_kf_mean': '5.0%'}
# ----
# window: 67 knn: 2.898
# Top causes: {'Harsh maneuvers': '27.3%', 'Unstable steering': '19.6%'}
# Top features: {'road_width_mean': '15.2%', 'course_mean': '11.0%', 'roll_mean': '7.3%', 'num_vehicles_mean': '7.3%', 'lat_mean': '6.2%', 'alt_mean': '5.6%'}
# ----
# window: 68 knn: 3.48
# Top causes: {'Unstable steering': '8.5%', 'Tailgating': '2.3%'}
# Top features: {'road_width_mean': '19.2%', 'roll_mean': '15.7%', 'lon_mean': '8.8%', 'course_mean': '8.1%', 'speed_kmh_mean': '6.6%', 'gps_speed_osm_mean': '6.5%'}
# ----
# window: 69 knn: 4.746
# Top causes: {'Unstable steering': '10.5%', 'Tailgating': '7.5%'}
# Top features: {'acc_x_kf_mean': '13.3%', 'acc_x_mean': '13.0%', 'active_mean': '11.5%', 'phi_mean': '8.6%', 'pitch_mean': '6.7%', 'difcourse_mean': '6.4%'}
# ----
# window: 70 knn: 4.277
# Top causes: {'Unstable steering': '15.0%', 'Tailgating': '2.9%'}
# Top features: {'active_mean': '15.0%', 'phi_mean': '14.9%', 'acc_x_mean': '8.8%', 'hdop_mean': '7.8%', 'acc_x_kf_mean': '7.3%', 'pitch_mean': '5.8%'}
# ----
# window: 71 knn: 2.69
# Top causes: {'Harsh maneuvers': '28.7%', 'Tailgating': '20.8%'}
# Top features: {'road_width_mean': '19.3%', 'yaw_mean': '12.6%', 'lon_mean': '8.5%', 'x_lane_mean': '6.6%', 'lat_mean': '6.6%', 'num_vehicles_mean': '6.6%'}
# ----
# window: 72 knn: 2.39
# Top causes: {'Harsh maneuvers': '17.1%', 'Tailgating': '3.4%'}
# Top features: {'road_width_mean': '15.6%', 'yaw_mean': '11.0%', 'x_lane_mean': '10.5%', 'gps_speed_osm_mean': '8.0%', 'speed_kmh_mean': '7.9%', 'gps_speed_mean': '7.9%'}
# ----
# window: 73 knn: 2.259
# Top causes: {'Unstable steering': '29.8%', 'Tailgating': '16.6%'}
# Top features: {'road_width_mean': '14.2%', 'yaw_mean': '13.2%', 'course_mean': '9.5%', 'roll_mean': '8.0%', 'gps_speed_osm_mean': '5.2%', 'speed_kmh_mean': '5.2%'}
# ----
# window: 74 knn: 2.36
# Top causes: {'Overspeed': '25.2%', 'Harsh maneuvers': '23.0%'}
# Top features: {'yaw_mean': '15.3%', 'course_mean': '14.8%', 'road_width_mean': '14.4%', 'vdop_mean': '10.6%', 'dist_front_mean': '6.6%', 'acc_z_mean': '4.0%'}
# ----
# window: 75 knn: 2.503
# Top causes: {'Harsh maneuvers': '18.1%', 'Tailgating': '6.0%'}
# Top features: {'course_mean': '13.8%', 'road_width_mean': '12.4%', 'alt_mean': '11.9%', 'yaw_mean': '11.8%', 'lane_state_mean': '6.7%', 'lon_mean': '4.5%'}
# ----
# window: 76 knn: 3.482
# Top causes: {'Harsh maneuvers': '7.0%', 'Unstable steering': '20.1%'}
# Top features: {'hdop_mean': '17.8%', 'alt_mean': '13.6%', 'x_lane_mean': '12.7%', 'lat_mean': '6.4%', 'num_vehicles_mean': '5.9%', 'road_width_mean': '5.2%'}
# ----
# window: 77 knn: 91.677
# Top causes: {'Harsh maneuvers': '99.8%', 'Overspeed': '0.1%'}
# Top features: {'acc_y_kf_mean': '39.5%', 'acc_y_mean': '37.2%', 'acc_x_kf_mean': '7.7%', 'acc_x_mean': '7.2%', 'pitch_mean': '4.8%', 'acc_z_kf_mean': '1.5%'}
# ----
# window: 78 knn: 90.649
# Top causes: {'Harsh maneuvers': '99.8%', 'Overspeed': '0.2%'}
# Top features: {'acc_y_kf_mean': '35.5%', 'acc_y_mean': '33.3%', 'acc_x_kf_mean': '8.6%', 'acc_x_mean': '8.0%', 'pitch_mean': '4.9%', 'acc_z_kf_mean': '4.6%'}
# ----
# window: 79 knn: 84.415
# Top causes: {'Harsh maneuvers': '99.9%', 'Overspeed': '0.1%'}
# Top features: {'acc_y_kf_mean': '31.4%', 'acc_y_mean': '29.5%', 'acc_z_kf_mean': '8.9%', 'acc_z_mean': '8.8%', 'acc_x_kf_mean': '8.0%', 'acc_x_mean': '7.6%'}
# ----
# window: 80 knn: 54.441
# Top causes: {'Harsh maneuvers': '99.7%', 'Overspeed': '0.2%'}
# Top features: {'acc_y_kf_mean': '31.5%', 'acc_y_mean': '29.7%', 'acc_z_kf_mean': '10.8%', 'acc_z_mean': '10.8%', 'acc_x_kf_mean': '5.5%', 'acc_x_mean': '5.3%'}
# ----
# window: 81 knn: 13.458
# Top causes: {'Harsh maneuvers': '98.5%', 'Tailgating': '1.0%'}
# Top features: {'acc_y_kf_mean': '32.6%', 'acc_y_mean': '31.0%', 'acc_z_mean': '9.6%', 'acc_z_kf_mean': '9.4%', 'acc_x_mean': '4.3%', 'pitch_mean': '4.3%'}
# ----
# window: 82 knn: 6.506
# Top causes: {'Overspeed': '14.6%', 'Unstable steering': '7.8%'}
# Top features: {'acc_x_mean': '24.2%', 'acc_x_kf_mean': '23.4%', 'road_width_mean': '5.9%', 'difcourse_mean': '5.5%', 'pitch_mean': '4.2%', 'lon_mean': '4.1%'}
# ----
# window: 83 knn: 7.034
# Top causes: {'Harsh maneuvers': '71.3%', 'Overspeed': '16.0%'}
# Top features: {'acc_x_kf_mean': '16.0%', 'acc_x_mean': '14.5%', 'acc_z_mean': '10.3%', 'acc_z_kf_mean': '9.4%', 'road_width_mean': '7.8%', 'difcourse_mean': '7.2%'}
# ----
# window: 84 knn: 4.238
# Top causes: {'Harsh maneuvers': '17.7%', 'Overspeed': '9.1%'}
# Top features: {'road_width_mean': '25.7%', 'yaw_mean': '19.5%', 'lon_mean': '9.5%', 'ttc_front_mean': '8.7%', 'lat_mean': '5.2%', 'course_mean': '5.1%'}
# ----
# window: 85 knn: 3.563
# Top causes: {'Overspeed': '19.9%', 'Harsh maneuvers': '15.2%'}
# Top features: {'yaw_mean': '23.8%', 'road_width_mean': '20.9%', 'roll_mean': '5.8%', 'lat_mean': '5.4%', 'course_mean': '5.4%', 'lon_mean': '4.9%'}
# ----
# window: 86 knn: 3.816
# Top causes: {'Unstable steering': '24.6%', 'Harsh maneuvers': '16.2%'}
# Top features: {'yaw_mean': '17.1%', 'gps_speed_osm_mean': '12.7%', 'gps_speed_mean': '12.6%', 'speed_kmh_mean': '12.6%', 'road_width_mean': '11.6%', 'course_mean': '4.8%'}
# ----
# window: 87 knn: 4.951
# Top causes: {'Unstable steering': '12.2%', 'Harsh maneuvers': '7.9%'}
# Top features: {'gps_speed_mean': '19.2%', 'speed_kmh_mean': '19.2%', 'gps_speed_osm_mean': '19.1%', 'yaw_mean': '9.6%', 'road_width_mean': '6.3%', 'course_mean': '4.1%'}
# ----
# window: 88 knn: 4.706
# Top causes: {'Unstable steering': '13.7%', 'Harsh maneuvers': '10.7%'}
# Top features: {'speed_kmh_mean': '14.6%', 'gps_speed_osm_mean': '14.6%', 'gps_speed_mean': '14.5%', 'roll_mean': '10.2%', 'yaw_mean': '9.0%', 'road_width_mean': '6.6%'}
# ----
# window: 89 knn: 4.137
# Top causes: {'Tailgating': '1.5%', 'Harsh maneuvers': '24.9%'}
# Top features: {'lane_state_mean': '19.7%', 'yaw_mean': '14.5%', 'lat_mean': '7.7%', 'course_mean': '7.4%', 'vdop_mean': '5.8%', 'vert_acc_mean': '5.4%'}
# ----
# window: 90 knn: 10.029
# Top causes: {'Harsh maneuvers': '62.6%', 'Overspeed': '16.3%'}
# Top features: {'pdop_mean': '41.1%', 'hdop_mean': '23.0%', 'vdop_mean': '14.0%', 'x_lane_mean': '8.7%', 'alt_mean': '3.7%', 'lat_mean': '2.8%'}
# ----
# window: 91 knn: 87.295
# Top causes: {'Harsh maneuvers': '63.0%', 'Unstable steering': '14.1%'}
# Top features: {'pdop_mean': '98.5%', 'vdop_mean': '0.6%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.2%', 'lane_state_mean': '0.1%', 'alt_mean': '0.0%'}
# ----
# window: 92 knn: 117.884
# Top causes: {'Harsh maneuvers': '64.9%', 'Unstable steering': '15.9%'}
# Top features: {'pdop_mean': '99.3%', 'vdop_mean': '0.4%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'lane_state_mean': '0.1%', 'vert_acc_mean': '0.0%'}
# ----
# window: 93 knn: 37.899
# Top causes: {'Harsh maneuvers': '48.9%', 'Tailgating': '28.5%'}
# Top features: {'pdop_mean': '94.6%', 'vdop_mean': '2.5%', 'hdop_mean': '1.1%', 'lane_state_mean': '0.7%', 'x_lane_mean': '0.5%', 'pitch_mean': '0.1%'}
# ----
# window: 94 knn: 9.29
# Top causes: {'Tailgating': '56.1%', 'Harsh maneuvers': '24.9%'}
# Top features: {'vdop_mean': '35.4%', 'lane_state_mean': '22.5%', 'hdop_mean': '20.6%', 'x_lane_mean': '9.4%', 'num_vehicles_mean': '1.9%', 'ttc_front_mean': '1.3%'}
# ----
# window: 95 knn: 8.308
# Top causes: {'Harsh maneuvers': '32.6%', 'Overspeed': '31.6%'}
# Top features: {'vdop_mean': '38.3%', 'hdop_mean': '22.3%', 'lane_state_mean': '15.7%', 'x_lane_mean': '11.3%', 'pitch_mean': '3.4%', 'course_mean': '1.7%'}
# ----
# window: 96 knn: 6.838
# Top causes: {'Overspeed': '58.0%', 'Harsh maneuvers': '16.2%'}
# Top features: {'vdop_mean': '46.0%', 'x_lane_mean': '13.8%', 'hdop_mean': '11.1%', 'gps_speed_osm_mean': '3.3%', 'speed_kmh_mean': '3.3%', 'gps_speed_mean': '3.3%'}
# ----
# window: 97 knn: 6.528
# Top causes: {'Harsh maneuvers': '17.4%', 'Tailgating': '7.3%'}
# Top features: {'vdop_mean': '24.8%', 'gps_speed_osm_mean': '11.0%', 'speed_kmh_mean': '11.0%', 'gps_speed_mean': '11.0%', 'x_lane_mean': '6.3%', 'lane_state_mean': '4.3%'}
# ----
# window: 98 knn: 7.539
# Top causes: {'Harsh maneuvers': '41.4%', 'Overspeed': '31.4%'}
# Top features: {'difcourse_mean': '13.0%', 'acc_x_mean': '11.2%', 'acc_x_kf_mean': '10.9%', 'gps_speed_osm_mean': '7.8%', 'speed_kmh_mean': '7.8%', 'gps_speed_mean': '7.7%'}
# ----
# window: 99 knn: 6.819
# Top causes: {'Unstable steering': '20.2%', 'Tailgating': '0.3%'}
# Top features: {'vdop_mean': '18.4%', 'x_lane_mean': '11.5%', 'hdop_mean': '9.0%', 'acc_x_mean': '8.0%', 'acc_x_kf_mean': '7.7%', 'difcourse_mean': '7.7%'}
# ----
# window: 100 knn: 6.83
# Top causes: {'Overspeed': '13.9%', 'Harsh maneuvers': '12.1%'}
# Top features: {'vdop_mean': '36.3%', 'lane_state_mean': '14.6%', 'hdop_mean': '14.0%', 'x_lane_mean': '13.1%', 'yaw_mean': '4.1%', 'pitch_mean': '3.3%'}
# ----
# window: 101 knn: 4.886
# Top causes: {'Overspeed': '10.5%', 'Harsh maneuvers': '6.7%'}
# Top features: {'vdop_mean': '23.8%', 'lane_state_mean': '15.9%', 'x_lane_mean': '15.5%', 'hdop_mean': '10.4%', 'yaw_mean': '8.0%', 'course_mean': '4.1%'}
# ----
# window: 102 knn: 9.004
# Top causes: {'Unstable steering': '54.8%', 'Tailgating': '20.8%'}
# Top features: {'pdop_mean': '60.3%', 'vdop_mean': '14.6%', 'hdop_mean': '11.5%', 'x_lane_mean': '5.6%', 'yaw_mean': '2.2%', 'course_mean': '1.3%'}
# ----
# window: 103 knn: 9.423
# Top causes: {'Harsh maneuvers': '40.5%', 'Unstable steering': '37.6%'}
# Top features: {'pdop_mean': '50.2%', 'vdop_mean': '21.6%', 'hdop_mean': '14.0%', 'x_lane_mean': '3.7%', 'yaw_mean': '1.8%', 'course_mean': '1.6%'}
# ----
# window: 104 knn: 5.286
# Top causes: {'Tailgating': '18.9%', 'Overspeed': '13.3%'}
# Top features: {'vdop_mean': '32.0%', 'lane_state_mean': '15.4%', 'hdop_mean': '13.7%', 'x_lane_mean': '8.4%', 'course_mean': '5.3%', 'yaw_mean': '5.0%'}
# ----
# window: 105 knn: 6.189
# Top causes: {'Overspeed': '7.3%', 'Tailgating': '0.7%'}
# Top features: {'lane_state_mean': '37.9%', 'vdop_mean': '22.9%', 'x_lane_mean': '6.0%', 'hdop_mean': '5.6%', 'yaw_mean': '3.9%', 'course_mean': '3.8%'}
# ----
# window: 106 knn: 5.896
# Top causes: {'Overspeed': '18.7%', 'Tailgating': '3.0%'}
# Top features: {'vdop_mean': '24.0%', 'hdop_mean': '15.2%', 'x_lane_mean': '12.3%', 'lane_state_mean': '11.9%', 'lat_mean': '5.6%', 'alt_mean': '5.6%'}
# ----
# window: 107 knn: 3.493
# Top causes: {'Overspeed': '10.7%', 'Unstable steering': '5.1%'}
# Top features: {'lat_mean': '15.5%', 'alt_mean': '13.6%', 'roll_mean': '12.6%', 'road_width_mean': '12.2%', 'lon_mean': '9.5%', 'acc_x_mean': '4.2%'}
# ----
# window: 108 knn: 2.974
# Top causes: {'Tailgating': '25.4%', 'Unstable steering': '9.3%'}
# Top features: {'acc_x_mean': '12.9%', 'acc_x_kf_mean': '8.6%', 'vert_acc_mean': '8.0%', 'lat_mean': '7.9%', 'lon_mean': '7.4%', 'num_vehicles_mean': '7.0%'}
# ----
# window: 109 knn: 2.806
# Top causes: {'Overspeed': '5.4%', 'Unstable steering': '1.2%'}
# Top features: {'acc_z_mean': '11.7%', 'num_vehicles_mean': '11.3%', 'acc_z_kf_mean': '10.6%', 'pitch_mean': '7.9%', 'vdop_mean': '7.6%', 'ttc_front_mean': '7.2%'}
# ----
# window: 110 knn: 2.991
# Top causes: {'Overspeed': '11.3%', 'Unstable steering': '1.2%'}
# Top features: {'pitch_mean': '13.8%', 'x_lane_mean': '12.1%', 'dist_front_mean': '11.2%', 'acc_x_kf_mean': '9.2%', 'ttc_front_mean': '6.7%', 'acc_z_mean': '6.2%'}
# ----
# window: 111 knn: 3.124
# Top causes: {'Unstable steering': '7.8%', 'Overspeed': '5.0%'}
# Top features: {'roll_mean': '19.4%', 'course_mean': '9.8%', 'dist_front_mean': '7.3%', 'vdop_mean': '7.3%', 'lat_mean': '5.3%', 'osm_delay_mean': '4.6%'}
# ----
# window: 112 knn: 4.772
# Top causes: {'Unstable steering': '8.4%', 'Tailgating': '4.6%'}
# Top features: {'active_mean': '17.5%', 'lane_state_mean': '16.1%', 'phi_mean': '15.1%', 'hdop_mean': '10.8%', 'x_lane_mean': '6.8%', 'acc_x_kf_mean': '3.4%'}
# ----
# window: 113 knn: 4.756
# Top causes: {'Unstable steering': '6.5%', 'Tailgating': '2.8%'}
# Top features: {'phi_mean': '15.9%', 'active_mean': '15.8%', 'x_lane_mean': '11.8%', 'speed_kmh_mean': '6.2%', 'gps_speed_mean': '6.2%', 'gps_speed_osm_mean': '6.2%'}
# ----
# window: 114 knn: 3.963
# Top causes: {'Unstable steering': '9.2%', 'Harsh maneuvers': '7.8%'}
# Top features: {'gps_speed_mean': '11.7%', 'speed_kmh_mean': '11.7%', 'gps_speed_osm_mean': '11.5%', 'ttc_front_mean': '10.5%', 'num_vehicles_mean': '9.0%', 'lane_state_mean': '7.6%'}
# ----
# window: 115 knn: 3.276
# Top causes: {'Harsh maneuvers': '13.9%', 'Unstable steering': '11.2%'}
# Top features: {'num_vehicles_mean': '23.5%', 'gps_speed_mean': '8.2%', 'speed_kmh_mean': '8.1%', 'gps_speed_osm_mean': '8.1%', 'yaw_mean': '7.1%', 'ttc_front_mean': '6.4%'}
# ----
# window: 116 knn: 2.798
# Top causes: {'Tailgating': '15.2%', 'Overspeed': '13.6%'}
# Top features: {'yaw_mean': '12.9%', 'x_lane_mean': '10.2%', 'vdop_mean': '6.9%', 'lane_state_mean': '6.4%', 'acc_x_mean': '6.2%', 'course_mean': '5.6%'}
# ----
# window: 117 knn: 2.671
# Top causes: {'Unstable steering': '20.6%', 'Harsh maneuvers': '7.7%'}
# Top features: {'dist_front_mean': '22.5%', 'ttc_front_mean': '14.1%', 'x_lane_mean': '11.2%', 'yaw_mean': '10.7%', 'course_mean': '7.6%', 'lane_state_mean': '6.0%'}
# ----
# window: 118 knn: 2.666
# Top causes: {'Unstable steering': '13.8%', 'Harsh maneuvers': '11.2%'}
# Top features: {'dist_front_mean': '22.0%', 'ttc_front_mean': '19.3%', 'yaw_mean': '8.8%', 'course_mean': '8.3%', 'num_vehicles_mean': '5.5%', 'x_lane_mean': '5.2%'}
# ----
# window: 119 knn: 2.671
# Top causes: {'Unstable steering': '21.0%', 'Harsh maneuvers': '17.5%'}
# Top features: {'dist_front_mean': '17.0%', 'ttc_front_mean': '15.4%', 'yaw_mean': '11.4%', 'course_mean': '9.6%', 'vdop_mean': '6.1%', 'lane_state_mean': '5.5%'}
# ----
# window: 120 knn: 3.424
# Top causes: {'Unstable steering': '29.4%', 'Tailgating': '15.8%'}
# Top features: {'lat_mean': '10.9%', 'yaw_mean': '9.0%', 'alt_mean': '8.1%', 'lon_mean': '6.8%', 'course_mean': '6.6%', 'roll_mean': '6.6%'}
# ----
# window: 121 knn: 4.253
# Top causes: {'Tailgating': '10.3%', 'Unstable steering': '2.2%'}
# Top features: {'acc_x_kf_mean': '18.8%', 'acc_x_mean': '18.2%', 'lat_mean': '10.1%', 'alt_mean': '6.9%', 'lon_mean': '6.3%', 'vdop_mean': '4.7%'}
# ----
# window: 122 knn: 3.321
# Top causes: {'Tailgating': '13.2%', 'Unstable steering': '6.6%'}
# Top features: {'roll_mean': '15.1%', 'gps_speed_mean': '6.6%', 'acc_x_kf_mean': '6.6%', 'gps_speed_osm_mean': '6.6%', 'speed_kmh_mean': '6.6%', 'acc_z_kf_mean': '5.6%'}
# ----
# window: 123 knn: 3.442
# Top causes: {'Tailgating': '12.2%', 'Unstable steering': '6.2%'}
# Top features: {'roll_mean': '27.8%', 'alt_mean': '13.0%', 'acc_x_mean': '9.5%', 'acc_x_kf_mean': '8.5%', 'course_mean': '6.6%', 'hdop_mean': '3.3%'}
# ----
# window: 124 knn: 3.311
# Top causes: {'Overspeed': '11.2%', 'Unstable steering': '3.6%'}
# Top features: {'pitch_mean': '13.7%', 'alt_mean': '10.8%', 'course_mean': '9.5%', 'ttc_front_mean': '8.8%', 'acc_x_mean': '6.6%', 'acc_x_kf_mean': '6.4%'}
# ----
# window: 125 knn: 3.491
# Top causes: {'Harsh maneuvers': '26.8%', 'Overspeed': '11.1%'}
# Top features: {'ttc_front_mean': '14.3%', 'dist_front_mean': '13.8%', 'course_mean': '11.3%', 'pitch_mean': '8.0%', 'acc_z_mean': '7.1%', 'lat_mean': '6.1%'}
# ----
# window: 126 knn: 3.941
# Top causes: {'Tailgating': '20.8%', 'Overspeed': '12.6%'}
# Top features: {'vert_acc_mean': '26.4%', 'course_mean': '9.6%', 'speed_rel_mean': '6.5%', 'ttc_front_mean': '6.4%', 'lon_mean': '5.9%', 'lat_mean': '5.5%'}
# ----
# window: 127 knn: 7.718
# Top causes: {'Harsh maneuvers': '85.4%', 'Unstable steering': '7.6%'}
# Top features: {'acc_z_mean': '30.1%', 'acc_z_kf_mean': '29.4%', 'acc_x_kf_mean': '7.2%', 'difcourse_mean': '6.6%', 'acc_x_mean': '5.6%', 'lon_mean': '3.1%'}
# ----
# window: 128 knn: 7.103
# Top causes: {'Harsh maneuvers': '62.5%', 'Overspeed': '21.5%'}
# Top features: {'acc_x_mean': '17.4%', 'acc_x_kf_mean': '16.6%', 'difcourse_mean': '10.2%', 'acc_z_mean': '7.5%', 'acc_z_kf_mean': '7.4%', 'road_width_mean': '5.5%'}
# ----
# window: 129 knn: 7.618
# Top causes: {'Overspeed': '66.9%', 'Harsh maneuvers': '16.9%'}
# Top features: {'x_lane_mean': '18.2%', 'active_mean': '14.6%', 'phi_mean': '14.3%', 'gps_speed_osm_mean': '7.9%', 'speed_kmh_mean': '7.9%', 'gps_speed_mean': '7.8%'}
# ----
# window: 130 knn: 9.512
# Top causes: {'Overspeed': '49.2%', 'Tailgating': '42.2%'}
# Top features: {'active_mean': '23.0%', 'phi_mean': '20.7%', 'x_lane_mean': '12.1%', 'lane_state_mean': '12.0%', 'hdop_mean': '9.5%', 'num_vehicles_mean': '5.8%'}
# ----
# window: 131 knn: 5.587
# Top causes: {'Overspeed': '6.4%', 'Unstable steering': '5.0%'}
# Top features: {'x_lane_mean': '13.8%', 'active_mean': '13.5%', 'phi_mean': '13.4%', 'num_vehicles_mean': '11.5%', 'osm_delay_mean': '10.0%', 'hdop_mean': '7.9%'}
# ----
# window: 132 knn: 4.269
# Top causes: {'Overspeed': '18.6%', 'Unstable steering': '3.3%'}
# Top features: {'num_vehicles_mean': '19.2%', 'course_mean': '14.2%', 'vert_acc_mean': '12.5%', 'lon_mean': '5.0%', 'lat_mean': '4.9%', 'osm_delay_mean': '4.7%'}
# ----
# window: 133 knn: 4.486
# Top causes: {'Tailgating': '18.9%', 'Overspeed': '14.7%'}
# Top features: {'lat_mean': '12.8%', 'alt_mean': '9.9%', 'acc_x_mean': '8.7%', 'course_mean': '8.4%', 'lon_mean': '8.0%', 'acc_x_kf_mean': '7.6%'}
# ----
# window: 134 knn: 7.94
# Top causes: {'Tailgating': '47.7%', 'Unstable steering': '40.1%'}
# Top features: {'pdop_mean': '18.8%', 'road_width_mean': '17.1%', 'vdop_mean': '14.3%', 'hdop_mean': '13.6%', 'difcourse_mean': '6.7%', 'lane_state_mean': '5.6%'}
# ----
# window: 135 knn: 9.449
# Top causes: {'Tailgating': '79.8%', 'Harsh maneuvers': '12.6%'}
# Top features: {'vdop_mean': '37.8%', 'pdop_mean': '12.8%', 'hdop_mean': '12.8%', 'road_width_mean': '12.5%', 'ttc_front_mean': '4.9%', 'dist_front_mean': '4.1%'}
# ----
# window: 136 knn: 49.302
# Top causes: {'Tailgating': '60.3%', 'Harsh maneuvers': '27.3%'}
# Top features: {'pdop_mean': '95.9%', 'vdop_mean': '1.9%', 'hdop_mean': '0.8%', 'road_width_mean': '0.6%', 'lane_state_mean': '0.2%', 'ttc_front_mean': '0.1%'}
# ----
# window: 137 knn: 64.44
# Top causes: {'Tailgating': '32.5%', 'Overspeed': '32.0%'}
# Top features: {'pdop_mean': '97.6%', 'vdop_mean': '1.2%', 'hdop_mean': '0.6%', 'road_width_mean': '0.4%', 'lane_state_mean': '0.1%', 'x_lane_mean': '0.0%'}
# ----
# window: 138 knn: 34.169
# Top causes: {'Tailgating': '48.2%', 'Overspeed': '34.8%'}
# Top features: {'pdop_mean': '92.9%', 'vdop_mean': '3.5%', 'road_width_mean': '1.2%', 'hdop_mean': '1.1%', 'lane_state_mean': '0.4%', 'x_lane_mean': '0.2%'}
# ----
# window: 139 knn: 34.22
# Top causes: {'Overspeed': '52.0%', 'Tailgating': '21.3%'}
# Top features: {'pdop_mean': '92.9%', 'vdop_mean': '3.5%', 'road_width_mean': '1.1%', 'hdop_mean': '0.7%', 'x_lane_mean': '0.4%', 'lane_state_mean': '0.4%'}
# ----
# window: 140 knn: 16.044
# Top causes: {'Harsh maneuvers': '40.0%', 'Overspeed': '38.8%'}
# Top features: {'pdop_mean': '76.8%', 'vdop_mean': '7.4%', 'road_width_mean': '2.1%', 'acc_z_mean': '1.5%', 'acc_z_kf_mean': '1.4%', 'gps_speed_osm_mean': '1.1%'}
# ----
# window: 141 knn: 5.883
# Top causes: {'Unstable steering': '8.9%', 'Tailgating': '3.7%'}
# Top features: {'acc_x_mean': '10.3%', 'gps_speed_osm_mean': '10.2%', 'speed_kmh_mean': '10.1%', 'gps_speed_mean': '10.1%', 'acc_z_kf_mean': '7.7%', 'acc_x_kf_mean': '7.5%'}
# ----
# window: 142 knn: 67.984
# Top causes: {'Overspeed': '45.6%', 'Harsh maneuvers': '21.3%'}
# Top features: {'pdop_mean': '98.9%', 'hdop_mean': '0.4%', 'vdop_mean': '0.3%', 'lane_state_mean': '0.0%', 'num_vehicles_mean': '0.0%', 'gps_speed_osm_mean': '0.0%'}
# ----
# window: 143 knn: 114.118
# Top causes: {'Harsh maneuvers': '60.8%', 'Unstable steering': '22.0%'}
# Top features: {'pdop_mean': '99.2%', 'vdop_mean': '0.4%', 'hdop_mean': '0.3%', 'x_lane_mean': '0.0%', 'yaw_mean': '0.0%', 'acc_x_mean': '0.0%'}
# ----
# window: 144 knn: 91.089
# Top causes: {'Harsh maneuvers': '39.6%', 'Unstable steering': '35.8%'}
# Top features: {'pdop_mean': '99.0%', 'vdop_mean': '0.6%', 'hdop_mean': '0.3%', 'vert_acc_mean': '0.0%', 'yaw_mean': '0.0%', 'x_lane_mean': '0.0%'}
# ----
# window: 145 knn: 45.289
# Top causes: {'Unstable steering': '42.6%', 'Overspeed': '27.0%'}
# Top features: {'pdop_mean': '96.7%', 'vdop_mean': '1.9%', 'hdop_mean': '0.9%', 'yaw_mean': '0.1%', 'course_mean': '0.1%', 'x_lane_mean': '0.1%'}
# ----
# window: 146 knn: 71.922
# Top causes: {'Unstable steering': '48.3%', 'Overspeed': '24.7%'}
# Top features: {'pdop_mean': '98.4%', 'vdop_mean': '0.8%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.1%', 'yaw_mean': '0.0%', 'course_mean': '0.0%'}
# ----
# window: 147 knn: 75.873
# Top causes: {'Harsh maneuvers': '32.8%', 'Overspeed': '29.8%'}
# Top features: {'pdop_mean': '98.2%', 'vdop_mean': '0.8%', 'hdop_mean': '0.5%', 'x_lane_mean': '0.2%', 'lane_state_mean': '0.1%', 'yaw_mean': '0.0%'}
# ----
# window: 148 knn: 37.983
# Top causes: {'Harsh maneuvers': '64.4%', 'Overspeed': '20.7%'}
# Top features: {'pdop_mean': '93.5%', 'vdop_mean': '2.7%', 'hdop_mean': '1.3%', 'vert_acc_mean': '1.0%', 'x_lane_mean': '0.3%', 'lat_mean': '0.2%'}
# ----
# window: 149 knn: 2.955
# Top causes: {'Tailgating': '21.8%', 'Unstable steering': '9.1%'}
# Top features: {'lat_mean': '21.7%', 'lon_mean': '14.5%', 'vdop_mean': '12.2%', 'roll_mean': '8.1%', 'course_mean': '6.5%', 'alt_mean': '5.8%'}
# ----
# window: 150 knn: 2.891
# Top causes: {'Overspeed': '29.8%', 'Tailgating': '9.6%'}
# Top features: {'pitch_mean': '21.2%', 'osm_delay_mean': '17.2%', 'acc_z_mean': '10.1%', 'acc_z_kf_mean': '10.0%', 'x_lane_mean': '5.6%', 'course_mean': '5.2%'}
# ----
# window: 151 knn: 3.232
# Top causes: {'Overspeed': '6.8%', 'Unstable steering': '3.8%'}
# Top features: {'pitch_mean': '31.1%', 'osm_delay_mean': '20.6%', 'acc_z_mean': '5.7%', 'course_mean': '5.1%', 'acc_z_kf_mean': '5.0%', 'alt_mean': '4.6%'}
# ----
# window: 152 knn: 4.4
# Top causes: {'Unstable steering': '21.5%', 'Overspeed': '16.1%'}
# Top features: {'difcourse_mean': '13.6%', 'osm_delay_mean': '10.6%', 'acc_y_kf_mean': '9.6%', 'acc_y_mean': '9.5%', 'acc_x_mean': '9.3%', 'acc_x_kf_mean': '8.8%'}
# ----
# window: 153 knn: 4.483
# Top causes: {'Unstable steering': '22.0%', 'Tailgating': '7.4%'}
# Top features: {'acc_y_mean': '16.9%', 'acc_y_kf_mean': '16.9%', 'difcourse_mean': '13.3%', 'osm_delay_mean': '11.9%', 'acc_x_kf_mean': '5.3%', 'acc_x_mean': '4.5%'}
# ----
# window: 154 knn: 2.925
# Top causes: {'Harsh maneuvers': '28.9%', 'Overspeed': '2.4%'}
# Top features: {'num_vehicles_mean': '18.1%', 'osm_delay_mean': '15.3%', 'pitch_mean': '14.6%', 'yaw_mean': '11.2%', 'course_mean': '7.5%', 'lane_state_mean': '4.4%'}
# ----
# window: 155 knn: 3.22
# Top causes: {'Unstable steering': '24.3%', 'Overspeed': '4.2%'}
# Top features: {'num_vehicles_mean': '16.8%', 'pitch_mean': '12.5%', 'yaw_mean': '9.9%', 'course_mean': '8.7%', 'osm_delay_mean': '8.6%', 'acc_x_kf_mean': '7.1%'}
# ----
# window: 156 knn: 4.818
# Top causes: {'Tailgating': '28.6%', 'Unstable steering': '1.1%'}
# Top features: {'speed_kmh_mean': '8.9%', 'gps_speed_osm_mean': '8.9%', 'gps_speed_mean': '8.8%', 'ttc_front_mean': '7.7%', 'osm_delay_mean': '7.2%', 'dist_front_mean': '6.6%'}
# ----
# window: 157 knn: 5.048
# Top causes: {'Tailgating': '9.8%', 'Unstable steering': '2.6%'}
# Top features: {'gps_speed_mean': '16.7%', 'gps_speed_osm_mean': '16.7%', 'speed_kmh_mean': '16.6%', 'pitch_mean': '13.9%', 'roll_mean': '9.6%', 'lane_state_mean': '5.6%'}
# ----
# window: 158 knn: 5.212
# Top causes: {'Unstable steering': '4.6%', 'Tailgating': '2.3%'}
# Top features: {'acc_x_mean': '16.4%', 'acc_x_kf_mean': '15.8%', 'acc_y_kf_mean': '6.6%', 'course_mean': '5.3%', 'acc_y_mean': '4.6%', 'pitch_mean': '4.4%'}
# ----
# window: 159 knn: 15.397
# Top causes: {'Harsh maneuvers': '95.9%', 'Unstable steering': '3.7%'}
# Top features: {'acc_z_kf_mean': '32.6%', 'acc_z_mean': '32.6%', 'acc_x_kf_mean': '8.3%', 'acc_x_mean': '8.0%', 'roll_mean': '6.6%', 'difcourse_mean': '3.3%'}
# ----
# window: 160 knn: 13.637
# Top causes: {'Harsh maneuvers': '97.4%', 'Unstable steering': '2.2%'}
# Top features: {'acc_z_mean': '34.0%', 'acc_z_kf_mean': '33.8%', 'roll_mean': '6.1%', 'acc_y_kf_mean': '5.7%', 'acc_y_mean': '5.4%', 'acc_x_mean': '3.3%'}
# ----
# window: 161 knn: 5.08
# Top causes: {'Harsh maneuvers': '23.7%', 'Unstable steering': '16.4%'}
# Top features: {'vdop_mean': '19.2%', 'road_width_mean': '10.5%', 'pitch_mean': '10.4%', 'gps_speed_mean': '6.9%', 'speed_kmh_mean': '6.8%', 'gps_speed_osm_mean': '6.8%'}
# ----
# window: 162 knn: 4.438
# Top causes: {'Unstable steering': '21.2%', 'Harsh maneuvers': '14.0%'}
# Top features: {'vdop_mean': '13.4%', 'road_width_mean': '11.8%', 'osm_delay_mean': '10.4%', 'yaw_mean': '7.9%', 'course_mean': '7.7%', 'speed_kmh_mean': '7.6%'}
# ----
# window: 163 knn: 132.146
# Top causes: {'Harsh maneuvers': '100.0%', 'Overspeed': '0.0%'}
# Top features: {'pdop_mean': '28.7%', 'acc_y_kf_mean': '26.0%', 'acc_y_mean': '24.4%', 'acc_x_kf_mean': '8.7%', 'acc_x_mean': '8.1%', 'pitch_mean': '3.6%'}
# ----
# window: 164 knn: 117.341
# Top causes: {'Harsh maneuvers': '99.9%', 'Tailgating': '0.1%'}
# Top features: {'acc_y_kf_mean': '33.6%', 'acc_y_mean': '31.6%', 'acc_x_kf_mean': '13.5%', 'acc_x_mean': '12.7%', 'pitch_mean': '4.8%', 'acc_z_kf_mean': '1.7%'}
# ----
# window: 165 knn: 111.892
# Top causes: {'Harsh maneuvers': '99.5%', 'Tailgating': '0.5%'}
# Top features: {'acc_y_kf_mean': '33.2%', 'acc_y_mean': '31.2%', 'acc_x_kf_mean': '13.5%', 'acc_x_mean': '12.8%', 'pitch_mean': '5.0%', 'acc_z_mean': '1.6%'}
# ----
# window: 166 knn: 103.68
# Top causes: {'Harsh maneuvers': '99.5%', 'Tailgating': '0.4%'}
# Top features: {'acc_y_kf_mean': '35.7%', 'acc_y_mean': '33.6%', 'acc_x_kf_mean': '12.5%', 'acc_x_mean': '11.8%', 'pitch_mean': '5.4%', 'dist_front_mean': '0.2%'}
# ----
# window: 167 knn: 113.585
# Top causes: {'Harsh maneuvers': '99.6%', 'Tailgating': '0.3%'}
# Top features: {'pdop_mean': '34.9%', 'acc_y_kf_mean': '22.2%', 'acc_y_mean': '20.8%', 'acc_x_kf_mean': '8.6%', 'acc_x_mean': '8.0%', 'pitch_mean': '3.2%'}
# ----
# window: 168 knn: 80.712
# Top causes: {'Harsh maneuvers': '99.2%', 'Overspeed': '0.4%'}
# Top features: {'pdop_mean': '68.0%', 'acc_y_kf_mean': '11.2%', 'acc_y_mean': '10.5%', 'acc_x_kf_mean': '4.1%', 'acc_x_mean': '3.9%', 'pitch_mean': '1.0%'}
# ----
# window: 169 knn: 99.209
# Top causes: {'Harsh maneuvers': '77.2%', 'Overspeed': '10.6%'}
# Top features: {'pdop_mean': '97.8%', 'vdop_mean': '0.7%', 'hdop_mean': '0.5%', 'acc_y_kf_mean': '0.2%', 'acc_y_mean': '0.2%', 'acc_z_kf_mean': '0.1%'}
# ----
# window: 170 knn: 221.675
# Top causes: {'Harsh maneuvers': '45.9%', 'Overspeed': '31.3%'}
# Top features: {'pdop_mean': '99.6%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'vert_acc_mean': '0.0%', 'yaw_mean': '0.0%', 'osm_delay_mean': '0.0%'}
# ----
# window: 171 knn: 171.737
# Top causes: {'Harsh maneuvers': '39.8%', 'Overspeed': '24.4%'}
# Top features: {'pdop_mean': '99.4%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'vert_acc_mean': '0.0%', 'osm_delay_mean': '0.0%'}
# ----
# window: 172 knn: 171.814
# Top causes: {'Tailgating': '58.8%', 'Harsh maneuvers': '17.9%'}
# Top features: {'pdop_mean': '99.3%', 'vdop_mean': '0.3%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.1%', 'dist_front_mean': '0.0%', 'ttc_front_mean': '0.0%'}
# ----
# window: 173 knn: 244.651
# Top causes: {'Tailgating': '50.0%', 'Overspeed': '19.8%'}
# Top features: {'pdop_mean': '99.6%', 'vdop_mean': '0.2%', 'hdop_mean': '0.1%', 'x_lane_mean': '0.0%', 'dist_front_mean': '0.0%', 'ttc_front_mean': '0.0%'}
# ----
#
# === SECONDARY ===
# window: 0 knn: 5.089
# Top causes: {'Tailgating': '16.3%', 'Unstable steering': '11.8%'}
# Top features: {'x_lane_mean': '8.4%', 'vdop_mean': '7.3%', 'lon_osm_mean': '6.2%', 'lon_mean': '6.1%', 'speed_ratio_mean': '6.1%', 'vert_acc_mean': '5.0%'}
# ----
# window: 1 knn: 4.992
# Top causes: {'Overspeed': '21.8%', 'Tailgating': '14.4%'}
# Top features: {'osm_delay_mean': '13.3%', 'acc_y_kf_mean': '11.2%', 'acc_y_mean': '10.9%', 'x_lane_mean': '8.1%', 'vert_acc_mean': '5.1%', 'vdop_mean': '5.0%'}
# ----
# window: 2 knn: 5.068
# Top causes: {'Overspeed': '26.5%', 'Unstable steering': '5.5%'}
# Top features: {'acc_y_kf_mean': '9.9%', 'osm_delay_mean': '9.9%', 'acc_y_mean': '9.1%', 'x_lane_mean': '7.3%', 'acc_z_kf_mean': '6.4%', 'acc_z_mean': '6.4%'}
# ----
# window: 3 knn: 5.175
# Top causes: {'Harsh maneuvers': '28.4%', 'Unstable steering': '12.4%'}
# Top features: {'x_lane_mean': '11.0%', 'gps_speed_osm_mean': '10.2%', 'gps_speed_mean': '10.0%', 'speed_kmh_mean': '9.9%', 'vert_acc_mean': '8.3%', 'hdop_mean': '6.8%'}
# ----
# window: 4 knn: 9.728
# Top causes: {'Overspeed': '82.3%', 'Harsh maneuvers': '11.3%'}
# Top features: {'gps_speed_mean': '20.0%', 'gps_speed_osm_mean': '19.9%', 'speed_kmh_mean': '19.9%', 'hdop_mean': '10.0%', 'vdop_mean': '3.2%', 'acc_x_kf_mean': '2.8%'}
# ----
# window: 5 knn: 9.138
# Top causes: {'Overspeed': '77.9%', 'Harsh maneuvers': '17.1%'}
# Top features: {'gps_speed_mean': '21.5%', 'speed_kmh_mean': '21.5%', 'gps_speed_osm_mean': '21.4%', 'acc_x_kf_mean': '4.5%', 'acc_y_kf_mean': '2.8%', 'osm_delay_mean': '2.8%'}
# ----
# window: 6 knn: 13.265
# Top causes: {'Harsh maneuvers': '54.7%', 'Overspeed': '38.9%'}
# Top features: {'acc_x_kf_mean': '11.7%', 'gps_speed_mean': '11.2%', 'speed_kmh_mean': '11.2%', 'gps_speed_osm_mean': '11.2%', 'acc_z_kf_mean': '11.1%', 'acc_z_mean': '10.6%'}
# ----
# window: 7 knn: 10.774
# Top causes: {'Overspeed': '49.1%', 'Harsh maneuvers': '40.2%'}
# Top features: {'gps_speed_osm_mean': '14.6%', 'speed_kmh_mean': '14.5%', 'gps_speed_mean': '14.5%', 'acc_z_mean': '9.2%', 'acc_x_kf_mean': '9.1%', 'acc_z_kf_mean': '8.6%'}
# ----
# window: 8 knn: 15.317
# Top causes: {'Overspeed': '42.8%', 'Harsh maneuvers': '32.4%'}
# Top features: {'course_mean': '65.9%', 'hdop_mean': '9.4%', 'lane_state_mean': '6.1%', 'roll_mean': '1.7%', 'phi_mean': '1.6%', 'x_lane_mean': '1.3%'}
# ----
# window: 9 knn: 15.363
# Top causes: {'Overspeed': '71.4%', 'Tailgating': '13.1%'}
# Top features: {'course_mean': '57.6%', 'hdop_mean': '14.6%', 'vdop_mean': '6.6%', 'phi_mean': '4.2%', 'x_lane_mean': '2.9%', 'gps_speed_mean': '2.1%'}
# ----
# window: 10 knn: 14.469
# Top causes: {'Harsh maneuvers': '36.3%', 'Overspeed': '36.3%'}
# Top features: {'course_mean': '69.5%', 'vdop_mean': '7.3%', 'hdop_mean': '5.3%', 'x_lane_mean': '2.8%', 'num_lanes_mean': '2.3%', 'roll_mean': '1.7%'}
# ----
# window: 11 knn: 14.499
# Top causes: {'Harsh maneuvers': '46.6%', 'Overspeed': '22.8%'}
# Top features: {'course_mean': '63.3%', 'hdop_mean': '10.8%', 'vdop_mean': '9.4%', 'x_lane_mean': '2.9%', 'num_lanes_mean': '1.5%', 'yaw_mean': '1.4%'}
# ----
# window: 12 knn: 14.892
# Top causes: {'Unstable steering': '43.7%', 'Overspeed': '39.5%'}
# Top features: {'course_mean': '64.4%', 'vdop_mean': '9.9%', 'hdop_mean': '9.9%', 'yaw_mean': '3.5%', 'x_lane_mean': '3.4%', 'phi_mean': '1.2%'}
# ----
# window: 13 knn: 4.394
# Top causes: {'Overspeed': '25.8%', 'Tailgating': '17.8%'}
# Top features: {'lane_state_mean': '19.1%', 'acc_x_kf_mean': '11.4%', 'acc_x_mean': '10.9%', 'hdop_mean': '7.5%', 'lon_osm_mean': '4.8%', 'lon_mean': '4.8%'}
# ----
# window: 14 knn: 3.568
# Top causes: {'Harsh maneuvers': '19.7%', 'Tailgating': '19.2%'}
# Top features: {'gps_speed_osm_mean': '8.2%', 'gps_speed_mean': '8.2%', 'speed_kmh_mean': '8.1%', 'osm_delay_mean': '7.1%', 'max_speed_mean': '6.9%', 'difcourse_mean': '6.5%'}
# ----
# window: 15 knn: 3.917
# Top causes: {'Tailgating': '20.5%', 'Unstable steering': '4.0%'}
# Top features: {'acc_y_kf_mean': '11.8%', 'acc_y_mean': '11.5%', 'osm_delay_mean': '8.0%', 'alt_mean': '7.0%', 'max_speed_mean': '7.0%', 'pitch_mean': '5.6%'}
# ----
# window: 16 knn: 4.104
# Top causes: {'Overspeed': '29.9%', 'Unstable steering': '23.1%'}
# Top features: {'pitch_mean': '15.4%', 'difcourse_mean': '8.4%', 'speed_rel_mean': '7.1%', 'alt_mean': '6.1%', 'yaw_mean': '5.9%', 'acc_x_kf_mean': '5.5%'}
# ...
# ----
# window: 42 knn: 4.131
# Top causes: {'Unstable steering': '9.1%', 'Overspeed': '8.8%'}
# Top features: {'lat_osm_mean': '8.6%', 'lat_mean': '8.5%', 'lon_osm_mean': '7.1%', 'lon_mean': '7.1%', 'acc_x_kf_mean': '6.0%', 'acc_x_mean': '5.7%'}
# ----
# window: 43 knn: 9.943
# Top causes: {'Overspeed': '56.4%', 'Harsh maneuvers': '39.2%'}
# Top features: {'lane_state_mean': '29.8%', 'speed_kmh_mean': '9.5%', 'gps_speed_osm_mean': '9.4%', 'gps_speed_mean': '9.4%', 'acc_z_kf_mean': '6.7%', 'acc_z_mean': '6.5%'}
# ----
# window: 44 knn: 7.83
# Top causes: {'Harsh maneuvers': '76.1%', 'Overspeed': '15.4%'}
# Top features: {'acc_x_kf_mean': '15.9%', 'acc_x_mean': '13.8%', 'acc_y_kf_mean': '8.1%', 'acc_y_mean': '8.0%', 'hdop_mean': '7.8%', 'vdop_mean': '4.4%'}
# ----
# window: 45 knn: 5.073
# Top causes: {'Overspeed': '15.2%', 'Tailgating': '12.8%'}
# Top features: {'course_mean': '11.1%', 'vdop_mean': '8.1%', 'acc_z_mean': '7.2%', 'acc_z_kf_mean': '6.7%', 'acc_y_kf_mean': '6.3%', 'acc_y_mean': '5.7%'}
# ----
# window: 46 knn: 5.853
# Top causes: {'Unstable steering': '28.6%', 'Tailgating': '7.5%'}
# Top features: {'difcourse_mean': '15.0%', 'course_mean': '14.6%', 'acc_z_mean': '6.2%', 'acc_x_kf_mean': '6.1%', 'pitch_mean': '6.0%', 'acc_z_kf_mean': '5.7%'}
# ----
# window: 47 knn: 7.603
# Top causes: {'Harsh maneuvers': '68.8%', 'Overspeed': '25.0%'}
# Top features: {'acc_x_kf_mean': '18.4%', 'acc_x_mean': '15.9%', 'phi_mean': '9.3%', 'acc_z_kf_mean': '7.9%', 'acc_z_mean': '7.7%', 'speed_kmh_mean': '4.5%'}
# ----
# window: 48 knn: 9.959
# Top causes: {'Harsh maneuvers': '71.6%', 'Overspeed': '24.0%'}
# Top features: {'phi_mean': '25.3%', 'acc_x_kf_mean': '14.1%', 'acc_x_mean': '12.1%', 'max_speed_mean': '7.2%', 'acc_z_mean': '5.6%', 'acc_z_kf_mean': '5.5%'}
# ----
# window: 49 knn: 6.872
# Top causes: {'Overspeed': '60.5%', 'Harsh maneuvers': '27.6%'}
# Top features: {'phi_mean': '30.7%', 'max_speed_mean': '16.1%', 'course_mean': '9.0%', 'roll_mean': '6.0%', 'alt_mean': '2.9%', 'osm_delay_mean': '2.6%'}
# ----
# window: 50 knn: 6.707
# Top causes: {'Harsh maneuvers': '75.1%', 'Overspeed': '16.8%'}
# Top features: {'acc_y_kf_mean': '17.1%', 'acc_y_mean': '17.0%', 'phi_mean': '12.8%', 'alt_mean': '9.8%', 'pitch_mean': '7.5%', 'acc_z_kf_mean': '4.8%'}
# ----
# window: 51 knn: 6.571
# Top causes: {'Harsh maneuvers': '69.6%', 'Unstable steering': '13.9%'}
# Top features: {'acc_y_kf_mean': '14.8%', 'acc_y_mean': '14.8%', 'phi_mean': '11.1%', 'pitch_mean': '8.1%', 'alt_mean': '7.2%', 'difcourse_mean': '5.3%'}
# ----
# window: 52 knn: 7.534
# Top causes: {'Harsh maneuvers': '55.8%', 'Overspeed': '33.1%'}
# Top features: {'acc_z_mean': '16.7%', 'acc_z_kf_mean': '16.4%', 'hdop_mean': '10.1%', 'phi_mean': '8.6%', 'speed_kmh_mean': '7.0%', 'gps_speed_mean': '6.9%'}
# ----
# window: 53 knn: 7.75
# Top causes: {'Overspeed': '40.2%', 'Harsh maneuvers': '35.1%'}
# Top features: {'hdop_mean': '20.8%', 'phi_mean': '17.5%', 'vdop_mean': '13.7%', 'x_lane_mean': '4.8%', 'yaw_mean': '4.5%', 'acc_x_kf_mean': '3.9%'}
# ----
# window: 54 knn: 7.29
# Top causes: {'Overspeed': '40.1%', 'Harsh maneuvers': '33.0%'}
# Top features: {'vdop_mean': '24.3%', 'hdop_mean': '10.7%', 'yaw_mean': '6.3%', 'lat_osm_mean': '5.1%', 'lat_mean': '5.1%', 'lon_osm_mean': '4.2%'}
# ----
# window: 55 knn: 14.159
# Top causes: {'Harsh maneuvers': '46.8%', 'Overspeed': '28.4%'}
# Top features: {'course_mean': '73.3%', 'hdop_mean': '8.2%', 'phi_mean': '3.0%', 'vdop_mean': '2.0%', 'road_width_mean': '1.8%', 'lat_osm_mean': '1.4%'}
# ----
# window: 56 knn: 13.819
# Top causes: {'Harsh maneuvers': '56.6%', 'Overspeed': '13.0%'}
# Top features: {'course_mean': '66.4%', 'hdop_mean': '13.8%', 'vdop_mean': '5.4%', 'phi_mean': '2.5%', 'road_width_mean': '2.0%', 'acc_z_mean': '1.0%'}
# ----
# window: 57 knn: 14.56
# Top causes: {'Tailgating': '36.3%', 'Harsh maneuvers': '34.8%'}
# Top features: {'course_mean': '60.4%', 'hdop_mean': '14.8%', 'vdop_mean': '5.8%', 'num_lanes_mean': '4.1%', 'phi_mean': '3.3%', 'pitch_mean': '3.3%'}
# ----
# window: 58 knn: 16.079
# Top causes: {'Unstable steering': '53.3%', 'Harsh maneuvers': '17.3%'}
# Top features: {'course_mean': '62.6%', 'hdop_mean': '8.3%', 'lane_state_mean': '7.2%', 'vdop_mean': '4.4%', 'num_lanes_mean': '3.7%', 'phi_mean': '3.7%'}
# ----
# window: 59 knn: 17.844
# Top causes: {'Overspeed': '39.9%', 'Harsh maneuvers': '28.5%'}
# Top features: {'course_mean': '63.3%', 'lane_state_mean': '13.6%', 'hdop_mean': '4.7%', 'speed_rel_mean': '3.9%', 'vdop_mean': '2.7%', 'alt_mean': '2.0%'}
# ----
# window: 60 knn: 15.987
# Top causes: {'Overspeed': '54.0%', 'Unstable steering': '29.4%'}
# Top features: {'course_mean': '67.6%', 'hdop_mean': '11.8%', 'vdop_mean': '3.5%', 'speed_rel_mean': '2.9%', 'lane_state_mean': '2.3%', 'alt_mean': '2.1%'}
# ----
# window: 61 knn: 13.573
# Top causes: {'Overspeed': '49.6%', 'Unstable steering': '17.4%'}
# Top features: {'course_mean': '55.4%', 'hdop_mean': '13.7%', 'vdop_mean': '6.4%', 'phi_mean': '3.2%', 'yaw_mean': '2.3%', 'x_lane_mean': '1.8%'}
# ----
# window: 62 knn: 12.956
# Top causes: {'Harsh maneuvers': '36.3%', 'Unstable steering': '26.7%'}
# Top features: {'course_mean': '61.3%', 'hdop_mean': '7.5%', 'vdop_mean': '5.9%', 'yaw_mean': '4.0%', 'phi_mean': '3.2%', 'roll_mean': '1.8%'}
# ----
# window: 63 knn: 15.193
# Top causes: {'Unstable steering': '44.5%', 'Harsh maneuvers': '34.6%'}
# Top features: {'course_mean': '69.0%', 'hdop_mean': '8.6%', 'vdop_mean': '4.6%', 'yaw_mean': '4.6%', 'phi_mean': '3.0%', 'x_lane_mean': '1.7%'}
# ----
# window: 64 knn: 17.319
# Top causes: {'Unstable steering': '50.8%', 'Harsh maneuvers': '28.7%'}
# Top features: {'course_mean': '62.9%', 'hdop_mean': '14.6%', 'vdop_mean': '5.2%', 'yaw_mean': '3.9%', 'phi_mean': '2.0%', 'pitch_mean': '1.5%'}
# ----
# window: 65 knn: 17.078
# Top causes: {'Harsh maneuvers': '47.0%', 'Unstable steering': '29.8%'}
# Top features: {'course_mean': '61.6%', 'hdop_mean': '11.3%', 'vdop_mean': '6.4%', 'yaw_mean': '3.8%', 'acc_x_mean': '1.7%', 'acc_x_kf_mean': '1.5%'}
# ----
# window: 66 knn: 14.465
# Top causes: {'Unstable steering': '43.6%', 'Harsh maneuvers': '23.6%'}
# Top features: {'course_mean': '70.7%', 'vdop_mean': '5.4%', 'yaw_mean': '5.3%', 'hdop_mean': '2.8%', 'phi_mean': '2.1%', 'acc_z_mean': '1.5%'}
# ----
# window: 67 knn: 13.825
# Top causes: {'Overspeed': '54.5%', 'Unstable steering': '32.4%'}
# Top features: {'course_mean': '57.8%', 'lane_state_mean': '11.7%', 'yaw_mean': '5.5%', 'phi_mean': '3.5%', 'gps_speed_mean': '2.4%', 'gps_speed_osm_mean': '2.4%'}
# ----
# window: 68 knn: 3.551
# Top causes: {'Harsh maneuvers': '22.0%', 'Unstable steering': '21.7%'}
# Top features: {'lon_mean': '12.0%', 'lon_osm_mean': '11.9%', 'lat_osm_mean': '8.3%', 'lat_mean': '8.3%', 'alt_mean': '7.9%', 'road_width_mean': '6.0%'}
# ----
# window: 69 knn: 3.579
# Top causes: {'Overspeed': '11.6%', 'Unstable steering': '8.4%'}
# Top features: {'acc_z_kf_mean': '16.2%', 'acc_z_mean': '15.8%', 'pitch_mean': '6.6%', 'hdop_mean': '6.3%', 'lon_mean': '5.8%', 'lon_osm_mean': '5.8%'}
# ----
# window: 70 knn: 4.124
# Top causes: {'Overspeed': '26.6%', 'Unstable steering': '15.7%'}
# Top features: {'course_mean': '14.5%', 'pitch_mean': '14.0%', 'acc_z_mean': '6.8%', 'acc_x_kf_mean': '6.7%', 'acc_z_kf_mean': '6.5%', 'difcourse_mean': '6.3%'}
# ----
# window: 71 knn: 3.639
# Top causes: {'Tailgating': '22.0%', 'Harsh maneuvers': '8.3%'}
# Top features: {'gps_speed_mean': '10.4%', 'gps_speed_osm_mean': '10.2%', 'speed_kmh_mean': '10.0%', 'speed_rel_mean': '9.3%', 'num_vehicles_mean': '9.1%', 'num_lanes_mean': '6.7%'}
# ----
# window: 72 knn: 3.496
# Top causes: {'Tailgating': '16.7%', 'Harsh maneuvers': '12.1%'}
# Top features: {'course_mean': '20.8%', 'max_speed_mean': '13.6%', 'num_lanes_mean': '7.5%', 'speed_rel_mean': '5.5%', 'gps_speed_mean': '5.4%', 'gps_speed_osm_mean': '5.4%'}
# ----
# window: 73 knn: 3.958
# Top causes: {'Tailgating': '25.5%', 'Unstable steering': '4.7%'}
# Top features: {'roll_mean': '10.9%', 'alt_mean': '10.1%', 'course_mean': '7.0%', 'num_vehicles_mean': '5.4%', 'gps_speed_mean': '5.2%', 'gps_speed_osm_mean': '5.2%'}
# ----
# window: 74 knn: 3.848
# Top causes: {'Tailgating': '23.1%', 'Unstable steering': '9.0%'}
# Top features: {'acc_x_mean': '12.4%', 'num_lanes_mean': '11.9%', 'alt_mean': '10.7%', 'acc_x_kf_mean': '9.3%', 'pitch_mean': '9.1%', 'num_vehicles_mean': '4.9%'}
# ----
# window: 75 knn: 4.294
# Top causes: {'Unstable steering': '8.5%', 'Overspeed': '4.5%'}
# Top features: {'acc_x_kf_mean': '14.0%', 'acc_x_mean': '13.9%', 'num_lanes_mean': '13.2%', 'acc_z_kf_mean': '8.4%', 'acc_z_mean': '8.1%', 'vert_acc_mean': '7.0%'}
# ----
# window: 76 knn: 3.844
# Top causes: {'Tailgating': '11.2%', 'Overspeed': '8.8%'}
# Top features: {'vert_acc_mean': '12.8%', 'acc_y_mean': '9.6%', 'acc_y_kf_mean': '8.9%', 'roll_mean': '6.0%', 'lat_mean': '5.8%', 'lat_osm_mean': '5.8%'}
# ----
# window: 77 knn: 3.774
# Top causes: {'Tailgating': '29.7%', 'Harsh maneuvers': '24.4%'}
# Top features: {'lat_osm_mean': '7.5%', 'lat_mean': '7.4%', 'lon_osm_mean': '6.1%', 'lon_mean': '6.1%', 'num_vehicles_mean': '5.4%', 'ttc_front_mean': '5.4%'}
# ----
# window: 78 knn: 7.096
# Top causes: {'Overspeed': '52.0%', 'Harsh maneuvers': '22.4%'}
# Top features: {'active_mean': '40.4%', 'phi_mean': '6.4%', 'gps_speed_osm_mean': '4.5%', 'speed_kmh_mean': '4.4%', 'gps_speed_mean': '4.4%', 'lat_osm_mean': '3.7%'}
# ----
# window: 79 knn: 6.108
# Top causes: {'Overspeed': '44.3%', 'Harsh maneuvers': '43.9%'}
# Top features: {'speed_kmh_mean': '9.1%', 'gps_speed_mean': '9.0%', 'gps_speed_osm_mean': '9.0%', 'pitch_mean': '7.9%', 'course_mean': '7.8%', 'acc_x_mean': '6.7%'}
# ----
# window: 80 knn: 5.8
# Top causes: {'Harsh maneuvers': '65.7%', 'Overspeed': '22.2%'}
# Top features: {'acc_z_mean': '18.0%', 'acc_z_kf_mean': '15.0%', 'speed_rel_mean': '6.9%', 'road_width_mean': '6.3%', 'num_vehicles_mean': '4.4%', 'acc_y_mean': '4.3%'}
# ----
# window: 81 knn: 7.234
# Top causes: {'Harsh maneuvers': '56.5%', 'Overspeed': '38.3%'}
# Top features: {'osm_delay_mean': '21.2%', 'speed_ratio_mean': '19.0%', 'acc_z_mean': '14.9%', 'acc_z_kf_mean': '12.5%', 'course_mean': '4.7%', 'road_width_mean': '4.2%'}
# ----
# window: 82 knn: 7.391
# Top causes: {'Overspeed': '49.4%', 'Harsh maneuvers': '44.6%'}
# Top features: {'osm_delay_mean': '27.8%', 'speed_ratio_mean': '19.0%', 'acc_z_mean': '9.8%', 'acc_z_kf_mean': '8.5%', 'speed_rel_mean': '4.7%', 'vdop_mean': '4.4%'}
# ----
# window: 83 knn: 14.443
# Top causes: {'Harsh maneuvers': '70.3%', 'Overspeed': '14.3%'}
# Top features: {'course_mean': '73.6%', 'hdop_mean': '4.4%', 'acc_y_mean': '2.6%', 'acc_y_kf_mean': '2.4%', 'osm_delay_mean': '2.4%', 'vdop_mean': '2.3%'}
# ----
# window: 84 knn: 14.89
# Top causes: {'Harsh maneuvers': '75.2%', 'Overspeed': '21.1%'}
# Top features: {'course_mean': '58.2%', 'hdop_mean': '8.7%', 'acc_y_kf_mean': '6.2%', 'acc_y_mean': '5.5%', 'vdop_mean': '5.1%', 'osm_delay_mean': '5.1%'}
# ----
# window: 85 knn: 15.048
# Top causes: {'Harsh maneuvers': '61.4%', 'Unstable steering': '19.9%'}
# Top features: {'course_mean': '64.7%', 'hdop_mean': '11.3%', 'vdop_mean': '4.0%', 'yaw_mean': '3.2%', 'acc_x_kf_mean': '1.7%', 'acc_z_mean': '1.7%'}
# ----
# window: 86 knn: 15.665
# Top causes: {'Unstable steering': '45.8%', 'Harsh maneuvers': '40.0%'}
# Top features: {'course_mean': '70.4%', 'hdop_mean': '8.7%', 'vdop_mean': '5.8%', 'yaw_mean': '3.9%', 'x_lane_mean': '3.3%', 'acc_x_kf_mean': '1.0%'}
# ----
# window: 87 knn: 14.519
# Top causes: {'Harsh maneuvers': '61.3%', 'Unstable steering': '29.8%'}
# Top features: {'course_mean': '67.4%', 'vdop_mean': '8.5%', 'acc_x_kf_mean': '5.0%', 'yaw_mean': '4.4%', 'hdop_mean': '3.9%', 'acc_x_mean': '3.9%'}
# ----
# window: 88 knn: 3.169
# Top causes: {'Harsh maneuvers': '19.1%', 'Unstable steering': '10.4%'}
# Top features: {'lon_mean': '8.9%', 'lon_osm_mean': '8.8%', 'road_width_mean': '8.1%', 'speed_ratio_mean': '6.9%', 'lat_mean': '6.4%', 'lat_osm_mean': '6.3%'}
# ----
# window: 89 knn: 3.148
# Top causes: {'Harsh maneuvers': '28.2%', 'Unstable steering': '16.1%'}
# Top features: {'road_width_mean': '9.0%', 'speed_ratio_mean': '6.7%', 'vert_acc_mean': '6.2%', 'speed_rel_mean': '6.1%', 'course_mean': '5.7%', 'pitch_mean': '5.5%'}
# ----
# window: 90 knn: 3.697
# Top causes: {'Unstable steering': '13.3%', 'Harsh maneuvers': '13.0%'}
# Top features: {'speed_ratio_mean': '30.8%', 'road_width_mean': '8.8%', 'difcourse_mean': '6.7%', 'speed_rel_mean': '6.5%', 'hdop_mean': '5.7%', 'vdop_mean': '5.6%'}
# ----
# window: 91 knn: 4.834
# Top causes: {'Harsh maneuvers': '14.8%', 'Tailgating': '13.8%'}
# Top features: {'speed_ratio_mean': '48.1%', 'dist_front_mean': '6.7%', 'speed_rel_mean': '6.1%', 'osm_delay_mean': '5.5%', 'ttc_front_mean': '4.1%', 'acc_z_mean': '4.0%'}
# ----
# window: 92 knn: 3.748
# Top causes: {'Overspeed': '25.3%', 'Harsh maneuvers': '17.5%'}
# Top features: {'dist_front_mean': '14.9%', 'ttc_front_mean': '10.0%', 'x_lane_mean': '8.7%', 'num_lanes_mean': '7.7%', 'osm_delay_mean': '6.8%', 'alt_mean': '6.2%'}
# ----
# window: 93 knn: 3.435
# Top causes: {'Overspeed': '18.3%', 'Harsh maneuvers': '10.6%'}
# Top features: {'dist_front_mean': '15.6%', 'yaw_mean': '11.6%', 'ttc_front_mean': '10.8%', 'lat_mean': '5.2%', 'lon_osm_mean': '5.2%', 'lon_mean': '5.2%'}
# ----
# window: 94 knn: 4.052
# Top causes: {'Unstable steering': '18.9%', 'Overspeed': '15.3%'}
# Top features: {'dist_front_mean': '13.4%', 'ttc_front_mean': '10.2%', 'yaw_mean': '8.7%', 'lat_osm_mean': '8.3%', 'lat_mean': '8.2%', 'phi_mean': '6.8%'}
# ----
# window: 95 knn: 16.388
# Top causes: {'Harsh maneuvers': '84.0%', 'Overspeed': '16.0%'}
# Top features: {'acc_z_kf_mean': '30.1%', 'acc_z_mean': '27.7%', 'acc_y_kf_mean': '6.4%', 'acc_y_mean': '6.4%', 'gps_speed_mean': '5.1%', 'speed_kmh_mean': '5.0%'}
# ----
# window: 96 knn: 7.335
# Top causes: {'Harsh maneuvers': '86.1%', 'Tailgating': '6.0%'}
# Top features: {'acc_y_kf_mean': '25.3%', 'acc_y_mean': '25.0%', 'pitch_mean': '9.7%', 'hdop_mean': '8.4%', 'vdop_mean': '5.1%', 'alt_mean': '4.1%'}
# ----
# window: 97 knn: 9.434
# Top causes: {'Harsh maneuvers': '80.0%', 'Overspeed': '10.8%'}
# Top features: {'acc_z_kf_mean': '22.4%', 'acc_z_mean': '20.8%', 'vdop_mean': '8.8%', 'hdop_mean': '8.2%', 'acc_y_kf_mean': '6.5%', 'acc_y_mean': '5.7%'}
# ----
# window: 98 knn: 14.356
# Top causes: {'Harsh maneuvers': '74.8%', 'Overspeed': '12.0%'}
# Top features: {'course_mean': '67.3%', 'hdop_mean': '9.8%', 'vdop_mean': '4.9%', 'x_lane_mean': '4.1%', 'acc_x_mean': '1.6%', 'acc_y_kf_mean': '1.3%'}
# ----
# window: 99 knn: 14.873
# Top causes: {'Harsh maneuvers': '74.3%', 'Overspeed': '11.1%'}
# Top features: {'course_mean': '63.2%', 'hdop_mean': '10.4%', 'vdop_mean': '10.3%', 'x_lane_mean': '5.2%', 'num_lanes_mean': '1.5%', 'roll_mean': '1.4%'}
# ----
# window: 100 knn: 15.383
# Top causes: {'Overspeed': '31.5%', 'Harsh maneuvers': '26.3%'}
# Top features: {'course_mean': '70.5%', 'vdop_mean': '8.1%', 'hdop_mean': '7.4%', 'x_lane_mean': '5.4%', 'speed_rel_mean': '1.3%', 'alt_mean': '1.3%'}
# ----
# window: 101 knn: 14.823
# Top causes: {'Tailgating': '33.4%', 'Unstable steering': '25.4%'}
# Top features: {'course_mean': '59.1%', 'vdop_mean': '12.4%', 'hdop_mean': '12.4%', 'x_lane_mean': '5.9%', 'phi_mean': '3.0%', 'alt_mean': '1.0%'}
# ----
# window: 102 knn: 15.307
# Top causes: {'Unstable steering': '45.3%', 'Overspeed': '27.8%'}
# Top features: {'course_mean': '52.0%', 'hdop_mean': '16.5%', 'vdop_mean': '15.9%', 'x_lane_mean': '6.2%', 'phi_mean': '3.0%', 'yaw_mean': '1.7%'}
# ----
# window: 103 knn: 16.914
# Top causes: {'Harsh maneuvers': '57.9%', 'Unstable steering': '33.1%'}
# Top features: {'course_mean': '61.0%', 'vdop_mean': '14.6%', 'hdop_mean': '10.0%', 'x_lane_mean': '2.7%', 'phi_mean': '2.3%', 'yaw_mean': '2.2%'}
# ----
# window: 104 knn: 17.275
# Top causes: {'Unstable steering': '54.8%', 'Tailgating': '20.4%'}
# Top features: {'course_mean': '54.6%', 'hdop_mean': '19.2%', 'vdop_mean': '13.8%', 'x_lane_mean': '3.7%', 'yaw_mean': '1.8%', 'pitch_mean': '1.5%'}
# ----
# window: 105 knn: 16.397
# Top causes: {'Unstable steering': '51.5%', 'Tailgating': '21.5%'}
# Top features: {'course_mean': '49.5%', 'hdop_mean': '18.6%', 'vdop_mean': '14.1%', 'x_lane_mean': '5.7%', 'phi_mean': '2.6%', 'yaw_mean': '2.1%'}
# ----
