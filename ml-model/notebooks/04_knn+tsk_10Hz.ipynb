# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
motor_df = pd.read_csv("motor_window_features_10Hz_KNN_ready.csv")
secondary_df = pd.read_csv("secondary_window_features_10Hz_KNN_ready.csv")

print("Motor windows:", motor_df.shape)
print("Secondary windows:", secondary_df.shape)

secondary_df.head(5)
# Out:
# Motor windows: (535, 40)
# Secondary windows: (327, 40)
#    t_10hz_mean  timestamp_mean  speed_kmh_mean   lat_mean  lon_mean  \
# 0       1199.5          119.95      113.150138  40.529548 -3.441663
# 1       1459.5          145.95      114.150083  40.534167 -3.446960
# 2       1719.5          171.95      113.640000  40.537531 -3.454224
# 3       1979.5          197.95      113.905958  40.540639 -3.461621
# 4       2239.5          223.95      114.565333  40.543104 -3.469355
#
#      alt_mean  vert_acc_mean  horiz_acc_mean  course_mean  difcourse_mean  \
# 0  635.907523       5.553246        5.245833   291.986450        2.299453
# 1  646.916125       5.488333        5.245833   302.150958        2.292566
# 2  656.628042       5.624167        5.245833   300.947750        2.273659
# 3  668.014375       5.746667        5.245833   295.752417        2.211698
# 4  680.536583       5.824167        5.245833   293.369667        2.384398
#
#    ...  gps_speed_mean  max_speed_mean  speed_rel_mean  num_lanes_mean  \
# 0  ...      113.332708       90.740665        1.130833        1.962154
# 1  ...      114.161667       86.033333        1.130833        1.834583
# 2  ...      113.642333       85.158333        1.089167        1.843750
# 3  ...      113.916542       84.652917        1.078333        1.850833
# 4  ...      114.602958       84.732083        1.094167        1.874167
#
#    lat_osm_mean  lon_osm_mean  osm_delay_mean  gps_speed_osm_mean  \
# 0     40.529483     -3.440870        1.623084          112.821897
# 1     40.533707     -3.445721        1.942002          114.040458
# 2     40.536876     -3.452646        2.135032          112.815292
# 3     40.540000     -3.459575        2.760698          113.192542
# 4     40.542584     -3.466453        3.569630          113.995958
#
#    speed_ratio_mean  label
# 0          1.346173      0
# 1          1.481055      0
# 2          1.486653      0
# 3          0.810597      0
# 4          0.816965      0
#
# [5 rows x 40 columns]

# %% [markdown]
# We isolate normal driving windows to use them as the reference baseline for distance calculations.

# %%
motor_normal_df = motor_df[motor_df["label"] == 2]
secondary_normal_df = secondary_df[secondary_df["label"] == 2]

print("Motor NORMAL:", motor_normal_df.shape)
print("Secondary NORMAL:", secondary_normal_df.shape)
# Out:
# Motor NORMAL: (170, 40)
# Secondary NORMAL: (110, 40)

# %% [markdown]
# We define which numeric driving features are used to measure similarity and distance.

# %%
feature_cols = (motor_normal_df.select_dtypes(include=["int64", "float64"]).drop(columns=["label"]).columns.tolist())
print("Number of features:", len(feature_cols))
feature_cols[:5]
# Out:
# Number of features: 39
# ['t_10hz_mean', 'timestamp_mean', 'speed_kmh_mean', 'lat_mean', 'lon_mean']

# %% [markdown]
# Scaling = teaching the system what “normal” looks like, feature by feature.

# %%
motor_scaler = StandardScaler()
secondary_scaler = StandardScaler()

motor_normal_scaled = motor_scaler.fit_transform(motor_normal_df[feature_cols])
secondary_normal_scaled = secondary_scaler.fit_transform(secondary_normal_df[feature_cols])

print("Scalers fitted for both road types")
# Out:
# Scalers fitted for both road types

# %%
motor_knn = NearestNeighbors(n_neighbors=5, metric="euclidean")
secondary_knn = NearestNeighbors(n_neighbors=5, metric="euclidean")

motor_knn.fit(motor_normal_scaled)
secondary_knn.fit(secondary_normal_scaled)

print("KNN models trained for motor & secondary")
# Out:
# KNN models trained for motor & secondary

# %%
def knn_distance(row, scaler, knn, feature_cols):
    row_df = row[feature_cols].to_frame().T
    row_scaled = scaler.transform(row_df)
    distances, _ = knn.kneighbors(row_scaled)
    return distances.mean()

# %% [markdown]
# Apply distance to all windows (per road)

# %%
motor_df["knn_distance"] = motor_df.apply(
    lambda row: knn_distance(row, motor_scaler, motor_knn, feature_cols),
    axis=1
)

# %%
secondary_df["knn_distance"] = secondary_df.apply(
    lambda row: knn_distance(row, secondary_scaler, secondary_knn, feature_cols),
    axis=1
)

# %%
print("Motor mean distance by label")
print(motor_df.groupby("label")["knn_distance"].mean())

print("\nSecondary mean distance by label")
print(secondary_df.groupby("label")["knn_distance"].mean())
# Out:
# Motor mean distance by label
# label
# 0     9.497777
# 1    18.118607
# 2     1.553104
# Name: knn_distance, dtype: float64
#
# Secondary mean distance by label
# label
# 0    11.034117
# 1    11.872582
# 2     2.107862
# Name: knn_distance, dtype: float64

# %%
# Motor threshold (based on NORMAL only)
motor_normal_dist = motor_df[motor_df["label"] == 2]["knn_distance"]
motor_threshold = motor_normal_dist.mean() + 2 * motor_normal_dist.std()

# Secondary threshold
secondary_normal_dist = secondary_df[secondary_df["label"] == 2]["knn_distance"]
secondary_threshold = secondary_normal_dist.mean() + 2 * secondary_normal_dist.std()

motor_threshold, secondary_threshold
# Out:
# (np.float64(3.131017499373553), np.float64(3.318903349217031))

# %%
motor_abnormal = motor_df[motor_df["knn_distance"] > motor_threshold].copy()
secondary_abnormal = secondary_df[secondary_df["knn_distance"] > secondary_threshold].copy()

motor_abnormal.shape, secondary_abnormal.shape
# Out:
# ((344, 41), (220, 41))

# %% [markdown]
# These are just quick checks to see if everything is okay

# %%
motor_abnormal["label"].value_counts()
# Out:
# label
# 1    208
# 0    127
# 2      9
# Name: count, dtype: int64

# %%
motor_df.groupby("label")["knn_distance"].describe()
# Out:
#        count       mean        std       min       25%       50%        75%  \
# label
# 0      154.0   9.497777  15.827434  1.586122  3.561238  4.957280   7.296057
# 1      211.0  18.118607  30.679579  2.372704  5.765132  7.799655  10.381865
# 2      170.0   1.553104   0.788957  0.750604  1.020095  1.231511   1.807330
#
#               max
# label
# 0       96.049859
# 1      128.370839
# 2        5.177361

# %%
motor_df.shape, motor_abnormal.shape
len(motor_abnormal) / len(motor_df)
# Out:
# 0.6429906542056075

# %% [markdown]
# Preparing data for clustering

# %%
motor_X = motor_scaler.transform(motor_abnormal[feature_cols])
secondary_X = secondary_scaler.transform(secondary_abnormal[feature_cols])

# %%
from sklearn.cluster import KMeans

motor_kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

motor_clusters = motor_kmeans.fit_predict(motor_X)

motor_abnormal["cluster"] = motor_clusters
motor_abnormal["cluster"].value_counts()
# Out:
# cluster
# 0    309
# 1     19
# 2     16
# Name: count, dtype: int64

# %%
secondary_kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

secondary_clusters = secondary_kmeans.fit_predict(secondary_X)

secondary_abnormal["cluster"] = secondary_clusters
secondary_abnormal["cluster"].value_counts()
# Out:
# cluster
# 2    101
# 0     91
# 1     28
# Name: count, dtype: int64

# %% [markdown]
# Naming the clusters, we decide this through seeing which features are the highest in each cluster (for each type of aggressive or drowsy behaving there is features that explain the type of this action, example: max_speed --> overspeeding and so on...

# %%
# Look at average feature values per cluster (motor)
motor_cluster_summary = (
    motor_abnormal
    .groupby("cluster")[feature_cols]
    .mean()
)

motor_cluster_summary
# Out:
#          t_10hz_mean  timestamp_mean  speed_kmh_mean   lat_mean  lon_mean  \
# cluster
# 0        4943.781077      494.378108       98.078137  40.479547 -3.422619
# 1        2581.213750      258.121375       89.173330  40.481543 -3.411545
# 2        3815.537630      381.553763       96.778714  40.479824 -3.424510
#
#            alt_mean  vert_acc_mean  horiz_acc_mean  course_mean  \
# cluster
# 0        591.817552       3.962128        7.234170   149.380020
# 1        592.336465       5.204803       15.444715   232.458606
# 2        594.022680       4.148385       20.598568   188.919003
#
#          difcourse_mean  ...  num_vehicles_mean  gps_speed_mean  \
# cluster                  ...
# 0              1.666064  ...           1.464029       98.926379
# 1              1.225628  ...           1.501601       91.594436
# 2              1.786037  ...           1.540990      100.289352
#
#          max_speed_mean  speed_rel_mean  num_lanes_mean  lat_osm_mean  \
# cluster
# 0            111.024513        1.016808        2.700698     40.274563
# 1            111.121798        1.042390        2.802544     40.481324
# 2            112.128229        1.025495        2.732708     40.478492
#
#          lon_osm_mean  osm_delay_mean  gps_speed_osm_mean  speed_ratio_mean
# cluster
# 0           -3.406974        2.054703           98.820019         -1.151836
# 1           -3.412249        2.727827           91.572823         -3.403812
# 2           -3.426966        1.908712          100.658648         -0.167782
#
# [3 rows x 39 columns]

# %%
# Look at average feature values per cluster (secondary)
secondary_cluster_summary = (
    secondary_abnormal
    .groupby("cluster")[feature_cols]
    .mean()
)

secondary_cluster_summary
# Out:
#          t_10hz_mean  timestamp_mean  speed_kmh_mean   lat_mean  lon_mean  \
# cluster
# 0        2844.301447      284.430145       93.170407  40.555438 -3.494769
# 1        3859.088571      385.908857       87.618605  40.560254 -3.506600
# 2        3397.068020      339.706802       88.682899  40.547160 -3.476965
#
#            alt_mean  vert_acc_mean  horiz_acc_mean  course_mean  \
# cluster
# 0        659.168312       4.250068        8.945432   265.030969
# 1        685.903168       3.609613        6.685565   248.214608
# 2        665.957520       3.911677        8.245440   129.114117
#
#          difcourse_mean  ...  num_vehicles_mean  gps_speed_mean  \
# cluster                  ...
# 0              2.493731  ...           0.640842       94.234898
# 1              2.674874  ...           0.796190       87.878984
# 2              2.345008  ...           0.289773       89.777634
#
#          max_speed_mean  speed_rel_mean  num_lanes_mean  lat_osm_mean  \
# cluster
# 0             88.810014        1.145512        1.972784     40.553749
# 1             79.728897        1.080089        1.674745     40.558994
# 2             89.881432        1.137209        2.050695     40.547153
#
#          lon_osm_mean  osm_delay_mean  gps_speed_osm_mean  speed_ratio_mean
# cluster
# 0           -3.492427        2.402207           93.841304          0.854620
# 1           -3.501485       17.869709           87.767247         -8.421191
# 2           -3.478473        2.102073           89.648656          0.892955
#
# [3 rows x 39 columns]

# %%
motor_cluster_summary["harsh_score"] = (
    motor_cluster_summary["vert_acc_mean"].rank() +
    motor_cluster_summary["horiz_acc_mean"].rank()
)

motor_cluster_summary["overspeed_score"] = (
    motor_cluster_summary["speed_kmh_mean"].rank() +
    motor_cluster_summary["speed_ratio_mean"].rank()
)

motor_cluster_summary["unstable_score"] = (
    motor_cluster_summary["difcourse_mean"].rank()
    + motor_cluster_summary["horiz_acc_mean"].rank()
    + motor_cluster_summary["course_mean"].rank()
)

motor_cluster_summary[
    ["harsh_score", "overspeed_score", "unstable_score"]
]
# Out:
#          harsh_score  overspeed_score  unstable_score
# cluster
# 0                2.0              5.0             4.0
# 1                5.0              2.0             6.0
# 2                5.0              5.0             8.0

# %%
motor_cluster_labels = {}

for cluster_id, row in motor_cluster_summary.iterrows():

    scores = {
        "Overspeeding": row["overspeed_score"],
        "Harsh acceleration / braking": row["harsh_score"],
        "Unstable driving": row["unstable_score"]
    }

    dominant_behavior = max(scores, key=scores.get)
    motor_cluster_labels[cluster_id] = dominant_behavior

motor_cluster_labels
# Out:
# {0: 'Overspeeding', 1: 'Unstable driving', 2: 'Unstable driving'}

# %%
motor_cluster_summary[
    ["speed_kmh_mean", "vert_acc_mean", "horiz_acc_mean", "difcourse_mean",
     "overspeed_score", "harsh_score", "unstable_score"]
]
# Out:
#          speed_kmh_mean  vert_acc_mean  horiz_acc_mean  difcourse_mean  \
# cluster
# 0             98.078137       3.962128        7.234170        1.666064
# 1             89.173330       5.204803       15.444715        1.225628
# 2             96.778714       4.148385       20.598568        1.786037
#
#          overspeed_score  harsh_score  unstable_score
# cluster
# 0                    5.0          2.0             4.0
# 1                    2.0          5.0             6.0
# 2                    5.0          5.0             8.0

# %% [markdown]
# Now for secondary

# %%
secondary_cluster_summary["overspeed_score"] = (
    secondary_cluster_summary["speed_kmh_mean"].rank() +
    secondary_cluster_summary["speed_ratio_mean"].rank()
)

secondary_cluster_summary["harsh_score"] = (
    secondary_cluster_summary["vert_acc_mean"].rank() +
    secondary_cluster_summary["horiz_acc_mean"].rank()
)

secondary_cluster_summary["unstable_score"] = (
    secondary_cluster_summary["difcourse_mean"].rank()
    + secondary_cluster_summary["horiz_acc_mean"].rank()

)

secondary_cluster_summary[
    ["harsh_score", "overspeed_score", "unstable_score"]
]
# Out:
#          harsh_score  overspeed_score  unstable_score
# cluster
# 0                6.0              5.0             5.0
# 1                2.0              2.0             4.0
# 2                4.0              5.0             3.0

# %%
secondary_cluster_labels = {}

for cluster_id, row in secondary_cluster_summary.iterrows():

    scores = {
        "Overspeeding": row["overspeed_score"],
        "Harsh acceleration / braking": row["harsh_score"],
        "Unstable driving": row["unstable_score"]
    }

    dominant_behavior = max(scores, key=scores.get)
    secondary_cluster_labels[cluster_id] = dominant_behavior

secondary_cluster_labels
# Out:
# {0: 'Harsh acceleration / braking', 1: 'Unstable driving', 2: 'Overspeeding'}

# %%
secondary_cluster_summary[
    ["speed_kmh_mean", "vert_acc_mean", "horiz_acc_mean", "difcourse_mean",
     "overspeed_score", "harsh_score", "unstable_score"]
]
# Out:
#          speed_kmh_mean  vert_acc_mean  horiz_acc_mean  difcourse_mean  \
# cluster
# 0             93.170407       4.250068        8.945432        2.493731
# 1             87.618605       3.609613        6.685565        2.674874
# 2             88.682899       3.911677        8.245440        2.345008
#
#          overspeed_score  harsh_score  unstable_score
# cluster
# 0                    5.0          6.0             5.0
# 1                    2.0          2.0             4.0
# 2                    5.0          4.0             3.0

# %% [markdown]
# ### KNN NORMAL DIFFERENCES (Tells us how far a window is from normal driving) & CLUSTERING (Tell us what type of abnormal behaviour it looks like) PHASE IS DONE

# %% [markdown]
# ### Now we move to the next step: ALERTS APPEARING ON THE APP:
# This is the logic:
#
# If knn_distance > threshold → abnormal
# Else → no alert

# %%
def motor_alert(row, threshold):
    if row["knn_distance"] <= threshold:
        return "No alert"

    return row["cluster_label"]

# %% [markdown]
# Here we only assign clusters and behavior labels to windows that are far from normal, while normal windows remain unclustered and produce no alerts.

# %%
motor_df["cluster"] = np.nan
motor_df.loc[motor_abnormal.index, "cluster"] = motor_abnormal["cluster"]
motor_df["cluster_label"] = motor_df["cluster"].map(motor_cluster_labels)

# %%
secondary_df["cluster"] = np.nan
secondary_df.loc[secondary_abnormal.index, "cluster"] = secondary_abnormal["cluster"]
secondary_df["cluster_label"] = secondary_df["cluster"].map(secondary_cluster_labels)

# %%
motor_df["alert"] = motor_df.apply(
    lambda row: motor_alert(row, motor_threshold),
    axis=1
)

motor_df[["knn_distance", "cluster_label", "alert"]].head(10)
# Out:
#    knn_distance cluster_label         alert
# 0      6.023721  Overspeeding  Overspeeding
# 1      5.465373  Overspeeding  Overspeeding
# 2      5.254406  Overspeeding  Overspeeding
# 3      4.722549  Overspeeding  Overspeeding
# 4      4.460244  Overspeeding  Overspeeding
# 5      4.666339  Overspeeding  Overspeeding
# 6      5.218133  Overspeeding  Overspeeding
# 7      5.385052  Overspeeding  Overspeeding
# 8      5.273426  Overspeeding  Overspeeding
# 9      5.254328  Overspeeding  Overspeeding

# %%
secondary_df["alert"] = secondary_df.apply(
    lambda row: motor_alert(row, secondary_threshold),
    axis=1
)

secondary_df[["knn_distance", "cluster_label", "alert"]].head(10)
# Out:
#    knn_distance                 cluster_label                         alert
# 0     10.350809  Harsh acceleration / braking  Harsh acceleration / braking
# 1      9.510120  Harsh acceleration / braking  Harsh acceleration / braking
# 2      9.050889  Harsh acceleration / braking  Harsh acceleration / braking
# 3      8.658917  Harsh acceleration / braking  Harsh acceleration / braking
# 4      8.565062  Harsh acceleration / braking  Harsh acceleration / braking
# 5     10.252315  Harsh acceleration / braking  Harsh acceleration / braking
# 6     10.931043  Harsh acceleration / braking  Harsh acceleration / braking
# 7     10.305757  Harsh acceleration / braking  Harsh acceleration / braking
# 8     10.399414  Harsh acceleration / braking  Harsh acceleration / braking
# 9     10.683659  Harsh acceleration / braking  Harsh acceleration / braking

# %%
motor_df["alert"].value_counts()
# Out:
# alert
# Overspeeding        309
# No alert            191
# Unstable driving     35
# Name: count, dtype: int64

# %%
secondary_df["alert"].value_counts()
# Out:
# alert
# No alert                        107
# Overspeeding                    101
# Harsh acceleration / braking     91
# Unstable driving                 28
# Name: count, dtype: int64

# %% [markdown]
# Now we create the mapping messages

# %%
alert_messages = {
    "Overspeeding": "⚠️ Speed limit exceeded",
    "Harsh acceleration / braking": "⚠️ Harsh driving detected",
    "Unstable driving": "⚠️ Vehicle instability detected",
    "No alert": "Normal driving"
}

# %%
motor_df["alert_message"] = motor_df["alert"].map(alert_messages)
secondary_df["alert_message"] = secondary_df["alert"].map(alert_messages)

# %%
motor_df[["alert", "alert_message"]].head()
# Out:
#           alert            alert_message
# 0  Overspeeding  ⚠️ Speed limit exceeded
# 1  Overspeeding  ⚠️ Speed limit exceeded
# 2  Overspeeding  ⚠️ Speed limit exceeded
# 3  Overspeeding  ⚠️ Speed limit exceeded
# 4  Overspeeding  ⚠️ Speed limit exceeded

# %%
secondary_df[["alert", "alert_message"]].head()
# Out:
#                           alert              alert_message
# 0  Harsh acceleration / braking  ⚠️ Harsh driving detected
# 1  Harsh acceleration / braking  ⚠️ Harsh driving detected
# 2  Harsh acceleration / braking  ⚠️ Harsh driving detected
# 3  Harsh acceleration / braking  ⚠️ Harsh driving detected
# 4  Harsh acceleration / braking  ⚠️ Harsh driving detected

# %% [markdown]
# ### Normalizing

# %%
motor_alert_pct = (
    motor_df["alert"]
    .value_counts(normalize=True) * 100
).round(2)

motor_alert_pct
# Out:
# alert
# Overspeeding        57.76
# No alert            35.70
# Unstable driving     6.54
# Name: proportion, dtype: float64

# %%
secondary_alert_pct = (
    secondary_df["alert"]
    .value_counts(normalize=True) * 100
).round(2)

secondary_alert_pct
# Out:
# alert
# No alert                        32.72
# Overspeeding                    30.89
# Harsh acceleration / braking    27.83
# Unstable driving                 8.56
# Name: proportion, dtype: float64

# %% [markdown]
# ### Side-by-side comparison table

# %%
alert_comparison = (
    pd.concat(
        [
            motor_alert_pct.rename("Motorway (%)"),
            secondary_alert_pct.rename("Secondary (%)")
        ],
        axis=1
    )
    .fillna(0)
)

alert_comparison
# Out:
#                               Motorway (%)  Secondary (%)
# alert
# Overspeeding                         57.76          30.89
# No alert                             35.70          32.72
# Unstable driving                      6.54           8.56
# Harsh acceleration / braking          0.00          27.83

# %%
alert_comparison.plot(
    kind="bar",
    figsize=(7,4),
    title="Alert Distribution by Road Type"
)
# Out:
# <Axes: title={'center': 'Alert Distribution by Road Type'}, xlabel='alert'>

# %% [markdown]
# The alert distribution aligns with real-world driving expectations, confirming that the KNN-based detection and clustering pipeline produces meaningful and context-aware driving risk alerts.

# %% [markdown]
# # NOW WE REACHED THE PERFORMANCE SCORING

# %% [markdown]
# ### `“Given all detected behaviours, how risky is this driving profile?”`

# %% [markdown]
# We need a score that: increases when alerts increase, increases when alerts are severe and easy to explain
#
# The clean formula we’ll use
# Average severity × scaling factor

# %%
severity_map = {
    "No alert": 0,
    "Unstable driving": 1,
    "Harsh acceleration / braking": 2,
    "Overspeeding": 3
}

# %%
motor_df["severity"] = motor_df["alert"].map(severity_map)
secondary_df["severity"] = secondary_df["alert"].map(severity_map)

# %%
motor_avg_severity = motor_df["severity"].mean()
motor_avg_severity
# Out:
# np.float64(1.7981308411214953)

# %%
secondary_avg_severity = secondary_df["severity"].mean()
secondary_avg_severity
# Out:
# np.float64(1.5688073394495412)

# %% [markdown]
# Here we define the formula

# %%
def compute_session_performance(df, max_severity=3):
    avg_severity = df["severity"].mean()
    score = 100 - (avg_severity / max_severity) * 100
    return round(score, 2)

# %%
motor_score = compute_session_performance(motor_df)
secondary_score = compute_session_performance(secondary_df)

motor_score, secondary_score
# Out:
# (np.float64(40.06), np.float64(47.71))

# %% [markdown]
# # Phase (3): Feedback

# %%
import numpy as np
import pandas as pd

NORMAL_LABEL = 2

# Convert distance -> normal_score (bounded)
motor_df["normal_score"] = 1.0 / (1.0 + motor_df["knn_distance"])
secondary_df["normal_score"] = 1.0 / (1.0 + secondary_df["knn_distance"])

# Road-specific quantiles from NORMAL windows (used to normalize severity for fuzzy)
motor_q95 = motor_df.loc[motor_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.95)
motor_q99 = motor_df.loc[motor_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.99)

sec_q95   = secondary_df.loc[secondary_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.95)
sec_q99   = secondary_df.loc[secondary_df["label"]==NORMAL_LABEL, "knn_distance"].quantile(0.99)

def normalize_distance(d, q95, q99):
    # maps knn_distance -> severity s in [0,1]
    if d <= q95: return 0.0
    if d >= q99: return 1.0
    return float((d - q95) / (q99 - q95))

# %%
def window_zscores(df, scaler, cols):
    Z = scaler.transform(df[cols])
    return pd.DataFrame(Z, columns=cols, index=df.index)

motor_Z = window_zscores(motor_df, motor_scaler, feature_cols)
sec_Z   = window_zscores(secondary_df, secondary_scaler, feature_cols)

# squared deviation per feature (in z-space)
motor_contrib = motor_Z**2
sec_contrib   = sec_Z**2

# normalize per window -> percentages (sum = 1)
motor_contrib_norm = motor_contrib.div(motor_contrib.sum(axis=1).replace(0,np.nan), axis=0).fillna(0)
sec_contrib_norm   = sec_contrib.div(sec_contrib.sum(axis=1).replace(0,np.nan), axis=0).fillna(0)

# %%
def pick_cols_by_keywords(cols, keywords):
    cols = list(cols)
    out = []
    for c in cols:
        lc = c.lower()
        if any(k in lc for k in keywords):
            out.append(c)
    return out

CAUSE_GROUPS = {
    "Overspeed": pick_cols_by_keywords(feature_cols, ["speed", "max_speed", "speed_ratio", "gps_speed"]),
    "Tailgating": pick_cols_by_keywords(feature_cols, ["dist_front", "ttc_front", "headway", "num_vehicles"]),
    "Harsh maneuvers": pick_cols_by_keywords(feature_cols, ["acc_", "vert_acc", "horiz_acc", "jerk"]),
    "Unstable steering": pick_cols_by_keywords(feature_cols, ["difcourse", "yaw", "steer"]),
}

# remove empty groups (if any keywords don't exist in your file)
CAUSE_GROUPS = {k:v for k,v in CAUSE_GROUPS.items() if len(v)>0}
print("CAUSE_GROUPS:", {k: len(v) for k,v in CAUSE_GROUPS.items()})
# Out:
# CAUSE_GROUPS: {'Overspeed': 6, 'Tailgating': 3, 'Harsh maneuvers': 8, 'Unstable steering': 2}

# %%
def cause_percentages(contrib_norm_row, cause_groups):
    out = {}
    for cause, cols in cause_groups.items():
        cols = [c for c in cols if c in contrib_norm_row.index]
        if cols:
            out[cause] = float(contrib_norm_row[cols].sum())
    s = sum(out.values())
    if s > 0:
        out = {k: v/s for k,v in out.items()}  # re-normalize causes to sum=1
    return dict(sorted(out.items(), key=lambda x: x[1], reverse=True))

motor_df["top_causes_norm"] = motor_contrib_norm.apply(lambda r: cause_percentages(r, CAUSE_GROUPS), axis=1)
secondary_df["top_causes_norm"] = sec_contrib_norm.apply(lambda r: cause_percentages(r, CAUSE_GROUPS), axis=1)

# %%
def tri(x, a, b, c):
    if x < a or x > c: return 0.0
    if x == b: return 1.0
    if a <= x < b:
        return 0.0 if b == a else (x - a) / (b - a)
    return 0.0 if c == b else (c - x) / (c - b)

def trap(x, a, b, c, d):
    if x < a or x > d: return 0.0
    if b <= x <= c: return 1.0
    if a <= x < b:
        return 0.0 if b == a else (x - a) / (b - a)
    return 0.0 if d == c else (d - x) / (d - c)

def fuzzify_inputs(s, p):
    # severity sets
    s_low  = trap(s, 0.0, 0.0, 0.2, 0.4)
    s_med  = tri (s, 0.3, 0.6, 0.85)
    s_high = trap(s, 0.7, 0.85, 1.0, 1.0)

    # dominance sets (tuned for percentages)
    p_small = trap(p, 0.0, 0.0, 0.15, 0.30)
    p_med   = tri (p, 0.25, 0.45, 0.65)
    p_dom   = trap(p, 0.45, 0.60, 1.0, 1.0)

    return {"s_low": s_low, "s_med": s_med, "s_high": s_high,
            "p_small": p_small, "p_med": p_med, "p_dom": p_dom}

def tsk_output(weights, outputs):
    w = np.array(weights, dtype=float)
    y = np.array(outputs, dtype=float)
    if w.sum() == 0:
        return 0.0
    return float((w*y).sum() / w.sum())

def intensity_for_cause(s, p):
    m = fuzzify_inputs(s, p)
    w1 = m["s_high"] * m["p_dom"]
    w2 = m["s_med"]  * m["p_dom"]
    w3 = m["s_high"] * m["p_med"]
    w4 = m["p_small"]
    return tsk_output([w1,w2,w3,w4], [0.95, 0.80, 0.60, 0.10])

# %%
MSG = {
    "Overspeed": "Reduce speed and keep within the road limit.",
    "Tailgating": "Increase following distance and keep a safe time gap.",
    "Harsh maneuvers": "Avoid harsh braking/acceleration; drive more smoothly.",
    "Unstable steering": "Avoid sudden steering/lane changes; keep smoother control."
}

def phase3_for_row(knn_d, q95, q99, causes_norm_dict):
    s = normalize_distance(knn_d, q95, q99)
    ranked = []
    for cause, p in causes_norm_dict.items():
        inten = intensity_for_cause(s, p)
        ranked.append((cause, p, inten, MSG.get(cause, cause)))
    ranked.sort(key=lambda x: x[2], reverse=True)  # sort by intensity
    return s, ranked

def build_phase3_table(df, q95, q99, top_col="top_causes_norm"):
    rows = []
    for idx, r in df.iterrows():
        s, ranked = phase3_for_row(float(r["knn_distance"]), q95, q99, r[top_col])
        rows.append({
            "index": idx,
            "label": int(r["label"]),
            "knn_distance": float(r["knn_distance"]),
            "severity_0_1": float(s),
            "top_2": ranked[:2],   # (cause, percent, intensity, msg)
        })
    return pd.DataFrame(rows)

motor_phase3 = build_phase3_table(motor_df, motor_q95, motor_q99)
sec_phase3   = build_phase3_table(secondary_df, sec_q95, sec_q99)

motor_phase3.head(10)
# Out:
#    index  label  knn_distance  severity_0_1  \
# 0      0      0      6.023721           1.0
# 1      1      0      5.465373           1.0
# 2      2      0      5.254406           1.0
# 3      3      0      4.722549           1.0
# 4      4      0      4.460244           1.0
# 5      5      0      4.666339           1.0
# 6      6      0      5.218133           1.0
# 7      7      0      5.385052           1.0
# 8      8      0      5.273426           1.0
# 9      9      0      5.254328           1.0
#
#                                                top_2
# 0  [(Overspeed, 0.5784225940884703, 0.84682324955...
# 1  [(Overspeed, 0.6981638768079487, 0.95, Reduce ...
# 2  [(Overspeed, 0.7416274582921825, 0.95, Reduce ...
# 3  [(Overspeed, 0.7353889994607437, 0.95, Reduce ...
# 4  [(Overspeed, 0.7164194963355349, 0.95, Reduce ...
# 5  [(Overspeed, 0.5499589390603735, 0.79992960568...
# 6  [(Harsh maneuvers, 0.6884018024349665, 0.95, A...
# 7  [(Harsh maneuvers, 0.7636095227199108, 0.95, A...
# 8  [(Harsh maneuvers, 0.7984540750673029, 0.95, A...
# 9  [(Harsh maneuvers, 0.8065779764964093, 0.95, A...

# %%
motor_abn = motor_phase3[motor_phase3["label"] != NORMAL_LABEL].sort_values("knn_distance", ascending=False).head(10)
sec_abn   = sec_phase3[sec_phase3["label"] != NORMAL_LABEL].sort_values("knn_distance", ascending=False).head(10)

display(motor_abn)
display(sec_abn)
# Out:
#      index  label  knn_distance  severity_0_1  \
# 463    463      1    128.370839           1.0
# 464    464      1    128.120990           1.0
# 462    462      1    127.932574           1.0
# 465    465      1    126.281364           1.0
# 461    461      1    125.120231           1.0
# 466    466      1    123.811943           1.0
# 460    460      1    123.226133           1.0
# 467    467      1    121.248590           1.0
# 468    468      1    119.071539           1.0
# 469    469      1    116.918257           1.0
#
#                                                  top_2
# 463  [(Harsh maneuvers, 0.9990064667375309, 0.95, A...
# 464  [(Harsh maneuvers, 0.9979744633887693, 0.95, A...
# 462  [(Harsh maneuvers, 0.99954910689815, 0.95, Avo...
# 465  [(Harsh maneuvers, 0.9977424714875834, 0.95, A...
# 461  [(Harsh maneuvers, 0.9996501137661403, 0.95, A...
# 466  [(Harsh maneuvers, 0.9974183306360651, 0.95, A...
# 460  [(Harsh maneuvers, 0.999593694058574, 0.95, Av...
# 467  [(Harsh maneuvers, 0.9969769706357947, 0.95, A...
# 468  [(Harsh maneuvers, 0.9957514462169886, 0.95, A...
# 469  [(Harsh maneuvers, 0.9944159333732807, 0.95, A...
#      index  label  knn_distance  severity_0_1  \
# 205    205      0     37.240562           1.0
# 204    204      0     37.197843           1.0
# 202    202      0     37.095268           1.0
# 203    203      0     36.932455           1.0
# 206    206      0     36.831407           1.0
# 207    207      0     32.459940           1.0
# 208    208      0     27.270608           1.0
# 201    201      0     27.115556           1.0
# 209    209      0     21.340070           1.0
# 224    224      1     19.427346           1.0
#
#                                                  top_2
# 205  [(Overspeed, 0.9516530307689922, 0.95, Reduce ...
# 204  [(Overspeed, 0.9529149082954161, 0.95, Reduce ...
# 202  [(Overspeed, 0.9758743375437475, 0.95, Reduce ...
# 203  [(Overspeed, 0.9527827393259335, 0.95, Reduce ...
# 206  [(Overspeed, 0.9703056771201122, 0.95, Reduce ...
# 207  [(Overspeed, 0.9517773740770152, 0.95, Reduce ...
# 208  [(Overspeed, 0.9589386741442799, 0.95, Reduce ...
# 201  [(Overspeed, 0.9171319466551243, 0.95, Reduce ...
# 209  [(Overspeed, 0.9497280884975018, 0.95, Reduce ...
# 224  [(Harsh maneuvers, 0.43405317067840987, 0.6, A...

# %%
def pct_dict(d, top_n=None):
    # d can be dict or list of tuples
    if isinstance(d, list):
        d = dict(d)
    items = list(d.items())
    if top_n is not None:
        items = items[:top_n]
    return {k: f"{v*100:.1f}%" for k, v in items}

def dict_topn(d, n=5):
    return dict(list(d.items())[:n])  # keeps ordering if already sorted

# %%
for idx, r in motor_phase3.iterrows():
    # Get top causes from motor_df using the index from motor_phase3
    top_causes_list = [(cause_tuple[0], cause_tuple[1]) for cause_tuple in r["top_2"]]
    # Get top features from motor_contrib_norm using the index from motor_phase3
    top_features_dict = motor_contrib_norm.loc[r["index"]].nlargest(6).to_dict()

    print("window:", r["index"], "knn:", round(float(r["knn_distance"]), 3))
    print("Top causes:", pct_dict(top_causes_list))
    print("Top features:", pct_dict(top_features_dict))
    print("----")
# Out:
# window: 0 knn: 6.024
# Top causes: {'Overspeed': '57.8%', 'Tailgating': '20.8%'}
# Top features: {'gps_speed_mean': '14.0%', 'gps_speed_osm_mean': '13.5%', 'speed_kmh_mean': '11.2%', 'vert_acc_mean': '6.4%', 'num_vehicles_mean': '6.0%', 'ttc_front_mean': '5.4%'}
# ----
# window: 1 knn: 5.465
# Top causes: {'Overspeed': '69.8%', 'Tailgating': '23.4%'}
# Top features: {'road_width_mean': '16.8%', 'gps_speed_mean': '15.1%', 'speed_kmh_mean': '15.0%', 'gps_speed_osm_mean': '14.7%', 'ttc_front_mean': '6.0%', 'num_vehicles_mean': '5.9%'}
# ----
# window: 2 knn: 5.254
# Top causes: {'Overspeed': '74.2%', 'Harsh maneuvers': '3.8%'}
# Top features: {'road_width_mean': '17.3%', 'speed_kmh_mean': '15.0%', 'gps_speed_mean': '14.9%', 'gps_speed_osm_mean': '14.8%', 'num_vehicles_mean': '5.7%', 'ttc_front_mean': '4.6%'}
# ----
# window: 3 knn: 4.723
# Top causes: {'Overspeed': '73.5%', 'Tailgating': '17.3%'}
# Top features: {'road_width_mean': '19.5%', 'speed_kmh_mean': '12.9%', 'gps_speed_mean': '12.8%', 'gps_speed_osm_mean': '12.7%', 'alt_mean': '6.2%', 'num_vehicles_mean': '4.9%'}
# ----
# window: 4 knn: 4.46
# Top causes: {'Overspeed': '71.6%', 'Tailgating': '16.9%'}
# Top features: {'road_width_mean': '21.5%', 'speed_kmh_mean': '10.9%', 'gps_speed_osm_mean': '10.7%', 'gps_speed_mean': '10.7%', 'alt_mean': '9.2%', 'num_vehicles_mean': '3.9%'}
# ----
# window: 5 knn: 4.666
# Top causes: {'Overspeed': '55.0%', 'Harsh maneuvers': '29.2%'}
# Top features: {'road_width_mean': '24.8%', 'alt_mean': '12.0%', 'speed_kmh_mean': '7.1%', 'gps_speed_osm_mean': '6.9%', 'gps_speed_mean': '6.8%', 'acc_x_mean': '4.7%'}
# ----
# window: 6 knn: 5.218
# Top causes: {'Harsh maneuvers': '68.8%', 'Overspeed': '18.2%'}
# Top features: {'road_width_mean': '14.3%', 'acc_x_mean': '13.3%', 'alt_mean': '12.3%', 'acc_x_kf_mean': '10.9%', 'vdop_mean': '4.9%', 'acc_z_kf_mean': '4.9%'}
# ----
# window: 7 knn: 5.385
# Top causes: {'Harsh maneuvers': '76.4%', 'Tailgating': '9.8%'}
# Top features: {'acc_x_mean': '12.7%', 'road_width_mean': '12.6%', 'acc_x_kf_mean': '10.7%', 'acc_z_kf_mean': '10.3%', 'acc_z_mean': '10.1%', 'alt_mean': '8.5%'}
# ----
# window: 8 knn: 5.273
# Top causes: {'Harsh maneuvers': '79.8%', 'Unstable steering': '9.3%'}
# Top features: {'acc_x_mean': '13.6%', 'acc_x_kf_mean': '11.6%', 'acc_z_kf_mean': '11.4%', 'acc_z_mean': '11.1%', 'road_width_mean': '10.9%', 'alt_mean': '7.8%'}
# ----
# window: 9 knn: 5.254
# Top causes: {'Harsh maneuvers': '80.7%', 'Unstable steering': '9.0%'}
# Top features: {'acc_z_kf_mean': '15.7%', 'acc_z_mean': '15.5%', 'acc_x_mean': '11.5%', 'acc_x_kf_mean': '9.8%', 'road_width_mean': '8.3%', 'difcourse_mean': '6.0%'}
# ----
# window: 10 knn: 5.037
# Top causes: {'Harsh maneuvers': '83.0%', 'Unstable steering': '9.6%'}
# Top features: {'acc_z_kf_mean': '17.7%', 'acc_z_mean': '17.5%', 'acc_x_mean': '10.4%', 'acc_x_kf_mean': '9.3%', 'road_width_mean': '6.8%', 'difcourse_mean': '6.3%'}
# ----
# window: 11 knn: 4.998
# Top causes: {'Harsh maneuvers': '82.6%', 'Unstable steering': '11.2%'}
# Top features: {'acc_z_kf_mean': '19.4%', 'acc_z_mean': '19.3%', 'acc_x_mean': '8.7%', 'acc_x_kf_mean': '7.7%', 'difcourse_mean': '7.1%', 'lon_mean': '5.3%'}
# ----
# window: 12 knn: 4.849
# Top causes: {'Harsh maneuvers': '71.2%', 'Unstable steering': '15.0%'}
# Top features: {'acc_z_kf_mean': '14.7%', 'acc_z_mean': '14.6%', 'difcourse_mean': '8.6%', 'acc_x_mean': '8.2%', 'acc_x_kf_mean': '7.1%', 'roll_mean': '6.6%'}
# ----
# window: 13 knn: 5.325
# Top causes: {'Harsh maneuvers': '66.4%', 'Tailgating': '14.8%'}
# Top features: {'acc_z_kf_mean': '15.5%', 'acc_z_mean': '15.2%', 'difcourse_mean': '8.1%', 'acc_x_mean': '7.4%', 'acc_x_kf_mean': '6.1%', 'roll_mean': '6.1%'}
# ----
# window: 14 knn: 5.635
# Top causes: {'Harsh maneuvers': '49.5%', 'Tailgating': '23.4%'}
# Top features: {'acc_z_kf_mean': '9.6%', 'acc_z_mean': '9.5%', 'difcourse_mean': '8.2%', 'roll_mean': '7.6%', 'num_vehicles_mean': '7.3%', 'acc_x_mean': '6.9%'}
# ----
# window: 15 knn: 5.995
# Top causes: {'Harsh maneuvers': '30.9%', 'Tailgating': '30.9%'}
# Top features: {'num_vehicles_mean': '9.1%', 'dist_front_mean': '7.4%', 'ttc_front_mean': '6.8%', 'gps_speed_mean': '6.8%', 'speed_kmh_mean': '6.7%', 'gps_speed_osm_mean': '6.4%'}
# ----
# window: 16 knn: 5.333
# Top causes: {'Overspeed': '48.0%', 'Tailgating': '33.8%'}
# Top features: {'gps_speed_mean': '12.6%', 'speed_kmh_mean': '12.5%', 'gps_speed_osm_mean': '12.1%', 'num_vehicles_mean': '10.0%', 'ttc_front_mean': '8.4%', 'dist_front_mean': '8.2%'}
# ----
# window: 17 knn: 5.286
# Top causes: {'Overspeed': '59.7%', 'Tailgating': '24.9%'}
# Top features: {'gps_speed_mean': '16.9%', 'speed_kmh_mean': '16.7%', 'gps_speed_osm_mean': '16.1%', 'num_vehicles_mean': '8.2%', 'ttc_front_mean': '7.2%', 'dist_front_mean': '5.7%'}
# ----
# window: 18 knn: 5.556
# Top causes: {'Overspeed': '64.2%', 'Tailgating': '19.7%'}
# Top features: {'gps_speed_mean': '19.0%', 'speed_kmh_mean': '18.8%', 'gps_speed_osm_mean': '18.3%', 'num_vehicles_mean': '7.2%', 'vert_acc_mean': '6.2%', 'ttc_front_mean': '6.2%'}
# ----
# window: 19 knn: 5.413
# Top causes: {'Overspeed': '65.9%', 'Tailgating': '14.9%'}
# Top features: {'gps_speed_mean': '19.2%', 'speed_kmh_mean': '19.2%', 'gps_speed_osm_mean': '18.8%', 'vert_acc_mean': '7.6%', 'num_vehicles_mean': '5.1%', 'ttc_front_mean': '4.7%'}
# ----
# window: 20 knn: 5.501
# Top causes: {'Overspeed': '63.5%', 'Tailgating': '18.1%'}
# Top features: {'gps_speed_mean': '18.2%', 'speed_kmh_mean': '18.2%', 'gps_speed_osm_mean': '17.8%', 'vert_acc_mean': '6.7%', 'ttc_front_mean': '5.7%', 'num_vehicles_mean': '5.6%'}
# ----
# window: 21 knn: 5.247
# Top causes: {'Overspeed': '62.4%', 'Tailgating': '21.2%'}
# Top features: {'speed_kmh_mean': '16.2%', 'gps_speed_mean': '16.1%', 'gps_speed_osm_mean': '16.1%', 'vert_acc_mean': '7.2%', 'num_vehicles_mean': '6.2%', 'ttc_front_mean': '5.8%'}
# ----
# window: 22 knn: 7.124
# Top causes: {'Harsh maneuvers': '47.6%', 'Overspeed': '31.4%'}
# Top features: {'vert_acc_mean': '26.5%', 'horiz_acc_mean': '8.8%', 'gps_speed_mean': '8.5%', 'gps_speed_osm_mean': '8.4%', 'speed_kmh_mean': '6.3%', 'num_vehicles_mean': '5.1%'}
# ----
# window: 23 knn: 6.547
# Top causes: {'Harsh maneuvers': '51.8%', 'Overspeed': '24.5%'}
# Top features: {'vert_acc_mean': '28.6%', 'horiz_acc_mean': '9.4%', 'gps_speed_mean': '6.6%', 'gps_speed_osm_mean': '6.5%', 'road_width_mean': '5.6%', 'ttc_front_mean': '5.5%'}
# ----
# window: 24 knn: 6.054
# Top causes: {'Harsh maneuvers': '54.6%', 'Tailgating': '23.0%'}
# Top features: {'vert_acc_mean': '29.1%', 'horiz_acc_mean': '10.0%', 'road_width_mean': '6.3%', 'num_vehicles_mean': '6.1%', 'ttc_front_mean': '5.9%', 'gps_speed_mean': '5.2%'}
# ----
# window: 25 knn: 5.687
# Top causes: {'Harsh maneuvers': '60.6%', 'Tailgating': '23.2%'}
# Top features: {'vert_acc_mean': '29.7%', 'horiz_acc_mean': '10.3%', 'road_width_mean': '7.0%', 'num_vehicles_mean': '5.8%', 'lat_mean': '5.7%', 'ttc_front_mean': '5.7%'}
# ----
# window: 26 knn: 5.315
# Top causes: {'Harsh maneuvers': '64.6%', 'Tailgating': '23.5%'}
# Top features: {'vert_acc_mean': '30.0%', 'horiz_acc_mean': '10.6%', 'road_width_mean': '7.9%', 'lat_mean': '6.8%', 'ttc_front_mean': '5.5%', 'num_vehicles_mean': '5.4%'}
# ----
# window: 27 knn: 4.619
# Top causes: {'Harsh maneuvers': '69.5%', 'Tailgating': '23.7%'}
# Top features: {'vert_acc_mean': '29.5%', 'horiz_acc_mean': '9.5%', 'road_width_mean': '7.6%', 'vdop_mean': '7.2%', 'lat_mean': '6.3%', 'ttc_front_mean': '5.0%'}
# ----
# window: 28 knn: 4.571
# Top causes: {'Harsh maneuvers': '72.1%', 'Tailgating': '24.8%'}
# Top features: {'vert_acc_mean': '26.1%', 'vdop_mean': '11.3%', 'pdop_mean': '9.5%', 'horiz_acc_mean': '8.4%', 'road_width_mean': '7.5%', 'lat_mean': '5.3%'}
# ----
# window: 29 knn: 5.159
# Top causes: {'Harsh maneuvers': '66.7%', 'Tailgating': '31.8%'}
# Top features: {'vert_acc_mean': '21.4%', 'vdop_mean': '14.0%', 'pdop_mean': '8.8%', 'road_width_mean': '8.3%', 'horiz_acc_mean': '7.8%', 'ttc_front_mean': '5.7%'}
# ----
# window: 30 knn: 5.523
# Top causes: {'Harsh maneuvers': '69.9%', 'Tailgating': '28.3%'}
# Top features: {'vert_acc_mean': '21.7%', 'vdop_mean': '15.5%', 'pdop_mean': '8.5%', 'road_width_mean': '8.1%', 'horiz_acc_mean': '7.5%', 'dist_front_mean': '4.7%'}
# ----
# window: 31 knn: 5.99
# Top causes: {'Harsh maneuvers': '71.4%', 'Tailgating': '27.0%'}
# Top features: {'vert_acc_mean': '21.4%', 'vdop_mean': '14.7%', 'pdop_mean': '7.9%', 'road_width_mean': '7.8%', 'horiz_acc_mean': '7.0%', 'ttc_front_mean': '4.5%'}
# ----
# window: 32 knn: 8.0
# Top causes: {'Harsh maneuvers': '46.9%', 'Tailgating': '45.2%'}
# Top features: {'vdop_mean': '31.5%', 'hdop_mean': '9.3%', 'pdop_mean': '9.0%', 'vert_acc_mean': '7.3%', 'x_lane_mean': '5.0%', 'alt_mean': '4.9%'}
# ----
# window: 33 knn: 8.455
# Top causes: {'Harsh maneuvers': '54.3%', 'Tailgating': '35.8%'}
# Top features: {'vdop_mean': '33.3%', 'pdop_mean': '14.6%', 'hdop_mean': '8.2%', 'vert_acc_mean': '7.6%', 'alt_mean': '5.4%', 'x_lane_mean': '5.3%'}
# ----
# window: 34 knn: 9.076
# Top causes: {'Harsh maneuvers': '65.0%', 'Tailgating': '26.1%'}
# Top features: {'vdop_mean': '32.3%', 'pdop_mean': '20.5%', 'hdop_mean': '9.4%', 'vert_acc_mean': '8.3%', 'x_lane_mean': '5.1%', 'alt_mean': '4.9%'}
# ----
# window: 35 knn: 9.753
# Top causes: {'Harsh maneuvers': '71.3%', 'Tailgating': '21.5%'}
# Top features: {'pdop_mean': '31.0%', 'vdop_mean': '30.2%', 'hdop_mean': '8.7%', 'vert_acc_mean': '8.5%', 'alt_mean': '4.2%', 'x_lane_mean': '4.0%'}
# ----
# window: 36 knn: 9.949
# Top causes: {'Harsh maneuvers': '81.5%', 'Tailgating': '11.4%'}
# Top features: {'pdop_mean': '40.4%', 'vdop_mean': '28.9%', 'vert_acc_mean': '8.3%', 'hdop_mean': '6.0%', 'alt_mean': '3.8%', 'x_lane_mean': '3.1%'}
# ----
# window: 37 knn: 9.336
# Top causes: {'Harsh maneuvers': '77.9%', 'Tailgating': '14.0%'}
# Top features: {'vdop_mean': '31.5%', 'pdop_mean': '31.1%', 'vert_acc_mean': '9.2%', 'hdop_mean': '6.4%', 'alt_mean': '4.9%', 'x_lane_mean': '4.4%'}
# ----
# window: 38 knn: 8.742
# Top causes: {'Harsh maneuvers': '79.8%', 'Tailgating': '11.7%'}
# Top features: {'vdop_mean': '31.1%', 'pdop_mean': '24.7%', 'vert_acc_mean': '10.7%', 'hdop_mean': '8.6%', 'alt_mean': '5.2%', 'x_lane_mean': '4.6%'}
# ----
# window: 39 knn: 8.787
# Top causes: {'Harsh maneuvers': '85.6%', 'Tailgating': '7.7%'}
# Top features: {'vdop_mean': '31.4%', 'pdop_mean': '24.5%', 'vert_acc_mean': '13.1%', 'hdop_mean': '9.0%', 'alt_mean': '4.6%', 'x_lane_mean': '4.2%'}
# ----
# window: 40 knn: 8.856
# Top causes: {'Harsh maneuvers': '81.6%', 'Tailgating': '13.5%'}
# Top features: {'vdop_mean': '32.9%', 'pdop_mean': '24.0%', 'vert_acc_mean': '13.5%', 'hdop_mean': '9.0%', 'x_lane_mean': '4.5%', 'alt_mean': '3.8%'}
# ----
# window: 41 knn: 8.752
# Top causes: {'Harsh maneuvers': '78.4%', 'Tailgating': '17.8%'}
# Top features: {'vdop_mean': '32.9%', 'pdop_mean': '23.8%', 'vert_acc_mean': '11.6%', 'hdop_mean': '7.6%', 'roll_mean': '3.4%', 'x_lane_mean': '3.3%'}
# ----
# window: 42 knn: 8.58
# Top causes: {'Harsh maneuvers': '71.8%', 'Tailgating': '15.4%'}
# Top features: {'vdop_mean': '25.0%', 'pdop_mean': '20.6%', 'vert_acc_mean': '8.4%', 'roll_mean': '7.4%', 'hdop_mean': '5.3%', 'acc_z_mean': '4.5%'}
# ----
# window: 43 knn: 7.8
# Top causes: {'Harsh maneuvers': '65.9%', 'Tailgating': '19.3%'}
# Top features: {'vdop_mean': '23.4%', 'pdop_mean': '15.6%', 'vert_acc_mean': '9.5%', 'roll_mean': '7.2%', 'hdop_mean': '5.9%', 'acc_z_mean': '5.3%'}
# ----
# window: 44 knn: 6.951
# Top causes: {'Harsh maneuvers': '66.1%', 'Tailgating': '18.5%'}
# Top features: {'vdop_mean': '22.3%', 'pdop_mean': '10.4%', 'roll_mean': '10.1%', 'vert_acc_mean': '9.4%', 'acc_z_mean': '6.5%', 'acc_z_kf_mean': '6.3%'}
# ----
# window: 45 knn: 5.96
# Top causes: {'Harsh maneuvers': '68.2%', 'Tailgating': '15.8%'}
# Top features: {'vdop_mean': '20.9%', 'roll_mean': '13.9%', 'vert_acc_mean': '9.9%', 'acc_z_mean': '7.5%', 'acc_z_kf_mean': '7.3%', 'difcourse_mean': '5.1%'}
# ----
# window: 46 knn: 5.493
# Top causes: {'Harsh maneuvers': '64.9%', 'Unstable steering': '12.5%'}
# Top features: {'vdop_mean': '16.9%', 'roll_mean': '12.5%', 'vert_acc_mean': '10.2%', 'acc_z_mean': '8.4%', 'acc_z_kf_mean': '8.2%', 'difcourse_mean': '5.8%'}
# ----
# window: 47 knn: 5.513
# Top causes: {'Harsh maneuvers': '63.9%', 'Unstable steering': '13.5%'}
# Top features: {'vdop_mean': '17.1%', 'roll_mean': '12.7%', 'acc_z_mean': '8.7%', 'vert_acc_mean': '8.6%', 'acc_z_kf_mean': '8.5%', 'hdop_mean': '6.4%'}
# ----
# window: 48 knn: 5.502
# Top causes: {'Harsh maneuvers': '60.3%', 'Tailgating': '19.5%'}
# Top features: {'vdop_mean': '21.8%', 'roll_mean': '9.7%', 'hdop_mean': '7.9%', 'acc_z_mean': '7.5%', 'acc_z_kf_mean': '7.3%', 'difcourse_mean': '5.6%'}
# ----
# window: 49 knn: 6.306
# Top causes: {'Harsh maneuvers': '58.5%', 'Unstable steering': '18.4%'}
# Top features: {'vdop_mean': '26.8%', 'roll_mean': '9.3%', 'hdop_mean': '8.0%', 'acc_z_mean': '6.7%', 'acc_z_kf_mean': '6.6%', 'pdop_mean': '6.2%'}
# ----
# window: 50 knn: 7.615
# Top causes: {'Harsh maneuvers': '60.7%', 'Unstable steering': '19.6%'}
# Top features: {'vdop_mean': '29.9%', 'pdop_mean': '16.1%', 'roll_mean': '8.4%', 'hdop_mean': '7.5%', 'acc_z_mean': '4.8%', 'acc_z_kf_mean': '4.8%'}
# ----
# window: 51 knn: 9.258
# Top causes: {'Harsh maneuvers': '40.8%', 'Unstable steering': '29.1%'}
# Top features: {'vdop_mean': '35.0%', 'pdop_mean': '29.0%', 'hdop_mean': '9.2%', 'x_lane_mean': '4.6%', 'roll_mean': '3.7%', 'vert_acc_mean': '2.6%'}
# ----
# window: 52 knn: 10.418
# Top causes: {'Harsh maneuvers': '53.3%', 'Unstable steering': '24.5%'}
# Top features: {'pdop_mean': '37.2%', 'vdop_mean': '33.7%', 'hdop_mean': '7.6%', 'x_lane_mean': '3.8%', 'vert_acc_mean': '2.3%', 'yaw_mean': '1.9%'}
# ----
# window: 53 knn: 10.674
# Top causes: {'Harsh maneuvers': '48.9%', 'Unstable steering': '26.7%'}
# Top features: {'pdop_mean': '37.5%', 'vdop_mean': '34.8%', 'hdop_mean': '6.3%', 'x_lane_mean': '3.8%', 'alt_mean': '2.1%', 'vert_acc_mean': '1.9%'}
# ----
# window: 54 knn: 10.715
# Top causes: {'Harsh maneuvers': '42.5%', 'Unstable steering': '32.3%'}
# Top features: {'pdop_mean': '37.3%', 'vdop_mean': '34.9%', 'hdop_mean': '6.8%', 'x_lane_mean': '4.2%', 'alt_mean': '2.2%', 'yaw_mean': '2.2%'}
# ----
# window: 55 knn: 10.705
# Top causes: {'Harsh maneuvers': '38.9%', 'Unstable steering': '28.8%'}
# Top features: {'pdop_mean': '36.9%', 'vdop_mean': '34.5%', 'hdop_mean': '6.4%', 'x_lane_mean': '4.0%', 'alt_mean': '2.2%', 'yaw_mean': '1.9%'}
# ----
# window: 56 knn: 10.852
# Top causes: {'Harsh maneuvers': '41.7%', 'Unstable steering': '24.3%'}
# Top features: {'pdop_mean': '35.4%', 'vdop_mean': '34.2%', 'hdop_mean': '7.0%', 'x_lane_mean': '4.2%', 'vert_acc_mean': '2.1%', 'alt_mean': '2.0%'}
# ----
# window: 57 knn: 10.595
# Top causes: {'Harsh maneuvers': '53.7%', 'Unstable steering': '17.9%'}
# Top features: {'pdop_mean': '35.8%', 'vdop_mean': '34.2%', 'hdop_mean': '6.5%', 'x_lane_mean': '3.9%', 'vert_acc_mean': '2.8%', 'roll_mean': '2.2%'}
# ----
# window: 58 knn: 10.107
# Top causes: {'Harsh maneuvers': '60.5%', 'Tailgating': '17.1%'}
# Top features: {'vdop_mean': '35.4%', 'pdop_mean': '31.3%', 'hdop_mean': '6.5%', 'vert_acc_mean': '4.3%', 'x_lane_mean': '4.2%', 'roll_mean': '2.3%'}
# ----
# window: 59 knn: 9.927
# Top causes: {'Harsh maneuvers': '59.5%', 'Tailgating': '23.2%'}
# Top features: {'vdop_mean': '33.5%', 'pdop_mean': '29.1%', 'hdop_mean': '7.6%', 'x_lane_mean': '4.5%', 'vert_acc_mean': '4.4%', 'roll_mean': '3.4%'}
# ----
# window: 60 knn: 9.69
# Top causes: {'Harsh maneuvers': '59.8%', 'Tailgating': '28.4%'}
# Top features: {'vdop_mean': '31.1%', 'pdop_mean': '29.1%', 'hdop_mean': '8.7%', 'x_lane_mean': '4.6%', 'vert_acc_mean': '4.2%', 'roll_mean': '3.2%'}
# ----
# window: 61 knn: 6.806
# Top causes: {'Harsh maneuvers': '74.5%', 'Tailgating': '19.9%'}
# Top features: {'pdop_mean': '24.7%', 'vdop_mean': '22.1%', 'vert_acc_mean': '13.6%', 'roll_mean': '6.7%', 'road_width_mean': '6.4%', 'horiz_acc_mean': '3.4%'}
# ----
# window: 62 knn: 5.812
# Top causes: {'Harsh maneuvers': '80.5%', 'Tailgating': '16.4%'}
# Top features: {'vert_acc_mean': '18.9%', 'vdop_mean': '16.8%', 'pdop_mean': '14.6%', 'roll_mean': '8.3%', 'road_width_mean': '8.0%', 'horiz_acc_mean': '6.6%'}
# ----
# window: 63 knn: 5.051
# Top causes: {'Harsh maneuvers': '79.2%', 'Tailgating': '18.0%'}
# Top features: {'vert_acc_mean': '18.8%', 'vdop_mean': '16.5%', 'pdop_mean': '13.5%', 'roll_mean': '8.4%', 'road_width_mean': '7.5%', 'horiz_acc_mean': '7.0%'}
# ----
# window: 64 knn: 4.492
# Top causes: {'Harsh maneuvers': '76.8%', 'Tailgating': '20.9%'}
# Top features: {'vert_acc_mean': '17.7%', 'vdop_mean': '16.6%', 'pdop_mean': '13.9%', 'roll_mean': '8.3%', 'horiz_acc_mean': '7.2%', 'road_width_mean': '6.7%'}
# ----
# window: 65 knn: 3.426
# Top causes: {'Tailgating': '16.9%', 'Overspeed': '1.3%'}
# Top features: {'vert_acc_mean': '17.9%', 'vdop_mean': '16.6%', 'pdop_mean': '15.6%', 'horiz_acc_mean': '8.1%', 'road_width_mean': '6.2%', 'roll_mean': '4.8%'}
# ----
# window: 66 knn: 2.684
# Top causes: {'Tailgating': '17.2%', 'Overspeed': '1.6%'}
# Top features: {'vert_acc_mean': '17.5%', 'pdop_mean': '16.6%', 'vdop_mean': '14.6%', 'horiz_acc_mean': '8.6%', 'road_width_mean': '5.4%', 'lat_mean': '5.3%'}
# ----
# window: 67 knn: 2.024
# Top causes: {'Tailgating': '8.5%', 'Overspeed': '2.9%'}
# Top features: {'vert_acc_mean': '19.0%', 'pdop_mean': '18.6%', 'vdop_mean': '11.7%', 'horiz_acc_mean': '9.6%', 'lat_mean': '5.7%', 'road_width_mean': '4.8%'}
# ----
# window: 68 knn: 1.925
# Top causes: {'Tailgating': '4.6%', 'Overspeed': '4.3%'}
# Top features: {'pdop_mean': '20.1%', 'vert_acc_mean': '19.2%', 'horiz_acc_mean': '10.4%', 'vdop_mean': '7.9%', 'lat_mean': '5.4%', 'active_mean': '4.8%'}
# ----
# window: 69 knn: 2.124
# Top causes: {'Overspeed': '6.4%', 'Tailgating': '5.5%'}
# Top features: {'vert_acc_mean': '23.1%', 'horiz_acc_mean': '12.3%', 'pdop_mean': '10.2%', 'active_mean': '5.7%', 'lat_mean': '5.1%', 'vdop_mean': '4.2%'}
# ----
# window: 70 knn: 3.305
# Top causes: {'Overspeed': '9.7%', 'Tailgating': '4.7%'}
# Top features: {'vert_acc_mean': '25.2%', 'horiz_acc_mean': '13.3%', 'active_mean': '6.1%', 'phi_mean': '4.3%', 'lane_state_mean': '4.0%', 'timestamp_mean': '3.9%'}
# ----
# window: 71 knn: 2.166
# Top causes: {'Tailgating': '8.0%', 'Unstable steering': '1.1%'}
# Top features: {'vert_acc_mean': '15.3%', 'timestamp_mean': '11.0%', 't_10hz_mean': '11.0%', 'gps_speed_mean': '7.5%', 'gps_speed_osm_mean': '7.1%', 'speed_kmh_mean': '6.8%'}
# ----
# window: 72 knn: 1.471
# Top causes: {'Tailgating': '8.0%', 'Unstable steering': '3.3%'}
# Top features: {'speed_kmh_mean': '10.1%', 'gps_speed_mean': '9.9%', 'gps_speed_osm_mean': '9.6%', 'timestamp_mean': '7.9%', 't_10hz_mean': '7.9%', 'acc_x_kf_mean': '5.8%'}
# ----
# window: 73 knn: 1.16
# Top causes: {'Tailgating': '8.1%', 'Unstable steering': '5.0%'}
# Top features: {'speed_kmh_mean': '10.4%', 'gps_speed_mean': '10.3%', 'gps_speed_osm_mean': '10.2%', 'vert_acc_mean': '7.1%', 'timestamp_mean': '6.3%', 't_10hz_mean': '6.3%'}
# ----
# window: 74 knn: 0.977
# Top causes: {'Tailgating': '7.6%', 'Unstable steering': '5.0%'}
# Top features: {'vert_acc_mean': '11.6%', 'alt_mean': '10.7%', 'speed_kmh_mean': '9.1%', 'gps_speed_osm_mean': '8.9%', 'gps_speed_mean': '8.9%', 'roll_mean': '5.7%'}
# ----
# window: 75 knn: 0.928
# Top causes: {'Tailgating': '7.5%', 'Unstable steering': '5.1%'}
# Top features: {'alt_mean': '13.8%', 'vert_acc_mean': '12.1%', 'speed_kmh_mean': '8.5%', 'gps_speed_mean': '8.3%', 'gps_speed_osm_mean': '8.3%', 'acc_x_kf_mean': '4.1%'}
# ----
# window: 76 knn: 1.164
# Top causes: {'Harsh maneuvers': '27.0%', 'Tailgating': '20.4%'}
# Top features: {'alt_mean': '16.1%', 'vert_acc_mean': '9.4%', 'speed_kmh_mean': '7.8%', 'gps_speed_osm_mean': '7.7%', 'gps_speed_mean': '7.7%', 'dist_front_mean': '7.1%'}
# ----
# window: 77 knn: 1.079
# Top causes: {'Tailgating': '10.3%', 'Unstable steering': '6.0%'}
# Top features: {'alt_mean': '20.8%', 'vert_acc_mean': '10.2%', 'roll_mean': '7.3%', 'speed_kmh_mean': '6.3%', 'gps_speed_osm_mean': '6.2%', 'gps_speed_mean': '6.1%'}
# ----
# window: 78 knn: 1.612
# Top causes: {'Tailgating': '12.2%', 'Unstable steering': '4.8%'}
# Top features: {'alt_mean': '26.4%', 'vert_acc_mean': '10.9%', 'roll_mean': '9.4%', 'course_mean': '6.0%', 'pitch_mean': '4.5%', 'gps_speed_osm_mean': '3.6%'}
# ----
# window: 79 knn: 2.586
# Top causes: {'Tailgating': '22.7%', 'Overspeed': '11.3%'}
# Top features: {'alt_mean': '27.8%', 'vert_acc_mean': '10.6%', 'course_mean': '7.6%', 'roll_mean': '4.4%', 'road_width_mean': '3.9%', 'vdop_mean': '3.5%'}
# ----
# window: 80 knn: 1.446
# Top causes: {'Unstable steering': '7.3%', 'Tailgating': '6.2%'}
# Top features: {'acc_y_mean': '15.3%', 'acc_y_kf_mean': '15.2%', 'acc_z_mean': '14.0%', 'acc_z_kf_mean': '14.0%', 'alt_mean': '9.6%', 'difcourse_mean': '5.2%'}
# ----
# window: 81 knn: 1.082
# Top causes: {'Unstable steering': '9.0%', 'Tailgating': '5.0%'}
# Top features: {'acc_y_mean': '15.8%', 'acc_y_kf_mean': '15.7%', 'acc_z_kf_mean': '14.3%', 'acc_z_mean': '14.2%', 'alt_mean': '7.3%', 'difcourse_mean': '6.6%'}
# ----
# window: 82 knn: 0.95
# Top causes: {'Unstable steering': '13.6%', 'Tailgating': '3.1%'}
# Top features: {'acc_y_mean': '15.4%', 'acc_y_kf_mean': '15.3%', 'acc_z_kf_mean': '13.9%', 'acc_z_mean': '13.7%', 'difcourse_mean': '10.0%', 'alt_mean': '6.1%'}
# ----
# window: 83 knn: 1.001
# Top causes: {'Unstable steering': '13.4%', 'Tailgating': '2.6%'}
# Top features: {'acc_y_mean': '16.7%', 'acc_y_kf_mean': '16.6%', 'acc_z_kf_mean': '14.2%', 'acc_z_mean': '14.0%', 'difcourse_mean': '9.9%', 'lon_mean': '4.3%'}
# ----
# window: 84 knn: 1.056
# Top causes: {'Unstable steering': '15.1%', 'Tailgating': '2.5%'}
# Top features: {'acc_y_mean': '17.1%', 'acc_y_kf_mean': '17.0%', 'acc_z_kf_mean': '14.5%', 'acc_z_mean': '14.2%', 'difcourse_mean': '10.7%', 'lon_mean': '4.5%'}
# ----
# window: 85 knn: 1.147
# Top causes: {'Unstable steering': '15.9%', 'Tailgating': '2.2%'}
# Top features: {'acc_y_mean': '16.4%', 'acc_y_kf_mean': '16.3%', 'acc_z_kf_mean': '14.6%', 'acc_z_mean': '14.2%', 'difcourse_mean': '10.6%', 'lon_mean': '4.1%'}
# ----
# window: 86 knn: 1.282
# Top causes: {'Unstable steering': '16.8%', 'Tailgating': '7.0%'}
# Top features: {'acc_y_mean': '16.5%', 'acc_y_kf_mean': '16.3%', 'acc_z_kf_mean': '12.1%', 'acc_z_mean': '11.9%', 'difcourse_mean': '10.4%', 'road_width_mean': '3.6%'}
# ----
# window: 87 knn: 1.439
# Top causes: {'Unstable steering': '17.3%', 'Tailgating': '12.8%'}
# Top features: {'acc_y_kf_mean': '13.4%', 'acc_y_mean': '13.4%', 'acc_z_kf_mean': '12.6%', 'acc_z_mean': '12.1%', 'difcourse_mean': '9.6%', 'num_vehicles_mean': '4.9%'}
# ----
# window: 88 knn: 1.807
# Top causes: {'Tailgating': '17.4%', 'Unstable steering': '15.2%'}
# Top features: {'acc_y_kf_mean': '12.6%', 'acc_y_mean': '12.5%', 'acc_z_kf_mean': '9.5%', 'acc_z_mean': '9.1%', 'difcourse_mean': '6.4%', 'num_vehicles_mean': '6.0%'}
# ----
# window: 89 knn: 2.822
# Top causes: {'Overspeed': '18.5%', 'Unstable steering': '14.7%'}
# Top features: {'num_vehicles_mean': '8.9%', 'ttc_front_mean': '8.8%', 'yaw_mean': '8.3%', 'acc_y_kf_mean': '7.1%', 'acc_y_mean': '6.9%', 'dist_front_mean': '5.6%'}
# ----
# window: 90 knn: 1.438
# Top causes: {'Tailgating': '26.4%', 'Harsh maneuvers': '21.1%'}
# Top features: {'yaw_mean': '9.4%', 'gps_speed_osm_mean': '8.7%', 'speed_kmh_mean': '8.5%', 'gps_speed_mean': '8.4%', 'num_vehicles_mean': '8.2%', 'ttc_front_mean': '6.8%'}
# ----
# window: 91 knn: 1.073
# Top causes: {'Harsh maneuvers': '25.1%', 'Tailgating': '16.9%'}
# Top features: {'gps_speed_osm_mean': '9.5%', 'speed_kmh_mean': '9.3%', 'gps_speed_mean': '9.2%', 'yaw_mean': '9.2%', 'osm_delay_mean': '7.5%', 'num_vehicles_mean': '5.9%'}
# ----
# window: 92 knn: 0.982
# Top causes: {'Unstable steering': '17.2%', 'Harsh maneuvers': '29.8%'}
# Top features: {'yaw_mean': '9.6%', 'gps_speed_osm_mean': '9.0%', 'speed_kmh_mean': '8.8%', 'gps_speed_mean': '8.6%', 'osm_delay_mean': '7.4%', 'acc_x_kf_mean': '6.7%'}
# ----
# window: 93 knn: 1.059
# Top causes: {'Harsh maneuvers': '29.2%', 'Unstable steering': '20.4%'}
# Top features: {'yaw_mean': '10.8%', 'gps_speed_osm_mean': '8.6%', 'speed_kmh_mean': '8.2%', 'gps_speed_mean': '8.1%', 'acc_x_kf_mean': '6.5%', 'course_mean': '6.3%'}
# ----
# window: 94 knn: 1.14
# Top causes: {'Unstable steering': '21.5%', 'Tailgating': '11.1%'}
# Top features: {'yaw_mean': '11.4%', 'acc_x_kf_mean': '7.4%', 'speed_kmh_mean': '7.2%', 'course_mean': '7.1%', 'gps_speed_mean': '7.0%', 'gps_speed_osm_mean': '7.0%'}
# ----
# window: 95 knn: 1.261
# Top causes: {'Overspeed': '29.5%', 'Unstable steering': '23.8%'}
# Top features: {'yaw_mean': '11.2%', 'acc_x_kf_mean': '9.0%', 'roll_mean': '7.9%', 'acc_x_mean': '7.3%', 'course_mean': '7.3%', 't_10hz_mean': '5.6%'}
# ----
# window: 96 knn: 1.382
# Top causes: {'Unstable steering': '29.8%', 'Overspeed': '27.8%'}
# Top features: {'yaw_mean': '12.6%', 'course_mean': '8.3%', 'roll_mean': '8.2%', 't_10hz_mean': '7.6%', 'timestamp_mean': '7.6%', 'acc_x_kf_mean': '6.6%'}
# ----
# window: 97 knn: 2.028
# Top causes: {'Overspeed': '10.4%', 'Tailgating': '7.3%'}
# Top features: {'roll_mean': '15.1%', 'yaw_mean': '12.2%', 't_10hz_mean': '8.9%', 'timestamp_mean': '8.9%', 'acc_x_kf_mean': '8.2%', 'course_mean': '7.8%'}
# ----
# window: 98 knn: 10.961
# Top causes: {'Unstable steering': '28.6%', 'Tailgating': '27.7%'}
# Top features: {'pdop_mean': '38.9%', 'vdop_mean': '17.9%', 'active_mean': '6.4%', 'x_lane_mean': '5.6%', 'phi_mean': '5.2%', 'road_width_mean': '5.1%'}
# ----
# window: 99 knn: 11.065
# Top causes: {'Overspeed': '56.6%', 'Harsh maneuvers': '22.6%'}
# Top features: {'pdop_mean': '54.1%', 'vdop_mean': '25.4%', 'hdop_mean': '6.9%', 'alt_mean': '2.6%', 'timestamp_mean': '1.3%', 't_10hz_mean': '1.3%'}
# ----
# window: 100 knn: 10.907
# Top causes: {'Overspeed': '58.2%', 'Harsh maneuvers': '25.0%'}
# Top features: {'pdop_mean': '56.8%', 'vdop_mean': '24.6%', 'hdop_mean': '6.2%', 'alt_mean': '2.2%', 'timestamp_mean': '1.2%', 't_10hz_mean': '1.2%'}
# ----
# window: 101 knn: 9.895
# Top causes: {'Overspeed': '59.7%', 'Harsh maneuvers': '23.7%'}
# Top features: {'pdop_mean': '55.1%', 'vdop_mean': '24.0%', 'hdop_mean': '5.7%', 'alt_mean': '2.2%', 'timestamp_mean': '1.3%', 't_10hz_mean': '1.3%'}
# ----
# window: 102 knn: 8.98
# Top causes: {'Overspeed': '65.8%', 'Harsh maneuvers': '20.7%'}
# Top features: {'pdop_mean': '50.3%', 'vdop_mean': '23.2%', 'hdop_mean': '5.0%', 'alt_mean': '2.3%', 'speed_kmh_mean': '2.2%', 'gps_speed_mean': '2.2%'}
# ----
# window: 103 knn: 7.353
# Top causes: {'Overspeed': '69.7%', 'Harsh maneuvers': '15.8%'}
# Top features: {'pdop_mean': '41.4%', 'vdop_mean': '21.3%', 'hdop_mean': '4.5%', 'speed_kmh_mean': '4.0%', 'gps_speed_mean': '3.9%', 'gps_speed_osm_mean': '3.8%'}
# ----
# window: 104 knn: 5.752
# Top causes: {'Overspeed': '59.2%', 'Harsh maneuvers': '22.6%'}
# Top features: {'pdop_mean': '29.0%', 'vdop_mean': '17.1%', 'speed_kmh_mean': '5.6%', 'gps_speed_mean': '5.5%', 'gps_speed_osm_mean': '5.5%', 'hdop_mean': '3.5%'}
# ----
# window: 105 knn: 4.349
# Top causes: {'Overspeed': '55.4%', 'Tailgating': '13.1%'}
# Top features: {'pdop_mean': '13.7%', 'vdop_mean': '11.9%', 'speed_kmh_mean': '6.8%', 'gps_speed_mean': '6.6%', 'gps_speed_osm_mean': '6.6%', 'course_mean': '5.2%'}
# ----
# window: 106 knn: 3.839
# Top causes: {'Harsh maneuvers': '47.7%', 'Tailgating': '16.5%'}
# Top features: {'course_mean': '8.5%', 'acc_x_mean': '8.5%', 'acc_x_kf_mean': '7.8%', 'num_vehicles_mean': '5.9%', 'pitch_mean': '5.7%', 'vdop_mean': '5.0%'}
# ----
# window: 107 knn: 3.812
# Top causes: {'Harsh maneuvers': '72.5%', 'Tailgating': '15.4%'}
# Top features: {'acc_x_mean': '13.9%', 'acc_x_kf_mean': '12.9%', 'course_mean': '10.0%', 'vert_acc_mean': '7.4%', 'num_vehicles_mean': '4.8%', 'hdop_mean': '4.7%'}
# ----
# window: 108 knn: 3.559
# Top causes: {'Harsh maneuvers': '78.2%', 'Unstable steering': '15.0%'}
# Top features: {'acc_x_mean': '21.1%', 'acc_x_kf_mean': '21.1%', 'difcourse_mean': '10.5%', 'acc_z_mean': '4.5%', 'pitch_mean': '4.3%', 'acc_z_kf_mean': '4.0%'}
# ----
# window: 109 knn: 2.796
# Top causes: {'Unstable steering': '24.2%', 'Overspeed': '5.8%'}
# Top features: {'difcourse_mean': '16.5%', 'acc_x_kf_mean': '14.7%', 'acc_x_mean': '14.3%', 'acc_z_mean': '5.6%', 'acc_z_kf_mean': '5.1%', 'roll_mean': '4.7%'}
# ----
# window: 110 knn: 2.786
# Top causes: {'Unstable steering': '24.1%', 'Overspeed': '5.2%'}
# Top features: {'difcourse_mean': '15.0%', 'acc_x_kf_mean': '13.4%', 'acc_x_mean': '13.3%', 'roll_mean': '12.5%', 'acc_z_mean': '5.6%', 'acc_z_kf_mean': '5.4%'}
# ----
# window: 111 knn: 2.588
# Top causes: {'Unstable steering': '28.2%', 'Tailgating': '5.5%'}
# Top features: {'difcourse_mean': '16.4%', 'acc_x_kf_mean': '13.5%', 'acc_x_mean': '12.4%', 'roll_mean': '11.4%', 'lon_mean': '5.2%', 'pitch_mean': '4.0%'}
# ----
# window: 112 knn: 2.706
# Top causes: {'Tailgating': '5.6%', 'Overspeed': '2.8%'}
# Top features: {'difcourse_mean': '16.8%', 'acc_x_kf_mean': '13.8%', 'acc_x_mean': '12.2%', 'roll_mean': '11.6%', 'lon_mean': '5.4%', 'pitch_mean': '4.2%'}
# ----
# window: 113 knn: 2.794
# Top causes: {'Tailgating': '5.5%', 'Overspeed': '2.5%'}
# Top features: {'difcourse_mean': '16.5%', 'acc_x_kf_mean': '13.2%', 'acc_x_mean': '12.0%', 'roll_mean': '11.8%', 'pitch_mean': '5.1%', 'lon_mean': '4.8%'}
# ----
# window: 114 knn: 3.079
# Top causes: {'Tailgating': '6.4%', 'Overspeed': '4.3%'}
# Top features: {'difcourse_mean': '17.6%', 'roll_mean': '13.7%', 'acc_x_kf_mean': '7.6%', 'acc_x_mean': '6.8%', 'pitch_mean': '6.5%', 'lon_mean': '4.3%'}
# ----
# window: 115 knn: 3.412
# Top causes: {'Overspeed': '7.5%', 'Tailgating': '4.6%'}
# Top features: {'difcourse_mean': '16.2%', 'roll_mean': '16.0%', 'acc_x_kf_mean': '8.5%', 'acc_x_mean': '8.1%', 'pitch_mean': '5.0%', 'yaw_mean': '4.9%'}
# ----
# window: 116 knn: 3.87
# Top causes: {'Tailgating': '5.0%', 'Overspeed': '19.2%'}
# Top features: {'roll_mean': '14.6%', 'difcourse_mean': '12.6%', 'pitch_mean': '9.0%', 'yaw_mean': '7.4%', 'vdop_mean': '6.1%', 'acc_x_kf_mean': '5.0%'}
# ----
# window: 117 knn: 4.398
# Top causes: {'Overspeed': '37.8%', 'Unstable steering': '32.8%'}
# Top features: {'roll_mean': '13.2%', 'yaw_mean': '10.0%', 'difcourse_mean': '8.0%', 'speed_kmh_mean': '7.0%', 'gps_speed_mean': '6.8%', 'gps_speed_osm_mean': '6.6%'}
# ----
# window: 118 knn: 2.728
# Top causes: {'Harsh maneuvers': '14.9%', 'Tailgating': '5.1%'}
# Top features: {'speed_kmh_mean': '12.8%', 'gps_speed_mean': '12.6%', 'yaw_mean': '12.4%', 'gps_speed_osm_mean': '12.4%', 'course_mean': '6.1%', 'roll_mean': '5.0%'}
# ----
# window: 119 knn: 2.946
# Top causes: {'Unstable steering': '17.7%', 'Harsh maneuvers': '12.0%'}
# Top features: {'speed_kmh_mean': '14.3%', 'gps_speed_mean': '14.2%', 'gps_speed_osm_mean': '13.4%', 'yaw_mean': '10.0%', 'roll_mean': '7.1%', 'course_mean': '5.2%'}
# ----
# window: 120 knn: 2.96
# Top causes: {'Unstable steering': '17.3%', 'Harsh maneuvers': '13.1%'}
# Top features: {'speed_kmh_mean': '14.3%', 'gps_speed_mean': '14.1%', 'gps_speed_osm_mean': '13.4%', 'yaw_mean': '9.7%', 'course_mean': '5.4%', 'x_lane_mean': '4.4%'}
# ----
# window: 121 knn: 3.038
# Top causes: {'Unstable steering': '18.4%', 'Harsh maneuvers': '11.4%'}
# Top features: {'speed_kmh_mean': '13.3%', 'gps_speed_mean': '13.2%', 'gps_speed_osm_mean': '12.7%', 'yaw_mean': '9.8%', 'course_mean': '5.7%', 'osm_delay_mean': '5.4%'}
# ----
# window: 122 knn: 3.095
# Top causes: {'Unstable steering': '21.4%', 'Harsh maneuvers': '11.5%'}
# Top features: {'speed_kmh_mean': '10.6%', 'gps_speed_mean': '10.5%', 'gps_speed_osm_mean': '10.4%', 'yaw_mean': '10.1%', 'osm_delay_mean': '7.4%', 'course_mean': '6.3%'}
# ----
# window: 123 knn: 3.733
# Top causes: {'Unstable steering': '23.4%', 'Harsh maneuvers': '21.2%'}
# Top features: {'osm_delay_mean': '15.4%', 'yaw_mean': '9.3%', 'speed_kmh_mean': '6.4%', 'gps_speed_osm_mean': '6.3%', 'gps_speed_mean': '6.3%', 'course_mean': '6.1%'}
# ----
# window: 124 knn: 4.042
# Top causes: {'Overspeed': '39.4%', 'Unstable steering': '31.4%'}
# Top features: {'osm_delay_mean': '16.2%', 'yaw_mean': '9.7%', 't_10hz_mean': '6.7%', 'timestamp_mean': '6.7%', 'course_mean': '6.5%', 'x_lane_mean': '6.2%'}
# ----
# window: 125 knn: 6.57
# Top causes: {'Unstable steering': '35.6%', 'Tailgating': '27.1%'}
# Top features: {'road_width_mean': '23.1%', 'osm_delay_mean': '11.8%', 'yaw_mean': '6.3%', 'active_mean': '5.9%', 'lat_mean': '5.6%', 't_10hz_mean': '4.5%'}
# ----
# window: 126 knn: 9.264
# Top causes: {'Harsh maneuvers': '39.5%', 'Tailgating': '29.3%'}
# Top features: {'road_width_mean': '25.6%', 'active_mean': '15.3%', 'phi_mean': '12.5%', 'lane_state_mean': '11.3%', 'x_lane_mean': '8.9%', 'lat_mean': '4.2%'}
# ----
# window: 127 knn: 9.068
# Top causes: {'Harsh maneuvers': '39.8%', 'Tailgating': '34.4%'}
# Top features: {'road_width_mean': '24.8%', 'active_mean': '15.3%', 'phi_mean': '12.6%', 'lane_state_mean': '11.3%', 'x_lane_mean': '9.1%', 'lat_mean': '5.2%'}
# ----
# window: 128 knn: 8.969
# Top causes: {'Harsh maneuvers': '49.1%', 'Tailgating': '35.0%'}
# Top features: {'road_width_mean': '23.7%', 'active_mean': '15.2%', 'phi_mean': '12.9%', 'lane_state_mean': '11.1%', 'x_lane_mean': '9.6%', 'lat_mean': '6.0%'}
# ----
# window: 129 knn: 8.803
# Top causes: {'Harsh maneuvers': '48.5%', 'Tailgating': '34.8%'}
# Top features: {'road_width_mean': '22.6%', 'active_mean': '15.2%', 'phi_mean': '12.9%', 'lane_state_mean': '11.2%', 'x_lane_mean': '9.6%', 'lat_mean': '6.6%'}
# ----
# window: 130 knn: 8.931
# Top causes: {'Harsh maneuvers': '52.6%', 'Tailgating': '28.4%'}
# Top features: {'road_width_mean': '20.7%', 'active_mean': '14.6%', 'phi_mean': '12.3%', 'x_lane_mean': '11.0%', 'lane_state_mean': '11.0%', 'lat_mean': '6.6%'}
# ----
# window: 131 knn: 8.929
# Top causes: {'Harsh maneuvers': '55.1%', 'Overspeed': '24.8%'}
# Top features: {'road_width_mean': '18.7%', 'active_mean': '13.8%', 'phi_mean': '11.4%', 'x_lane_mean': '10.6%', 'lane_state_mean': '9.4%', 'vdop_mean': '6.6%'}
# ----
# window: 132 knn: 8.99
# Top causes: {'Harsh maneuvers': '50.2%', 'Overspeed': '32.3%'}
# Top features: {'road_width_mean': '16.3%', 'active_mean': '12.5%', 'x_lane_mean': '10.5%', 'phi_mean': '10.2%', 'vdop_mean': '9.3%', 'lane_state_mean': '9.1%'}
# ----
# window: 133 knn: 9.121
# Top causes: {'Harsh maneuvers': '71.6%', 'Tailgating': '5.9%'}
# Top features: {'road_width_mean': '15.4%', 'active_mean': '12.2%', 'vdop_mean': '11.5%', 'x_lane_mean': '10.7%', 'phi_mean': '9.9%', 'lane_state_mean': '8.8%'}
# ----
# window: 134 knn: 9.014
# Top causes: {'Harsh maneuvers': '71.8%', 'Overspeed': '14.2%'}
# Top features: {'road_width_mean': '15.1%', 'active_mean': '12.5%', 'x_lane_mean': '11.9%', 'vdop_mean': '11.3%', 'phi_mean': '9.9%', 'lane_state_mean': '9.7%'}
# ----
# window: 135 knn: 6.988
# Top causes: {'Harsh maneuvers': '49.5%', 'Unstable steering': '27.4%'}
# Top features: {'vdop_mean': '21.0%', 'hdop_mean': '12.5%', 'pdop_mean': '12.5%', 'road_width_mean': '8.8%', 'roll_mean': '5.4%', 'active_mean': '5.2%'}
# ----
# window: 136 knn: 6.427
# Top causes: {'Harsh maneuvers': '41.7%', 'Tailgating': '25.7%'}
# Top features: {'vdop_mean': '33.6%', 'pdop_mean': '16.9%', 'hdop_mean': '16.2%', 'timestamp_mean': '3.9%', 't_10hz_mean': '3.9%', 'alt_mean': '2.4%'}
# ----
# window: 137 knn: 7.018
# Top causes: {'Harsh maneuvers': '35.9%', 'Tailgating': '26.7%'}
# Top features: {'vdop_mean': '39.9%', 'hdop_mean': '17.8%', 'pdop_mean': '15.3%', 'timestamp_mean': '2.9%', 't_10hz_mean': '2.9%', 'roll_mean': '2.0%'}
# ----
# window: 138 knn: 7.406
# Top causes: {'Harsh maneuvers': '31.0%', 'Overspeed': '26.0%'}
# Top features: {'vdop_mean': '44.1%', 'hdop_mean': '18.3%', 'pdop_mean': '14.2%', 'timestamp_mean': '2.3%', 't_10hz_mean': '2.3%', 'vert_acc_mean': '1.7%'}
# ----
# window: 139 knn: 8.173
# Top causes: {'Tailgating': '31.5%', 'Harsh maneuvers': '29.9%'}
# Top features: {'vdop_mean': '43.9%', 'pdop_mean': '20.4%', 'hdop_mean': '16.8%', 'timestamp_mean': '1.6%', 't_10hz_mean': '1.6%', 'num_vehicles_mean': '1.5%'}
# ----
# window: 140 knn: 8.359
# Top causes: {'Harsh maneuvers': '36.4%', 'Tailgating': '33.1%'}
# Top features: {'vdop_mean': '43.6%', 'pdop_mean': '25.4%', 'hdop_mean': '12.9%', 'num_vehicles_mean': '2.1%', 'x_lane_mean': '1.5%', 'vert_acc_mean': '1.4%'}
# ----
# window: 141 knn: 7.303
# Top causes: {'Harsh maneuvers': '38.4%', 'Tailgating': '30.6%'}
# Top features: {'vdop_mean': '48.6%', 'hdop_mean': '15.4%', 'pdop_mean': '13.3%', 'num_vehicles_mean': '2.4%', 'x_lane_mean': '2.3%', 'course_mean': '1.8%'}
# ----
# window: 142 knn: 6.796
# Top causes: {'Harsh maneuvers': '43.1%', 'Tailgating': '25.2%'}
# Top features: {'vdop_mean': '49.1%', 'hdop_mean': '20.6%', 'pdop_mean': '4.9%', 'x_lane_mean': '4.1%', 'course_mean': '2.2%', 'num_vehicles_mean': '2.1%'}
# ----
# window: 143 knn: 7.443
# Top causes: {'Harsh maneuvers': '49.5%', 'Unstable steering': '19.5%'}
# Top features: {'vdop_mean': '46.6%', 'hdop_mean': '21.3%', 'pdop_mean': '10.6%', 'x_lane_mean': '2.9%', 'course_mean': '2.2%', 'vert_acc_mean': '1.8%'}
# ----
# window: 144 knn: 7.887
# Top causes: {'Harsh maneuvers': '47.2%', 'Tailgating': '24.9%'}
# Top features: {'vdop_mean': '48.9%', 'hdop_mean': '17.6%', 'pdop_mean': '15.0%', 'x_lane_mean': '2.5%', 'course_mean': '2.2%', 'vert_acc_mean': '1.6%'}
# ----
# window: 145 knn: 7.783
# Top causes: {'Harsh maneuvers': '44.3%', 'Tailgating': '24.2%'}
# Top features: {'vdop_mean': '49.9%', 'pdop_mean': '15.8%', 'hdop_mean': '14.5%', 'course_mean': '2.4%', 'vert_acc_mean': '1.7%', 'x_lane_mean': '1.7%'}
# ----
# window: 146 knn: 6.869
# Top causes: {'Harsh maneuvers': '35.8%', 'Unstable steering': '27.0%'}
# Top features: {'vdop_mean': '39.6%', 'pdop_mean': '14.9%', 'hdop_mean': '13.1%', 'difcourse_mean': '3.8%', 'roll_mean': '3.2%', 'pitch_mean': '2.5%'}
# ----
# window: 147 knn: 6.233
# Top causes: {'Harsh maneuvers': '35.5%', 'Overspeed': '28.7%'}
# Top features: {'vdop_mean': '33.0%', 'pdop_mean': '15.6%', 'hdop_mean': '11.7%', 'difcourse_mean': '4.8%', 'pitch_mean': '3.0%', 'acc_x_kf_mean': '2.5%'}
# ----
# window: 148 knn: 5.633
# Top causes: {'Harsh maneuvers': '37.2%', 'Overspeed': '34.1%'}
# Top features: {'vdop_mean': '28.0%', 'pdop_mean': '16.5%', 'hdop_mean': '9.2%', 'difcourse_mean': '5.5%', 'roll_mean': '4.9%', 'acc_x_kf_mean': '3.8%'}
# ----
# window: 149 knn: 4.518
# Top causes: {'Harsh maneuvers': '36.8%', 'Overspeed': '34.2%'}
# Top features: {'vdop_mean': '25.7%', 'pdop_mean': '11.2%', 'roll_mean': '8.2%', 'hdop_mean': '7.3%', 'difcourse_mean': '6.9%', 'acc_x_kf_mean': '4.3%'}
# ----
# window: 150 knn: 3.546
# Top causes: {'Unstable steering': '25.4%', 'Tailgating': '5.2%'}
# Top features: {'vdop_mean': '21.7%', 'hdop_mean': '11.0%', 'roll_mean': '9.7%', 'difcourse_mean': '8.4%', 'lon_mean': '4.9%', 'pdop_mean': '4.2%'}
# ----
# window: 151 knn: 3.141
# Top causes: {'Overspeed': '29.3%', 'Unstable steering': '26.8%'}
# Top features: {'vdop_mean': '17.6%', 'hdop_mean': '10.0%', 'difcourse_mean': '9.7%', 'roll_mean': '8.1%', 'lon_mean': '5.5%', 'pdop_mean': '4.8%'}
# ----
# window: 152 knn: 2.865
# Top causes: {'Overspeed': '26.3%', 'Tailgating': '6.5%'}
# Top features: {'vdop_mean': '13.9%', 'roll_mean': '11.2%', 'difcourse_mean': '10.1%', 'hdop_mean': '7.3%', 'acc_x_kf_mean': '6.4%', 'pitch_mean': '5.1%'}
# ----
# window: 153 knn: 2.373
# Top causes: {'Overspeed': '25.2%', 'Tailgating': '4.2%'}
# Top features: {'roll_mean': '13.6%', 'difcourse_mean': '12.1%', 'vdop_mean': '11.0%', 'hdop_mean': '7.9%', 'lon_mean': '5.4%', 'acc_x_kf_mean': '4.9%'}
# ----
# window: 154 knn: 2.754
# Top causes: {'Overspeed': '16.4%', 'Tailgating': '8.1%'}
# Top features: {'roll_mean': '16.4%', 'hdop_mean': '14.1%', 'vdop_mean': '10.0%', 'pitch_mean': '8.3%', 'difcourse_mean': '7.9%', 'lon_mean': '3.8%'}
# ----
# window: 155 knn: 4.155
# Top causes: {'Unstable steering': '39.3%', 'Harsh maneuvers': '35.8%'}
# Top features: {'hdop_mean': '22.3%', 'vdop_mean': '17.3%', 'roll_mean': '16.1%', 'yaw_mean': '4.3%', 'pdop_mean': '3.6%', 'course_mean': '3.6%'}
# ----
# window: 156 knn: 5.267
# Top causes: {'Harsh maneuvers': '44.2%', 'Unstable steering': '30.5%'}
# Top features: {'vdop_mean': '27.6%', 'hdop_mean': '19.4%', 'pdop_mean': '17.2%', 'roll_mean': '5.3%', 'yaw_mean': '3.9%', 'course_mean': '3.4%'}
# ----
# window: 157 knn: 6.774
# Top causes: {'Harsh maneuvers': '52.8%', 'Overspeed': '14.9%'}
# Top features: {'pdop_mean': '27.9%', 'vdop_mean': '27.4%', 'hdop_mean': '14.6%', 'roll_mean': '4.2%', 'acc_z_mean': '2.7%', 'yaw_mean': '2.5%'}
# ----
# window: 158 knn: 7.336
# Top causes: {'Harsh maneuvers': '45.8%', 'Overspeed': '29.1%'}
# Top features: {'vdop_mean': '30.1%', 'pdop_mean': '27.0%', 'hdop_mean': '16.9%', 'roll_mean': '2.8%', 'yaw_mean': '2.2%', 'course_mean': '2.2%'}
# ----
# window: 159 knn: 8.952
# Top causes: {'Harsh maneuvers': '42.4%', 'Overspeed': '32.4%'}
# Top features: {'pdop_mean': '35.6%', 'vdop_mean': '29.9%', 'hdop_mean': '15.8%', 'course_mean': '1.7%', 'yaw_mean': '1.6%', 't_10hz_mean': '1.6%'}
# ----
# window: 160 knn: 10.191
# Top causes: {'Overspeed': '33.0%', 'Harsh maneuvers': '29.2%'}
# Top features: {'pdop_mean': '44.5%', 'vdop_mean': '30.1%', 'hdop_mean': '11.1%', 't_10hz_mean': '1.5%', 'timestamp_mean': '1.5%', 'course_mean': '1.5%'}
# ----
# window: 161 knn: 10.284
# Top causes: {'Overspeed': '36.3%', 'Unstable steering': '26.6%'}
# Top features: {'pdop_mean': '44.6%', 'vdop_mean': '31.5%', 'hdop_mean': '9.6%', 'roll_mean': '1.9%', 't_10hz_mean': '1.7%', 'timestamp_mean': '1.7%'}
# ----
# window: 162 knn: 10.211
# Top causes: {'Overspeed': '32.7%', 'Harsh maneuvers': '26.7%'}
# Top features: {'pdop_mean': '44.1%', 'vdop_mean': '29.8%', 'hdop_mean': '10.0%', 't_10hz_mean': '1.9%', 'timestamp_mean': '1.9%', 'roll_mean': '1.9%'}
# ----
# window: 163 knn: 10.072
# Top causes: {'Overspeed': '32.2%', 'Unstable steering': '27.8%'}
# Top features: {'pdop_mean': '43.9%', 'vdop_mean': '30.4%', 'hdop_mean': '9.4%', 't_10hz_mean': '2.2%', 'timestamp_mean': '2.2%', 'roll_mean': '1.6%'}
# ----
# window: 164 knn: 9.745
# Top causes: {'Unstable steering': '32.0%', 'Tailgating': '26.5%'}
# Top features: {'pdop_mean': '45.7%', 'vdop_mean': '30.2%', 'hdop_mean': '7.7%', 't_10hz_mean': '2.7%', 'timestamp_mean': '2.7%', 'course_mean': '1.6%'}
# ----
# window: 165 knn: 7.838
# Top causes: {'Tailgating': '54.3%', 'Unstable steering': '26.5%'}
# Top features: {'pdop_mean': '45.0%', 'vdop_mean': '28.5%', 'hdop_mean': '3.5%', 't_10hz_mean': '2.8%', 'timestamp_mean': '2.8%', 'alt_mean': '2.0%'}
# ----
# window: 166 knn: 7.059
# Top causes: {'Tailgating': '55.9%', 'Harsh maneuvers': '22.6%'}
# Top features: {'pdop_mean': '34.8%', 'vdop_mean': '26.6%', 'hdop_mean': '4.9%', 'alt_mean': '4.3%', 'roll_mean': '4.3%', 'lat_mean': '3.8%'}
# ----
# window: 167 knn: 6.016
# Top causes: {'Tailgating': '45.3%', 'Unstable steering': '17.7%'}
# Top features: {'vdop_mean': '29.2%', 'pdop_mean': '22.1%', 'alt_mean': '9.3%', 'lat_mean': '6.9%', 'roll_mean': '5.5%', 'hdop_mean': '4.9%'}
# ----
# window: 168 knn: 5.247
# Top causes: {'Overspeed': '36.6%', 'Harsh maneuvers': '28.4%'}
# Top features: {'vdop_mean': '27.4%', 'pdop_mean': '21.8%', 'alt_mean': '13.3%', 'lat_mean': '9.4%', 'lon_mean': '6.1%', 'roll_mean': '4.0%'}
# ----
# window: 169 knn: 3.55
# Top causes: {'Overspeed': '45.8%', 'Tailgating': '13.7%'}
# Top features: {'vdop_mean': '21.3%', 'alt_mean': '20.5%', 'lat_mean': '13.9%', 'lon_mean': '8.9%', 'roll_mean': '7.9%', 'pdop_mean': '7.1%'}
# ----
# window: 170 knn: 1.759
# Top causes: {'Tailgating': '5.0%', 'Unstable steering': '2.9%'}
# Top features: {'alt_mean': '26.1%', 'lat_mean': '16.8%', 'vdop_mean': '10.6%', 'lon_mean': '10.6%', 'roll_mean': '7.8%', 'lane_state_mean': '5.6%'}
# ----
# window: 171 knn: 1.237
# Top causes: {'Tailgating': '2.2%', 'Unstable steering': '1.7%'}
# Top features: {'alt_mean': '28.5%', 'lat_mean': '17.0%', 'lon_mean': '10.9%', 'lane_state_mean': '6.0%', 'roll_mean': '5.3%', 'vdop_mean': '5.1%'}
# ----
# window: 172 knn: 1.13
# Top causes: {'Overspeed': '27.7%', 'Tailgating': '1.7%'}
# Top features: {'alt_mean': '28.1%', 'lat_mean': '15.6%', 'lon_mean': '10.4%', 'lane_state_mean': '6.7%', 'acc_z_kf_mean': '4.1%', 'osm_delay_mean': '3.2%'}
# ----
# window: 173 knn: 1.314
# Top causes: {'Overspeed': '18.7%', 'Tailgating': '4.1%'}
# Top features: {'alt_mean': '24.5%', 'lat_mean': '13.1%', 'lon_mean': '9.4%', 'timestamp_mean': '6.2%', 't_10hz_mean': '6.2%', 'acc_z_kf_mean': '4.6%'}
# ----
# window: 174 knn: 1.744
# Top causes: {'Overspeed': '8.7%', 'Tailgating': '8.6%'}
# Top features: {'alt_mean': '18.5%', 'timestamp_mean': '10.0%', 't_10hz_mean': '10.0%', 'lat_mean': '9.2%', 'roll_mean': '8.5%', 'lon_mean': '7.4%'}
# ----
# window: 175 knn: 1.496
# Top causes: {'Unstable steering': '15.3%', 'Overspeed': '14.6%'}
# Top features: {'alt_mean': '17.6%', 'timestamp_mean': '11.5%', 't_10hz_mean': '11.5%', 'lat_mean': '7.8%', 'lon_mean': '7.2%', 'osm_delay_mean': '5.5%'}
# ----
# window: 176 knn: 0.967
# Top causes: {'Unstable steering': '17.5%', 'Harsh maneuvers': '27.9%'}
# Top features: {'alt_mean': '13.4%', 'timestamp_mean': '10.9%', 't_10hz_mean': '10.9%', 'osm_delay_mean': '6.5%', 'lon_mean': '5.8%', 'lat_mean': '5.1%'}
# ----
# window: 177 knn: 0.938
# Top causes: {'Tailgating': '24.0%', 'Unstable steering': '21.0%'}
# Top features: {'timestamp_mean': '10.2%', 't_10hz_mean': '10.2%', 'alt_mean': '9.1%', 'osm_delay_mean': '7.1%', 'difcourse_mean': '5.2%', 'course_mean': '5.2%'}
# ----
# window: 178 knn: 0.839
# Top causes: {'Tailgating': '28.0%', 'Harsh maneuvers': '25.2%'}
# Top features: {'timestamp_mean': '8.7%', 't_10hz_mean': '8.7%', 'osm_delay_mean': '6.6%', 'alt_mean': '6.0%', 'course_mean': '5.7%', 'x_lane_mean': '5.0%'}
# ----
# window: 179 knn: 0.989
# Top causes: {'Unstable steering': '17.5%', 'Harsh maneuvers': '29.8%'}
# Top features: {'timestamp_mean': '7.9%', 't_10hz_mean': '7.9%', 'course_mean': '6.9%', 'osm_delay_mean': '5.9%', 'difcourse_mean': '5.7%', 'x_lane_mean': '5.7%'}
# ----
# window: 180 knn: 1.014
# Top causes: {'Harsh maneuvers': '26.8%', 'Unstable steering': '17.9%'}
# Top features: {'course_mean': '8.5%', 'ttc_front_mean': '8.0%', 'timestamp_mean': '6.9%', 't_10hz_mean': '6.9%', 'x_lane_mean': '6.9%', 'difcourse_mean': '6.5%'}
# ----
# window: 181 knn: 0.987
# Top causes: {'Harsh maneuvers': '28.1%', 'Overspeed': '14.7%'}
# Top features: {'course_mean': '9.7%', 'ttc_front_mean': '7.5%', 'num_vehicles_mean': '7.0%', 'x_lane_mean': '6.9%', 'difcourse_mean': '6.7%', 'timestamp_mean': '5.3%'}
# ----
# window: 182 knn: 0.981
# Top causes: {'Unstable steering': '21.0%', 'Overspeed': '12.5%'}
# Top features: {'course_mean': '10.5%', 'num_vehicles_mean': '7.7%', 'x_lane_mean': '7.7%', 'osm_delay_mean': '7.6%', 'difcourse_mean': '6.5%', 'ttc_front_mean': '4.4%'}
# ----
# window: 183 knn: 1.075
# Top causes: {'Unstable steering': '26.5%', 'Tailgating': '26.5%'}
# Top features: {'course_mean': '12.8%', 'osm_delay_mean': '9.0%', 'num_vehicles_mean': '7.9%', 'difcourse_mean': '6.8%', 'x_lane_mean': '6.8%', 'lane_state_mean': '4.7%'}
# ----
# window: 184 knn: 1.439
# Top causes: {'Overspeed': '27.4%', 'Tailgating': '16.2%'}
# Top features: {'course_mean': '16.5%', 'osm_delay_mean': '10.9%', 'lat_mean': '6.1%', 'x_lane_mean': '6.0%', 'lon_mean': '4.4%', 'phi_mean': '4.4%'}
# ----
# window: 185 knn: 2.374
# Top causes: {'Harsh maneuvers': '24.4%', 'Unstable steering': '8.1%'}
# Top features: {'course_mean': '13.6%', 'osm_delay_mean': '10.2%', 'lon_mean': '6.5%', 'gps_speed_mean': '6.5%', 'hdop_mean': '6.2%', 'lat_mean': '6.1%'}
# ----
# window: 186 knn: 1.324
# Top causes: {'Overspeed': '29.9%', 'Unstable steering': '23.9%'}
# Top features: {'difcourse_mean': '13.6%', 'pitch_mean': '7.4%', 'acc_x_mean': '7.2%', 'acc_x_kf_mean': '6.4%', 'osm_delay_mean': '5.7%', 'gps_speed_mean': '5.7%'}
# ----
# window: 187 knn: 1.188
# Top causes: {'Unstable steering': '19.2%', 'Tailgating': '2.8%'}
# Top features: {'difcourse_mean': '11.7%', 'pitch_mean': '8.5%', 'gps_speed_mean': '8.2%', 'acc_x_mean': '8.1%', 'gps_speed_osm_mean': '7.9%', 'speed_kmh_mean': '7.6%'}
# ----
# window: 188 knn: 0.991
# Top causes: {'Unstable steering': '16.7%', 'Tailgating': '4.0%'}
# Top features: {'difcourse_mean': '10.3%', 'acc_x_mean': '8.2%', 'acc_x_kf_mean': '8.1%', 'gps_speed_mean': '7.8%', 'gps_speed_osm_mean': '7.7%', 'pitch_mean': '7.4%'}
# ----
# window: 189 knn: 1.075
# Top causes: {'Tailgating': '5.0%', 'Unstable steering': '18.9%'}
# Top features: {'difcourse_mean': '11.2%', 'roll_mean': '8.8%', 'acc_x_mean': '7.8%', 'acc_x_kf_mean': '7.6%', 'pitch_mean': '6.1%', 'gps_speed_osm_mean': '6.0%'}
# ----
# window: 190 knn: 0.962
# Top causes: {'Unstable steering': '19.8%', 'Tailgating': '7.2%'}
# Top features: {'difcourse_mean': '12.4%', 'acc_x_mean': '9.3%', 'acc_x_kf_mean': '8.7%', 'pitch_mean': '7.2%', 'gps_speed_mean': '6.3%', 'lon_mean': '5.9%'}
# ----
# window: 191 knn: 0.946
# Top causes: {'Overspeed': '28.9%', 'Unstable steering': '20.7%'}
# Top features: {'difcourse_mean': '12.3%', 'acc_x_mean': '9.2%', 'acc_x_kf_mean': '8.7%', 'pitch_mean': '6.4%', 'gps_speed_mean': '5.8%', 'gps_speed_osm_mean': '5.7%'}
# ----
# window: 192 knn: 1.097
# ...
# Top features: {'acc_y_kf_mean': '30.3%', 'acc_y_mean': '30.0%', 'acc_x_kf_mean': '17.6%', 'acc_x_mean': '15.4%', 'pitch_mean': '5.7%', 'dist_front_mean': '0.3%'}
# ----
# window: 471 knn: 109.635
# Top causes: {'Harsh maneuvers': '99.4%', 'Tailgating': '0.5%'}
# Top features: {'acc_y_kf_mean': '30.3%', 'acc_y_mean': '29.9%', 'acc_x_kf_mean': '17.3%', 'acc_x_mean': '15.1%', 'pitch_mean': '5.8%', 'dist_front_mean': '0.3%'}
# ----
# window: 472 knn: 97.266
# Top causes: {'Harsh maneuvers': '99.4%', 'Tailgating': '0.5%'}
# Top features: {'acc_y_kf_mean': '29.6%', 'acc_y_mean': '29.3%', 'acc_x_kf_mean': '17.7%', 'acc_x_mean': '15.5%', 'pitch_mean': '5.5%', 'acc_z_kf_mean': '0.5%'}
# ----
# window: 473 knn: 87.166
# Top causes: {'Harsh maneuvers': '99.5%', 'Tailgating': '0.3%'}
# Top features: {'acc_y_kf_mean': '30.8%', 'acc_y_mean': '30.4%', 'acc_x_kf_mean': '16.9%', 'acc_x_mean': '14.8%', 'pitch_mean': '5.1%', 'acc_z_mean': '0.4%'}
# ----
# window: 474 knn: 75.204
# Top causes: {'Harsh maneuvers': '99.6%', 'Tailgating': '0.2%'}
# Top features: {'acc_y_kf_mean': '30.6%', 'acc_y_mean': '30.2%', 'acc_x_kf_mean': '16.7%', 'acc_x_mean': '14.6%', 'pitch_mean': '4.9%', 'acc_z_mean': '0.7%'}
# ----
# window: 475 knn: 63.715
# Top causes: {'Harsh maneuvers': '99.5%', 'Overspeed': '0.2%'}
# Top features: {'acc_y_kf_mean': '30.5%', 'acc_y_mean': '30.2%', 'acc_x_kf_mean': '16.5%', 'acc_x_mean': '14.5%', 'pitch_mean': '4.7%', 'acc_z_kf_mean': '0.8%'}
# ----
# window: 476 knn: 52.263
# Top causes: {'Harsh maneuvers': '99.4%', 'Overspeed': '0.3%'}
# Top features: {'acc_y_kf_mean': '30.2%', 'acc_y_mean': '29.8%', 'acc_x_kf_mean': '16.3%', 'acc_x_mean': '14.4%', 'pitch_mean': '4.6%', 'vdop_mean': '1.0%'}
# ----
# window: 477 knn: 40.998
# Top causes: {'Harsh maneuvers': '99.2%', 'Overspeed': '0.5%'}
# Top features: {'acc_y_kf_mean': '29.6%', 'acc_y_mean': '29.3%', 'acc_x_kf_mean': '15.6%', 'acc_x_mean': '13.8%', 'pitch_mean': '4.2%', 'vdop_mean': '2.1%'}
# ----
# window: 478 knn: 30.12
# Top causes: {'Harsh maneuvers': '98.5%', 'Overspeed': '1.0%'}
# Top features: {'acc_y_kf_mean': '28.0%', 'acc_y_mean': '27.7%', 'acc_x_kf_mean': '14.0%', 'acc_x_mean': '12.4%', 'pdop_mean': '5.4%', 'vdop_mean': '4.8%'}
# ----
# window: 479 knn: 20.03
# Top causes: {'Harsh maneuvers': '96.4%', 'Overspeed': '2.6%'}
# Top features: {'acc_y_kf_mean': '24.9%', 'acc_y_mean': '24.6%', 'acc_x_kf_mean': '11.3%', 'pdop_mean': '10.8%', 'vdop_mean': '10.2%', 'acc_x_mean': '10.1%'}
# ----
# window: 480 knn: 12.897
# Top causes: {'Harsh maneuvers': '86.4%', 'Overspeed': '9.4%'}
# Top features: {'pdop_mean': '24.2%', 'vdop_mean': '21.6%', 'acc_y_kf_mean': '13.2%', 'acc_y_mean': '13.1%', 'acc_x_kf_mean': '5.0%', 'acc_x_mean': '4.6%'}
# ----
# window: 481 knn: 12.821
# Top causes: {'Harsh maneuvers': '63.0%', 'Overspeed': '26.0%'}
# Top features: {'pdop_mean': '38.3%', 'vdop_mean': '29.8%', 'hdop_mean': '6.2%', 'acc_z_kf_mean': '5.0%', 'acc_z_mean': '4.9%', 'acc_y_mean': '2.0%'}
# ----
# window: 482 knn: 13.712
# Top causes: {'Harsh maneuvers': '61.1%', 'Overspeed': '28.3%'}
# Top features: {'pdop_mean': '44.1%', 'vdop_mean': '30.7%', 'hdop_mean': '5.9%', 'acc_z_kf_mean': '3.0%', 'acc_z_mean': '2.9%', 'acc_y_kf_mean': '1.7%'}
# ----
# window: 483 knn: 15.158
# Top causes: {'Overspeed': '54.6%', 'Unstable steering': '26.1%'}
# Top features: {'pdop_mean': '48.9%', 'vdop_mean': '33.3%', 'hdop_mean': '7.4%', 'yaw_mean': '1.4%', 'gps_speed_mean': '1.0%', 'gps_speed_osm_mean': '1.0%'}
# ----
# window: 484 knn: 16.146
# Top causes: {'Overspeed': '42.5%', 'Harsh maneuvers': '28.9%'}
# Top features: {'pdop_mean': '53.1%', 'vdop_mean': '30.9%', 'hdop_mean': '6.1%', 'yaw_mean': '1.2%', 'gps_speed_mean': '0.8%', 'x_lane_mean': '0.8%'}
# ----
# window: 485 knn: 16.763
# Top causes: {'Overspeed': '36.5%', 'Harsh maneuvers': '25.6%'}
# Top features: {'pdop_mean': '54.2%', 'vdop_mean': '29.1%', 'hdop_mean': '5.5%', 'x_lane_mean': '1.2%', 'yaw_mean': '1.1%', 'gps_speed_mean': '0.8%'}
# ----
# window: 486 knn: 16.917
# Top causes: {'Tailgating': '32.9%', 'Overspeed': '31.3%'}
# Top features: {'pdop_mean': '53.7%', 'vdop_mean': '28.0%', 'hdop_mean': '4.6%', 'x_lane_mean': '2.0%', 'dist_front_mean': '1.4%', 'ttc_front_mean': '1.4%'}
# ----
# window: 487 knn: 16.236
# Top causes: {'Tailgating': '39.2%', 'Overspeed': '29.9%'}
# Top features: {'pdop_mean': '52.4%', 'vdop_mean': '27.2%', 'hdop_mean': '4.2%', 'x_lane_mean': '2.8%', 'ttc_front_mean': '1.9%', 'dist_front_mean': '1.8%'}
# ----
# window: 488 knn: 15.933
# Top causes: {'Tailgating': '38.6%', 'Overspeed': '30.9%'}
# Top features: {'pdop_mean': '54.3%', 'vdop_mean': '24.6%', 'hdop_mean': '4.3%', 'x_lane_mean': '3.0%', 'ttc_front_mean': '2.0%', 'dist_front_mean': '1.8%'}
# ----
# window: 489 knn: 15.457
# Top causes: {'Tailgating': '35.8%', 'Overspeed': '30.8%'}
# Top features: {'pdop_mean': '53.7%', 'vdop_mean': '24.0%', 'hdop_mean': '4.1%', 'x_lane_mean': '3.2%', 'ttc_front_mean': '1.9%', 'dist_front_mean': '1.7%'}
# ----
# window: 490 knn: 14.768
# Top causes: {'Tailgating': '46.8%', 'Overspeed': '26.4%'}
# Top features: {'pdop_mean': '47.6%', 'vdop_mean': '25.4%', 'hdop_mean': '4.4%', 'ttc_front_mean': '3.5%', 'x_lane_mean': '3.2%', 'dist_front_mean': '2.9%'}
# ----
# window: 491 knn: 14.347
# Top causes: {'Tailgating': '52.5%', 'Overspeed': '23.5%'}
# Top features: {'pdop_mean': '43.0%', 'vdop_mean': '25.8%', 'hdop_mean': '5.1%', 'ttc_front_mean': '4.6%', 'dist_front_mean': '3.9%', 'x_lane_mean': '3.3%'}
# ----
# window: 492 knn: 14.133
# Top causes: {'Tailgating': '50.3%', 'Overspeed': '23.5%'}
# Top features: {'pdop_mean': '43.6%', 'vdop_mean': '25.3%', 'hdop_mean': '5.3%', 'ttc_front_mean': '4.3%', 'dist_front_mean': '3.7%', 'x_lane_mean': '3.3%'}
# ----
# window: 493 knn: 14.18
# Top causes: {'Tailgating': '51.5%', 'Overspeed': '22.6%'}
# Top features: {'pdop_mean': '43.0%', 'vdop_mean': '25.3%', 'hdop_mean': '5.1%', 'ttc_front_mean': '4.5%', 'dist_front_mean': '3.9%', 'x_lane_mean': '3.2%'}
# ----
# window: 494 knn: 14.191
# Top causes: {'Tailgating': '53.2%', 'Overspeed': '23.4%'}
# Top features: {'pdop_mean': '42.7%', 'vdop_mean': '25.8%', 'hdop_mean': '4.9%', 'ttc_front_mean': '4.3%', 'dist_front_mean': '3.7%', 'x_lane_mean': '3.1%'}
# ----
# window: 495 knn: 14.887
# Top causes: {'Tailgating': '57.4%', 'Overspeed': '21.4%'}
# Top features: {'pdop_mean': '45.2%', 'vdop_mean': '23.7%', 'ttc_front_mean': '4.6%', 'hdop_mean': '4.6%', 'dist_front_mean': '4.1%', 'x_lane_mean': '2.8%'}
# ----
# window: 496 knn: 14.595
# Top causes: {'Tailgating': '42.6%', 'Overspeed': '29.5%'}
# Top features: {'pdop_mean': '47.7%', 'vdop_mean': '24.1%', 'hdop_mean': '4.9%', 'x_lane_mean': '2.9%', 't_10hz_mean': '2.6%', 'timestamp_mean': '2.6%'}
# ----
# window: 497 knn: 10.857
# Top causes: {'Overspeed': '33.8%', 'Harsh maneuvers': '27.5%'}
# Top features: {'pdop_mean': '51.5%', 'vdop_mean': '17.9%', 't_10hz_mean': '2.3%', 'timestamp_mean': '2.3%', 'ttc_front_mean': '2.2%', 'active_mean': '2.1%'}
# ----
# window: 498 knn: 9.078
# Top causes: {'Overspeed': '34.4%', 'Tailgating': '27.8%'}
# Top features: {'pdop_mean': '47.8%', 'vdop_mean': '17.6%', 'active_mean': '2.6%', 'alt_mean': '2.4%', 'ttc_front_mean': '2.3%', 'phi_mean': '2.3%'}
# ----
# window: 499 knn: 7.677
# Top causes: {'Harsh maneuvers': '35.8%', 'Overspeed': '31.5%'}
# Top features: {'pdop_mean': '44.6%', 'vdop_mean': '17.6%', 'alt_mean': '3.3%', 'active_mean': '3.1%', 'phi_mean': '2.7%', 'road_width_mean': '2.6%'}
# ----
# window: 500 knn: 6.902
# Top causes: {'Harsh maneuvers': '44.4%', 'Overspeed': '25.6%'}
# Top features: {'pdop_mean': '46.9%', 'vdop_mean': '16.8%', 'alt_mean': '3.4%', 'active_mean': '3.4%', 'lat_mean': '3.1%', 'phi_mean': '2.9%'}
# ----
# window: 501 knn: 5.795
# Top causes: {'Harsh maneuvers': '56.6%', 'Overspeed': '23.9%'}
# Top features: {'pdop_mean': '47.1%', 'vdop_mean': '15.8%', 'active_mean': '3.9%', 'lat_mean': '3.7%', 'alt_mean': '3.4%', 'phi_mean': '3.3%'}
# ----
# window: 502 knn: 4.068
# Top causes: {'Harsh maneuvers': '68.7%', 'Overspeed': '18.8%'}
# Top features: {'pdop_mean': '40.0%', 'vdop_mean': '13.6%', 'active_mean': '5.2%', 'lat_mean': '4.8%', 'phi_mean': '4.4%', 'road_width_mean': '4.3%'}
# ----
# window: 503 knn: 3.092
# Top causes: {'Overspeed': '12.6%', 'Unstable steering': '7.4%'}
# Top features: {'pdop_mean': '30.2%', 'vdop_mean': '8.1%', 'active_mean': '7.1%', 'lat_mean': '6.0%', 'phi_mean': '5.9%', 'road_width_mean': '5.9%'}
# ----
# window: 504 knn: 2.792
# Top causes: {'Tailgating': '6.5%', 'Unstable steering': '4.9%'}
# Top features: {'pdop_mean': '16.6%', 'active_mean': '9.0%', 'road_width_mean': '7.8%', 'phi_mean': '7.6%', 'lat_mean': '6.4%', 'acc_x_kf_mean': '6.3%'}
# ----
# window: 505 knn: 3.094
# Top causes: {'Unstable steering': '4.8%', 'Tailgating': '3.2%'}
# Top features: {'active_mean': '10.7%', 'road_width_mean': '9.5%', 'phi_mean': '9.3%', 'x_lane_mean': '8.7%', 'hdop_mean': '8.3%', 'lane_state_mean': '7.5%'}
# ----
# window: 506 knn: 3.826
# Top causes: {'Harsh maneuvers': '88.0%', 'Tailgating': '4.4%'}
# Top features: {'hdop_mean': '11.8%', 'active_mean': '9.8%', 'x_lane_mean': '9.8%', 'road_width_mean': '9.4%', 'phi_mean': '8.7%', 'lane_state_mean': '6.6%'}
# ----
# window: 507 knn: 1.808
# Top causes: {'Tailgating': '5.2%', 'Unstable steering': '4.8%'}
# Top features: {'timestamp_mean': '12.4%', 't_10hz_mean': '12.4%', 'lon_mean': '6.7%', 'lat_mean': '6.6%', 'acc_x_kf_mean': '6.4%', 'pitch_mean': '6.3%'}
# ----
# window: 508 knn: 1.294
# Top causes: {'Unstable steering': '6.1%', 'Tailgating': '4.5%'}
# Top features: {'timestamp_mean': '10.3%', 't_10hz_mean': '10.3%', 'pitch_mean': '8.9%', 'acc_z_kf_mean': '5.2%', 'acc_z_mean': '5.2%', 'gps_speed_osm_mean': '5.0%'}
# ----
# window: 509 knn: 1.18
# Top causes: {'Unstable steering': '6.8%', 'Tailgating': '4.9%'}
# Top features: {'pitch_mean': '11.0%', 'acc_z_kf_mean': '10.1%', 'acc_z_mean': '9.9%', 'timestamp_mean': '7.5%', 't_10hz_mean': '7.5%', 'speed_rel_mean': '4.5%'}
# ----
# window: 510 knn: 1.036
# Top causes: {'Overspeed': '26.9%', 'Tailgating': '13.4%'}
# Top features: {'pitch_mean': '12.9%', 'acc_z_kf_mean': '10.7%', 'acc_z_mean': '10.7%', 'num_vehicles_mean': '6.2%', 'timestamp_mean': '6.1%', 't_10hz_mean': '6.1%'}
# ----
# window: 511 knn: 1.047
# Top causes: {'Tailgating': '20.5%', 'Unstable steering': '7.8%'}
# Top features: {'pitch_mean': '17.0%', 'num_vehicles_mean': '9.0%', 'acc_z_kf_mean': '7.8%', 'acc_z_mean': '7.7%', 'timestamp_mean': '5.4%', 't_10hz_mean': '5.4%'}
# ----
# window: 512 knn: 1.09
# Top causes: {'Overspeed': '27.7%', 'Unstable steering': '8.5%'}
# Top features: {'pitch_mean': '18.8%', 'osm_delay_mean': '12.7%', 'acc_z_kf_mean': '7.8%', 'acc_z_mean': '7.3%', 'num_vehicles_mean': '6.5%', 'course_mean': '5.1%'}
# ----
# window: 513 knn: 1.178
# Top causes: {'Tailgating': '22.9%', 'Unstable steering': '11.0%'}
# Top features: {'pitch_mean': '25.5%', 'osm_delay_mean': '14.9%', 'course_mean': '6.2%', 'alt_mean': '6.0%', 'speed_rel_mean': '5.0%', 'num_vehicles_mean': '4.7%'}
# ----
# window: 514 knn: 1.426
# Top causes: {'Tailgating': '28.9%', 'Harsh maneuvers': '28.9%'}
# Top features: {'pitch_mean': '28.7%', 'osm_delay_mean': '11.7%', 'alt_mean': '6.8%', 'course_mean': '6.7%', 'speed_rel_mean': '5.6%', 'num_vehicles_mean': '5.4%'}
# ----
# window: 515 knn: 2.402
# Top causes: {'Tailgating': '18.4%', 'Overspeed': '14.9%'}
# Top features: {'pitch_mean': '33.3%', 'osm_delay_mean': '8.9%', 'course_mean': '6.0%', 'alt_mean': '5.0%', 'acc_y_mean': '4.4%', 'speed_rel_mean': '4.4%'}
# ----
# window: 516 knn: 2.447
# Top causes: {'Overspeed': '11.6%', 'Tailgating': '5.0%'}
# Top features: {'acc_y_mean': '21.6%', 'acc_y_kf_mean': '21.2%', 'pitch_mean': '15.5%', 'osm_delay_mean': '6.3%', 'speed_rel_mean': '5.0%', 'course_mean': '4.1%'}
# ----
# window: 517 knn: 1.499
# Top causes: {'Overspeed': '13.3%', 'Unstable steering': '7.2%'}
# Top features: {'acc_y_mean': '18.8%', 'acc_y_kf_mean': '18.6%', 'acc_x_kf_mean': '7.4%', 'pitch_mean': '7.3%', 'acc_x_mean': '6.4%', 'difcourse_mean': '5.1%'}
# ----
# window: 518 knn: 1.371
# Top causes: {'Overspeed': '13.8%', 'Unstable steering': '7.6%'}
# Top features: {'acc_y_mean': '18.1%', 'acc_y_kf_mean': '18.0%', 'acc_x_kf_mean': '8.3%', 'acc_x_mean': '7.6%', 'pitch_mean': '6.2%', 'difcourse_mean': '5.5%'}
# ----
# window: 519 knn: 1.199
# Top causes: {'Overspeed': '10.5%', 'Unstable steering': '8.2%'}
# Top features: {'acc_y_mean': '15.8%', 'acc_y_kf_mean': '15.8%', 'acc_x_kf_mean': '9.3%', 'acc_x_mean': '8.2%', 'pitch_mean': '6.1%', 'osm_delay_mean': '5.9%'}
# ----
# window: 520 knn: 1.137
# Top causes: {'Unstable steering': '8.5%', 'Overspeed': '8.0%'}
# Top features: {'acc_y_mean': '16.4%', 'acc_y_kf_mean': '16.4%', 'acc_x_kf_mean': '6.9%', 'pitch_mean': '6.5%', 'acc_x_mean': '6.2%', 'difcourse_mean': '5.8%'}
# ----
# window: 521 knn: 1.035
# Top causes: {'Unstable steering': '10.0%', 'Tailgating': '7.4%'}
# Top features: {'acc_y_kf_mean': '17.8%', 'acc_y_mean': '17.8%', 'pitch_mean': '7.5%', 'difcourse_mean': '6.3%', 'osm_delay_mean': '5.6%', 'acc_x_kf_mean': '4.3%'}
# ----
# window: 522 knn: 1.066
# Top causes: {'Tailgating': '11.1%', 'Unstable steering': '10.9%'}
# Top features: {'acc_y_kf_mean': '16.8%', 'acc_y_mean': '16.7%', 'pitch_mean': '6.9%', 'difcourse_mean': '6.6%', 'acc_z_mean': '5.1%', 'acc_z_kf_mean': '4.8%'}
# ----
# window: 523 knn: 1.045
# Top causes: {'Unstable steering': '12.3%', 'Tailgating': '8.9%'}
# Top features: {'acc_y_kf_mean': '16.2%', 'acc_y_mean': '16.0%', 'difcourse_mean': '6.5%', 'pitch_mean': '6.2%', 'acc_z_mean': '4.9%', 'acc_z_kf_mean': '4.4%'}
# ----
# window: 524 knn: 1.262
# Top causes: {'Unstable steering': '14.0%', 'Tailgating': '10.3%'}
# Top features: {'acc_y_kf_mean': '15.9%', 'acc_y_mean': '15.7%', 'difcourse_mean': '6.8%', 'pitch_mean': '5.7%', 'acc_x_mean': '5.6%', 'acc_x_kf_mean': '5.4%'}
# ----
# window: 525 knn: 2.301
# Top causes: {'Unstable steering': '24.8%', 'Tailgating': '15.8%'}
# Top features: {'acc_y_kf_mean': '10.0%', 'acc_y_mean': '9.6%', 'osm_delay_mean': '8.2%', 'yaw_mean': '7.4%', 'difcourse_mean': '6.6%', 'ttc_front_mean': '4.5%'}
# ----
# window: 526 knn: 2.042
# Top causes: {'Tailgating': '29.5%', 'Harsh maneuvers': '17.1%'}
# Top features: {'yaw_mean': '16.6%', 'osm_delay_mean': '13.6%', 'course_mean': '9.1%', 'pitch_mean': '7.1%', 'lat_mean': '4.6%', 'lane_state_mean': '4.5%'}
# ----
# window: 527 knn: 1.226
# Top causes: {'Tailgating': '28.0%', 'Harsh maneuvers': '23.9%'}
# Top features: {'osm_delay_mean': '15.0%', 'pitch_mean': '14.9%', 'yaw_mean': '13.7%', 'num_vehicles_mean': '8.7%', 'course_mean': '7.4%', 't_10hz_mean': '3.8%'}
# ----
# window: 528 knn: 0.903
# Top causes: {'Harsh maneuvers': '19.7%', 'Overspeed': '9.0%'}
# Top features: {'pitch_mean': '14.4%', 'yaw_mean': '13.3%', 'num_vehicles_mean': '12.3%', 'osm_delay_mean': '9.5%', 'course_mean': '7.9%', 't_10hz_mean': '4.9%'}
# ----
# window: 529 knn: 0.802
# Top causes: {'Harsh maneuvers': '14.9%', 'Overspeed': '6.1%'}
# Top features: {'num_vehicles_mean': '16.3%', 'yaw_mean': '13.2%', 'pitch_mean': '12.9%', 'course_mean': '8.6%', 'osm_delay_mean': '6.2%', 't_10hz_mean': '6.2%'}
# ----
# window: 530 knn: 0.793
# Top causes: {'Harsh maneuvers': '16.5%', 'Overspeed': '4.8%'}
# Top features: {'num_vehicles_mean': '17.7%', 'yaw_mean': '12.8%', 'pitch_mean': '11.5%', 'course_mean': '9.2%', 't_10hz_mean': '7.4%', 'timestamp_mean': '7.4%'}
# ----
# window: 531 knn: 0.903
# Top causes: {'Harsh maneuvers': '17.5%', 'Overspeed': '3.6%'}
# Top features: {'num_vehicles_mean': '18.4%', 'yaw_mean': '12.2%', 'pitch_mean': '11.0%', 'course_mean': '9.4%', 't_10hz_mean': '8.4%', 'timestamp_mean': '8.4%'}
# ----
# window: 532 knn: 1.008
# Top causes: {'Harsh maneuvers': '15.0%', 'Overspeed': '3.5%'}
# Top features: {'num_vehicles_mean': '18.1%', 'yaw_mean': '11.7%', 'pitch_mean': '10.7%', 't_10hz_mean': '9.5%', 'timestamp_mean': '9.5%', 'course_mean': '9.4%'}
# ----
# window: 533 knn: 1.149
# Top causes: {'Harsh maneuvers': '14.4%', 'Overspeed': '6.2%'}
# Top features: {'num_vehicles_mean': '16.8%', 'yaw_mean': '10.6%', 't_10hz_mean': '10.0%', 'timestamp_mean': '10.0%', 'pitch_mean': '9.6%', 'course_mean': '8.8%'}
# ----
# window: 534 knn: 1.367
# Top causes: {'Harsh maneuvers': '19.6%', 'Overspeed': '6.3%'}
# Top features: {'num_vehicles_mean': '14.0%', 't_10hz_mean': '10.6%', 'timestamp_mean': '10.6%', 'yaw_mean': '9.8%', 'pitch_mean': '9.3%', 'course_mean': '8.3%'}
# ----

# %%
print(motor_phase3.columns.tolist())
# Out:
# ['index', 'label', 'knn_distance', 'severity_0_1', 'top_2']

# %%
print("\n=== MOTOR ===")
for idx, r in motor_phase3.iterrows():
    top_causes_list = [(cause_tuple[0], cause_tuple[1]) for cause_tuple in r["top_2"]]
    top_features_dict = motor_contrib_norm.loc[r["index"]].nlargest(6).to_dict()

    print("window:", r["index"], "knn:", round(float(r["knn_distance"]), 3))
    print("Top causes:", pct_dict(top_causes_list))
    print("Top features:", pct_dict(top_features_dict))
    print("----")

print("\n=== SECONDARY ===")
for idx, r in sec_phase3.iterrows():
    top_causes_list = [(cause_tuple[0], cause_tuple[1]) for cause_tuple in r["top_2"]]
    top_features_dict = sec_contrib_norm.loc[r["index"]].nlargest(6).to_dict()

    print("window:", r["index"], "knn:", round(float(r["knn_distance"]), 3))
    print("Top causes:", pct_dict(top_causes_list))
    print("Top features:", pct_dict(top_features_dict))
    print("----")
# Out:
# === MOTOR ===
# window: 0 knn: 6.024
# Top causes: {'Overspeed': '57.8%', 'Tailgating': '20.8%'}
# Top features: {'gps_speed_mean': '14.0%', 'gps_speed_osm_mean': '13.5%', 'speed_kmh_mean': '11.2%', 'vert_acc_mean': '6.4%', 'num_vehicles_mean': '6.0%', 'ttc_front_mean': '5.4%'}
# ----
# window: 1 knn: 5.465
# Top causes: {'Overspeed': '69.8%', 'Tailgating': '23.4%'}
# Top features: {'road_width_mean': '16.8%', 'gps_speed_mean': '15.1%', 'speed_kmh_mean': '15.0%', 'gps_speed_osm_mean': '14.7%', 'ttc_front_mean': '6.0%', 'num_vehicles_mean': '5.9%'}
# ----
# window: 2 knn: 5.254
# Top causes: {'Overspeed': '74.2%', 'Harsh maneuvers': '3.8%'}
# Top features: {'road_width_mean': '17.3%', 'speed_kmh_mean': '15.0%', 'gps_speed_mean': '14.9%', 'gps_speed_osm_mean': '14.8%', 'num_vehicles_mean': '5.7%', 'ttc_front_mean': '4.6%'}
# ----
# window: 3 knn: 4.723
# Top causes: {'Overspeed': '73.5%', 'Tailgating': '17.3%'}
# Top features: {'road_width_mean': '19.5%', 'speed_kmh_mean': '12.9%', 'gps_speed_mean': '12.8%', 'gps_speed_osm_mean': '12.7%', 'alt_mean': '6.2%', 'num_vehicles_mean': '4.9%'}
# ----
# window: 4 knn: 4.46
# Top causes: {'Overspeed': '71.6%', 'Tailgating': '16.9%'}
# Top features: {'road_width_mean': '21.5%', 'speed_kmh_mean': '10.9%', 'gps_speed_osm_mean': '10.7%', 'gps_speed_mean': '10.7%', 'alt_mean': '9.2%', 'num_vehicles_mean': '3.9%'}
# ----
# window: 5 knn: 4.666
# Top causes: {'Overspeed': '55.0%', 'Harsh maneuvers': '29.2%'}
# Top features: {'road_width_mean': '24.8%', 'alt_mean': '12.0%', 'speed_kmh_mean': '7.1%', 'gps_speed_osm_mean': '6.9%', 'gps_speed_mean': '6.8%', 'acc_x_mean': '4.7%'}
# ----
# window: 6 knn: 5.218
# Top causes: {'Harsh maneuvers': '68.8%', 'Overspeed': '18.2%'}
# Top features: {'road_width_mean': '14.3%', 'acc_x_mean': '13.3%', 'alt_mean': '12.3%', 'acc_x_kf_mean': '10.9%', 'vdop_mean': '4.9%', 'acc_z_kf_mean': '4.9%'}
# ----
# window: 7 knn: 5.385
# Top causes: {'Harsh maneuvers': '76.4%', 'Tailgating': '9.8%'}
# Top features: {'acc_x_mean': '12.7%', 'road_width_mean': '12.6%', 'acc_x_kf_mean': '10.7%', 'acc_z_kf_mean': '10.3%', 'acc_z_mean': '10.1%', 'alt_mean': '8.5%'}
# ----
# window: 8 knn: 5.273
# Top causes: {'Harsh maneuvers': '79.8%', 'Unstable steering': '9.3%'}
# Top features: {'acc_x_mean': '13.6%', 'acc_x_kf_mean': '11.6%', 'acc_z_kf_mean': '11.4%', 'acc_z_mean': '11.1%', 'road_width_mean': '10.9%', 'alt_mean': '7.8%'}
# ----
# window: 9 knn: 5.254
# Top causes: {'Harsh maneuvers': '80.7%', 'Unstable steering': '9.0%'}
# Top features: {'acc_z_kf_mean': '15.7%', 'acc_z_mean': '15.5%', 'acc_x_mean': '11.5%', 'acc_x_kf_mean': '9.8%', 'road_width_mean': '8.3%', 'difcourse_mean': '6.0%'}
# ----
# window: 10 knn: 5.037
# Top causes: {'Harsh maneuvers': '83.0%', 'Unstable steering': '9.6%'}
# Top features: {'acc_z_kf_mean': '17.7%', 'acc_z_mean': '17.5%', 'acc_x_mean': '10.4%', 'acc_x_kf_mean': '9.3%', 'road_width_mean': '6.8%', 'difcourse_mean': '6.3%'}
# ----
# window: 11 knn: 4.998
# Top causes: {'Harsh maneuvers': '82.6%', 'Unstable steering': '11.2%'}
# Top features: {'acc_z_kf_mean': '19.4%', 'acc_z_mean': '19.3%', 'acc_x_mean': '8.7%', 'acc_x_kf_mean': '7.7%', 'difcourse_mean': '7.1%', 'lon_mean': '5.3%'}
# ----
# window: 12 knn: 4.849
# Top causes: {'Harsh maneuvers': '71.2%', 'Unstable steering': '15.0%'}
# Top features: {'acc_z_kf_mean': '14.7%', 'acc_z_mean': '14.6%', 'difcourse_mean': '8.6%', 'acc_x_mean': '8.2%', 'acc_x_kf_mean': '7.1%', 'roll_mean': '6.6%'}
# ----
# window: 13 knn: 5.325
# Top causes: {'Harsh maneuvers': '66.4%', 'Tailgating': '14.8%'}
# Top features: {'acc_z_kf_mean': '15.5%', 'acc_z_mean': '15.2%', 'difcourse_mean': '8.1%', 'acc_x_mean': '7.4%', 'acc_x_kf_mean': '6.1%', 'roll_mean': '6.1%'}
# ----
# window: 14 knn: 5.635
# Top causes: {'Harsh maneuvers': '49.5%', 'Tailgating': '23.4%'}
# Top features: {'acc_z_kf_mean': '9.6%', 'acc_z_mean': '9.5%', 'difcourse_mean': '8.2%', 'roll_mean': '7.6%', 'num_vehicles_mean': '7.3%', 'acc_x_mean': '6.9%'}
# ----
# window: 15 knn: 5.995
# Top causes: {'Harsh maneuvers': '30.9%', 'Tailgating': '30.9%'}
# Top features: {'num_vehicles_mean': '9.1%', 'dist_front_mean': '7.4%', 'ttc_front_mean': '6.8%', 'gps_speed_mean': '6.8%', 'speed_kmh_mean': '6.7%', 'gps_speed_osm_mean': '6.4%'}
# ----
# window: 16 knn: 5.333
# Top causes: {'Overspeed': '48.0%', 'Tailgating': '33.8%'}
# Top features: {'gps_speed_mean': '12.6%', 'speed_kmh_mean': '12.5%', 'gps_speed_osm_mean': '12.1%', 'num_vehicles_mean': '10.0%', 'ttc_front_mean': '8.4%', 'dist_front_mean': '8.2%'}
# ----
# window: 17 knn: 5.286
# Top causes: {'Overspeed': '59.7%', 'Tailgating': '24.9%'}
# Top features: {'gps_speed_mean': '16.9%', 'speed_kmh_mean': '16.7%', 'gps_speed_osm_mean': '16.1%', 'num_vehicles_mean': '8.2%', 'ttc_front_mean': '7.2%', 'dist_front_mean': '5.7%'}
# ----
# window: 18 knn: 5.556
# Top causes: {'Overspeed': '64.2%', 'Tailgating': '19.7%'}
# Top features: {'gps_speed_mean': '19.0%', 'speed_kmh_mean': '18.8%', 'gps_speed_osm_mean': '18.3%', 'num_vehicles_mean': '7.2%', 'vert_acc_mean': '6.2%', 'ttc_front_mean': '6.2%'}
# ----
# window: 19 knn: 5.413
# Top causes: {'Overspeed': '65.9%', 'Tailgating': '14.9%'}
# Top features: {'gps_speed_mean': '19.2%', 'speed_kmh_mean': '19.2%', 'gps_speed_osm_mean': '18.8%', 'vert_acc_mean': '7.6%', 'num_vehicles_mean': '5.1%', 'ttc_front_mean': '4.7%'}
# ----
# window: 20 knn: 5.501
# Top causes: {'Overspeed': '63.5%', 'Tailgating': '18.1%'}
# Top features: {'gps_speed_mean': '18.2%', 'speed_kmh_mean': '18.2%', 'gps_speed_osm_mean': '17.8%', 'vert_acc_mean': '6.7%', 'ttc_front_mean': '5.7%', 'num_vehicles_mean': '5.6%'}
# ----
# window: 21 knn: 5.247
# Top causes: {'Overspeed': '62.4%', 'Tailgating': '21.2%'}
# Top features: {'speed_kmh_mean': '16.2%', 'gps_speed_mean': '16.1%', 'gps_speed_osm_mean': '16.1%', 'vert_acc_mean': '7.2%', 'num_vehicles_mean': '6.2%', 'ttc_front_mean': '5.8%'}
# ----
# window: 22 knn: 7.124
# Top causes: {'Harsh maneuvers': '47.6%', 'Overspeed': '31.4%'}
# Top features: {'vert_acc_mean': '26.5%', 'horiz_acc_mean': '8.8%', 'gps_speed_mean': '8.5%', 'gps_speed_osm_mean': '8.4%', 'speed_kmh_mean': '6.3%', 'num_vehicles_mean': '5.1%'}
# ----
# window: 23 knn: 6.547
# Top causes: {'Harsh maneuvers': '51.8%', 'Overspeed': '24.5%'}
# Top features: {'vert_acc_mean': '28.6%', 'horiz_acc_mean': '9.4%', 'gps_speed_mean': '6.6%', 'gps_speed_osm_mean': '6.5%', 'road_width_mean': '5.6%', 'ttc_front_mean': '5.5%'}
# ----
# window: 24 knn: 6.054
# Top causes: {'Harsh maneuvers': '54.6%', 'Tailgating': '23.0%'}
# Top features: {'vert_acc_mean': '29.1%', 'horiz_acc_mean': '10.0%', 'road_width_mean': '6.3%', 'num_vehicles_mean': '6.1%', 'ttc_front_mean': '5.9%', 'gps_speed_mean': '5.2%'}
# ----
# window: 25 knn: 5.687
# Top causes: {'Harsh maneuvers': '60.6%', 'Tailgating': '23.2%'}
# Top features: {'vert_acc_mean': '29.7%', 'horiz_acc_mean': '10.3%', 'road_width_mean': '7.0%', 'num_vehicles_mean': '5.8%', 'lat_mean': '5.7%', 'ttc_front_mean': '5.7%'}
# ----
# window: 26 knn: 5.315
# Top causes: {'Harsh maneuvers': '64.6%', 'Tailgating': '23.5%'}
# Top features: {'vert_acc_mean': '30.0%', 'horiz_acc_mean': '10.6%', 'road_width_mean': '7.9%', 'lat_mean': '6.8%', 'ttc_front_mean': '5.5%', 'num_vehicles_mean': '5.4%'}
# ----
# window: 27 knn: 4.619
# Top causes: {'Harsh maneuvers': '69.5%', 'Tailgating': '23.7%'}
# Top features: {'vert_acc_mean': '29.5%', 'horiz_acc_mean': '9.5%', 'road_width_mean': '7.6%', 'vdop_mean': '7.2%', 'lat_mean': '6.3%', 'ttc_front_mean': '5.0%'}
# ----
# window: 28 knn: 4.571
# Top causes: {'Harsh maneuvers': '72.1%', 'Tailgating': '24.8%'}
# Top features: {'vert_acc_mean': '26.1%', 'vdop_mean': '11.3%', 'pdop_mean': '9.5%', 'horiz_acc_mean': '8.4%', 'road_width_mean': '7.5%', 'lat_mean': '5.3%'}
# ----
# window: 29 knn: 5.159
# Top causes: {'Harsh maneuvers': '66.7%', 'Tailgating': '31.8%'}
# Top features: {'vert_acc_mean': '21.4%', 'vdop_mean': '14.0%', 'pdop_mean': '8.8%', 'road_width_mean': '8.3%', 'horiz_acc_mean': '7.8%', 'ttc_front_mean': '5.7%'}
# ----
# window: 30 knn: 5.523
# Top causes: {'Harsh maneuvers': '69.9%', 'Tailgating': '28.3%'}
# Top features: {'vert_acc_mean': '21.7%', 'vdop_mean': '15.5%', 'pdop_mean': '8.5%', 'road_width_mean': '8.1%', 'horiz_acc_mean': '7.5%', 'dist_front_mean': '4.7%'}
# ----
# window: 31 knn: 5.99
# Top causes: {'Harsh maneuvers': '71.4%', 'Tailgating': '27.0%'}
# Top features: {'vert_acc_mean': '21.4%', 'vdop_mean': '14.7%', 'pdop_mean': '7.9%', 'road_width_mean': '7.8%', 'horiz_acc_mean': '7.0%', 'ttc_front_mean': '4.5%'}
# ----
# window: 32 knn: 8.0
# Top causes: {'Harsh maneuvers': '46.9%', 'Tailgating': '45.2%'}
# Top features: {'vdop_mean': '31.5%', 'hdop_mean': '9.3%', 'pdop_mean': '9.0%', 'vert_acc_mean': '7.3%', 'x_lane_mean': '5.0%', 'alt_mean': '4.9%'}
# ----
# window: 33 knn: 8.455
# Top causes: {'Harsh maneuvers': '54.3%', 'Tailgating': '35.8%'}
# Top features: {'vdop_mean': '33.3%', 'pdop_mean': '14.6%', 'hdop_mean': '8.2%', 'vert_acc_mean': '7.6%', 'alt_mean': '5.4%', 'x_lane_mean': '5.3%'}
# ----
# window: 34 knn: 9.076
# Top causes: {'Harsh maneuvers': '65.0%', 'Tailgating': '26.1%'}
# Top features: {'vdop_mean': '32.3%', 'pdop_mean': '20.5%', 'hdop_mean': '9.4%', 'vert_acc_mean': '8.3%', 'x_lane_mean': '5.1%', 'alt_mean': '4.9%'}
# ----
# window: 35 knn: 9.753
# Top causes: {'Harsh maneuvers': '71.3%', 'Tailgating': '21.5%'}
# Top features: {'pdop_mean': '31.0%', 'vdop_mean': '30.2%', 'hdop_mean': '8.7%', 'vert_acc_mean': '8.5%', 'alt_mean': '4.2%', 'x_lane_mean': '4.0%'}
# ----
# window: 36 knn: 9.949
# Top causes: {'Harsh maneuvers': '81.5%', 'Tailgating': '11.4%'}
# Top features: {'pdop_mean': '40.4%', 'vdop_mean': '28.9%', 'vert_acc_mean': '8.3%', 'hdop_mean': '6.0%', 'alt_mean': '3.8%', 'x_lane_mean': '3.1%'}
# ----
# window: 37 knn: 9.336
# Top causes: {'Harsh maneuvers': '77.9%', 'Tailgating': '14.0%'}
# Top features: {'vdop_mean': '31.5%', 'pdop_mean': '31.1%', 'vert_acc_mean': '9.2%', 'hdop_mean': '6.4%', 'alt_mean': '4.9%', 'x_lane_mean': '4.4%'}
# ----
# window: 38 knn: 8.742
# Top causes: {'Harsh maneuvers': '79.8%', 'Tailgating': '11.7%'}
# Top features: {'vdop_mean': '31.1%', 'pdop_mean': '24.7%', 'vert_acc_mean': '10.7%', 'hdop_mean': '8.6%', 'alt_mean': '5.2%', 'x_lane_mean': '4.6%'}
# ----
# window: 39 knn: 8.787
# Top causes: {'Harsh maneuvers': '85.6%', 'Tailgating': '7.7%'}
# Top features: {'vdop_mean': '31.4%', 'pdop_mean': '24.5%', 'vert_acc_mean': '13.1%', 'hdop_mean': '9.0%', 'alt_mean': '4.6%', 'x_lane_mean': '4.2%'}
# ----
# window: 40 knn: 8.856
# Top causes: {'Harsh maneuvers': '81.6%', 'Tailgating': '13.5%'}
# Top features: {'vdop_mean': '32.9%', 'pdop_mean': '24.0%', 'vert_acc_mean': '13.5%', 'hdop_mean': '9.0%', 'x_lane_mean': '4.5%', 'alt_mean': '3.8%'}
# ----
# window: 41 knn: 8.752
# Top causes: {'Harsh maneuvers': '78.4%', 'Tailgating': '17.8%'}
# Top features: {'vdop_mean': '32.9%', 'pdop_mean': '23.8%', 'vert_acc_mean': '11.6%', 'hdop_mean': '7.6%', 'roll_mean': '3.4%', 'x_lane_mean': '3.3%'}
# ----
# window: 42 knn: 8.58
# Top causes: {'Harsh maneuvers': '71.8%', 'Tailgating': '15.4%'}
# Top features: {'vdop_mean': '25.0%', 'pdop_mean': '20.6%', 'vert_acc_mean': '8.4%', 'roll_mean': '7.4%', 'hdop_mean': '5.3%', 'acc_z_mean': '4.5%'}
# ----
# window: 43 knn: 7.8
# Top causes: {'Harsh maneuvers': '65.9%', 'Tailgating': '19.3%'}
# Top features: {'vdop_mean': '23.4%', 'pdop_mean': '15.6%', 'vert_acc_mean': '9.5%', 'roll_mean': '7.2%', 'hdop_mean': '5.9%', 'acc_z_mean': '5.3%'}
# ----
# window: 44 knn: 6.951
# Top causes: {'Harsh maneuvers': '66.1%', 'Tailgating': '18.5%'}
# Top features: {'vdop_mean': '22.3%', 'pdop_mean': '10.4%', 'roll_mean': '10.1%', 'vert_acc_mean': '9.4%', 'acc_z_mean': '6.5%', 'acc_z_kf_mean': '6.3%'}
# ----
# window: 45 knn: 5.96
# Top causes: {'Harsh maneuvers': '68.2%', 'Tailgating': '15.8%'}
# Top features: {'vdop_mean': '20.9%', 'roll_mean': '13.9%', 'vert_acc_mean': '9.9%', 'acc_z_mean': '7.5%', 'acc_z_kf_mean': '7.3%', 'difcourse_mean': '5.1%'}
# ----
# window: 46 knn: 5.493
# Top causes: {'Harsh maneuvers': '64.9%', 'Unstable steering': '12.5%'}
# Top features: {'vdop_mean': '16.9%', 'roll_mean': '12.5%', 'vert_acc_mean': '10.2%', 'acc_z_mean': '8.4%', 'acc_z_kf_mean': '8.2%', 'difcourse_mean': '5.8%'}
# ----
# window: 47 knn: 5.513
# Top causes: {'Harsh maneuvers': '63.9%', 'Unstable steering': '13.5%'}
# Top features: {'vdop_mean': '17.1%', 'roll_mean': '12.7%', 'acc_z_mean': '8.7%', 'vert_acc_mean': '8.6%', 'acc_z_kf_mean': '8.5%', 'hdop_mean': '6.4%'}
# ----
# window: 48 knn: 5.502
# Top causes: {'Harsh maneuvers': '60.3%', 'Tailgating': '19.5%'}
# Top features: {'vdop_mean': '21.8%', 'roll_mean': '9.7%', 'hdop_mean': '7.9%', 'acc_z_mean': '7.5%', 'acc_z_kf_mean': '7.3%', 'difcourse_mean': '5.6%'}
# ----
# window: 49 knn: 6.306
# Top causes: {'Harsh maneuvers': '58.5%', 'Unstable steering': '18.4%'}
# Top features: {'vdop_mean': '26.8%', 'roll_mean': '9.3%', 'hdop_mean': '8.0%', 'acc_z_mean': '6.7%', 'acc_z_kf_mean': '6.6%', 'pdop_mean': '6.2%'}
# ----
# window: 50 knn: 7.615
# Top causes: {'Harsh maneuvers': '60.7%', 'Unstable steering': '19.6%'}
# Top features: {'vdop_mean': '29.9%', 'pdop_mean': '16.1%', 'roll_mean': '8.4%', 'hdop_mean': '7.5%', 'acc_z_mean': '4.8%', 'acc_z_kf_mean': '4.8%'}
# ----
# window: 51 knn: 9.258
# Top causes: {'Harsh maneuvers': '40.8%', 'Unstable steering': '29.1%'}
# Top features: {'vdop_mean': '35.0%', 'pdop_mean': '29.0%', 'hdop_mean': '9.2%', 'x_lane_mean': '4.6%', 'roll_mean': '3.7%', 'vert_acc_mean': '2.6%'}
# ----
# window: 52 knn: 10.418
# Top causes: {'Harsh maneuvers': '53.3%', 'Unstable steering': '24.5%'}
# Top features: {'pdop_mean': '37.2%', 'vdop_mean': '33.7%', 'hdop_mean': '7.6%', 'x_lane_mean': '3.8%', 'vert_acc_mean': '2.3%', 'yaw_mean': '1.9%'}
# ----
# window: 53 knn: 10.674
# Top causes: {'Harsh maneuvers': '48.9%', 'Unstable steering': '26.7%'}
# Top features: {'pdop_mean': '37.5%', 'vdop_mean': '34.8%', 'hdop_mean': '6.3%', 'x_lane_mean': '3.8%', 'alt_mean': '2.1%', 'vert_acc_mean': '1.9%'}
# ----
# window: 54 knn: 10.715
# Top causes: {'Harsh maneuvers': '42.5%', 'Unstable steering': '32.3%'}
# Top features: {'pdop_mean': '37.3%', 'vdop_mean': '34.9%', 'hdop_mean': '6.8%', 'x_lane_mean': '4.2%', 'alt_mean': '2.2%', 'yaw_mean': '2.2%'}
# ----
# window: 55 knn: 10.705
# Top causes: {'Harsh maneuvers': '38.9%', 'Unstable steering': '28.8%'}
# Top features: {'pdop_mean': '36.9%', 'vdop_mean': '34.5%', 'hdop_mean': '6.4%', 'x_lane_mean': '4.0%', 'alt_mean': '2.2%', 'yaw_mean': '1.9%'}
# ----
# window: 56 knn: 10.852
# Top causes: {'Harsh maneuvers': '41.7%', 'Unstable steering': '24.3%'}
# Top features: {'pdop_mean': '35.4%', 'vdop_mean': '34.2%', 'hdop_mean': '7.0%', 'x_lane_mean': '4.2%', 'vert_acc_mean': '2.1%', 'alt_mean': '2.0%'}
# ----
# window: 57 knn: 10.595
# Top causes: {'Harsh maneuvers': '53.7%', 'Unstable steering': '17.9%'}
# Top features: {'pdop_mean': '35.8%', 'vdop_mean': '34.2%', 'hdop_mean': '6.5%', 'x_lane_mean': '3.9%', 'vert_acc_mean': '2.8%', 'roll_mean': '2.2%'}
# ----
# window: 58 knn: 10.107
# Top causes: {'Harsh maneuvers': '60.5%', 'Tailgating': '17.1%'}
# Top features: {'vdop_mean': '35.4%', 'pdop_mean': '31.3%', 'hdop_mean': '6.5%', 'vert_acc_mean': '4.3%', 'x_lane_mean': '4.2%', 'roll_mean': '2.3%'}
# ----
# window: 59 knn: 9.927
# Top causes: {'Harsh maneuvers': '59.5%', 'Tailgating': '23.2%'}
# Top features: {'vdop_mean': '33.5%', 'pdop_mean': '29.1%', 'hdop_mean': '7.6%', 'x_lane_mean': '4.5%', 'vert_acc_mean': '4.4%', 'roll_mean': '3.4%'}
# ----
# window: 60 knn: 9.69
# Top causes: {'Harsh maneuvers': '59.8%', 'Tailgating': '28.4%'}
# Top features: {'vdop_mean': '31.1%', 'pdop_mean': '29.1%', 'hdop_mean': '8.7%', 'x_lane_mean': '4.6%', 'vert_acc_mean': '4.2%', 'roll_mean': '3.2%'}
# ----
# window: 61 knn: 6.806
# Top causes: {'Harsh maneuvers': '74.5%', 'Tailgating': '19.9%'}
# Top features: {'pdop_mean': '24.7%', 'vdop_mean': '22.1%', 'vert_acc_mean': '13.6%', 'roll_mean': '6.7%', 'road_width_mean': '6.4%', 'horiz_acc_mean': '3.4%'}
# ----
# window: 62 knn: 5.812
# Top causes: {'Harsh maneuvers': '80.5%', 'Tailgating': '16.4%'}
# Top features: {'vert_acc_mean': '18.9%', 'vdop_mean': '16.8%', 'pdop_mean': '14.6%', 'roll_mean': '8.3%', 'road_width_mean': '8.0%', 'horiz_acc_mean': '6.6%'}
# ----
# window: 63 knn: 5.051
# Top causes: {'Harsh maneuvers': '79.2%', 'Tailgating': '18.0%'}
# Top features: {'vert_acc_mean': '18.8%', 'vdop_mean': '16.5%', 'pdop_mean': '13.5%', 'roll_mean': '8.4%', 'road_width_mean': '7.5%', 'horiz_acc_mean': '7.0%'}
# ----
# window: 64 knn: 4.492
# Top causes: {'Harsh maneuvers': '76.8%', 'Tailgating': '20.9%'}
# Top features: {'vert_acc_mean': '17.7%', 'vdop_mean': '16.6%', 'pdop_mean': '13.9%', 'roll_mean': '8.3%', 'horiz_acc_mean': '7.2%', 'road_width_mean': '6.7%'}
# ----
# window: 65 knn: 3.426
# Top causes: {'Tailgating': '16.9%', 'Overspeed': '1.3%'}
# Top features: {'vert_acc_mean': '17.9%', 'vdop_mean': '16.6%', 'pdop_mean': '15.6%', 'horiz_acc_mean': '8.1%', 'road_width_mean': '6.2%', 'roll_mean': '4.8%'}
# ----
# window: 66 knn: 2.684
# Top causes: {'Tailgating': '17.2%', 'Overspeed': '1.6%'}
# Top features: {'vert_acc_mean': '17.5%', 'pdop_mean': '16.6%', 'vdop_mean': '14.6%', 'horiz_acc_mean': '8.6%', 'road_width_mean': '5.4%', 'lat_mean': '5.3%'}
# ----
# window: 67 knn: 2.024
# Top causes: {'Tailgating': '8.5%', 'Overspeed': '2.9%'}
# Top features: {'vert_acc_mean': '19.0%', 'pdop_mean': '18.6%', 'vdop_mean': '11.7%', 'horiz_acc_mean': '9.6%', 'lat_mean': '5.7%', 'road_width_mean': '4.8%'}
# ----
# window: 68 knn: 1.925
# Top causes: {'Tailgating': '4.6%', 'Overspeed': '4.3%'}
# Top features: {'pdop_mean': '20.1%', 'vert_acc_mean': '19.2%', 'horiz_acc_mean': '10.4%', 'vdop_mean': '7.9%', 'lat_mean': '5.4%', 'active_mean': '4.8%'}
# ----
# window: 69 knn: 2.124
# Top causes: {'Overspeed': '6.4%', 'Tailgating': '5.5%'}
# Top features: {'vert_acc_mean': '23.1%', 'horiz_acc_mean': '12.3%', 'pdop_mean': '10.2%', 'active_mean': '5.7%', 'lat_mean': '5.1%', 'vdop_mean': '4.2%'}
# ----
# window: 70 knn: 3.305
# Top causes: {'Overspeed': '9.7%', 'Tailgating': '4.7%'}
# Top features: {'vert_acc_mean': '25.2%', 'horiz_acc_mean': '13.3%', 'active_mean': '6.1%', 'phi_mean': '4.3%', 'lane_state_mean': '4.0%', 'timestamp_mean': '3.9%'}
# ----
# window: 71 knn: 2.166
# Top causes: {'Tailgating': '8.0%', 'Unstable steering': '1.1%'}
# Top features: {'vert_acc_mean': '15.3%', 'timestamp_mean': '11.0%', 't_10hz_mean': '11.0%', 'gps_speed_mean': '7.5%', 'gps_speed_osm_mean': '7.1%', 'speed_kmh_mean': '6.8%'}
# ----
# window: 72 knn: 1.471
# Top causes: {'Tailgating': '8.0%', 'Unstable steering': '3.3%'}
# Top features: {'speed_kmh_mean': '10.1%', 'gps_speed_mean': '9.9%', 'gps_speed_osm_mean': '9.6%', 'timestamp_mean': '7.9%', 't_10hz_mean': '7.9%', 'acc_x_kf_mean': '5.8%'}
# ----
# window: 73 knn: 1.16
# Top causes: {'Tailgating': '8.1%', 'Unstable steering': '5.0%'}
# Top features: {'speed_kmh_mean': '10.4%', 'gps_speed_mean': '10.3%', 'gps_speed_osm_mean': '10.2%', 'vert_acc_mean': '7.1%', 'timestamp_mean': '6.3%', 't_10hz_mean': '6.3%'}
# ----
# window: 74 knn: 0.977
# Top causes: {'Tailgating': '7.6%', 'Unstable steering': '5.0%'}
# Top features: {'vert_acc_mean': '11.6%', 'alt_mean': '10.7%', 'speed_kmh_mean': '9.1%', 'gps_speed_osm_mean': '8.9%', 'gps_speed_mean': '8.9%', 'roll_mean': '5.7%'}
# ----
# window: 75 knn: 0.928
# Top causes: {'Tailgating': '7.5%', 'Unstable steering': '5.1%'}
# Top features: {'alt_mean': '13.8%', 'vert_acc_mean': '12.1%', 'speed_kmh_mean': '8.5%', 'gps_speed_mean': '8.3%', 'gps_speed_osm_mean': '8.3%', 'acc_x_kf_mean': '4.1%'}
# ----
# window: 76 knn: 1.164
# Top causes: {'Harsh maneuvers': '27.0%', 'Tailgating': '20.4%'}
# Top features: {'alt_mean': '16.1%', 'vert_acc_mean': '9.4%', 'speed_kmh_mean': '7.8%', 'gps_speed_osm_mean': '7.7%', 'gps_speed_mean': '7.7%', 'dist_front_mean': '7.1%'}
# ----
# window: 77 knn: 1.079
# Top causes: {'Tailgating': '10.3%', 'Unstable steering': '6.0%'}
# Top features: {'alt_mean': '20.8%', 'vert_acc_mean': '10.2%', 'roll_mean': '7.3%', 'speed_kmh_mean': '6.3%', 'gps_speed_osm_mean': '6.2%', 'gps_speed_mean': '6.1%'}
# ----
# window: 78 knn: 1.612
# Top causes: {'Tailgating': '12.2%', 'Unstable steering': '4.8%'}
# Top features: {'alt_mean': '26.4%', 'vert_acc_mean': '10.9%', 'roll_mean': '9.4%', 'course_mean': '6.0%', 'pitch_mean': '4.5%', 'gps_speed_osm_mean': '3.6%'}
# ----
# window: 79 knn: 2.586
# Top causes: {'Tailgating': '22.7%', 'Overspeed': '11.3%'}
# Top features: {'alt_mean': '27.8%', 'vert_acc_mean': '10.6%', 'course_mean': '7.6%', 'roll_mean': '4.4%', 'road_width_mean': '3.9%', 'vdop_mean': '3.5%'}
# ----
# window: 80 knn: 1.446
# Top causes: {'Unstable steering': '7.3%', 'Tailgating': '6.2%'}
# Top features: {'acc_y_mean': '15.3%', 'acc_y_kf_mean': '15.2%', 'acc_z_mean': '14.0%', 'acc_z_kf_mean': '14.0%', 'alt_mean': '9.6%', 'difcourse_mean': '5.2%'}
# ----
# window: 81 knn: 1.082
# Top causes: {'Unstable steering': '9.0%', 'Tailgating': '5.0%'}
# Top features: {'acc_y_mean': '15.8%', 'acc_y_kf_mean': '15.7%', 'acc_z_kf_mean': '14.3%', 'acc_z_mean': '14.2%', 'alt_mean': '7.3%', 'difcourse_mean': '6.6%'}
# ----
# window: 82 knn: 0.95
# Top causes: {'Unstable steering': '13.6%', 'Tailgating': '3.1%'}
# Top features: {'acc_y_mean': '15.4%', 'acc_y_kf_mean': '15.3%', 'acc_z_kf_mean': '13.9%', 'acc_z_mean': '13.7%', 'difcourse_mean': '10.0%', 'alt_mean': '6.1%'}
# ----
# window: 83 knn: 1.001
# Top causes: {'Unstable steering': '13.4%', 'Tailgating': '2.6%'}
# Top features: {'acc_y_mean': '16.7%', 'acc_y_kf_mean': '16.6%', 'acc_z_kf_mean': '14.2%', 'acc_z_mean': '14.0%', 'difcourse_mean': '9.9%', 'lon_mean': '4.3%'}
# ----
# window: 84 knn: 1.056
# Top causes: {'Unstable steering': '15.1%', 'Tailgating': '2.5%'}
# Top features: {'acc_y_mean': '17.1%', 'acc_y_kf_mean': '17.0%', 'acc_z_kf_mean': '14.5%', 'acc_z_mean': '14.2%', 'difcourse_mean': '10.7%', 'lon_mean': '4.5%'}
# ----
# window: 85 knn: 1.147
# Top causes: {'Unstable steering': '15.9%', 'Tailgating': '2.2%'}
# Top features: {'acc_y_mean': '16.4%', 'acc_y_kf_mean': '16.3%', 'acc_z_kf_mean': '14.6%', 'acc_z_mean': '14.2%', 'difcourse_mean': '10.6%', 'lon_mean': '4.1%'}
# ----
# window: 86 knn: 1.282
# Top causes: {'Unstable steering': '16.8%', 'Tailgating': '7.0%'}
# Top features: {'acc_y_mean': '16.5%', 'acc_y_kf_mean': '16.3%', 'acc_z_kf_mean': '12.1%', 'acc_z_mean': '11.9%', 'difcourse_mean': '10.4%', 'road_width_mean': '3.6%'}
# ----
# window: 87 knn: 1.439
# Top causes: {'Unstable steering': '17.3%', 'Tailgating': '12.8%'}
# Top features: {'acc_y_kf_mean': '13.4%', 'acc_y_mean': '13.4%', 'acc_z_kf_mean': '12.6%', 'acc_z_mean': '12.1%', 'difcourse_mean': '9.6%', 'num_vehicles_mean': '4.9%'}
# ----
# window: 88 knn: 1.807
# Top causes: {'Tailgating': '17.4%', 'Unstable steering': '15.2%'}
# Top features: {'acc_y_kf_mean': '12.6%', 'acc_y_mean': '12.5%', 'acc_z_kf_mean': '9.5%', 'acc_z_mean': '9.1%', 'difcourse_mean': '6.4%', 'num_vehicles_mean': '6.0%'}
# ----
# window: 89 knn: 2.822
# Top causes: {'Overspeed': '18.5%', 'Unstable steering': '14.7%'}
# Top features: {'num_vehicles_mean': '8.9%', 'ttc_front_mean': '8.8%', 'yaw_mean': '8.3%', 'acc_y_kf_mean': '7.1%', 'acc_y_mean': '6.9%', 'dist_front_mean': '5.6%'}
# ----
# window: 90 knn: 1.438
# Top causes: {'Tailgating': '26.4%', 'Harsh maneuvers': '21.1%'}
# Top features: {'yaw_mean': '9.4%', 'gps_speed_osm_mean': '8.7%', 'speed_kmh_mean': '8.5%', 'gps_speed_mean': '8.4%', 'num_vehicles_mean': '8.2%', 'ttc_front_mean': '6.8%'}
# ----
# window: 91 knn: 1.073
# Top causes: {'Harsh maneuvers': '25.1%', 'Tailgating': '16.9%'}
# Top features: {'gps_speed_osm_mean': '9.5%', 'speed_kmh_mean': '9.3%', 'gps_speed_mean': '9.2%', 'yaw_mean': '9.2%', 'osm_delay_mean': '7.5%', 'num_vehicles_mean': '5.9%'}
# ----
# window: 92 knn: 0.982
# Top causes: {'Unstable steering': '17.2%', 'Harsh maneuvers': '29.8%'}
# Top features: {'yaw_mean': '9.6%', 'gps_speed_osm_mean': '9.0%', 'speed_kmh_mean': '8.8%', 'gps_speed_mean': '8.6%', 'osm_delay_mean': '7.4%', 'acc_x_kf_mean': '6.7%'}
# ----
# window: 93 knn: 1.059
# Top causes: {'Harsh maneuvers': '29.2%', 'Unstable steering': '20.4%'}
# Top features: {'yaw_mean': '10.8%', 'gps_speed_osm_mean': '8.6%', 'speed_kmh_mean': '8.2%', 'gps_speed_mean': '8.1%', 'acc_x_kf_mean': '6.5%', 'course_mean': '6.3%'}
# ----
# window: 94 knn: 1.14
# Top causes: {'Unstable steering': '21.5%', 'Tailgating': '11.1%'}
# Top features: {'yaw_mean': '11.4%', 'acc_x_kf_mean': '7.4%', 'speed_kmh_mean': '7.2%', 'course_mean': '7.1%', 'gps_speed_mean': '7.0%', 'gps_speed_osm_mean': '7.0%'}
# ----
# window: 95 knn: 1.261
# Top causes: {'Overspeed': '29.5%', 'Unstable steering': '23.8%'}
# Top features: {'yaw_mean': '11.2%', 'acc_x_kf_mean': '9.0%', 'roll_mean': '7.9%', 'acc_x_mean': '7.3%', 'course_mean': '7.3%', 't_10hz_mean': '5.6%'}
# ----
# window: 96 knn: 1.382
# Top causes: {'Unstable steering': '29.8%', 'Overspeed': '27.8%'}
# Top features: {'yaw_mean': '12.6%', 'course_mean': '8.3%', 'roll_mean': '8.2%', 't_10hz_mean': '7.6%', 'timestamp_mean': '7.6%', 'acc_x_kf_mean': '6.6%'}
# ----
# window: 97 knn: 2.028
# Top causes: {'Overspeed': '10.4%', 'Tailgating': '7.3%'}
# Top features: {'roll_mean': '15.1%', 'yaw_mean': '12.2%', 't_10hz_mean': '8.9%', 'timestamp_mean': '8.9%', 'acc_x_kf_mean': '8.2%', 'course_mean': '7.8%'}
# ----
# window: 98 knn: 10.961
# Top causes: {'Unstable steering': '28.6%', 'Tailgating': '27.7%'}
# Top features: {'pdop_mean': '38.9%', 'vdop_mean': '17.9%', 'active_mean': '6.4%', 'x_lane_mean': '5.6%', 'phi_mean': '5.2%', 'road_width_mean': '5.1%'}
# ----
# window: 99 knn: 11.065
# Top causes: {'Overspeed': '56.6%', 'Harsh maneuvers': '22.6%'}
# Top features: {'pdop_mean': '54.1%', 'vdop_mean': '25.4%', 'hdop_mean': '6.9%', 'alt_mean': '2.6%', 'timestamp_mean': '1.3%', 't_10hz_mean': '1.3%'}
# ----
# window: 100 knn: 10.907
# Top causes: {'Overspeed': '58.2%', 'Harsh maneuvers': '25.0%'}
# Top features: {'pdop_mean': '56.8%', 'vdop_mean': '24.6%', 'hdop_mean': '6.2%', 'alt_mean': '2.2%', 'timestamp_mean': '1.2%', 't_10hz_mean': '1.2%'}
# ----
# window: 101 knn: 9.895
# Top causes: {'Overspeed': '59.7%', 'Harsh maneuvers': '23.7%'}
# Top features: {'pdop_mean': '55.1%', 'vdop_mean': '24.0%', 'hdop_mean': '5.7%', 'alt_mean': '2.2%', 'timestamp_mean': '1.3%', 't_10hz_mean': '1.3%'}
# ----
# window: 102 knn: 8.98
# Top causes: {'Overspeed': '65.8%', 'Harsh maneuvers': '20.7%'}
# Top features: {'pdop_mean': '50.3%', 'vdop_mean': '23.2%', 'hdop_mean': '5.0%', 'alt_mean': '2.3%', 'speed_kmh_mean': '2.2%', 'gps_speed_mean': '2.2%'}
# ----
# window: 103 knn: 7.353
# Top causes: {'Overspeed': '69.7%', 'Harsh maneuvers': '15.8%'}
# Top features: {'pdop_mean': '41.4%', 'vdop_mean': '21.3%', 'hdop_mean': '4.5%', 'speed_kmh_mean': '4.0%', 'gps_speed_mean': '3.9%', 'gps_speed_osm_mean': '3.8%'}
# ----
# window: 104 knn: 5.752
# Top causes: {'Overspeed': '59.2%', 'Harsh maneuvers': '22.6%'}
# Top features: {'pdop_mean': '29.0%', 'vdop_mean': '17.1%', 'speed_kmh_mean': '5.6%', 'gps_speed_mean': '5.5%', 'gps_speed_osm_mean': '5.5%', 'hdop_mean': '3.5%'}
# ----
# window: 105 knn: 4.349
# Top causes: {'Overspeed': '55.4%', 'Tailgating': '13.1%'}
# Top features: {'pdop_mean': '13.7%', 'vdop_mean': '11.9%', 'speed_kmh_mean': '6.8%', 'gps_speed_mean': '6.6%', 'gps_speed_osm_mean': '6.6%', 'course_mean': '5.2%'}
# ----
# window: 106 knn: 3.839
# Top causes: {'Harsh maneuvers': '47.7%', 'Tailgating': '16.5%'}
# Top features: {'course_mean': '8.5%', 'acc_x_mean': '8.5%', 'acc_x_kf_mean': '7.8%', 'num_vehicles_mean': '5.9%', 'pitch_mean': '5.7%', 'vdop_mean': '5.0%'}
# ----
# window: 107 knn: 3.812
# Top causes: {'Harsh maneuvers': '72.5%', 'Tailgating': '15.4%'}
# Top features: {'acc_x_mean': '13.9%', 'acc_x_kf_mean': '12.9%', 'course_mean': '10.0%', 'vert_acc_mean': '7.4%', 'num_vehicles_mean': '4.8%', 'hdop_mean': '4.7%'}
# ----
# window: 108 knn: 3.559
# Top causes: {'Harsh maneuvers': '78.2%', 'Unstable steering': '15.0%'}
# Top features: {'acc_x_mean': '21.1%', 'acc_x_kf_mean': '21.1%', 'difcourse_mean': '10.5%', 'acc_z_mean': '4.5%', 'pitch_mean': '4.3%', 'acc_z_kf_mean': '4.0%'}
# ----
# window: 109 knn: 2.796
# Top causes: {'Unstable steering': '24.2%', 'Overspeed': '5.8%'}
# Top features: {'difcourse_mean': '16.5%', 'acc_x_kf_mean': '14.7%', 'acc_x_mean': '14.3%', 'acc_z_mean': '5.6%', 'acc_z_kf_mean': '5.1%', 'roll_mean': '4.7%'}
# ----
# window: 110 knn: 2.786
# Top causes: {'Unstable steering': '24.1%', 'Overspeed': '5.2%'}
# Top features: {'difcourse_mean': '15.0%', 'acc_x_kf_mean': '13.4%', 'acc_x_mean': '13.3%', 'roll_mean': '12.5%', 'acc_z_mean': '5.6%', 'acc_z_kf_mean': '5.4%'}
# ----
# window: 111 knn: 2.588
# Top causes: {'Unstable steering': '28.2%', 'Tailgating': '5.5%'}
# Top features: {'difcourse_mean': '16.4%', 'acc_x_kf_mean': '13.5%', 'acc_x_mean': '12.4%', 'roll_mean': '11.4%', 'lon_mean': '5.2%', 'pitch_mean': '4.0%'}
# ----
# window: 112 knn: 2.706
# Top causes: {'Tailgating': '5.6%', 'Overspeed': '2.8%'}
# Top features: {'difcourse_mean': '16.8%', 'acc_x_kf_mean': '13.8%', 'acc_x_mean': '12.2%', 'roll_mean': '11.6%', 'lon_mean': '5.4%', 'pitch_mean': '4.2%'}
# ----
# window: 113 knn: 2.794
# Top causes: {'Tailgating': '5.5%', 'Overspeed': '2.5%'}
# Top features: {'difcourse_mean': '16.5%', 'acc_x_kf_mean': '13.2%', 'acc_x_mean': '12.0%', 'roll_mean': '11.8%', 'pitch_mean': '5.1%', 'lon_mean': '4.8%'}
# ----
# window: 114 knn: 3.079
# Top causes: {'Tailgating': '6.4%', 'Overspeed': '4.3%'}
# Top features: {'difcourse_mean': '17.6%', 'roll_mean': '13.7%', 'acc_x_kf_mean': '7.6%', 'acc_x_mean': '6.8%', 'pitch_mean': '6.5%', 'lon_mean': '4.3%'}
# ----
# window: 115 knn: 3.412
# Top causes: {'Overspeed': '7.5%', 'Tailgating': '4.6%'}
# Top features: {'difcourse_mean': '16.2%', 'roll_mean': '16.0%', 'acc_x_kf_mean': '8.5%', 'acc_x_mean': '8.1%', 'pitch_mean': '5.0%', 'yaw_mean': '4.9%'}
# ----
# window: 116 knn: 3.87
# Top causes: {'Tailgating': '5.0%', 'Overspeed': '19.2%'}
# Top features: {'roll_mean': '14.6%', 'difcourse_mean': '12.6%', 'pitch_mean': '9.0%', 'yaw_mean': '7.4%', 'vdop_mean': '6.1%', 'acc_x_kf_mean': '5.0%'}
# ----
# window: 117 knn: 4.398
# Top causes: {'Overspeed': '37.8%', 'Unstable steering': '32.8%'}
# Top features: {'roll_mean': '13.2%', 'yaw_mean': '10.0%', 'difcourse_mean': '8.0%', 'speed_kmh_mean': '7.0%', 'gps_speed_mean': '6.8%', 'gps_speed_osm_mean': '6.6%'}
# ----
# window: 118 knn: 2.728
# Top causes: {'Harsh maneuvers': '14.9%', 'Tailgating': '5.1%'}
# Top features: {'speed_kmh_mean': '12.8%', 'gps_speed_mean': '12.6%', 'yaw_mean': '12.4%', 'gps_speed_osm_mean': '12.4%', 'course_mean': '6.1%', 'roll_mean': '5.0%'}
# ----
# window: 119 knn: 2.946
# Top causes: {'Unstable steering': '17.7%', 'Harsh maneuvers': '12.0%'}
# Top features: {'speed_kmh_mean': '14.3%', 'gps_speed_mean': '14.2%', 'gps_speed_osm_mean': '13.4%', 'yaw_mean': '10.0%', 'roll_mean': '7.1%', 'course_mean': '5.2%'}
# ----
# window: 120 knn: 2.96
# Top causes: {'Unstable steering': '17.3%', 'Harsh maneuvers': '13.1%'}
# Top features: {'speed_kmh_mean': '14.3%', 'gps_speed_mean': '14.1%', 'gps_speed_osm_mean': '13.4%', 'yaw_mean': '9.7%', 'course_mean': '5.4%', 'x_lane_mean': '4.4%'}
# ----
# window: 121 knn: 3.038
# Top causes: {'Unstable steering': '18.4%', 'Harsh maneuvers': '11.4%'}
# Top features: {'speed_kmh_mean': '13.3%', 'gps_speed_mean': '13.2%', 'gps_speed_osm_mean': '12.7%', 'yaw_mean': '9.8%', 'course_mean': '5.7%', 'osm_delay_mean': '5.4%'}
# ----
# window: 122 knn: 3.095
# Top causes: {'Unstable steering': '21.4%', 'Harsh maneuvers': '11.5%'}
# Top features: {'speed_kmh_mean': '10.6%', 'gps_speed_mean': '10.5%', 'gps_speed_osm_mean': '10.4%', 'yaw_mean': '10.1%', 'osm_delay_mean': '7.4%', 'course_mean': '6.3%'}
# ----
# window: 123 knn: 3.733
# Top causes: {'Unstable steering': '23.4%', 'Harsh maneuvers': '21.2%'}
# Top features: {'osm_delay_mean': '15.4%', 'yaw_mean': '9.3%', 'speed_kmh_mean': '6.4%', 'gps_speed_osm_mean': '6.3%', 'gps_speed_mean': '6.3%', 'course_mean': '6.1%'}
# ----
# window: 124 knn: 4.042
# Top causes: {'Overspeed': '39.4%', 'Unstable steering': '31.4%'}
# Top features: {'osm_delay_mean': '16.2%', 'yaw_mean': '9.7%', 't_10hz_mean': '6.7%', 'timestamp_mean': '6.7%', 'course_mean': '6.5%', 'x_lane_mean': '6.2%'}
# ----
# window: 125 knn: 6.57
# Top causes: {'Unstable steering': '35.6%', 'Tailgating': '27.1%'}
# Top features: {'road_width_mean': '23.1%', 'osm_delay_mean': '11.8%', 'yaw_mean': '6.3%', 'active_mean': '5.9%', 'lat_mean': '5.6%', 't_10hz_mean': '4.5%'}
# ----
# window: 126 knn: 9.264
# Top causes: {'Harsh maneuvers': '39.5%', 'Tailgating': '29.3%'}
# Top features: {'road_width_mean': '25.6%', 'active_mean': '15.3%', 'phi_mean': '12.5%', 'lane_state_mean': '11.3%', 'x_lane_mean': '8.9%', 'lat_mean': '4.2%'}
# ----
# window: 127 knn: 9.068
# Top causes: {'Harsh maneuvers': '39.8%', 'Tailgating': '34.4%'}
# Top features: {'road_width_mean': '24.8%', 'active_mean': '15.3%', 'phi_mean': '12.6%', 'lane_state_mean': '11.3%', 'x_lane_mean': '9.1%', 'lat_mean': '5.2%'}
# ----
# window: 128 knn: 8.969
# Top causes: {'Harsh maneuvers': '49.1%', 'Tailgating': '35.0%'}
# Top features: {'road_width_mean': '23.7%', 'active_mean': '15.2%', 'phi_mean': '12.9%', 'lane_state_mean': '11.1%', 'x_lane_mean': '9.6%', 'lat_mean': '6.0%'}
# ----
# window: 129 knn: 8.803
# Top causes: {'Harsh maneuvers': '48.5%', 'Tailgating': '34.8%'}
# Top features: {'road_width_mean': '22.6%', 'active_mean': '15.2%', 'phi_mean': '12.9%', 'lane_state_mean': '11.2%', 'x_lane_mean': '9.6%', 'lat_mean': '6.6%'}
# ----
# window: 130 knn: 8.931
# Top causes: {'Harsh maneuvers': '52.6%', 'Tailgating': '28.4%'}
# Top features: {'road_width_mean': '20.7%', 'active_mean': '14.6%', 'phi_mean': '12.3%', 'x_lane_mean': '11.0%', 'lane_state_mean': '11.0%', 'lat_mean': '6.6%'}
# ----
# window: 131 knn: 8.929
# Top causes: {'Harsh maneuvers': '55.1%', 'Overspeed': '24.8%'}
# Top features: {'road_width_mean': '18.7%', 'active_mean': '13.8%', 'phi_mean': '11.4%', 'x_lane_mean': '10.6%', 'lane_state_mean': '9.4%', 'vdop_mean': '6.6%'}
# ----
# window: 132 knn: 8.99
# Top causes: {'Harsh maneuvers': '50.2%', 'Overspeed': '32.3%'}
# Top features: {'road_width_mean': '16.3%', 'active_mean': '12.5%', 'x_lane_mean': '10.5%', 'phi_mean': '10.2%', 'vdop_mean': '9.3%', 'lane_state_mean': '9.1%'}
# ----
# window: 133 knn: 9.121
# Top causes: {'Harsh maneuvers': '71.6%', 'Tailgating': '5.9%'}
# Top features: {'road_width_mean': '15.4%', 'active_mean': '12.2%', 'vdop_mean': '11.5%', 'x_lane_mean': '10.7%', 'phi_mean': '9.9%', 'lane_state_mean': '8.8%'}
# ----
# window: 134 knn: 9.014
# Top causes: {'Harsh maneuvers': '71.8%', 'Overspeed': '14.2%'}
# Top features: {'road_width_mean': '15.1%', 'active_mean': '12.5%', 'x_lane_mean': '11.9%', 'vdop_mean': '11.3%', 'phi_mean': '9.9%', 'lane_state_mean': '9.7%'}
# ----
# window: 135 knn: 6.988
# Top causes: {'Harsh maneuvers': '49.5%', 'Unstable steering': '27.4%'}
# Top features: {'vdop_mean': '21.0%', 'hdop_mean': '12.5%', 'pdop_mean': '12.5%', 'road_width_mean': '8.8%', 'roll_mean': '5.4%', 'active_mean': '5.2%'}
# ----
# window: 136 knn: 6.427
# Top causes: {'Harsh maneuvers': '41.7%', 'Tailgating': '25.7%'}
# Top features: {'vdop_mean': '33.6%', 'pdop_mean': '16.9%', 'hdop_mean': '16.2%', 'timestamp_mean': '3.9%', 't_10hz_mean': '3.9%', 'alt_mean': '2.4%'}
# ----
# window: 137 knn: 7.018
# Top causes: {'Harsh maneuvers': '35.9%', 'Tailgating': '26.7%'}
# Top features: {'vdop_mean': '39.9%', 'hdop_mean': '17.8%', 'pdop_mean': '15.3%', 'timestamp_mean': '2.9%', 't_10hz_mean': '2.9%', 'roll_mean': '2.0%'}
# ----
# window: 138 knn: 7.406
# Top causes: {'Harsh maneuvers': '31.0%', 'Overspeed': '26.0%'}
# Top features: {'vdop_mean': '44.1%', 'hdop_mean': '18.3%', 'pdop_mean': '14.2%', 'timestamp_mean': '2.3%', 't_10hz_mean': '2.3%', 'vert_acc_mean': '1.7%'}
# ----
# window: 139 knn: 8.173
# Top causes: {'Tailgating': '31.5%', 'Harsh maneuvers': '29.9%'}
# Top features: {'vdop_mean': '43.9%', 'pdop_mean': '20.4%', 'hdop_mean': '16.8%', 'timestamp_mean': '1.6%', 't_10hz_mean': '1.6%', 'num_vehicles_mean': '1.5%'}
# ----
# window: 140 knn: 8.359
# Top causes: {'Harsh maneuvers': '36.4%', 'Tailgating': '33.1%'}
# Top features: {'vdop_mean': '43.6%', 'pdop_mean': '25.4%', 'hdop_mean': '12.9%', 'num_vehicles_mean': '2.1%', 'x_lane_mean': '1.5%', 'vert_acc_mean': '1.4%'}
# ----
# window: 141 knn: 7.303
# Top causes: {'Harsh maneuvers': '38.4%', 'Tailgating': '30.6%'}
# Top features: {'vdop_mean': '48.6%', 'hdop_mean': '15.4%', 'pdop_mean': '13.3%', 'num_vehicles_mean': '2.4%', 'x_lane_mean': '2.3%', 'course_mean': '1.8%'}
# ----
# window: 142 knn: 6.796
# Top causes: {'Harsh maneuvers': '43.1%', 'Tailgating': '25.2%'}
# Top features: {'vdop_mean': '49.1%', 'hdop_mean': '20.6%', 'pdop_mean': '4.9%', 'x_lane_mean': '4.1%', 'course_mean': '2.2%', 'num_vehicles_mean': '2.1%'}
# ----
# window: 143 knn: 7.443
# Top causes: {'Harsh maneuvers': '49.5%', 'Unstable steering': '19.5%'}
# Top features: {'vdop_mean': '46.6%', 'hdop_mean': '21.3%', 'pdop_mean': '10.6%', 'x_lane_mean': '2.9%', 'course_mean': '2.2%', 'vert_acc_mean': '1.8%'}
# ----
# window: 144 knn: 7.887
# Top causes: {'Harsh maneuvers': '47.2%', 'Tailgating': '24.9%'}
# Top features: {'vdop_mean': '48.9%', 'hdop_mean': '17.6%', 'pdop_mean': '15.0%', 'x_lane_mean': '2.5%', 'course_mean': '2.2%', 'vert_acc_mean': '1.6%'}
# ----
# window: 145 knn: 7.783
# Top causes: {'Harsh maneuvers': '44.3%', 'Tailgating': '24.2%'}
# Top features: {'vdop_mean': '49.9%', 'pdop_mean': '15.8%', 'hdop_mean': '14.5%', 'course_mean': '2.4%', 'vert_acc_mean': '1.7%', 'x_lane_mean': '1.7%'}
# ----
# window: 146 knn: 6.869
# Top causes: {'Harsh maneuvers': '35.8%', 'Unstable steering': '27.0%'}
# Top features: {'vdop_mean': '39.6%', 'pdop_mean': '14.9%', 'hdop_mean': '13.1%', 'difcourse_mean': '3.8%', 'roll_mean': '3.2%', 'pitch_mean': '2.5%'}
# ----
# window: 147 knn: 6.233
# Top causes: {'Harsh maneuvers': '35.5%', 'Overspeed': '28.7%'}
# Top features: {'vdop_mean': '33.0%', 'pdop_mean': '15.6%', 'hdop_mean': '11.7%', 'difcourse_mean': '4.8%', 'pitch_mean': '3.0%', 'acc_x_kf_mean': '2.5%'}
# ----
# window: 148 knn: 5.633
# Top causes: {'Harsh maneuvers': '37.2%', 'Overspeed': '34.1%'}
# Top features: {'vdop_mean': '28.0%', 'pdop_mean': '16.5%', 'hdop_mean': '9.2%', 'difcourse_mean': '5.5%', 'roll_mean': '4.9%', 'acc_x_kf_mean': '3.8%'}
# ----
# window: 149 knn: 4.518
# Top causes: {'Harsh maneuvers': '36.8%', 'Overspeed': '34.2%'}
# Top features: {'vdop_mean': '25.7%', 'pdop_mean': '11.2%', 'roll_mean': '8.2%', 'hdop_mean': '7.3%', 'difcourse_mean': '6.9%', 'acc_x_kf_mean': '4.3%'}
# ----
# window: 150 knn: 3.546
# Top causes: {'Unstable steering': '25.4%', 'Tailgating': '5.2%'}
# Top features: {'vdop_mean': '21.7%', 'hdop_mean': '11.0%', 'roll_mean': '9.7%', 'difcourse_mean': '8.4%', 'lon_mean': '4.9%', 'pdop_mean': '4.2%'}
# ----
# window: 151 knn: 3.141
# Top causes: {'Overspeed': '29.3%', 'Unstable steering': '26.8%'}
# Top features: {'vdop_mean': '17.6%', 'hdop_mean': '10.0%', 'difcourse_mean': '9.7%', 'roll_mean': '8.1%', 'lon_mean': '5.5%', 'pdop_mean': '4.8%'}
# ----
# window: 152 knn: 2.865
# Top causes: {'Overspeed': '26.3%', 'Tailgating': '6.5%'}
# Top features: {'vdop_mean': '13.9%', 'roll_mean': '11.2%', 'difcourse_mean': '10.1%', 'hdop_mean': '7.3%', 'acc_x_kf_mean': '6.4%', 'pitch_mean': '5.1%'}
# ----
# window: 153 knn: 2.373
# Top causes: {'Overspeed': '25.2%', 'Tailgating': '4.2%'}
# Top features: {'roll_mean': '13.6%', 'difcourse_mean': '12.1%', 'vdop_mean': '11.0%', 'hdop_mean': '7.9%', 'lon_mean': '5.4%', 'acc_x_kf_mean': '4.9%'}
# ----
# window: 154 knn: 2.754
# Top causes: {'Overspeed': '16.4%', 'Tailgating': '8.1%'}
# Top features: {'roll_mean': '16.4%', 'hdop_mean': '14.1%', 'vdop_mean': '10.0%', 'pitch_mean': '8.3%', 'difcourse_mean': '7.9%', 'lon_mean': '3.8%'}
# ----
# window: 155 knn: 4.155
# Top causes: {'Unstable steering': '39.3%', 'Harsh maneuvers': '35.8%'}
# Top features: {'hdop_mean': '22.3%', 'vdop_mean': '17.3%', 'roll_mean': '16.1%', 'yaw_mean': '4.3%', 'pdop_mean': '3.6%', 'course_mean': '3.6%'}
# ----
# window: 156 knn: 5.267
# Top causes: {'Harsh maneuvers': '44.2%', 'Unstable steering': '30.5%'}
# Top features: {'vdop_mean': '27.6%', 'hdop_mean': '19.4%', 'pdop_mean': '17.2%', 'roll_mean': '5.3%', 'yaw_mean': '3.9%', 'course_mean': '3.4%'}
# ----
# window: 157 knn: 6.774
# Top causes: {'Harsh maneuvers': '52.8%', 'Overspeed': '14.9%'}
# Top features: {'pdop_mean': '27.9%', 'vdop_mean': '27.4%', 'hdop_mean': '14.6%', 'roll_mean': '4.2%', 'acc_z_mean': '2.7%', 'yaw_mean': '2.5%'}
# ----
# window: 158 knn: 7.336
# Top causes: {'Harsh maneuvers': '45.8%', 'Overspeed': '29.1%'}
# Top features: {'vdop_mean': '30.1%', 'pdop_mean': '27.0%', 'hdop_mean': '16.9%', 'roll_mean': '2.8%', 'yaw_mean': '2.2%', 'course_mean': '2.2%'}
# ----
# window: 159 knn: 8.952
# Top causes: {'Harsh maneuvers': '42.4%', 'Overspeed': '32.4%'}
# Top features: {'pdop_mean': '35.6%', 'vdop_mean': '29.9%', 'hdop_mean': '15.8%', 'course_mean': '1.7%', 'yaw_mean': '1.6%', 't_10hz_mean': '1.6%'}
# ----
# window: 160 knn: 10.191
# Top causes: {'Overspeed': '33.0%', 'Harsh maneuvers': '29.2%'}
# Top features: {'pdop_mean': '44.5%', 'vdop_mean': '30.1%', 'hdop_mean': '11.1%', 't_10hz_mean': '1.5%', 'timestamp_mean': '1.5%', 'course_mean': '1.5%'}
# ----
# window: 161 knn: 10.284
# Top causes: {'Overspeed': '36.3%', 'Unstable steering': '26.6%'}
# Top features: {'pdop_mean': '44.6%', 'vdop_mean': '31.5%', 'hdop_mean': '9.6%', 'roll_mean': '1.9%', 't_10hz_mean': '1.7%', 'timestamp_mean': '1.7%'}
# ----
# window: 162 knn: 10.211
# Top causes: {'Overspeed': '32.7%', 'Harsh maneuvers': '26.7%'}
# Top features: {'pdop_mean': '44.1%', 'vdop_mean': '29.8%', 'hdop_mean': '10.0%', 't_10hz_mean': '1.9%', 'timestamp_mean': '1.9%', 'roll_mean': '1.9%'}
# ----
# window: 163 knn: 10.072
# Top causes: {'Overspeed': '32.2%', 'Unstable steering': '27.8%'}
# Top features: {'pdop_mean': '43.9%', 'vdop_mean': '30.4%', 'hdop_mean': '9.4%', 't_10hz_mean': '2.2%', 'timestamp_mean': '2.2%', 'roll_mean': '1.6%'}
# ----
# window: 164 knn: 9.745
# Top causes: {'Unstable steering': '32.0%', 'Tailgating': '26.5%'}
# Top features: {'pdop_mean': '45.7%', 'vdop_mean': '30.2%', 'hdop_mean': '7.7%', 't_10hz_mean': '2.7%', 'timestamp_mean': '2.7%', 'course_mean': '1.6%'}
# ----
# window: 165 knn: 7.838
# Top causes: {'Tailgating': '54.3%', 'Unstable steering': '26.5%'}
# Top features: {'pdop_mean': '45.0%', 'vdop_mean': '28.5%', 'hdop_mean': '3.5%', 't_10hz_mean': '2.8%', 'timestamp_mean': '2.8%', 'alt_mean': '2.0%'}
# ----
# window: 166 knn: 7.059
# Top causes: {'Tailgating': '55.9%', 'Harsh maneuvers': '22.6%'}
# Top features: {'pdop_mean': '34.8%', 'vdop_mean': '26.6%', 'hdop_mean': '4.9%', 'alt_mean': '4.3%', 'roll_mean': '4.3%', 'lat_mean': '3.8%'}
# ----
# window: 167 knn: 6.016
# Top causes: {'Tailgating': '45.3%', 'Unstable steering': '17.7%'}
# Top features: {'vdop_mean': '29.2%', 'pdop_mean': '22.1%', 'alt_mean': '9.3%', 'lat_mean': '6.9%', 'roll_mean': '5.5%', 'hdop_mean': '4.9%'}
# ----
# window: 168 knn: 5.247
# Top causes: {'Overspeed': '36.6%', 'Harsh maneuvers': '28.4%'}
# Top features: {'vdop_mean': '27.4%', 'pdop_mean': '21.8%', 'alt_mean': '13.3%', 'lat_mean': '9.4%', 'lon_mean': '6.1%', 'roll_mean': '4.0%'}
# ----
# window: 169 knn: 3.55
# Top causes: {'Overspeed': '45.8%', 'Tailgating': '13.7%'}
# Top features: {'vdop_mean': '21.3%', 'alt_mean': '20.5%', 'lat_mean': '13.9%', 'lon_mean': '8.9%', 'roll_mean': '7.9%', 'pdop_mean': '7.1%'}
# ----
# window: 170 knn: 1.759
# Top causes: {'Tailgating': '5.0%', 'Unstable steering': '2.9%'}
# Top features: {'alt_mean': '26.1%', 'lat_mean': '16.8%', 'vdop_mean': '10.6%', 'lon_mean': '10.6%', 'roll_mean': '7.8%', 'lane_state_mean': '5.6%'}
# ----
# window: 171 knn: 1.237
# Top causes: {'Tailgating': '2.2%', 'Unstable steering': '1.7%'}
# Top features: {'alt_mean': '28.5%', 'lat_mean': '17.0%', 'lon_mean': '10.9%', 'lane_state_mean': '6.0%', 'roll_mean': '5.3%', 'vdop_mean': '5.1%'}
# ----
# window: 172 knn: 1.13
# Top causes: {'Overspeed': '27.7%', 'Tailgating': '1.7%'}
# Top features: {'alt_mean': '28.1%', 'lat_mean': '15.6%', 'lon_mean': '10.4%', 'lane_state_mean': '6.7%', 'acc_z_kf_mean': '4.1%', 'osm_delay_mean': '3.2%'}
# ----
# window: 173 knn: 1.314
# Top causes: {'Overspeed': '18.7%', 'Tailgating': '4.1%'}
# Top features: {'alt_mean': '24.5%', 'lat_mean': '13.1%', 'lon_mean': '9.4%', 'timestamp_mean': '6.2%', 't_10hz_mean': '6.2%', 'acc_z_kf_mean': '4.6%'}
# ----
# window: 174 knn: 1.744
# Top causes: {'Overspeed': '8.7%', 'Tailgating': '8.6%'}
# Top features: {'alt_mean': '18.5%', 'timestamp_mean': '10.0%', 't_10hz_mean': '10.0%', 'lat_mean': '9.2%', 'roll_mean': '8.5%', 'lon_mean': '7.4%'}
# ----
# window: 175 knn: 1.496
# Top causes: {'Unstable steering': '15.3%', 'Overspeed': '14.6%'}
# Top features: {'alt_mean': '17.6%', 'timestamp_mean': '11.5%', 't_10hz_mean': '11.5%', 'lat_mean': '7.8%', 'lon_mean': '7.2%', 'osm_delay_mean': '5.5%'}
# ----
# window: 176 knn: 0.967
# Top causes: {'Unstable steering': '17.5%', 'Harsh maneuvers': '27.9%'}
# Top features: {'alt_mean': '13.4%', 'timestamp_mean': '10.9%', 't_10hz_mean': '10.9%', 'osm_delay_mean': '6.5%', 'lon_mean': '5.8%', 'lat_mean': '5.1%'}
# ----
# window: 177 knn: 0.938
# Top causes: {'Tailgating': '24.0%', 'Unstable steering': '21.0%'}
# Top features: {'timestamp_mean': '10.2%', 't_10hz_mean': '10.2%', 'alt_mean': '9.1%', 'osm_delay_mean': '7.1%', 'difcourse_mean': '5.2%', 'course_mean': '5.2%'}
# ----
# window: 178 knn: 0.839
# Top causes: {'Tailgating': '28.0%', 'Harsh maneuvers': '25.2%'}
# Top features: {'timestamp_mean': '8.7%', 't_10hz_mean': '8.7%', 'osm_delay_mean': '6.6%', 'alt_mean': '6.0%', 'course_mean': '5.7%', 'x_lane_mean': '5.0%'}
# ----
# window: 179 knn: 0.989
# Top causes: {'Unstable steering': '17.5%', 'Harsh maneuvers': '29.8%'}
# Top features: {'timestamp_mean': '7.9%', 't_10hz_mean': '7.9%', 'course_mean': '6.9%', 'osm_delay_mean': '5.9%', 'difcourse_mean': '5.7%', 'x_lane_mean': '5.7%'}
# ----
# window: 180 knn: 1.014
# Top causes: {'Harsh maneuvers': '26.8%', 'Unstable steering': '17.9%'}
# Top features: {'course_mean': '8.5%', 'ttc_front_mean': '8.0%', 'timestamp_mean': '6.9%', 't_10hz_mean': '6.9%', 'x_lane_mean': '6.9%', 'difcourse_mean': '6.5%'}
# ----
# window: 181 knn: 0.987
# Top causes: {'Harsh maneuvers': '28.1%', 'Overspeed': '14.7%'}
# Top features: {'course_mean': '9.7%', 'ttc_front_mean': '7.5%', 'num_vehicles_mean': '7.0%', 'x_lane_mean': '6.9%', 'difcourse_mean': '6.7%', 'timestamp_mean': '5.3%'}
# ----
# window: 182 knn: 0.981
# Top causes: {'Unstable steering': '21.0%', 'Overspeed': '12.5%'}
# Top features: {'course_mean': '10.5%', 'num_vehicles_mean': '7.7%', 'x_lane_mean': '7.7%', 'osm_delay_mean': '7.6%', 'difcourse_mean': '6.5%', 'ttc_front_mean': '4.4%'}
# ----
# window: 183 knn: 1.075
# Top causes: {'Unstable steering': '26.5%', 'Tailgating': '26.5%'}
# Top features: {'course_mean': '12.8%', 'osm_delay_mean': '9.0%', 'num_vehicles_mean': '7.9%', 'difcourse_mean': '6.8%', 'x_lane_mean': '6.8%', 'lane_state_mean': '4.7%'}
# ----
# window: 184 knn: 1.439
# Top causes: {'Overspeed': '27.4%', 'Tailgating': '16.2%'}
# Top features: {'course_mean': '16.5%', 'osm_delay_mean': '10.9%', 'lat_mean': '6.1%', 'x_lane_mean': '6.0%', 'lon_mean': '4.4%', 'phi_mean': '4.4%'}
# ----
# window: 185 knn: 2.374
# Top causes: {'Harsh maneuvers': '24.4%', 'Unstable steering': '8.1%'}
# Top features: {'course_mean': '13.6%', 'osm_delay_mean': '10.2%', 'lon_mean': '6.5%', 'gps_speed_mean': '6.5%', 'hdop_mean': '6.2%', 'lat_mean': '6.1%'}
# ----
# window: 186 knn: 1.324
# Top causes: {'Overspeed': '29.9%', 'Unstable steering': '23.9%'}
# Top features: {'difcourse_mean': '13.6%', 'pitch_mean': '7.4%', 'acc_x_mean': '7.2%', 'acc_x_kf_mean': '6.4%', 'osm_delay_mean': '5.7%', 'gps_speed_mean': '5.7%'}
# ----
# window: 187 knn: 1.188
# Top causes: {'Unstable steering': '19.2%', 'Tailgating': '2.8%'}
# Top features: {'difcourse_mean': '11.7%', 'pitch_mean': '8.5%', 'gps_speed_mean': '8.2%', 'acc_x_mean': '8.1%', 'gps_speed_osm_mean': '7.9%', 'speed_kmh_mean': '7.6%'}
# ----
# window: 188 knn: 0.991
# Top causes: {'Unstable steering': '16.7%', 'Tailgating': '4.0%'}
# Top features: {'difcourse_mean': '10.3%', 'acc_x_mean': '8.2%', 'acc_x_kf_mean': '8.1%', 'gps_speed_mean': '7.8%', 'gps_speed_osm_mean': '7.7%', 'pitch_mean': '7.4%'}
# ----
# window: 189 knn: 1.075
# Top causes: {'Tailgating': '5.0%', 'Unstable steering': '18.9%'}
# Top features: {'difcourse_mean': '11.2%', 'roll_mean': '8.8%', 'acc_x_mean': '7.8%', 'acc_x_kf_mean': '7.6%', 'pitch_mean': '6.1%', 'gps_speed_osm_mean': '6.0%'}
# ----
# window: 190 knn: 0.962
# Top causes: {'Unstable steering': '19.8%', 'Tailgating': '7.2%'}
# Top features: {'difcourse_mean': '12.4%', 'acc_x_mean': '9.3%', 'acc_x_kf_mean': '8.7%', 'pitch_mean': '7.2%', 'gps_speed_mean': '6.3%', 'lon_mean': '5.9%'}
# ----
# window: 191 knn: 0.946
# Top causes: {'Overspeed': '28.9%', 'Unstable steering': '20.7%'}
# Top features: {'difcourse_mean': '12.3%', 'acc_x_mean': '9.2%', 'acc_x_kf_mean': '8.7%', 'pitch_mean': '6.4%', 'gps_speed_mean': '5.8%', 'gps_speed_osm_mean': '5.7%'}
# ----
# ...
# ----
# window: 263 knn: 2.609
# Top causes: {'Tailgating': '17.8%', 'Overspeed': '25.5%'}
# Top features: {'t_10hz_mean': '8.4%', 'timestamp_mean': '8.4%', 'roll_mean': '8.3%', 'lat_osm_mean': '6.9%', 'lat_mean': '6.8%', 'lon_osm_mean': '6.4%'}
# ----
# window: 264 knn: 17.944
# Top causes: {'Harsh maneuvers': '95.5%', 'Overspeed': '3.9%'}
# Top features: {'acc_z_mean': '48.0%', 'acc_z_kf_mean': '35.0%', 'pdop_mean': '3.5%', 'acc_y_mean': '1.7%', 'acc_y_kf_mean': '1.3%', 'speed_kmh_mean': '1.1%'}
# ----
# window: 265 knn: 15.238
# Top causes: {'Harsh maneuvers': '95.9%', 'Overspeed': '2.5%'}
# Top features: {'acc_z_mean': '39.1%', 'acc_z_kf_mean': '34.9%', 'pdop_mean': '6.0%', 'acc_y_mean': '3.4%', 'acc_y_kf_mean': '3.2%', 'acc_x_kf_mean': '1.8%'}
# ----
# window: 266 knn: 14.706
# Top causes: {'Harsh maneuvers': '95.8%', 'Unstable steering': '1.9%'}
# Top features: {'acc_z_mean': '40.4%', 'acc_z_kf_mean': '36.2%', 'pdop_mean': '6.1%', 'pitch_mean': '3.3%', 'acc_x_kf_mean': '2.2%', 'acc_x_mean': '2.1%'}
# ----
# window: 267 knn: 7.17
# Top causes: {'Harsh maneuvers': '47.5%', 'Tailgating': '23.6%'}
# Top features: {'pdop_mean': '27.5%', 'num_lanes_mean': '12.4%', 'vdop_mean': '8.8%', 'num_vehicles_mean': '6.4%', 'pitch_mean': '5.5%', 'yaw_mean': '4.7%'}
# ----
# window: 268 knn: 7.969
# Top causes: {'Harsh maneuvers': '62.9%', 'Unstable steering': '16.6%'}
# Top features: {'pdop_mean': '22.4%', 'num_lanes_mean': '13.8%', 'vdop_mean': '8.4%', 'acc_z_mean': '8.2%', 'acc_z_kf_mean': '7.2%', 'num_vehicles_mean': '5.3%'}
# ----
# window: 269 knn: 7.914
# Top causes: {'Unstable steering': '37.9%', 'Tailgating': '22.6%'}
# Top features: {'pdop_mean': '38.5%', 'num_lanes_mean': '13.4%', 'vdop_mean': '11.3%', 'yaw_mean': '5.3%', 'num_vehicles_mean': '4.2%', 'pitch_mean': '3.2%'}
# ----
# window: 270 knn: 10.374
# Top causes: {'Harsh maneuvers': '67.4%', 'Overspeed': '18.0%'}
# Top features: {'pdop_mean': '28.6%', 'acc_z_mean': '13.5%', 'acc_z_kf_mean': '11.6%', 'num_lanes_mean': '7.8%', 'vdop_mean': '7.5%', 'yaw_mean': '3.8%'}
# ----
# window: 271 knn: 9.014
# Top causes: {'Harsh maneuvers': '44.3%', 'Overspeed': '41.2%'}
# Top features: {'pdop_mean': '26.5%', 'num_lanes_mean': '8.0%', 'gps_speed_osm_mean': '7.0%', 'vdop_mean': '6.6%', 'gps_speed_mean': '6.1%', 'speed_kmh_mean': '5.7%'}
# ----
# window: 272 knn: 8.968
# Top causes: {'Harsh maneuvers': '66.0%', 'Unstable steering': '9.0%'}
# Top features: {'acc_y_mean': '16.9%', 'acc_y_kf_mean': '14.7%', 'pdop_mean': '12.4%', 'num_lanes_mean': '6.4%', 'gps_speed_osm_mean': '6.0%', 'acc_z_mean': '5.1%'}
# ----
# window: 273 knn: 8.249
# Top causes: {'Harsh maneuvers': '55.6%', 'Overspeed': '32.1%'}
# Top features: {'acc_z_mean': '14.4%', 'acc_z_kf_mean': '11.4%', 'gps_speed_osm_mean': '7.2%', 'yaw_mean': '6.9%', 'gps_speed_mean': '6.2%', 'pdop_mean': '6.1%'}
# ----
# window: 274 knn: 8.652
# Top causes: {'Harsh maneuvers': '63.5%', 'Overspeed': '26.9%'}
# Top features: {'acc_z_mean': '16.8%', 'acc_z_kf_mean': '12.6%', 'acc_y_mean': '6.7%', 'gps_speed_osm_mean': '6.2%', 'gps_speed_mean': '5.5%', 'yaw_mean': '5.5%'}
# ----
# window: 275 knn: 8.135
# Top causes: {'Harsh maneuvers': '60.3%', 'Overspeed': '28.1%'}
# Top features: {'acc_z_mean': '16.7%', 'acc_z_kf_mean': '11.6%', 'pdop_mean': '5.9%', 'lat_mean': '5.9%', 'lat_osm_mean': '5.8%', 'gps_speed_osm_mean': '5.3%'}
# ----
# window: 276 knn: 9.144
# Top causes: {'Harsh maneuvers': '68.8%', 'Overspeed': '20.2%'}
# Top features: {'acc_z_mean': '18.7%', 'pdop_mean': '17.0%', 'acc_z_kf_mean': '13.4%', 'course_mean': '7.6%', 'lat_osm_mean': '5.1%', 'lat_mean': '5.0%'}
# ----
# window: 277 knn: 9.713
# Top causes: {'Harsh maneuvers': '50.1%', 'Overspeed': '29.8%'}
# Top features: {'pdop_mean': '33.8%', 'course_mean': '11.8%', 'acc_z_mean': '7.7%', 'acc_z_kf_mean': '5.2%', 'lat_osm_mean': '4.8%', 'lat_mean': '4.7%'}
# ----
# window: 278 knn: 9.929
# Top causes: {'Harsh maneuvers': '35.7%', 'Overspeed': '32.5%'}
# Top features: {'pdop_mean': '40.2%', 'course_mean': '15.7%', 'lat_osm_mean': '4.4%', 'lat_mean': '4.3%', 'lon_osm_mean': '3.5%', 'vdop_mean': '3.5%'}
# ----
# window: 279 knn: 10.165
# Top causes: {'Tailgating': '35.9%', 'Harsh maneuvers': '29.9%'}
# Top features: {'pdop_mean': '48.0%', 'course_mean': '19.0%', 'vdop_mean': '4.2%', 'lat_osm_mean': '3.9%', 'lat_mean': '3.7%', 'lon_osm_mean': '3.1%'}
# ----
# window: 280 knn: 10.913
# Top causes: {'Harsh maneuvers': '42.7%', 'Overspeed': '33.6%'}
# Top features: {'pdop_mean': '53.6%', 'course_mean': '18.7%', 'vdop_mean': '4.3%', 'lat_osm_mean': '2.7%', 'lat_mean': '2.5%', 'lon_osm_mean': '2.2%'}
# ----
# window: 281 knn: 11.491
# Top causes: {'Overspeed': '48.3%', 'Harsh maneuvers': '32.4%'}
# Top features: {'pdop_mean': '53.1%', 'course_mean': '20.0%', 'vdop_mean': '5.3%', 'lat_osm_mean': '1.9%', 'lat_mean': '1.8%', 'roll_mean': '1.7%'}
# ----
# window: 282 knn: 14.024
# Top causes: {'Harsh maneuvers': '72.3%', 'Overspeed': '16.4%'}
# Top features: {'pdop_mean': '55.0%', 'course_mean': '14.4%', 'vdop_mean': '7.4%', 'hdop_mean': '3.4%', 'acc_y_mean': '2.6%', 'acc_y_kf_mean': '2.5%'}
# ----
# window: 283 knn: 14.96
# Top causes: {'Harsh maneuvers': '40.7%', 'Overspeed': '39.5%'}
# Top features: {'pdop_mean': '62.0%', 'course_mean': '12.2%', 'vdop_mean': '8.6%', 'hdop_mean': '3.1%', 'num_lanes_mean': '2.8%', 'x_lane_mean': '1.6%'}
# ----
# window: 284 knn: 16.33
# Top causes: {'Harsh maneuvers': '60.2%', 'Overspeed': '23.6%'}
# Top features: {'pdop_mean': '66.9%', 'course_mean': '10.8%', 'vdop_mean': '8.3%', 'hdop_mean': '2.5%', 'x_lane_mean': '1.4%', 'acc_y_mean': '1.3%'}
# ----
# window: 285 knn: 16.213
# Top causes: {'Harsh maneuvers': '58.7%', 'Overspeed': '20.5%'}
# Top features: {'pdop_mean': '68.1%', 'course_mean': '11.1%', 'vdop_mean': '8.3%', 'hdop_mean': '2.2%', 'x_lane_mean': '1.3%', 'num_lanes_mean': '1.2%'}
# ----
# window: 286 knn: 16.158
# Top causes: {'Harsh maneuvers': '65.0%', 'Overspeed': '16.9%'}
# Top features: {'pdop_mean': '68.3%', 'course_mean': '11.0%', 'vdop_mean': '8.0%', 'hdop_mean': '2.0%', 'x_lane_mean': '1.3%', 'num_lanes_mean': '1.2%'}
# ----
# window: 287 knn: 15.806
# Top causes: {'Overspeed': '35.2%', 'Harsh maneuvers': '33.3%'}
# Top features: {'pdop_mean': '70.6%', 'course_mean': '10.8%', 'vdop_mean': '7.9%', 'hdop_mean': '2.3%', 'x_lane_mean': '1.5%', 'num_lanes_mean': '1.3%'}
# ----
# window: 288 knn: 15.625
# Top causes: {'Overspeed': '41.3%', 'Harsh maneuvers': '23.8%'}
# Top features: {'pdop_mean': '71.5%', 'course_mean': '10.7%', 'vdop_mean': '8.1%', 'hdop_mean': '2.5%', 'x_lane_mean': '1.6%', 'alt_mean': '0.6%'}
# ----
# window: 289 knn: 15.706
# Top causes: {'Overspeed': '36.9%', 'Tailgating': '29.2%'}
# Top features: {'pdop_mean': '70.7%', 'course_mean': '10.6%', 'vdop_mean': '8.6%', 'hdop_mean': '2.9%', 'x_lane_mean': '1.7%', 'alt_mean': '0.6%'}
# ----
# window: 290 knn: 16.883
# Top causes: {'Harsh maneuvers': '30.9%', 'Tailgating': '28.1%'}
# Top features: {'pdop_mean': '74.1%', 'course_mean': '9.3%', 'vdop_mean': '8.2%', 'hdop_mean': '2.4%', 'x_lane_mean': '1.4%', 'alt_mean': '0.5%'}
# ----
# window: 291 knn: 16.737
# Top causes: {'Overspeed': '35.6%', 'Tailgating': '27.1%'}
# Top features: {'pdop_mean': '74.1%', 'course_mean': '9.4%', 'vdop_mean': '9.0%', 'hdop_mean': '2.3%', 'x_lane_mean': '1.4%', 'yaw_mean': '0.5%'}
# ----
# window: 292 knn: 16.918
# Top causes: {'Overspeed': '29.4%', 'Harsh maneuvers': '25.4%'}
# Top features: {'pdop_mean': '72.5%', 'course_mean': '9.5%', 'vdop_mean': '9.3%', 'hdop_mean': '2.4%', 'x_lane_mean': '1.5%', 'yaw_mean': '0.7%'}
# ----
# window: 293 knn: 16.836
# Top causes: {'Unstable steering': '29.4%', 'Harsh maneuvers': '27.7%'}
# Top features: {'pdop_mean': '72.1%', 'vdop_mean': '10.0%', 'course_mean': '9.3%', 'hdop_mean': '2.4%', 'x_lane_mean': '1.2%', 'yaw_mean': '0.7%'}
# ----
# window: 294 knn: 17.061
# Top causes: {'Harsh maneuvers': '36.4%', 'Unstable steering': '29.7%'}
# Top features: {'pdop_mean': '69.9%', 'vdop_mean': '10.7%', 'course_mean': '9.1%', 'hdop_mean': '2.4%', 'x_lane_mean': '1.2%', 'yaw_mean': '0.8%'}
# ----
# window: 295 knn: 17.284
# Top causes: {'Unstable steering': '35.4%', 'Harsh maneuvers': '25.1%'}
# Top features: {'pdop_mean': '69.2%', 'vdop_mean': '11.2%', 'course_mean': '9.1%', 'hdop_mean': '3.0%', 'x_lane_mean': '1.3%', 'yaw_mean': '0.9%'}
# ----
# window: 296 knn: 17.34
# Top causes: {'Unstable steering': '38.0%', 'Harsh maneuvers': '20.8%'}
# Top features: {'pdop_mean': '68.2%', 'vdop_mean': '11.9%', 'course_mean': '9.0%', 'hdop_mean': '3.2%', 'x_lane_mean': '1.3%', 'yaw_mean': '1.0%'}
# ----
# window: 297 knn: 17.268
# Top causes: {'Unstable steering': '37.8%', 'Overspeed': '22.9%'}
# Top features: {'pdop_mean': '67.6%', 'vdop_mean': '12.3%', 'course_mean': '9.4%', 'hdop_mean': '3.2%', 'x_lane_mean': '1.3%', 'yaw_mean': '1.1%'}
# ----
# window: 298 knn: 16.91
# Top causes: {'Unstable steering': '37.2%', 'Overspeed': '24.1%'}
# Top features: {'pdop_mean': '67.4%', 'vdop_mean': '12.0%', 'course_mean': '10.1%', 'hdop_mean': '2.6%', 'yaw_mean': '1.3%', 'x_lane_mean': '1.2%'}
# ----
# window: 299 knn: 15.304
# Top causes: {'Harsh maneuvers': '49.0%', 'Unstable steering': '29.4%'}
# Top features: {'pdop_mean': '62.2%', 'course_mean': '11.7%', 'vdop_mean': '11.6%', 'hdop_mean': '2.2%', 'yaw_mean': '1.4%', 'acc_z_kf_mean': '1.3%'}
# ----
# window: 300 knn: 12.287
# Top causes: {'Harsh maneuvers': '57.0%', 'Overspeed': '19.8%'}
# Top features: {'pdop_mean': '55.0%', 'course_mean': '13.4%', 'vdop_mean': '7.3%', 'horiz_acc_mean': '4.5%', 'phi_mean': '1.7%', 'active_mean': '1.5%'}
# ----
# window: 301 knn: 10.084
# Top causes: {'Harsh maneuvers': '61.4%', 'Overspeed': '18.3%'}
# Top features: {'pdop_mean': '51.6%', 'course_mean': '12.7%', 'vdop_mean': '6.6%', 'horiz_acc_mean': '5.8%', 'phi_mean': '2.1%', 'active_mean': '2.0%'}
# ----
# window: 302 knn: 7.929
# Top causes: {'Harsh maneuvers': '64.4%', 'Overspeed': '18.2%'}
# Top features: {'pdop_mean': '46.9%', 'course_mean': '12.1%', 'horiz_acc_mean': '7.6%', 'vdop_mean': '5.8%', 'phi_mean': '2.7%', 'active_mean': '2.6%'}
# ----
# window: 303 knn: 6.13
# Top causes: {'Harsh maneuvers': '68.6%', 'Overspeed': '17.2%'}
# Top features: {'pdop_mean': '39.1%', 'course_mean': '10.1%', 'horiz_acc_mean': '9.9%', 'vdop_mean': '4.2%', 'phi_mean': '3.5%', 'active_mean': '3.3%'}
# ----
# window: 304 knn: 4.397
# Top causes: {'Harsh maneuvers': '72.6%', 'Overspeed': '15.5%'}
# Top features: {'pdop_mean': '27.6%', 'horiz_acc_mean': '12.5%', 'course_mean': '8.1%', 'acc_z_kf_mean': '5.2%', 'acc_z_mean': '5.0%', 'phi_mean': '4.4%'}
# ----
# window: 305 knn: 3.307
# Top causes: {'Overspeed': '11.9%', 'Tailgating': '5.7%'}
# Top features: {'horiz_acc_mean': '14.6%', 'pdop_mean': '14.3%', 'acc_z_kf_mean': '8.5%', 'acc_z_mean': '7.9%', 'course_mean': '6.5%', 'phi_mean': '5.1%'}
# ----
# window: 306 knn: 2.761
# Top causes: {'Overspeed': '12.2%', 'Tailgating': '6.5%'}
# Top features: {'horiz_acc_mean': '17.3%', 'hdop_mean': '7.4%', 'acc_z_kf_mean': '6.6%', 'phi_mean': '6.0%', 'active_mean': '5.9%', 'acc_z_mean': '5.8%'}
# ----
# window: 307 knn: 2.859
# Top causes: {'Overspeed': '10.0%', 'Unstable steering': '8.7%'}
# Top features: {'horiz_acc_mean': '18.3%', 'hdop_mean': '8.7%', 'x_lane_mean': '6.6%', 'active_mean': '6.2%', 'acc_z_kf_mean': '6.1%', 'phi_mean': '6.1%'}
# ----
# window: 308 knn: 2.97
# Top causes: {'Tailgating': '12.2%', 'Unstable steering': '9.1%'}
# Top features: {'horiz_acc_mean': '18.1%', 'hdop_mean': '8.9%', 'x_lane_mean': '7.2%', 'active_mean': '6.1%', 'phi_mean': '6.0%', 'lane_state_mean': '5.7%'}
# ----
# window: 309 knn: 2.639
# Top causes: {'Unstable steering': '4.1%', 'Overspeed': '3.3%'}
# Top features: {'acc_z_kf_mean': '10.2%', 'acc_z_mean': '9.7%', 'timestamp_mean': '7.6%', 't_10hz_mean': '7.6%', 'road_width_mean': '7.2%', 'num_vehicles_mean': '6.1%'}
# ----
# window: 310 knn: 2.325
# Top causes: {'Overspeed': '4.7%', 'Unstable steering': '3.8%'}
# Top features: {'road_width_mean': '9.3%', 'acc_z_kf_mean': '7.7%', 'timestamp_mean': '7.0%', 't_10hz_mean': '7.0%', 'num_vehicles_mean': '6.9%', 'acc_z_mean': '6.9%'}
# ----
# window: 311 knn: 2.398
# Top causes: {'Tailgating': '6.0%', 'Unstable steering': '3.5%'}
# Top features: {'speed_ratio_mean': '27.7%', 'num_lanes_mean': '12.5%', 'max_speed_mean': '10.6%', 'speed_rel_mean': '8.5%', 'road_width_mean': '4.4%', 'acc_z_kf_mean': '4.2%'}
# ----
# window: 312 knn: 2.015
# Top causes: {'Harsh maneuvers': '23.4%', 'Unstable steering': '5.4%'}
# Top features: {'speed_ratio_mean': '27.7%', 'num_lanes_mean': '12.5%', 'max_speed_mean': '10.5%', 'speed_rel_mean': '8.5%', 'acc_z_kf_mean': '6.8%', 'acc_z_mean': '6.8%'}
# ----
# window: 313 knn: 1.946
# Top causes: {'Unstable steering': '7.5%', 'Tailgating': '1.7%'}
# Top features: {'speed_ratio_mean': '28.9%', 'num_lanes_mean': '13.0%', 'max_speed_mean': '11.0%', 'speed_rel_mean': '8.9%', 'acc_z_kf_mean': '6.1%', 'acc_z_mean': '5.7%'}
# ----
# window: 314 knn: 2.069
# Top causes: {'Unstable steering': '7.7%', 'Tailgating': '5.7%'}
# Top features: {'speed_ratio_mean': '30.9%', 'num_lanes_mean': '14.6%', 'max_speed_mean': '11.8%', 'speed_rel_mean': '10.4%', 'osm_delay_mean': '6.7%', 'road_width_mean': '5.2%'}
# ----
# window: 315 knn: 2.021
# Top causes: {'Tailgating': '10.5%', 'Harsh maneuvers': '9.3%'}
# Top features: {'speed_ratio_mean': '27.8%', 'num_lanes_mean': '13.1%', 'osm_delay_mean': '11.2%', 'max_speed_mean': '10.5%', 'speed_rel_mean': '9.3%', 'dist_front_mean': '4.2%'}
# ----
# window: 316 knn: 2.317
# Top causes: {'Tailgating': '13.3%', 'Harsh maneuvers': '11.7%'}
# Top features: {'speed_ratio_mean': '24.5%', 'osm_delay_mean': '18.9%', 'num_lanes_mean': '9.6%', 'max_speed_mean': '9.5%', 'speed_rel_mean': '7.5%', 'dist_front_mean': '4.6%'}
# ----
# window: 317 knn: 1.868
# Top causes: {'Tailgating': '19.2%', 'Harsh maneuvers': '5.1%'}
# Top features: {'speed_ratio_mean': '25.1%', 'osm_delay_mean': '19.0%', 'max_speed_mean': '9.7%', 'speed_rel_mean': '7.7%', 'dist_front_mean': '6.8%', 'ttc_front_mean': '4.8%'}
# ----
# window: 318 knn: 2.068
# Top causes: {'Tailgating': '22.3%', 'Harsh maneuvers': '5.6%'}
# Top features: {'speed_ratio_mean': '23.3%', 'osm_delay_mean': '17.7%', 'max_speed_mean': '9.1%', 'dist_front_mean': '8.2%', 'speed_rel_mean': '7.6%', 'ttc_front_mean': '5.8%'}
# ----
# window: 319 knn: 2.339
# Top causes: {'Unstable steering': '4.2%', 'Harsh maneuvers': '1.6%'}
# Top features: {'speed_ratio_mean': '21.6%', 'osm_delay_mean': '15.7%', 'dist_front_mean': '11.0%', 'ttc_front_mean': '7.8%', 'max_speed_mean': '7.7%', 'pitch_mean': '4.4%'}
# ----
# window: 320 knn: 2.112
# Top causes: {'Overspeed': '26.2%', 'Unstable steering': '11.3%'}
# Top features: {'dist_front_mean': '16.4%', 'ttc_front_mean': '12.6%', 'osm_delay_mean': '11.0%', 'gps_speed_mean': '5.7%', 'pitch_mean': '5.6%', 'alt_mean': '5.4%'}
# ----
# window: 321 knn: 1.476
# Top causes: {'Overspeed': '26.2%', 'Unstable steering': '14.3%'}
# Top features: {'dist_front_mean': '13.6%', 'ttc_front_mean': '10.8%', 'osm_delay_mean': '9.8%', 'gps_speed_mean': '5.3%', 'yaw_mean': '4.4%', 'alt_mean': '4.2%'}
# ----
# window: 322 knn: 1.369
# Top causes: {'Overspeed': '25.0%', 'Unstable steering': '15.1%'}
# Top features: {'dist_front_mean': '12.5%', 'ttc_front_mean': '10.1%', 'osm_delay_mean': '7.2%', 'yaw_mean': '5.5%', 'gps_speed_mean': '4.9%', 't_10hz_mean': '4.2%'}
# ----
# window: 323 knn: 1.474
# Top causes: {'Overspeed': '22.5%', 'Harsh maneuvers': '20.3%'}
# Top features: {'dist_front_mean': '11.2%', 'ttc_front_mean': '9.1%', 'yaw_mean': '6.1%', 'osm_delay_mean': '5.3%', 't_10hz_mean': '5.1%', 'timestamp_mean': '5.1%'}
# ----
# window: 324 knn: 1.856
# Top causes: {'Overspeed': '21.8%', 'Harsh maneuvers': '19.8%'}
# Top features: {'dist_front_mean': '11.0%', 'ttc_front_mean': '8.7%', 'yaw_mean': '7.1%', 't_10hz_mean': '6.2%', 'timestamp_mean': '6.2%', 'lat_osm_mean': '5.4%'}
# ----
# window: 325 knn: 1.944
# Top causes: {'Overspeed': '18.5%', 'Unstable steering': '13.3%'}
# Top features: {'dist_front_mean': '11.0%', 'ttc_front_mean': '8.4%', 't_10hz_mean': '7.1%', 'timestamp_mean': '7.1%', 'yaw_mean': '6.8%', 'lat_mean': '6.3%'}
# ----
# window: 326 knn: 2.374
# Top causes: {'Overspeed': '21.2%', 'Harsh maneuvers': '20.1%'}
# Top features: {'dist_front_mean': '9.8%', 't_10hz_mean': '8.3%', 'timestamp_mean': '8.3%', 'ttc_front_mean': '7.8%', 'lat_mean': '7.6%', 'lat_osm_mean': '7.5%'}
# ----
